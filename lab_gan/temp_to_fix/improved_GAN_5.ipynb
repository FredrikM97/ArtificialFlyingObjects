# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()
import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns
from datetime import datetime
import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='Pix2Pix_model_v3'
    __changes__="Changed to a pix2pix model in order to test a greater network for generator and discriminator. Generator: U-Net, Discriminator: PatchGAN. Changed Discriminator optimizer to SGD. Disable Jitter"
    
    __normalization__='[-1,1]'
    __jitter__= False
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
    
    @staticmethod
    def discriminator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def main():
            
            initializer = tf.random_normal_initializer(0., 0.02)

            inp = tf.keras.layers.Input(shape=image_shape, name='input_image')
            tar = tf.keras.layers.Input(shape=image_shape, name='target_image')

            x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

            down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
            down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
            down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

            zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
            conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                        kernel_initializer=initializer,
                                        use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

            batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

            leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

            zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

            last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                        kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

            return tf.keras.Model(inputs=[inp, tar], outputs=last)
        
        
        return main()
    
    @staticmethod
    def generator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def upsample(filters, size, apply_dropout=False):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                            padding='same',
                                            kernel_initializer=initializer,
                                            use_bias=False))

            result.add(tf.keras.layers.BatchNormalization())

            if apply_dropout:
                result.add(tf.keras.layers.Dropout(0.5))

            result.add(tf.keras.layers.ReLU())

            return result

        def main():
            inputs = tf.keras.layers.Input(shape=image_shape)

            down_stack = [
                downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
                downsample(128, 4), # (bs, 64, 64, 128)
                downsample(256, 4), # (bs, 32, 32, 256)
                downsample(512, 4), # (bs, 16, 16, 512)
                downsample(512, 4), # (bs, 8, 8, 512)
                downsample(512, 4), # (bs, 4, 4, 512)
                downsample(512, 4), # (bs, 2, 2, 512)
                #downsample(512, 4), # (bs, 1, 1, 512)
            ]

            up_stack = [
                upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
                upsample(512, 4), # (bs, 16, 16, 1024)
                upsample(256, 4), # (bs, 32, 32, 512)
                upsample(128, 4), # (bs, 64, 64, 256)
                upsample(64, 4), # (bs, 128, 128, 128)
            ]

            initializer = tf.random_normal_initializer(0., 0.02)
            last = tf.keras.layers.Conv2DTranspose(3, 4,
                                                 strides=2,
                                                 padding='same',
                                                 kernel_initializer=initializer,
                                                 activation='tanh') # (bs, 256, 256, 3)

            x = inputs

            # Downsampling through the model
            skips = []
            for down in down_stack:
                x = down(x)
                skips.append(x)

            skips = reversed(skips[:-1])

            # Upsampling and establishing the skip connections
            for up, skip in zip(up_stack, skips):
                x = up(x)
                x = tf.keras.layers.Concatenate()([x, skip])

            x = last(x)

            return tf.keras.Model(inputs=inputs, outputs=x)
        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        LAMBDA = 100
        def generator_loss(disc_generated_output, gen_output, target): # https://arxiv.org/abs/1611.07004
            gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

            # mean absolute error
            l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

            total_gen_loss = gan_loss + (LAMBDA * l1_loss)

            return total_gen_loss, gan_loss, l1_loss

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss

        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__, jitter=architecture.__jitter__)
# Out:
# train_x (30, 128, 128, 3) float32 -1.0 1.0
# train_y (30, 128, 128, 3) float32 -1.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss(disc_generated_output, gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(gen_total_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'gen_total_loss':gen_total_loss,
                'gen_gan_loss':gen_gan_loss,
                'gen_l1_loss':gen_l1_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')
file_writer = tf.summary.create_file_writer(log_dir + "/plots/")

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - gen_total_loss: 97.2986 - gen_gan_loss: 0.8607 - gen_l1_loss: 0.9644 - disc_loss: 1.6813 - accuracy: 0.2224 - SSIM_loss: 0.9925WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/360 [..............................] - ETA: 40s - gen_total_loss: 92.6030 - gen_gan_loss: 0.8275 - gen_l1_loss: 0.9178 - disc_loss: 1.6374 - accuracy: 0.2296 - SSIM_loss: 0.9839WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0752s vs `on_train_batch_end` time: 0.1501s). Check your callbacks.
# 360/360 [==============================] - 95s 263ms/step - gen_total_loss: 8.6118 - gen_gan_loss: 0.8819 - gen_l1_loss: 0.0773 - disc_loss: 1.4436 - accuracy: 0.3321 - SSIM_loss: 0.1167 - val_accuracy: 0.5117 - val_SSIM_loss: 0.0795
# Epoch 2/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 2.8838 - gen_gan_loss: 0.7390 - gen_l1_loss: 0.0214 - disc_loss: 1.4077 - accuracy: 0.3971 - SSIM_loss: 0.0451 - val_accuracy: 0.2566 - val_SSIM_loss: 0.0750
# Epoch 3/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 1.9216 - gen_gan_loss: 0.7249 - gen_l1_loss: 0.0120 - disc_loss: 1.3988 - accuracy: 0.3891 - SSIM_loss: 0.0320 - val_accuracy: 0.3164 - val_SSIM_loss: 0.0573
# Epoch 4/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 1.4976 - gen_gan_loss: 0.7169 - gen_l1_loss: 0.0078 - disc_loss: 1.3984 - accuracy: 0.3898 - SSIM_loss: 0.0231 - val_accuracy: 0.6333 - val_SSIM_loss: 0.0794
# Epoch 5/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 1.2731 - gen_gan_loss: 0.7053 - gen_l1_loss: 0.0057 - disc_loss: 1.3977 - accuracy: 0.3984 - SSIM_loss: 0.0164 - val_accuracy: 0.3902 - val_SSIM_loss: 0.0755
# Epoch 6/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 1.1490 - gen_gan_loss: 0.7008 - gen_l1_loss: 0.0045 - disc_loss: 1.3971 - accuracy: 0.3931 - SSIM_loss: 0.0121 - val_accuracy: 0.4147 - val_SSIM_loss: 0.0509
# Epoch 7/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 1.0613 - gen_gan_loss: 0.6978 - gen_l1_loss: 0.0036 - disc_loss: 1.3944 - accuracy: 0.3845 - SSIM_loss: 0.0091 - val_accuracy: 0.3993 - val_SSIM_loss: 0.0555
# Epoch 8/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 1.0101 - gen_gan_loss: 0.6969 - gen_l1_loss: 0.0031 - disc_loss: 1.3933 - accuracy: 0.3909 - SSIM_loss: 0.0073 - val_accuracy: 0.4324 - val_SSIM_loss: 0.0554
# Epoch 9/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.9828 - gen_gan_loss: 0.6961 - gen_l1_loss: 0.0029 - disc_loss: 1.3918 - accuracy: 0.3746 - SSIM_loss: 0.0064 - val_accuracy: 0.3091 - val_SSIM_loss: 0.0794
# Epoch 10/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.9529 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0026 - disc_loss: 1.3911 - accuracy: 0.3829 - SSIM_loss: 0.0054 - val_accuracy: 0.3649 - val_SSIM_loss: 0.0534
# Epoch 11/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.9532 - gen_gan_loss: 0.6956 - gen_l1_loss: 0.0026 - disc_loss: 1.3906 - accuracy: 0.3741 - SSIM_loss: 0.0054 - val_accuracy: 0.2430 - val_SSIM_loss: 0.0767
# Epoch 12/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 1.0889 - gen_gan_loss: 0.6964 - gen_l1_loss: 0.0039 - disc_loss: 1.3898 - accuracy: 0.3650 - SSIM_loss: 0.0090 - val_accuracy: 0.7083 - val_SSIM_loss: 0.0669
# Epoch 13/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.9106 - gen_gan_loss: 0.6951 - gen_l1_loss: 0.0022 - disc_loss: 1.3899 - accuracy: 0.3704 - SSIM_loss: 0.0042 - val_accuracy: 0.2093 - val_SSIM_loss: 0.0523
# Epoch 14/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.8850 - gen_gan_loss: 0.6949 - gen_l1_loss: 0.0019 - disc_loss: 1.3894 - accuracy: 0.3643 - SSIM_loss: 0.0034 - val_accuracy: 0.4254 - val_SSIM_loss: 0.0560
# Epoch 15/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.8729 - gen_gan_loss: 0.6944 - gen_l1_loss: 0.0018 - disc_loss: 1.3892 - accuracy: 0.3659 - SSIM_loss: 0.0031 - val_accuracy: 0.4347 - val_SSIM_loss: 0.0557
# Epoch 16/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.8646 - gen_gan_loss: 0.6946 - gen_l1_loss: 0.0017 - disc_loss: 1.3889 - accuracy: 0.3669 - SSIM_loss: 0.0029 - val_accuracy: 0.2619 - val_SSIM_loss: 0.0538
# Epoch 17/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.8556 - gen_gan_loss: 0.6943 - gen_l1_loss: 0.0016 - disc_loss: 1.3886 - accuracy: 0.3641 - SSIM_loss: 0.0026 - val_accuracy: 0.2271 - val_SSIM_loss: 0.0507
# Epoch 18/200
# 360/360 [==============================] - 96s 265ms/step - gen_total_loss: 0.8511 - gen_gan_loss: 0.6943 - gen_l1_loss: 0.0016 - disc_loss: 1.3886 - accuracy: 0.3671 - SSIM_loss: 0.0025 - val_accuracy: 0.3416 - val_SSIM_loss: 0.0480
# Epoch 19/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 1.1802 - gen_gan_loss: 0.6973 - gen_l1_loss: 0.0048 - disc_loss: 1.3877 - accuracy: 0.3495 - SSIM_loss: 0.0098 - val_accuracy: 0.3309 - val_SSIM_loss: 0.0523
# Epoch 20/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.8625 - gen_gan_loss: 0.6946 - gen_l1_loss: 0.0017 - disc_loss: 1.3891 - accuracy: 0.3857 - SSIM_loss: 0.0029 - val_accuracy: 0.4467 - val_SSIM_loss: 0.0557
# Epoch 21/200
# 360/360 [==============================] - 96s 265ms/step - gen_total_loss: 0.8393 - gen_gan_loss: 0.6944 - gen_l1_loss: 0.0014 - disc_loss: 1.3884 - accuracy: 0.3853 - SSIM_loss: 0.0023 - val_accuracy: 0.3970 - val_SSIM_loss: 0.0524
# Epoch 22/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.8308 - gen_gan_loss: 0.6940 - gen_l1_loss: 0.0014 - disc_loss: 1.3881 - accuracy: 0.3815 - SSIM_loss: 0.0021 - val_accuracy: 0.3412 - val_SSIM_loss: 0.0511
# Epoch 23/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.8250 - gen_gan_loss: 0.6942 - gen_l1_loss: 0.0013 - disc_loss: 1.3882 - accuracy: 0.3839 - SSIM_loss: 0.0019 - val_accuracy: 0.4717 - val_SSIM_loss: 0.0511
# Epoch 24/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.8211 - gen_gan_loss: 0.6942 - gen_l1_loss: 0.0013 - disc_loss: 1.3880 - accuracy: 0.3801 - SSIM_loss: 0.0019 - val_accuracy: 0.4140 - val_SSIM_loss: 0.0515
# Epoch 25/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.8177 - gen_gan_loss: 0.6938 - gen_l1_loss: 0.0012 - disc_loss: 1.3878 - accuracy: 0.3852 - SSIM_loss: 0.0018 - val_accuracy: 0.4314 - val_SSIM_loss: 0.0534
# Epoch 26/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.8146 - gen_gan_loss: 0.6940 - gen_l1_loss: 0.0012 - disc_loss: 1.3880 - accuracy: 0.3881 - SSIM_loss: 0.0017 - val_accuracy: 0.3804 - val_SSIM_loss: 0.0494
# Epoch 27/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.8108 - gen_gan_loss: 0.6938 - gen_l1_loss: 0.0012 - disc_loss: 1.3876 - accuracy: 0.3930 - SSIM_loss: 0.0016 - val_accuracy: 0.4597 - val_SSIM_loss: 0.0514
# Epoch 28/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.8092 - gen_gan_loss: 0.6938 - gen_l1_loss: 0.0012 - disc_loss: 1.3876 - accuracy: 0.3926 - SSIM_loss: 0.0016 - val_accuracy: 0.3542 - val_SSIM_loss: 0.0491
# Epoch 29/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.8059 - gen_gan_loss: 0.6938 - gen_l1_loss: 0.0011 - disc_loss: 1.3875 - accuracy: 0.3955 - SSIM_loss: 0.0015 - val_accuracy: 0.5215 - val_SSIM_loss: 0.0479
# Epoch 30/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.8031 - gen_gan_loss: 0.6938 - gen_l1_loss: 0.0011 - disc_loss: 1.3876 - accuracy: 0.3916 - SSIM_loss: 0.0015 - val_accuracy: 0.4872 - val_SSIM_loss: 0.0497
# Epoch 31/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.8014 - gen_gan_loss: 0.6938 - gen_l1_loss: 0.0011 - disc_loss: 1.3875 - accuracy: 0.4000 - SSIM_loss: 0.0015 - val_accuracy: 0.5033 - val_SSIM_loss: 0.0500
# Epoch 32/200
# 360/360 [==============================] - 95s 263ms/step - gen_total_loss: 0.7982 - gen_gan_loss: 0.6937 - gen_l1_loss: 0.0010 - disc_loss: 1.3874 - accuracy: 0.3988 - SSIM_loss: 0.0014 - val_accuracy: 0.2752 - val_SSIM_loss: 0.0498
# Epoch 33/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7959 - gen_gan_loss: 0.6937 - gen_l1_loss: 0.0010 - disc_loss: 1.3875 - accuracy: 0.4032 - SSIM_loss: 0.0013 - val_accuracy: 0.4988 - val_SSIM_loss: 0.0464
# Epoch 34/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.7934 - gen_gan_loss: 0.6938 - gen_l1_loss: 9.9607e-04 - disc_loss: 1.3874 - accuracy: 0.4111 - SSIM_loss: 0.0013 - val_accuracy: 0.3698 - val_SSIM_loss: 0.0512
# Epoch 35/200
# 360/360 [==============================] - 95s 264ms/step - gen_total_loss: 1.1276 - gen_gan_loss: 0.6985 - gen_l1_loss: 0.0043 - disc_loss: 1.3866 - accuracy: 0.4597 - SSIM_loss: 0.0080 - val_accuracy: 0.4990 - val_SSIM_loss: 0.0570
# Epoch 36/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7979 - gen_gan_loss: 0.6939 - gen_l1_loss: 0.0010 - disc_loss: 1.3882 - accuracy: 0.4485 - SSIM_loss: 0.0014 - val_accuracy: 0.4730 - val_SSIM_loss: 0.0546
# Epoch 37/200
# 360/360 [==============================] - 95s 264ms/step - gen_total_loss: 0.7885 - gen_gan_loss: 0.6940 - gen_l1_loss: 9.4465e-04 - disc_loss: 1.3878 - accuracy: 0.4397 - SSIM_loss: 0.0012 - val_accuracy: 0.4491 - val_SSIM_loss: 0.0512
# Epoch 38/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7842 - gen_gan_loss: 0.6939 - gen_l1_loss: 9.0349e-04 - disc_loss: 1.3875 - accuracy: 0.4452 - SSIM_loss: 0.0011 - val_accuracy: 0.3968 - val_SSIM_loss: 0.0506
# Epoch 39/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7821 - gen_gan_loss: 0.6938 - gen_l1_loss: 8.8232e-04 - disc_loss: 1.3875 - accuracy: 0.4432 - SSIM_loss: 0.0011 - val_accuracy: 0.4253 - val_SSIM_loss: 0.0510
# Epoch 40/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7801 - gen_gan_loss: 0.6937 - gen_l1_loss: 8.6372e-04 - disc_loss: 1.3874 - accuracy: 0.4460 - SSIM_loss: 0.0010 - val_accuracy: 0.5928 - val_SSIM_loss: 0.0507
# Epoch 41/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7790 - gen_gan_loss: 0.6936 - gen_l1_loss: 8.5329e-04 - disc_loss: 1.3873 - accuracy: 0.4483 - SSIM_loss: 0.0010 - val_accuracy: 0.5325 - val_SSIM_loss: 0.0524
# Epoch 42/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7777 - gen_gan_loss: 0.6937 - gen_l1_loss: 8.4030e-04 - disc_loss: 1.3872 - accuracy: 0.4503 - SSIM_loss: 9.8556e-04 - val_accuracy: 0.3449 - val_SSIM_loss: 0.0497
# Epoch 43/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.7766 - gen_gan_loss: 0.6936 - gen_l1_loss: 8.3056e-04 - disc_loss: 1.3872 - accuracy: 0.4524 - SSIM_loss: 9.6860e-04 - val_accuracy: 0.5151 - val_SSIM_loss: 0.0488
# Epoch 44/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7755 - gen_gan_loss: 0.6936 - gen_l1_loss: 8.1844e-04 - disc_loss: 1.3872 - accuracy: 0.4533 - SSIM_loss: 9.4568e-04 - val_accuracy: 0.3436 - val_SSIM_loss: 0.0517
# Epoch 45/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7746 - gen_gan_loss: 0.6936 - gen_l1_loss: 8.0979e-04 - disc_loss: 1.3872 - accuracy: 0.4514 - SSIM_loss: 9.2731e-04 - val_accuracy: 0.4215 - val_SSIM_loss: 0.0507
# Epoch 46/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7734 - gen_gan_loss: 0.6935 - gen_l1_loss: 7.9914e-04 - disc_loss: 1.3871 - accuracy: 0.4556 - SSIM_loss: 9.1662e-04 - val_accuracy: 0.4236 - val_SSIM_loss: 0.0518
# Epoch 47/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.7728 - gen_gan_loss: 0.6936 - gen_l1_loss: 7.9170e-04 - disc_loss: 1.3872 - accuracy: 0.4597 - SSIM_loss: 8.9755e-04 - val_accuracy: 0.4682 - val_SSIM_loss: 0.0478
# Epoch 48/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7712 - gen_gan_loss: 0.6936 - gen_l1_loss: 7.7603e-04 - disc_loss: 1.3871 - accuracy: 0.4654 - SSIM_loss: 8.7117e-04 - val_accuracy: 0.5377 - val_SSIM_loss: 0.0522
# Epoch 49/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7708 - gen_gan_loss: 0.6935 - gen_l1_loss: 7.7247e-04 - disc_loss: 1.3870 - accuracy: 0.4626 - SSIM_loss: 8.6230e-04 - val_accuracy: 0.4539 - val_SSIM_loss: 0.0512
# Epoch 50/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7691 - gen_gan_loss: 0.6936 - gen_l1_loss: 7.5557e-04 - disc_loss: 1.3871 - accuracy: 0.4708 - SSIM_loss: 8.2838e-04 - val_accuracy: 0.5094 - val_SSIM_loss: 0.0489
# Epoch 51/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7682 - gen_gan_loss: 0.6935 - gen_l1_loss: 7.4604e-04 - disc_loss: 1.3871 - accuracy: 0.4731 - SSIM_loss: 8.1295e-04 - val_accuracy: 0.4841 - val_SSIM_loss: 0.0486
# Epoch 52/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7675 - gen_gan_loss: 0.6936 - gen_l1_loss: 7.3989e-04 - disc_loss: 1.3870 - accuracy: 0.4719 - SSIM_loss: 8.0965e-04 - val_accuracy: 0.5021 - val_SSIM_loss: 0.0552
# Epoch 53/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.8735 - gen_gan_loss: 0.6940 - gen_l1_loss: 0.0018 - disc_loss: 1.3870 - accuracy: 0.4831 - SSIM_loss: 0.0029 - val_accuracy: 0.4724 - val_SSIM_loss: 0.0584
# Epoch 54/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7733 - gen_gan_loss: 0.6936 - gen_l1_loss: 7.9686e-04 - disc_loss: 1.3872 - accuracy: 0.4893 - SSIM_loss: 8.9448e-04 - val_accuracy: 0.4912 - val_SSIM_loss: 0.0517
# Epoch 55/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7652 - gen_gan_loss: 0.6934 - gen_l1_loss: 7.1791e-04 - disc_loss: 1.3870 - accuracy: 0.4868 - SSIM_loss: 7.3939e-04 - val_accuracy: 0.4990 - val_SSIM_loss: 0.0542
# Epoch 56/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7619 - gen_gan_loss: 0.6936 - gen_l1_loss: 6.8288e-04 - disc_loss: 1.3871 - accuracy: 0.4883 - SSIM_loss: 6.8973e-04 - val_accuracy: 0.3982 - val_SSIM_loss: 0.0515
# Epoch 57/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7607 - gen_gan_loss: 0.6935 - gen_l1_loss: 6.7209e-04 - disc_loss: 1.3869 - accuracy: 0.4903 - SSIM_loss: 6.7743e-04 - val_accuracy: 0.5551 - val_SSIM_loss: 0.0518
# Epoch 58/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7598 - gen_gan_loss: 0.6935 - gen_l1_loss: 6.6337e-04 - disc_loss: 1.3870 - accuracy: 0.4913 - SSIM_loss: 6.6680e-04 - val_accuracy: 0.4986 - val_SSIM_loss: 0.0508
# Epoch 59/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7585 - gen_gan_loss: 0.6936 - gen_l1_loss: 6.4986e-04 - disc_loss: 1.3869 - accuracy: 0.4980 - SSIM_loss: 6.4109e-04 - val_accuracy: 0.5310 - val_SSIM_loss: 0.0499
# Epoch 60/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7581 - gen_gan_loss: 0.6935 - gen_l1_loss: 6.4616e-04 - disc_loss: 1.3869 - accuracy: 0.5011 - SSIM_loss: 6.4284e-04 - val_accuracy: 0.5171 - val_SSIM_loss: 0.0493
# Epoch 61/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7573 - gen_gan_loss: 0.6935 - gen_l1_loss: 6.3765e-04 - disc_loss: 1.3870 - accuracy: 0.5070 - SSIM_loss: 6.2660e-04 - val_accuracy: 0.4139 - val_SSIM_loss: 0.0508
# Epoch 62/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7568 - gen_gan_loss: 0.6934 - gen_l1_loss: 6.3345e-04 - disc_loss: 1.3869 - accuracy: 0.5056 - SSIM_loss: 6.1837e-04 - val_accuracy: 0.5908 - val_SSIM_loss: 0.0484
# Epoch 63/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7565 - gen_gan_loss: 0.6935 - gen_l1_loss: 6.2994e-04 - disc_loss: 1.3869 - accuracy: 0.5058 - SSIM_loss: 6.1637e-04 - val_accuracy: 0.5667 - val_SSIM_loss: 0.0495
# Epoch 64/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7555 - gen_gan_loss: 0.6935 - gen_l1_loss: 6.2036e-04 - disc_loss: 1.3869 - accuracy: 0.5116 - SSIM_loss: 5.9885e-04 - val_accuracy: 0.6105 - val_SSIM_loss: 0.0480
# Epoch 65/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7548 - gen_gan_loss: 0.6934 - gen_l1_loss: 6.1414e-04 - disc_loss: 1.3869 - accuracy: 0.5126 - SSIM_loss: 5.8953e-04 - val_accuracy: 0.5783 - val_SSIM_loss: 0.0493
# Epoch 66/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7549 - gen_gan_loss: 0.6934 - gen_l1_loss: 6.1504e-04 - disc_loss: 1.3869 - accuracy: 0.5116 - SSIM_loss: 5.9523e-04 - val_accuracy: 0.4177 - val_SSIM_loss: 0.0494
# Epoch 67/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7542 - gen_gan_loss: 0.6935 - gen_l1_loss: 6.0713e-04 - disc_loss: 1.3869 - accuracy: 0.5086 - SSIM_loss: 5.8159e-04 - val_accuracy: 0.5379 - val_SSIM_loss: 0.0481
# Epoch 68/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7536 - gen_gan_loss: 0.6934 - gen_l1_loss: 6.0158e-04 - disc_loss: 1.3869 - accuracy: 0.5111 - SSIM_loss: 5.7008e-04 - val_accuracy: 0.5268 - val_SSIM_loss: 0.0505
# Epoch 69/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7520 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.8626e-04 - disc_loss: 1.3868 - accuracy: 0.5155 - SSIM_loss: 5.4352e-04 - val_accuracy: 0.5845 - val_SSIM_loss: 0.0477
# Epoch 70/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 0.7523 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.8871e-04 - disc_loss: 1.3868 - accuracy: 0.5168 - SSIM_loss: 5.4919e-04 - val_accuracy: 0.5127 - val_SSIM_loss: 0.0490
# Epoch 71/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7512 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.7756e-04 - disc_loss: 1.3868 - accuracy: 0.5168 - SSIM_loss: 5.3340e-04 - val_accuracy: 0.4894 - val_SSIM_loss: 0.0483
# Epoch 72/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7508 - gen_gan_loss: 0.6935 - gen_l1_loss: 5.7350e-04 - disc_loss: 1.3869 - accuracy: 0.5129 - SSIM_loss: 5.2541e-04 - val_accuracy: 0.5076 - val_SSIM_loss: 0.0498
# Epoch 73/200
# 360/360 [==============================] - 97s 271ms/step - gen_total_loss: 0.7505 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.7091e-04 - disc_loss: 1.3868 - accuracy: 0.5210 - SSIM_loss: 5.2291e-04 - val_accuracy: 0.6462 - val_SSIM_loss: 0.0493
# Epoch 74/200
# 360/360 [==============================] - 95s 263ms/step - gen_total_loss: 0.7493 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.5969e-04 - disc_loss: 1.3868 - accuracy: 0.5209 - SSIM_loss: 5.0335e-04 - val_accuracy: 0.4527 - val_SSIM_loss: 0.0494
# Epoch 75/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7490 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.5606e-04 - disc_loss: 1.3868 - accuracy: 0.5226 - SSIM_loss: 4.9863e-04 - val_accuracy: 0.4063 - val_SSIM_loss: 0.0494
# Epoch 76/200
# 360/360 [==============================] - 95s 263ms/step - gen_total_loss: 0.7977 - gen_gan_loss: 0.6936 - gen_l1_loss: 0.0010 - disc_loss: 1.3867 - accuracy: 0.5237 - SSIM_loss: 0.0015 - val_accuracy: 0.8206 - val_SSIM_loss: 0.0647
# Epoch 77/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7627 - gen_gan_loss: 0.6934 - gen_l1_loss: 6.9247e-04 - disc_loss: 1.3868 - accuracy: 0.5310 - SSIM_loss: 7.3278e-04 - val_accuracy: 0.5150 - val_SSIM_loss: 0.0583
# Epoch 78/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7492 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.5832e-04 - disc_loss: 1.3868 - accuracy: 0.5281 - SSIM_loss: 4.8764e-04 - val_accuracy: 0.5482 - val_SSIM_loss: 0.0570
# Epoch 79/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7467 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.3269e-04 - disc_loss: 1.3869 - accuracy: 0.5330 - SSIM_loss: 4.4725e-04 - val_accuracy: 0.4887 - val_SSIM_loss: 0.0545
# Epoch 80/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7455 - gen_gan_loss: 0.6935 - gen_l1_loss: 5.2032e-04 - disc_loss: 1.3868 - accuracy: 0.5392 - SSIM_loss: 4.3735e-04 - val_accuracy: 0.5878 - val_SSIM_loss: 0.0534
# Epoch 81/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7447 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.1284e-04 - disc_loss: 1.3868 - accuracy: 0.5376 - SSIM_loss: 4.2376e-04 - val_accuracy: 0.6334 - val_SSIM_loss: 0.0539
# Epoch 82/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7441 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.0712e-04 - disc_loss: 1.3868 - accuracy: 0.5433 - SSIM_loss: 4.1903e-04 - val_accuracy: 0.6215 - val_SSIM_loss: 0.0533
# Epoch 83/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7441 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.0713e-04 - disc_loss: 1.3867 - accuracy: 0.5438 - SSIM_loss: 4.2329e-04 - val_accuracy: 0.5990 - val_SSIM_loss: 0.0535
# Epoch 84/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 0.7435 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.0108e-04 - disc_loss: 1.3868 - accuracy: 0.5484 - SSIM_loss: 4.1387e-04 - val_accuracy: 0.5707 - val_SSIM_loss: 0.0524
# Epoch 85/200
# 360/360 [==============================] - 96s 265ms/step - gen_total_loss: 0.7436 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.0151e-04 - disc_loss: 1.3868 - accuracy: 0.5472 - SSIM_loss: 4.1313e-04 - val_accuracy: 0.5624 - val_SSIM_loss: 0.0503
# Epoch 86/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7437 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.0299e-04 - disc_loss: 1.3867 - accuracy: 0.5520 - SSIM_loss: 4.2075e-04 - val_accuracy: 0.5782 - val_SSIM_loss: 0.0522
# Epoch 87/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7426 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.9223e-04 - disc_loss: 1.3867 - accuracy: 0.5468 - SSIM_loss: 4.0347e-04 - val_accuracy: 0.5756 - val_SSIM_loss: 0.0501
# Epoch 88/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7428 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.9371e-04 - disc_loss: 1.3867 - accuracy: 0.5516 - SSIM_loss: 4.0594e-04 - val_accuracy: 0.5923 - val_SSIM_loss: 0.0511
# Epoch 89/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7424 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.8995e-04 - disc_loss: 1.3867 - accuracy: 0.5513 - SSIM_loss: 4.0089e-04 - val_accuracy: 0.6047 - val_SSIM_loss: 0.0508
# Epoch 90/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 0.7421 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.8710e-04 - disc_loss: 1.3868 - accuracy: 0.5579 - SSIM_loss: 3.9772e-04 - val_accuracy: 0.5174 - val_SSIM_loss: 0.0519
# Epoch 91/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7414 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.8068e-04 - disc_loss: 1.3868 - accuracy: 0.5588 - SSIM_loss: 3.9007e-04 - val_accuracy: 0.4975 - val_SSIM_loss: 0.0513
# Epoch 92/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7645 - gen_gan_loss: 0.6934 - gen_l1_loss: 7.1075e-04 - disc_loss: 1.3867 - accuracy: 0.5592 - SSIM_loss: 8.7076e-04 - val_accuracy: 0.4323 - val_SSIM_loss: 0.0559
# Epoch 93/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7464 - gen_gan_loss: 0.6934 - gen_l1_loss: 5.2979e-04 - disc_loss: 1.3867 - accuracy: 0.5601 - SSIM_loss: 4.5177e-04 - val_accuracy: 0.5392 - val_SSIM_loss: 0.0567
# Epoch 94/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 0.7411 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.7693e-04 - disc_loss: 1.3867 - accuracy: 0.5641 - SSIM_loss: 3.7236e-04 - val_accuracy: 0.5415 - val_SSIM_loss: 0.0571
# Epoch 95/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 0.7397 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.6317e-04 - disc_loss: 1.3867 - accuracy: 0.5661 - SSIM_loss: 3.5809e-04 - val_accuracy: 0.5495 - val_SSIM_loss: 0.0574
# Epoch 96/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7394 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.6007e-04 - disc_loss: 1.3868 - accuracy: 0.5695 - SSIM_loss: 3.5429e-04 - val_accuracy: 0.5149 - val_SSIM_loss: 0.0546
# Epoch 97/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7381 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.4794e-04 - disc_loss: 1.3867 - accuracy: 0.5699 - SSIM_loss: 3.4209e-04 - val_accuracy: 0.4857 - val_SSIM_loss: 0.0546
# Epoch 98/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7386 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.5253e-04 - disc_loss: 1.3868 - accuracy: 0.5700 - SSIM_loss: 3.4845e-04 - val_accuracy: 0.5362 - val_SSIM_loss: 0.0521
# Epoch 99/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7385 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.5116e-04 - disc_loss: 1.3866 - accuracy: 0.5710 - SSIM_loss: 3.4902e-04 - val_accuracy: 0.5847 - val_SSIM_loss: 0.0524
# Epoch 100/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7386 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.5317e-04 - disc_loss: 1.3867 - accuracy: 0.5736 - SSIM_loss: 3.5112e-04 - val_accuracy: 0.5590 - val_SSIM_loss: 0.0523
# Epoch 101/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7378 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.4431e-04 - disc_loss: 1.3866 - accuracy: 0.5763 - SSIM_loss: 3.4054e-04 - val_accuracy: 0.5541 - val_SSIM_loss: 0.0507
# Epoch 102/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7379 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.4620e-04 - disc_loss: 1.3867 - accuracy: 0.5759 - SSIM_loss: 3.4162e-04 - val_accuracy: 0.5413 - val_SSIM_loss: 0.0537
# Epoch 103/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7374 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.4128e-04 - disc_loss: 1.3866 - accuracy: 0.5770 - SSIM_loss: 3.3853e-04 - val_accuracy: 0.5481 - val_SSIM_loss: 0.0490
# Epoch 104/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 0.7373 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.3953e-04 - disc_loss: 1.3866 - accuracy: 0.5793 - SSIM_loss: 3.3354e-04 - val_accuracy: 0.5514 - val_SSIM_loss: 0.0486
# Epoch 105/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7372 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.3780e-04 - disc_loss: 1.3868 - accuracy: 0.5811 - SSIM_loss: 3.3432e-04 - val_accuracy: 0.5934 - val_SSIM_loss: 0.0498
# Epoch 106/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7366 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.3238e-04 - disc_loss: 1.3866 - accuracy: 0.5827 - SSIM_loss: 3.2379e-04 - val_accuracy: 0.6372 - val_SSIM_loss: 0.0511
# Epoch 107/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7364 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.3042e-04 - disc_loss: 1.3867 - accuracy: 0.5853 - SSIM_loss: 3.2656e-04 - val_accuracy: 0.5290 - val_SSIM_loss: 0.0510
# Epoch 108/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7364 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.3075e-04 - disc_loss: 1.3866 - accuracy: 0.5893 - SSIM_loss: 3.2439e-04 - val_accuracy: 0.5547 - val_SSIM_loss: 0.0487
# Epoch 109/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7360 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.2630e-04 - disc_loss: 1.3867 - accuracy: 0.5917 - SSIM_loss: 3.2024e-04 - val_accuracy: 0.6029 - val_SSIM_loss: 0.0509
# Epoch 110/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7358 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.2509e-04 - disc_loss: 1.3867 - accuracy: 0.5935 - SSIM_loss: 3.1377e-04 - val_accuracy: 0.6549 - val_SSIM_loss: 0.0517
# Epoch 111/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7351 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.1818e-04 - disc_loss: 1.3867 - accuracy: 0.5921 - SSIM_loss: 3.0828e-04 - val_accuracy: 0.5440 - val_SSIM_loss: 0.0492
# Epoch 112/200
# 360/360 [==============================] - 97s 271ms/step - gen_total_loss: 0.7353 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.1921e-04 - disc_loss: 1.3866 - accuracy: 0.5949 - SSIM_loss: 3.0767e-04 - val_accuracy: 0.6378 - val_SSIM_loss: 0.0512
# Epoch 113/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7349 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.1613e-04 - disc_loss: 1.3866 - accuracy: 0.5946 - SSIM_loss: 3.0539e-04 - val_accuracy: 0.5624 - val_SSIM_loss: 0.0493
# Epoch 114/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7347 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.1399e-04 - disc_loss: 1.3867 - accuracy: 0.5981 - SSIM_loss: 3.0176e-04 - val_accuracy: 0.6319 - val_SSIM_loss: 0.0525
# Epoch 115/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7344 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.1057e-04 - disc_loss: 1.3866 - accuracy: 0.5972 - SSIM_loss: 2.9865e-04 - val_accuracy: 0.6056 - val_SSIM_loss: 0.0513
# Epoch 116/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 0.7340 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.0696e-04 - disc_loss: 1.3866 - accuracy: 0.6024 - SSIM_loss: 2.9383e-04 - val_accuracy: 0.6106 - val_SSIM_loss: 0.0511
# Epoch 117/200
# 360/360 [==============================] - 84s 234ms/step - gen_total_loss: 0.7338 - gen_gan_loss: 0.6934 - gen_l1_loss: 4.0439e-04 - disc_loss: 1.3867 - accuracy: 0.5978 - SSIM_loss: 2.8822e-04 - val_accuracy: 0.5743 - val_SSIM_loss: 0.0507
# Epoch 118/200
# 360/360 [==============================] - 85s 235ms/step - gen_total_loss: 0.7333 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.0067e-04 - disc_loss: 1.3866 - accuracy: 0.6054 - SSIM_loss: 2.8791e-04 - val_accuracy: 0.6322 - val_SSIM_loss: 0.0481
# Epoch 119/200
# 360/360 [==============================] - 84s 233ms/step - gen_total_loss: 0.7331 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.9776e-04 - disc_loss: 1.3866 - accuracy: 0.6043 - SSIM_loss: 2.8240e-04 - val_accuracy: 0.7205 - val_SSIM_loss: 0.0515
# Epoch 120/200
# 360/360 [==============================] - 84s 232ms/step - gen_total_loss: 0.7329 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.9547e-04 - disc_loss: 1.3866 - accuracy: 0.6045 - SSIM_loss: 2.8068e-04 - val_accuracy: 0.5660 - val_SSIM_loss: 0.0502
# Epoch 121/200
# 360/360 [==============================] - 84s 233ms/step - gen_total_loss: 0.7326 - gen_gan_loss: 0.6934 - gen_l1_loss: 3.9197e-04 - disc_loss: 1.3867 - accuracy: 0.6092 - SSIM_loss: 2.7657e-04 - val_accuracy: 0.6006 - val_SSIM_loss: 0.0505
# Epoch 122/200
# 360/360 [==============================] - 85s 235ms/step - gen_total_loss: 0.7324 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.9076e-04 - disc_loss: 1.3866 - accuracy: 0.6078 - SSIM_loss: 2.7229e-04 - val_accuracy: 0.6225 - val_SSIM_loss: 0.0490
# Epoch 123/200
# 360/360 [==============================] - 84s 233ms/step - gen_total_loss: 0.7321 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.8827e-04 - disc_loss: 1.3866 - accuracy: 0.6082 - SSIM_loss: 2.6964e-04 - val_accuracy: 0.5765 - val_SSIM_loss: 0.0486
# Epoch 124/200
# 360/360 [==============================] - 84s 232ms/step - gen_total_loss: 0.7324 - gen_gan_loss: 0.6934 - gen_l1_loss: 3.9085e-04 - disc_loss: 1.3866 - accuracy: 0.6103 - SSIM_loss: 2.7363e-04 - val_accuracy: 0.5668 - val_SSIM_loss: 0.0503
# Epoch 125/200
# 360/360 [==============================] - 84s 233ms/step - gen_total_loss: 0.7315 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.8260e-04 - disc_loss: 1.3866 - accuracy: 0.6075 - SSIM_loss: 2.6232e-04 - val_accuracy: 0.6412 - val_SSIM_loss: 0.0500
# Epoch 126/200
# 360/360 [==============================] - 92s 255ms/step - gen_total_loss: 0.7319 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.8576e-04 - disc_loss: 1.3866 - accuracy: 0.6120 - SSIM_loss: 2.6917e-04 - val_accuracy: 0.6142 - val_SSIM_loss: 0.0500
# Epoch 127/200
# 360/360 [==============================] - 95s 263ms/step - gen_total_loss: 0.7312 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.7931e-04 - disc_loss: 1.3866 - accuracy: 0.6136 - SSIM_loss: 2.5761e-04 - val_accuracy: 0.6160 - val_SSIM_loss: 0.0502
# Epoch 128/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7308 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.7459e-04 - disc_loss: 1.3866 - accuracy: 0.6169 - SSIM_loss: 2.5547e-04 - val_accuracy: 0.6903 - val_SSIM_loss: 0.0496
# Epoch 129/200
# 360/360 [==============================] - 91s 252ms/step - gen_total_loss: 0.7311 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.7842e-04 - disc_loss: 1.3866 - accuracy: 0.6145 - SSIM_loss: 2.5847e-04 - val_accuracy: 0.6074 - val_SSIM_loss: 0.0519
# Epoch 130/200
# 360/360 [==============================] - 95s 263ms/step - gen_total_loss: 0.7310 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.7654e-04 - disc_loss: 1.3866 - accuracy: 0.6194 - SSIM_loss: 2.5786e-04 - val_accuracy: 0.8013 - val_SSIM_loss: 0.0436
# Epoch 131/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.7400 - gen_gan_loss: 0.6933 - gen_l1_loss: 4.6629e-04 - disc_loss: 1.3866 - accuracy: 0.6176 - SSIM_loss: 4.0255e-04 - val_accuracy: 0.6131 - val_SSIM_loss: 0.0583
# Epoch 132/200
# 360/360 [==============================] - 84s 234ms/step - gen_total_loss: 0.7306 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.7350e-04 - disc_loss: 1.3866 - accuracy: 0.6131 - SSIM_loss: 2.5188e-04 - val_accuracy: 0.6441 - val_SSIM_loss: 0.0538
# Epoch 133/200
# 360/360 [==============================] - 84s 232ms/step - gen_total_loss: 0.7296 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.6301e-04 - disc_loss: 1.3866 - accuracy: 0.6208 - SSIM_loss: 2.3652e-04 - val_accuracy: 0.6345 - val_SSIM_loss: 0.0562
# Epoch 134/200
# 360/360 [==============================] - 84s 233ms/step - gen_total_loss: 0.7295 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.6200e-04 - disc_loss: 1.3866 - accuracy: 0.6184 - SSIM_loss: 2.3820e-04 - val_accuracy: 0.6894 - val_SSIM_loss: 0.0512
# Epoch 135/200
# 360/360 [==============================] - 84s 233ms/step - gen_total_loss: 0.7291 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.5842e-04 - disc_loss: 1.3865 - accuracy: 0.6236 - SSIM_loss: 2.3206e-04 - val_accuracy: 0.5930 - val_SSIM_loss: 0.0538
# Epoch 136/200
# 360/360 [==============================] - 85s 235ms/step - gen_total_loss: 0.7293 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.6021e-04 - disc_loss: 1.3866 - accuracy: 0.6284 - SSIM_loss: 2.3733e-04 - val_accuracy: 0.6197 - val_SSIM_loss: 0.0535
# Epoch 137/200
# 360/360 [==============================] - 85s 235ms/step - gen_total_loss: 0.7289 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.5603e-04 - disc_loss: 1.3866 - accuracy: 0.6278 - SSIM_loss: 2.2961e-04 - val_accuracy: 0.6649 - val_SSIM_loss: 0.0524
# Epoch 138/200
# 360/360 [==============================] - 84s 233ms/step - gen_total_loss: 0.7289 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.5648e-04 - disc_loss: 1.3866 - accuracy: 0.6321 - SSIM_loss: 2.3556e-04 - val_accuracy: 0.5968 - val_SSIM_loss: 0.0541
# Epoch 139/200
# 360/360 [==============================] - 84s 234ms/step - gen_total_loss: 0.7291 - gen_gan_loss: 0.6934 - gen_l1_loss: 3.5741e-04 - disc_loss: 1.3867 - accuracy: 0.6311 - SSIM_loss: 2.3443e-04 - val_accuracy: 0.6460 - val_SSIM_loss: 0.0520
# Epoch 140/200
# 360/360 [==============================] - 85s 236ms/step - gen_total_loss: 0.7285 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.5150e-04 - disc_loss: 1.3866 - accuracy: 0.6324 - SSIM_loss: 2.2777e-04 - val_accuracy: 0.5840 - val_SSIM_loss: 0.0529
# Epoch 141/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 0.7286 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.5283e-04 - disc_loss: 1.3866 - accuracy: 0.6349 - SSIM_loss: 2.2958e-04 - val_accuracy: 0.6203 - val_SSIM_loss: 0.0506
# Epoch 142/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7282 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4890e-04 - disc_loss: 1.3866 - accuracy: 0.6311 - SSIM_loss: 2.2328e-04 - val_accuracy: 0.6112 - val_SSIM_loss: 0.0517
# Epoch 143/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7283 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4994e-04 - disc_loss: 1.3866 - accuracy: 0.6371 - SSIM_loss: 2.2504e-04 - val_accuracy: 0.7241 - val_SSIM_loss: 0.0501
# Epoch 144/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7283 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4995e-04 - disc_loss: 1.3866 - accuracy: 0.6328 - SSIM_loss: 2.2752e-04 - val_accuracy: 0.7087 - val_SSIM_loss: 0.0512
# Epoch 145/200
# 360/360 [==============================] - 95s 264ms/step - gen_total_loss: 0.7278 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4465e-04 - disc_loss: 1.3866 - accuracy: 0.6357 - SSIM_loss: 2.1936e-04 - val_accuracy: 0.6566 - val_SSIM_loss: 0.0496
# Epoch 146/200
# 360/360 [==============================] - 96s 265ms/step - gen_total_loss: 0.7280 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4665e-04 - disc_loss: 1.3865 - accuracy: 0.6395 - SSIM_loss: 2.2124e-04 - val_accuracy: 0.6471 - val_SSIM_loss: 0.0498
# Epoch 147/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7278 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4528e-04 - disc_loss: 1.3865 - accuracy: 0.6361 - SSIM_loss: 2.2120e-04 - val_accuracy: 0.6285 - val_SSIM_loss: 0.0527
# Epoch 148/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 0.7275 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.4263e-04 - disc_loss: 1.3866 - accuracy: 0.6419 - SSIM_loss: 2.1707e-04 - val_accuracy: 0.6409 - val_SSIM_loss: 0.0503
# Epoch 149/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7273 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4013e-04 - disc_loss: 1.3866 - accuracy: 0.6416 - SSIM_loss: 2.1697e-04 - val_accuracy: 0.6248 - val_SSIM_loss: 0.0502
# Epoch 150/200
# 360/360 [==============================] - 96s 265ms/step - gen_total_loss: 0.7275 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.4175e-04 - disc_loss: 1.3865 - accuracy: 0.6456 - SSIM_loss: 2.1609e-04 - val_accuracy: 0.5892 - val_SSIM_loss: 0.0512
# Epoch 151/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7269 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.3666e-04 - disc_loss: 1.3866 - accuracy: 0.6419 - SSIM_loss: 2.0886e-04 - val_accuracy: 0.6772 - val_SSIM_loss: 0.0509
# Epoch 152/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7269 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.3630e-04 - disc_loss: 1.3866 - accuracy: 0.6472 - SSIM_loss: 2.1143e-04 - val_accuracy: 0.6805 - val_SSIM_loss: 0.0508
# Epoch 153/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7268 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.3505e-04 - disc_loss: 1.3865 - accuracy: 0.6457 - SSIM_loss: 2.0902e-04 - val_accuracy: 0.6684 - val_SSIM_loss: 0.0505
# Epoch 154/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7267 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.3419e-04 - disc_loss: 1.3866 - accuracy: 0.6464 - SSIM_loss: 2.0701e-04 - val_accuracy: 0.6144 - val_SSIM_loss: 0.0519
# Epoch 155/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7262 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.2911e-04 - disc_loss: 1.3865 - accuracy: 0.6466 - SSIM_loss: 2.0216e-04 - val_accuracy: 0.6735 - val_SSIM_loss: 0.0512
# Epoch 156/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.7262 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.2956e-04 - disc_loss: 1.3865 - accuracy: 0.6478 - SSIM_loss: 2.0124e-04 - val_accuracy: 0.6387 - val_SSIM_loss: 0.0500
# Epoch 157/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7263 - gen_gan_loss: 0.6934 - gen_l1_loss: 3.2835e-04 - disc_loss: 1.3867 - accuracy: 0.6501 - SSIM_loss: 2.0528e-04 - val_accuracy: 0.6957 - val_SSIM_loss: 0.0508
# Epoch 158/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7261 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.2762e-04 - disc_loss: 1.3866 - accuracy: 0.6516 - SSIM_loss: 1.9926e-04 - val_accuracy: 0.6845 - val_SSIM_loss: 0.0502
# Epoch 159/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7266 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.3282e-04 - disc_loss: 1.3866 - accuracy: 0.6523 - SSIM_loss: 2.1070e-04 - val_accuracy: 0.5891 - val_SSIM_loss: 0.0504
# Epoch 160/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7258 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.2509e-04 - disc_loss: 1.3865 - accuracy: 0.6535 - SSIM_loss: 1.9726e-04 - val_accuracy: 0.7149 - val_SSIM_loss: 0.0542
# Epoch 161/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7252 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.1871e-04 - disc_loss: 1.3866 - accuracy: 0.6562 - SSIM_loss: 1.8712e-04 - val_accuracy: 0.6303 - val_SSIM_loss: 0.0520
# Epoch 162/200
# 360/360 [==============================] - 95s 263ms/step - gen_total_loss: 0.7257 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.2443e-04 - disc_loss: 1.3865 - accuracy: 0.6581 - SSIM_loss: 1.9610e-04 - val_accuracy: 0.6389 - val_SSIM_loss: 0.0515
# Epoch 163/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7255 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.2252e-04 - disc_loss: 1.3865 - accuracy: 0.6547 - SSIM_loss: 1.9491e-04 - val_accuracy: 0.6821 - val_SSIM_loss: 0.0513
# Epoch 164/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7252 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.1936e-04 - disc_loss: 1.3865 - accuracy: 0.6555 - SSIM_loss: 1.9084e-04 - val_accuracy: 0.6514 - val_SSIM_loss: 0.0497
# Epoch 165/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7249 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.1613e-04 - disc_loss: 1.3866 - accuracy: 0.6574 - SSIM_loss: 1.8539e-04 - val_accuracy: 0.6849 - val_SSIM_loss: 0.0513
# Epoch 166/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.7251 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.1809e-04 - disc_loss: 1.3866 - accuracy: 0.6575 - SSIM_loss: 1.8918e-04 - val_accuracy: 0.6530 - val_SSIM_loss: 0.0521
# Epoch 167/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7244 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.1171e-04 - disc_loss: 1.3865 - accuracy: 0.6596 - SSIM_loss: 1.8261e-04 - val_accuracy: 0.6483 - val_SSIM_loss: 0.0503
# Epoch 168/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7247 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.1429e-04 - disc_loss: 1.3865 - accuracy: 0.6599 - SSIM_loss: 1.8618e-04 - val_accuracy: 0.6749 - val_SSIM_loss: 0.0510
# Epoch 169/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7245 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.1263e-04 - disc_loss: 1.3865 - accuracy: 0.6598 - SSIM_loss: 1.8409e-04 - val_accuracy: 0.6516 - val_SSIM_loss: 0.0510
# Epoch 170/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7244 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.1148e-04 - disc_loss: 1.3865 - accuracy: 0.6599 - SSIM_loss: 1.8251e-04 - val_accuracy: 0.6777 - val_SSIM_loss: 0.0500
# Epoch 171/200
# 360/360 [==============================] - 95s 264ms/step - gen_total_loss: 0.7244 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.1107e-04 - disc_loss: 1.3865 - accuracy: 0.6634 - SSIM_loss: 1.8052e-04 - val_accuracy: 0.6471 - val_SSIM_loss: 0.0510
# Epoch 172/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7242 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.1018e-04 - disc_loss: 1.3865 - accuracy: 0.6616 - SSIM_loss: 1.8184e-04 - val_accuracy: 0.6262 - val_SSIM_loss: 0.0498
# Epoch 173/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7243 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.1033e-04 - disc_loss: 1.3865 - accuracy: 0.6646 - SSIM_loss: 1.8123e-04 - val_accuracy: 0.7131 - val_SSIM_loss: 0.0512
# Epoch 174/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 0.7240 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.0779e-04 - disc_loss: 1.3865 - accuracy: 0.6659 - SSIM_loss: 1.7993e-04 - val_accuracy: 0.7044 - val_SSIM_loss: 0.0520
# Epoch 175/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7239 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.0693e-04 - disc_loss: 1.3865 - accuracy: 0.6662 - SSIM_loss: 1.7456e-04 - val_accuracy: 0.6786 - val_SSIM_loss: 0.0505
# Epoch 176/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7238 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.0504e-04 - disc_loss: 1.3866 - accuracy: 0.6666 - SSIM_loss: 1.7655e-04 - val_accuracy: 0.6260 - val_SSIM_loss: 0.0507
# Epoch 177/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7234 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.0132e-04 - disc_loss: 1.3865 - accuracy: 0.6679 - SSIM_loss: 1.6993e-04 - val_accuracy: 0.6424 - val_SSIM_loss: 0.0516
# Epoch 178/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7236 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.0307e-04 - disc_loss: 1.3865 - accuracy: 0.6705 - SSIM_loss: 1.7309e-04 - val_accuracy: 0.6634 - val_SSIM_loss: 0.0512
# Epoch 179/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 0.7235 - gen_gan_loss: 0.6932 - gen_l1_loss: 3.0220e-04 - disc_loss: 1.3865 - accuracy: 0.6721 - SSIM_loss: 1.7448e-04 - val_accuracy: 0.7169 - val_SSIM_loss: 0.0512
# Epoch 180/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7234 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.0142e-04 - disc_loss: 1.3865 - accuracy: 0.6735 - SSIM_loss: 1.7225e-04 - val_accuracy: 0.6747 - val_SSIM_loss: 0.0507
# Epoch 181/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 0.7238 - gen_gan_loss: 0.6933 - gen_l1_loss: 3.0567e-04 - disc_loss: 1.3866 - accuracy: 0.6742 - SSIM_loss: 1.7779e-04 - val_accuracy: 0.6191 - val_SSIM_loss: 0.0510
# Epoch 182/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7229 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.9721e-04 - disc_loss: 1.3865 - accuracy: 0.6766 - SSIM_loss: 1.6813e-04 - val_accuracy: 0.6623 - val_SSIM_loss: 0.0484
# Epoch 183/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7230 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.9763e-04 - disc_loss: 1.3865 - accuracy: 0.6760 - SSIM_loss: 1.6840e-04 - val_accuracy: 0.6925 - val_SSIM_loss: 0.0483
# Epoch 184/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7231 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.9807e-04 - disc_loss: 1.3865 - accuracy: 0.6761 - SSIM_loss: 1.6842e-04 - val_accuracy: 0.6436 - val_SSIM_loss: 0.0498
# Epoch 185/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7227 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.9379e-04 - disc_loss: 1.3865 - accuracy: 0.6765 - SSIM_loss: 1.6471e-04 - val_accuracy: 0.6705 - val_SSIM_loss: 0.0523
# Epoch 186/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7224 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.9126e-04 - disc_loss: 1.3865 - accuracy: 0.6828 - SSIM_loss: 1.6149e-04 - val_accuracy: 0.7051 - val_SSIM_loss: 0.0496
# Epoch 187/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7227 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.9440e-04 - disc_loss: 1.3865 - accuracy: 0.6816 - SSIM_loss: 1.6418e-04 - val_accuracy: 0.6937 - val_SSIM_loss: 0.0504
# Epoch 188/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 0.7224 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.9178e-04 - disc_loss: 1.3865 - accuracy: 0.6806 - SSIM_loss: 1.6351e-04 - val_accuracy: 0.6502 - val_SSIM_loss: 0.0499
# Epoch 189/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7226 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.9340e-04 - disc_loss: 1.3865 - accuracy: 0.6831 - SSIM_loss: 1.6486e-04 - val_accuracy: 0.6666 - val_SSIM_loss: 0.0508
# Epoch 190/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7219 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.8704e-04 - disc_loss: 1.3865 - accuracy: 0.6836 - SSIM_loss: 1.5686e-04 - val_accuracy: 0.7050 - val_SSIM_loss: 0.0511
# Epoch 191/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7222 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.8986e-04 - disc_loss: 1.3865 - accuracy: 0.6843 - SSIM_loss: 1.6034e-04 - val_accuracy: 0.6906 - val_SSIM_loss: 0.0503
# Epoch 192/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 0.7223 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.8994e-04 - disc_loss: 1.3865 - accuracy: 0.6843 - SSIM_loss: 1.6139e-04 - val_accuracy: 0.6797 - val_SSIM_loss: 0.0515
# Epoch 193/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7220 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.8718e-04 - disc_loss: 1.3865 - accuracy: 0.6854 - SSIM_loss: 1.5847e-04 - val_accuracy: 0.7036 - val_SSIM_loss: 0.0513
# Epoch 194/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 0.7217 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.8420e-04 - disc_loss: 1.3865 - accuracy: 0.6889 - SSIM_loss: 1.5561e-04 - val_accuracy: 0.6851 - val_SSIM_loss: 0.0501
# Epoch 195/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7218 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.8572e-04 - disc_loss: 1.3865 - accuracy: 0.6901 - SSIM_loss: 1.5639e-04 - val_accuracy: 0.6527 - val_SSIM_loss: 0.0507
# Epoch 196/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7219 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.8632e-04 - disc_loss: 1.3865 - accuracy: 0.6915 - SSIM_loss: 1.5834e-04 - val_accuracy: 0.7194 - val_SSIM_loss: 0.0509
# Epoch 197/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 0.7219 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.8567e-04 - disc_loss: 1.3865 - accuracy: 0.6895 - SSIM_loss: 1.5623e-04 - val_accuracy: 0.7360 - val_SSIM_loss: 0.0517
# Epoch 198/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7215 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.8241e-04 - disc_loss: 1.3865 - accuracy: 0.6907 - SSIM_loss: 1.5423e-04 - val_accuracy: 0.7137 - val_SSIM_loss: 0.0490
# Epoch 199/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 0.7214 - gen_gan_loss: 0.6932 - gen_l1_loss: 2.8199e-04 - disc_loss: 1.3865 - accuracy: 0.6924 - SSIM_loss: 1.5388e-04 - val_accuracy: 0.6539 - val_SSIM_loss: 0.0514
# Epoch 200/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 0.7213 - gen_gan_loss: 0.6933 - gen_l1_loss: 2.8063e-04 - disc_loss: 1.3865 - accuracy: 0.6947 - SSIM_loss: 1.5129e-04 - val_accuracy: 0.6728 - val_SSIM_loss: 0.0500
