# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()
import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns
from datetime import datetime
import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='default_model_v0'
    __changes__="Default model given from teacher. Changed Discriminator optimizer to SGD. Disable Jitter"
    
    __normalization__='[0,1]'
    __jitter__= False
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    
    @staticmethod
    def discriminator():
        def main():
            last_img = Input(shape=image_shape)
            first_img = Input(shape=image_shape)

            # Concatenate image and conditioning image by channels to produce input
            combined_imgs = Concatenate(axis=-1)([last_img, first_img])

            d1 = Conv2D(32, (3, 3), strides=2, padding='same')(combined_imgs) 
            d1 = Activation('relu')(d1) 
            d2 = Conv2D(64, (3, 3), strides=2, padding='same')(d1)
            d2 = Activation('relu')(d2) 
            d3 = Conv2D(128, (3, 3), strides=2, padding='same')(d2)
            d3 = Activation('relu')(d3) 

            validity = Conv2D(1, (3, 3), strides=2, padding='same')(d3)

            model = Model([last_img, first_img], validity)
            return model
        return main()
    
    @staticmethod
    def generator():

        def main():

            inputs = Input(shape=image_shape)

            down1 = Conv2D(32, (3, 3),padding='same')(inputs)
            down1 = Activation('relu')(down1) 
            down1_pool = MaxPooling2D((2, 2), strides=(2, 2))(down1)

            down2 = Conv2D(64, (3, 3), padding='same')(down1_pool)
            down2 = Activation('relu')(down2) 


            up1 = UpSampling2D((2, 2))(down2)
            up1 = concatenate([down1, up1], axis=3)
            up1 = Conv2D(256, (3, 3), padding='same')(up1) 
            up1 = Activation('relu')(up1) 


            up2 = Conv2D(256, (3, 3), padding='same')(up1) 
            up2 = Activation('relu')(up2) 

            nbr_img_channels = image_shape[2]
            outputs = Conv2D(nbr_img_channels, (1, 1), activation='sigmoid')(up2)

            model = Model(inputs=inputs, outputs=outputs, name='Generator')
            return model

        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.MeanSquaredError()
        LAMBDA = 100
        def generator_loss(disc_generated_output, gen_output, target): # https://arxiv.org/abs/1611.07004
            gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

            # mean absolute error
            l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

            total_gen_loss = gan_loss + (LAMBDA * l1_loss)

            return total_gen_loss, gan_loss, l1_loss

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss

        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__, jitter=architecture.__jitter__)
# Out:
# train_x (30, 128, 128, 3) float32 0.0 1.0
# train_y (30, 128, 128, 3) float32 0.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss(disc_generated_output, gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(gen_total_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'gen_total_loss':gen_total_loss,
                'gen_gan_loss':gen_gan_loss,
                'gen_l1_loss':gen_l1_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - gen_total_loss: 51.0745 - gen_gan_loss: 0.9663 - gen_l1_loss: 0.5011 - disc_loss: 0.9930 - accuracy: 0.9330 - SSIM_loss: 0.3172WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/360 [..............................] - ETA: 33s - gen_total_loss: 47.5283 - gen_gan_loss: 0.8593 - gen_l1_loss: 0.4667 - disc_loss: 0.8610 - accuracy: 0.9387 - SSIM_loss: 0.2840WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0544s vs `on_train_batch_end` time: 0.1318s). Check your callbacks.
# 360/360 [==============================] - 80s 223ms/step - gen_total_loss: 3.1187 - gen_gan_loss: 0.2765 - gen_l1_loss: 0.0284 - disc_loss: 0.4825 - accuracy: 0.3017 - SSIM_loss: 0.0572 - val_accuracy: 0.2292 - val_SSIM_loss: 0.0232
# Epoch 2/200
# 360/360 [==============================] - 81s 225ms/step - gen_total_loss: 2.1475 - gen_gan_loss: 0.2868 - gen_l1_loss: 0.0186 - disc_loss: 0.4684 - accuracy: 0.6364 - SSIM_loss: 0.0447 - val_accuracy: 0.9319 - val_SSIM_loss: 0.0232
# Epoch 3/200
# 360/360 [==============================] - 82s 228ms/step - gen_total_loss: 2.1251 - gen_gan_loss: 0.2957 - gen_l1_loss: 0.0183 - disc_loss: 0.4622 - accuracy: 0.5424 - SSIM_loss: 0.0431 - val_accuracy: 0.9221 - val_SSIM_loss: 0.0209
# Epoch 4/200
# 360/360 [==============================] - 80s 222ms/step - gen_total_loss: 2.1060 - gen_gan_loss: 0.3007 - gen_l1_loss: 0.0181 - disc_loss: 0.4578 - accuracy: 0.4721 - SSIM_loss: 0.0417 - val_accuracy: 0.2098 - val_SSIM_loss: 0.0217
# Epoch 5/200
# 360/360 [==============================] - 81s 224ms/step - gen_total_loss: 2.0909 - gen_gan_loss: 0.3056 - gen_l1_loss: 0.0179 - disc_loss: 0.4546 - accuracy: 0.3213 - SSIM_loss: 0.0407 - val_accuracy: 0.1298 - val_SSIM_loss: 0.0193
# Epoch 6/200
# 360/360 [==============================] - 81s 225ms/step - gen_total_loss: 2.0863 - gen_gan_loss: 0.3051 - gen_l1_loss: 0.0178 - disc_loss: 0.4777 - accuracy: 0.2612 - SSIM_loss: 0.0407 - val_accuracy: 0.1801 - val_SSIM_loss: 0.0198
# Epoch 7/200
# 360/360 [==============================] - 81s 225ms/step - gen_total_loss: 2.0731 - gen_gan_loss: 0.3042 - gen_l1_loss: 0.0177 - disc_loss: 0.4546 - accuracy: 0.2123 - SSIM_loss: 0.0402 - val_accuracy: 0.1697 - val_SSIM_loss: 0.0151
# Epoch 8/200
# 360/360 [==============================] - 79s 219ms/step - gen_total_loss: 2.0755 - gen_gan_loss: 0.3064 - gen_l1_loss: 0.0177 - disc_loss: 0.4539 - accuracy: 0.1835 - SSIM_loss: 0.0399 - val_accuracy: 0.9433 - val_SSIM_loss: 0.0156
# Epoch 9/200
# 360/360 [==============================] - 79s 220ms/step - gen_total_loss: 2.0625 - gen_gan_loss: 0.3110 - gen_l1_loss: 0.0175 - disc_loss: 0.4504 - accuracy: 0.1646 - SSIM_loss: 0.0396 - val_accuracy: 0.1105 - val_SSIM_loss: 0.0144
# Epoch 10/200
# 360/360 [==============================] - 80s 223ms/step - gen_total_loss: 2.0484 - gen_gan_loss: 0.3122 - gen_l1_loss: 0.0174 - disc_loss: 0.4495 - accuracy: 0.2181 - SSIM_loss: 0.0392 - val_accuracy: 0.1276 - val_SSIM_loss: 0.0171
# Epoch 11/200
# 360/360 [==============================] - 80s 222ms/step - gen_total_loss: 2.0576 - gen_gan_loss: 0.3129 - gen_l1_loss: 0.0174 - disc_loss: 0.4487 - accuracy: 0.2376 - SSIM_loss: 0.0393 - val_accuracy: 0.1424 - val_SSIM_loss: 0.0167
# Epoch 12/200
# 360/360 [==============================] - 80s 224ms/step - gen_total_loss: 2.0520 - gen_gan_loss: 0.3158 - gen_l1_loss: 0.0174 - disc_loss: 0.4468 - accuracy: 0.2252 - SSIM_loss: 0.0392 - val_accuracy: 0.1451 - val_SSIM_loss: 0.0141
# Epoch 13/200
# 360/360 [==============================] - 79s 219ms/step - gen_total_loss: 2.0562 - gen_gan_loss: 0.3184 - gen_l1_loss: 0.0174 - disc_loss: 0.4455 - accuracy: 0.2378 - SSIM_loss: 0.0393 - val_accuracy: 0.1236 - val_SSIM_loss: 0.0143
# Epoch 14/200
# 360/360 [==============================] - 78s 215ms/step - gen_total_loss: 2.0452 - gen_gan_loss: 0.3108 - gen_l1_loss: 0.0173 - disc_loss: 0.4523 - accuracy: 0.2715 - SSIM_loss: 0.0390 - val_accuracy: 0.8510 - val_SSIM_loss: 0.0134
# Epoch 15/200
# 360/360 [==============================] - 80s 223ms/step - gen_total_loss: 2.0352 - gen_gan_loss: 0.3182 - gen_l1_loss: 0.0172 - disc_loss: 0.4460 - accuracy: 0.3787 - SSIM_loss: 0.0388 - val_accuracy: 0.9051 - val_SSIM_loss: 0.0147
# Epoch 16/200
# 360/360 [==============================] - 79s 220ms/step - gen_total_loss: 2.0476 - gen_gan_loss: 0.3193 - gen_l1_loss: 0.0173 - disc_loss: 0.4454 - accuracy: 0.3166 - SSIM_loss: 0.0389 - val_accuracy: 0.9179 - val_SSIM_loss: 0.0134
# Epoch 17/200
# 360/360 [==============================] - 78s 217ms/step - gen_total_loss: 2.0478 - gen_gan_loss: 0.3211 - gen_l1_loss: 0.0173 - disc_loss: 0.4438 - accuracy: 0.4328 - SSIM_loss: 0.0390 - val_accuracy: 0.1867 - val_SSIM_loss: 0.0125
# Epoch 18/200
# 360/360 [==============================] - 77s 215ms/step - gen_total_loss: 2.0342 - gen_gan_loss: 0.3160 - gen_l1_loss: 0.0172 - disc_loss: 0.4477 - accuracy: 0.5971 - SSIM_loss: 0.0389 - val_accuracy: 0.7692 - val_SSIM_loss: 0.0117
# Epoch 19/200
# 360/360 [==============================] - 78s 216ms/step - gen_total_loss: 2.0436 - gen_gan_loss: 0.3252 - gen_l1_loss: 0.0172 - disc_loss: 0.4409 - accuracy: 0.5938 - SSIM_loss: 0.0388 - val_accuracy: 0.2864 - val_SSIM_loss: 0.0146
# Epoch 20/200
# 360/360 [==============================] - 79s 219ms/step - gen_total_loss: 1.9963 - gen_gan_loss: 0.2944 - gen_l1_loss: 0.0170 - disc_loss: 0.4693 - accuracy: 0.7338 - SSIM_loss: 0.0387 - val_accuracy: 0.9365 - val_SSIM_loss: 0.0121
# Epoch 21/200
# 360/360 [==============================] - 77s 215ms/step - gen_total_loss: 2.0248 - gen_gan_loss: 0.3059 - gen_l1_loss: 0.0172 - disc_loss: 0.4530 - accuracy: 0.8309 - SSIM_loss: 0.0390 - val_accuracy: 0.9329 - val_SSIM_loss: 0.0173
# Epoch 22/200
# 360/360 [==============================] - 77s 214ms/step - gen_total_loss: 2.0229 - gen_gan_loss: 0.3131 - gen_l1_loss: 0.0171 - disc_loss: 0.4485 - accuracy: 0.8887 - SSIM_loss: 0.0387 - val_accuracy: 0.9186 - val_SSIM_loss: 0.0139
# Epoch 23/200
# 360/360 [==============================] - 77s 215ms/step - gen_total_loss: 2.0325 - gen_gan_loss: 0.3179 - gen_l1_loss: 0.0171 - disc_loss: 0.4458 - accuracy: 0.9364 - SSIM_loss: 0.0389 - val_accuracy: 0.9503 - val_SSIM_loss: 0.0156
# Epoch 24/200
# 360/360 [==============================] - 81s 224ms/step - gen_total_loss: 2.0268 - gen_gan_loss: 0.3194 - gen_l1_loss: 0.0171 - disc_loss: 0.4448 - accuracy: 0.9437 - SSIM_loss: 0.0389 - val_accuracy: 0.9729 - val_SSIM_loss: 0.0139
# Epoch 25/200
# 360/360 [==============================] - 80s 223ms/step - gen_total_loss: 2.0127 - gen_gan_loss: 0.3217 - gen_l1_loss: 0.0169 - disc_loss: 0.4433 - accuracy: 0.9394 - SSIM_loss: 0.0386 - val_accuracy: 0.9458 - val_SSIM_loss: 0.0174
# Epoch 26/200
# 360/360 [==============================] - 78s 218ms/step - gen_total_loss: 2.0167 - gen_gan_loss: 0.3159 - gen_l1_loss: 0.0170 - disc_loss: 0.4501 - accuracy: 0.9411 - SSIM_loss: 0.0387 - val_accuracy: 0.9619 - val_SSIM_loss: 0.0168
# Epoch 27/200
# 360/360 [==============================] - 81s 224ms/step - gen_total_loss: 2.0183 - gen_gan_loss: 0.3177 - gen_l1_loss: 0.0170 - disc_loss: 0.4471 - accuracy: 0.9380 - SSIM_loss: 0.0386 - val_accuracy: 0.9397 - val_SSIM_loss: 0.0143
# Epoch 28/200
# 360/360 [==============================] - 82s 227ms/step - gen_total_loss: 2.0312 - gen_gan_loss: 0.3256 - gen_l1_loss: 0.0171 - disc_loss: 0.4416 - accuracy: 0.9393 - SSIM_loss: 0.0390 - val_accuracy: 0.9232 - val_SSIM_loss: 0.0145
# Epoch 29/200
# 360/360 [==============================] - 80s 223ms/step - gen_total_loss: 2.0068 - gen_gan_loss: 0.3228 - gen_l1_loss: 0.0168 - disc_loss: 0.4444 - accuracy: 0.9426 - SSIM_loss: 0.0385 - val_accuracy: 0.9353 - val_SSIM_loss: 0.0145
# Epoch 30/200
# 360/360 [==============================] - 80s 221ms/step - gen_total_loss: 2.0282 - gen_gan_loss: 0.3260 - gen_l1_loss: 0.0170 - disc_loss: 0.4409 - accuracy: 0.9444 - SSIM_loss: 0.0388 - val_accuracy: 0.9548 - val_SSIM_loss: 0.0170
# Epoch 31/200
# 360/360 [==============================] - 78s 217ms/step - gen_total_loss: 2.0163 - gen_gan_loss: 0.3259 - gen_l1_loss: 0.0169 - disc_loss: 0.4407 - accuracy: 0.9466 - SSIM_loss: 0.0385 - val_accuracy: 0.9489 - val_SSIM_loss: 0.0142
# Epoch 32/200
# 360/360 [==============================] - 77s 214ms/step - gen_total_loss: 2.0214 - gen_gan_loss: 0.3275 - gen_l1_loss: 0.0169 - disc_loss: 0.4401 - accuracy: 0.9401 - SSIM_loss: 0.0386 - val_accuracy: 0.9366 - val_SSIM_loss: 0.0178
# Epoch 33/200
# 360/360 [==============================] - 77s 215ms/step - gen_total_loss: 2.0030 - gen_gan_loss: 0.3278 - gen_l1_loss: 0.0168 - disc_loss: 0.4396 - accuracy: 0.9374 - SSIM_loss: 0.0384 - val_accuracy: 0.9518 - val_SSIM_loss: 0.0179
# Epoch 34/200
# 360/360 [==============================] - 78s 217ms/step - gen_total_loss: 2.0396 - gen_gan_loss: 0.3312 - gen_l1_loss: 0.0171 - disc_loss: 0.4375 - accuracy: 0.9390 - SSIM_loss: 0.0390 - val_accuracy: 0.9361 - val_SSIM_loss: 0.0155
# Epoch 35/200
# 360/360 [==============================] - 85s 237ms/step - gen_total_loss: 2.0123 - gen_gan_loss: 0.3311 - gen_l1_loss: 0.0168 - disc_loss: 0.4377 - accuracy: 0.9415 - SSIM_loss: 0.0384 - val_accuracy: 0.9393 - val_SSIM_loss: 0.0140
# Epoch 36/200
# 360/360 [==============================] - 171s 476ms/step - gen_total_loss: 2.0007 - gen_gan_loss: 0.3171 - gen_l1_loss: 0.0168 - disc_loss: 0.4514 - accuracy: 0.9399 - SSIM_loss: 0.0385 - val_accuracy: 0.9753 - val_SSIM_loss: 0.0181
# Epoch 37/200
# 360/360 [==============================] - 201s 557ms/step - gen_total_loss: 1.9885 - gen_gan_loss: 0.3230 - gen_l1_loss: 0.0167 - disc_loss: 0.4459 - accuracy: 0.9411 - SSIM_loss: 0.0381 - val_accuracy: 0.9635 - val_SSIM_loss: 0.0174
# Epoch 38/200
# 360/360 [==============================] - 195s 543ms/step - gen_total_loss: 2.0123 - gen_gan_loss: 0.3287 - gen_l1_loss: 0.0168 - disc_loss: 0.4402 - accuracy: 0.9426 - SSIM_loss: 0.0384 - val_accuracy: 0.9536 - val_SSIM_loss: 0.0187
# Epoch 39/200
# 360/360 [==============================] - 181s 501ms/step - gen_total_loss: 1.9903 - gen_gan_loss: 0.3311 - gen_l1_loss: 0.0166 - disc_loss: 0.4383 - accuracy: 0.9418 - SSIM_loss: 0.0380 - val_accuracy: 0.9345 - val_SSIM_loss: 0.0186
# Epoch 40/200
# 360/360 [==============================] - 184s 512ms/step - gen_total_loss: 2.0191 - gen_gan_loss: 0.3291 - gen_l1_loss: 0.0169 - disc_loss: 0.4404 - accuracy: 0.9479 - SSIM_loss: 0.0385 - val_accuracy: 0.9764 - val_SSIM_loss: 0.0191
# Epoch 41/200
# 360/360 [==============================] - 189s 526ms/step - gen_total_loss: 2.0114 - gen_gan_loss: 0.3321 - gen_l1_loss: 0.0168 - disc_loss: 0.4378 - accuracy: 0.9577 - SSIM_loss: 0.0383 - val_accuracy: 0.9859 - val_SSIM_loss: 0.0213
# Epoch 42/200
# 360/360 [==============================] - 188s 521ms/step - gen_total_loss: 2.0094 - gen_gan_loss: 0.3339 - gen_l1_loss: 0.0168 - disc_loss: 0.4368 - accuracy: 0.9542 - SSIM_loss: 0.0383 - val_accuracy: 0.9734 - val_SSIM_loss: 0.0167
# Epoch 43/200
# 360/360 [==============================] - 188s 522ms/step - gen_total_loss: 1.9812 - gen_gan_loss: 0.3332 - gen_l1_loss: 0.0165 - disc_loss: 0.4370 - accuracy: 0.9518 - SSIM_loss: 0.0377 - val_accuracy: 0.9779 - val_SSIM_loss: 0.0125
# Epoch 44/200
# 360/360 [==============================] - 180s 501ms/step - gen_total_loss: 2.0143 - gen_gan_loss: 0.3350 - gen_l1_loss: 0.0168 - disc_loss: 0.4360 - accuracy: 0.9542 - SSIM_loss: 0.0383 - val_accuracy: 0.9712 - val_SSIM_loss: 0.0161
# Epoch 45/200
# 360/360 [==============================] - 181s 503ms/step - gen_total_loss: 2.0107 - gen_gan_loss: 0.3339 - gen_l1_loss: 0.0168 - disc_loss: 0.4380 - accuracy: 0.9586 - SSIM_loss: 0.0383 - val_accuracy: 0.9760 - val_SSIM_loss: 0.0181
# Epoch 46/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.9666 - gen_gan_loss: 0.3211 - gen_l1_loss: 0.0165 - disc_loss: 0.4464 - accuracy: 0.9614 - SSIM_loss: 0.0377 - val_accuracy: 0.9673 - val_SSIM_loss: 0.0202
# Epoch 47/200
# 360/360 [==============================] - 206s 574ms/step - gen_total_loss: 1.9908 - gen_gan_loss: 0.3303 - gen_l1_loss: 0.0166 - disc_loss: 0.4395 - accuracy: 0.9579 - SSIM_loss: 0.0381 - val_accuracy: 0.9626 - val_SSIM_loss: 0.0162
# Epoch 48/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.9986 - gen_gan_loss: 0.3342 - gen_l1_loss: 0.0166 - disc_loss: 0.4368 - accuracy: 0.9575 - SSIM_loss: 0.0381 - val_accuracy: 0.9745 - val_SSIM_loss: 0.0168
# Epoch 49/200
# 360/360 [==============================] - 184s 510ms/step - gen_total_loss: 1.9893 - gen_gan_loss: 0.3371 - gen_l1_loss: 0.0165 - disc_loss: 0.4347 - accuracy: 0.9602 - SSIM_loss: 0.0379 - val_accuracy: 0.9731 - val_SSIM_loss: 0.0178
# Epoch 50/200
# 360/360 [==============================] - 180s 500ms/step - gen_total_loss: 1.9864 - gen_gan_loss: 0.3373 - gen_l1_loss: 0.0165 - disc_loss: 0.4348 - accuracy: 0.9611 - SSIM_loss: 0.0379 - val_accuracy: 0.9515 - val_SSIM_loss: 0.0183
# Epoch 51/200
# 360/360 [==============================] - 180s 501ms/step - gen_total_loss: 2.0080 - gen_gan_loss: 0.3382 - gen_l1_loss: 0.0167 - disc_loss: 0.4342 - accuracy: 0.9590 - SSIM_loss: 0.0382 - val_accuracy: 0.9813 - val_SSIM_loss: 0.0222
# Epoch 52/200
# 360/360 [==============================] - 181s 502ms/step - gen_total_loss: 1.9891 - gen_gan_loss: 0.3390 - gen_l1_loss: 0.0165 - disc_loss: 0.4338 - accuracy: 0.9639 - SSIM_loss: 0.0379 - val_accuracy: 0.9615 - val_SSIM_loss: 0.0196
# Epoch 53/200
# 360/360 [==============================] - 180s 500ms/step - gen_total_loss: 1.9789 - gen_gan_loss: 0.3276 - gen_l1_loss: 0.0165 - disc_loss: 0.4431 - accuracy: 0.9608 - SSIM_loss: 0.0379 - val_accuracy: 0.9472 - val_SSIM_loss: 0.0192
# Epoch 54/200
# 360/360 [==============================] - 180s 501ms/step - gen_total_loss: 1.9741 - gen_gan_loss: 0.3325 - gen_l1_loss: 0.0164 - disc_loss: 0.4385 - accuracy: 0.9595 - SSIM_loss: 0.0377 - val_accuracy: 0.9798 - val_SSIM_loss: 0.0195
# Epoch 55/200
# 360/360 [==============================] - 180s 501ms/step - gen_total_loss: 1.9866 - gen_gan_loss: 0.3383 - gen_l1_loss: 0.0165 - disc_loss: 0.4345 - accuracy: 0.9582 - SSIM_loss: 0.0378 - val_accuracy: 0.9554 - val_SSIM_loss: 0.0134
# Epoch 56/200
# 360/360 [==============================] - 179s 499ms/step - gen_total_loss: 1.9911 - gen_gan_loss: 0.3410 - gen_l1_loss: 0.0165 - disc_loss: 0.4328 - accuracy: 0.9598 - SSIM_loss: 0.0380 - val_accuracy: 0.9808 - val_SSIM_loss: 0.0198
# Epoch 57/200
# 360/360 [==============================] - 180s 500ms/step - gen_total_loss: 1.9722 - gen_gan_loss: 0.3417 - gen_l1_loss: 0.0163 - disc_loss: 0.4324 - accuracy: 0.9600 - SSIM_loss: 0.0376 - val_accuracy: 0.9588 - val_SSIM_loss: 0.0194
# Epoch 58/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 1.9977 - gen_gan_loss: 0.3428 - gen_l1_loss: 0.0165 - disc_loss: 0.4322 - accuracy: 0.9600 - SSIM_loss: 0.0380 - val_accuracy: 0.9579 - val_SSIM_loss: 0.0193
# Epoch 59/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.9977 - gen_gan_loss: 0.3442 - gen_l1_loss: 0.0165 - disc_loss: 0.4308 - accuracy: 0.9612 - SSIM_loss: 0.0379 - val_accuracy: 0.9693 - val_SSIM_loss: 0.0198
# Epoch 60/200
# 360/360 [==============================] - 212s 590ms/step - gen_total_loss: 1.9754 - gen_gan_loss: 0.3435 - gen_l1_loss: 0.0163 - disc_loss: 0.4314 - accuracy: 0.9621 - SSIM_loss: 0.0376 - val_accuracy: 0.9703 - val_SSIM_loss: 0.0206
# Epoch 61/200
# 360/360 [==============================] - 212s 589ms/step - gen_total_loss: 1.9839 - gen_gan_loss: 0.3447 - gen_l1_loss: 0.0164 - disc_loss: 0.4306 - accuracy: 0.9587 - SSIM_loss: 0.0375 - val_accuracy: 0.9599 - val_SSIM_loss: 0.0143
# Epoch 62/200
# 360/360 [==============================] - 183s 507ms/step - gen_total_loss: 1.9959 - gen_gan_loss: 0.3463 - gen_l1_loss: 0.0165 - disc_loss: 0.4296 - accuracy: 0.9602 - SSIM_loss: 0.0378 - val_accuracy: 0.9793 - val_SSIM_loss: 0.0198
# Epoch 63/200
# 360/360 [==============================] - 180s 500ms/step - gen_total_loss: 1.9857 - gen_gan_loss: 0.3464 - gen_l1_loss: 0.0164 - disc_loss: 0.4297 - accuracy: 0.9607 - SSIM_loss: 0.0376 - val_accuracy: 0.9707 - val_SSIM_loss: 0.0184
# Epoch 64/200
# 360/360 [==============================] - 215s 598ms/step - gen_total_loss: 1.9808 - gen_gan_loss: 0.3469 - gen_l1_loss: 0.0163 - disc_loss: 0.4295 - accuracy: 0.9643 - SSIM_loss: 0.0377 - val_accuracy: 0.9735 - val_SSIM_loss: 0.0183
# Epoch 65/200
# 360/360 [==============================] - 218s 604ms/step - gen_total_loss: 1.9921 - gen_gan_loss: 0.3461 - gen_l1_loss: 0.0165 - disc_loss: 0.4307 - accuracy: 0.9612 - SSIM_loss: 0.0377 - val_accuracy: 0.9661 - val_SSIM_loss: 0.0177
# Epoch 66/200
# 360/360 [==============================] - 217s 603ms/step - gen_total_loss: 1.9725 - gen_gan_loss: 0.3477 - gen_l1_loss: 0.0162 - disc_loss: 0.4287 - accuracy: 0.9660 - SSIM_loss: 0.0374 - val_accuracy: 0.9849 - val_SSIM_loss: 0.0210
# Epoch 67/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 1.9707 - gen_gan_loss: 0.3484 - gen_l1_loss: 0.0162 - disc_loss: 0.4284 - accuracy: 0.9615 - SSIM_loss: 0.0374 - val_accuracy: 0.9867 - val_SSIM_loss: 0.0211
# Epoch 68/200
# 360/360 [==============================] - 181s 502ms/step - gen_total_loss: 1.9791 - gen_gan_loss: 0.3486 - gen_l1_loss: 0.0163 - disc_loss: 0.4286 - accuracy: 0.9619 - SSIM_loss: 0.0375 - val_accuracy: 0.9759 - val_SSIM_loss: 0.0203
# Epoch 69/200
# 360/360 [==============================] - 143s 397ms/step - gen_total_loss: 1.9788 - gen_gan_loss: 0.3467 - gen_l1_loss: 0.0163 - disc_loss: 0.4335 - accuracy: 0.9630 - SSIM_loss: 0.0376 - val_accuracy: 0.9748 - val_SSIM_loss: 0.0202
# Epoch 70/200
# 360/360 [==============================] - 103s 285ms/step - gen_total_loss: 1.9408 - gen_gan_loss: 0.3230 - gen_l1_loss: 0.0162 - disc_loss: 0.4459 - accuracy: 0.9644 - SSIM_loss: 0.0374 - val_accuracy: 0.9662 - val_SSIM_loss: 0.0201
# Epoch 71/200
# 360/360 [==============================] - 78s 215ms/step - gen_total_loss: 1.9566 - gen_gan_loss: 0.3396 - gen_l1_loss: 0.0162 - disc_loss: 0.4346 - accuracy: 0.9623 - SSIM_loss: 0.0374 - val_accuracy: 0.9566 - val_SSIM_loss: 0.0205
# Epoch 72/200
# 360/360 [==============================] - 77s 214ms/step - gen_total_loss: 1.9716 - gen_gan_loss: 0.3438 - gen_l1_loss: 0.0163 - disc_loss: 0.4316 - accuracy: 0.9649 - SSIM_loss: 0.0374 - val_accuracy: 0.9700 - val_SSIM_loss: 0.0174
# Epoch 73/200
# 360/360 [==============================] - 77s 213ms/step - gen_total_loss: 1.9692 - gen_gan_loss: 0.3464 - gen_l1_loss: 0.0162 - disc_loss: 0.4305 - accuracy: 0.9640 - SSIM_loss: 0.0373 - val_accuracy: 0.9822 - val_SSIM_loss: 0.0212
# Epoch 74/200
# 360/360 [==============================] - 80s 222ms/step - gen_total_loss: 1.9770 - gen_gan_loss: 0.3484 - gen_l1_loss: 0.0163 - disc_loss: 0.4290 - accuracy: 0.9655 - SSIM_loss: 0.0374 - val_accuracy: 0.9505 - val_SSIM_loss: 0.0199
# Epoch 75/200
# 360/360 [==============================] - 104s 288ms/step - gen_total_loss: 1.9713 - gen_gan_loss: 0.3501 - gen_l1_loss: 0.0162 - disc_loss: 0.4277 - accuracy: 0.9625 - SSIM_loss: 0.0376 - val_accuracy: 0.9605 - val_SSIM_loss: 0.0206
# Epoch 76/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 1.9524 - gen_gan_loss: 0.3503 - gen_l1_loss: 0.0160 - disc_loss: 0.4282 - accuracy: 0.9635 - SSIM_loss: 0.0370 - val_accuracy: 0.9875 - val_SSIM_loss: 0.0199
# Epoch 77/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 1.9585 - gen_gan_loss: 0.3475 - gen_l1_loss: 0.0161 - disc_loss: 0.4448 - accuracy: 0.9643 - SSIM_loss: 0.0373 - val_accuracy: 0.9825 - val_SSIM_loss: 0.0212
# Epoch 78/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 1.9301 - gen_gan_loss: 0.3214 - gen_l1_loss: 0.0161 - disc_loss: 0.4483 - accuracy: 0.9667 - SSIM_loss: 0.0371 - val_accuracy: 0.9846 - val_SSIM_loss: 0.0180
# Epoch 79/200
# 360/360 [==============================] - 103s 285ms/step - gen_total_loss: 1.9438 - gen_gan_loss: 0.3434 - gen_l1_loss: 0.0160 - disc_loss: 0.4335 - accuracy: 0.9651 - SSIM_loss: 0.0370 - val_accuracy: 0.9659 - val_SSIM_loss: 0.0216
# Epoch 80/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 1.9870 - gen_gan_loss: 0.3484 - gen_l1_loss: 0.0164 - disc_loss: 0.4298 - accuracy: 0.9680 - SSIM_loss: 0.0376 - val_accuracy: 0.9858 - val_SSIM_loss: 0.0182
# Epoch 81/200
# 360/360 [==============================] - 93s 260ms/step - gen_total_loss: 1.9423 - gen_gan_loss: 0.3493 - gen_l1_loss: 0.0159 - disc_loss: 0.4288 - accuracy: 0.9704 - SSIM_loss: 0.0369 - val_accuracy: 0.9826 - val_SSIM_loss: 0.0217
# Epoch 82/200
# 360/360 [==============================] - 78s 216ms/step - gen_total_loss: 1.9743 - gen_gan_loss: 0.3510 - gen_l1_loss: 0.0162 - disc_loss: 0.4276 - accuracy: 0.9710 - SSIM_loss: 0.0374 - val_accuracy: 0.9806 - val_SSIM_loss: 0.0222
# Epoch 83/200
# 360/360 [==============================] - 85s 237ms/step - gen_total_loss: 1.9445 - gen_gan_loss: 0.3502 - gen_l1_loss: 0.0159 - disc_loss: 0.4282 - accuracy: 0.9695 - SSIM_loss: 0.0368 - val_accuracy: 0.9886 - val_SSIM_loss: 0.0216
# Epoch 84/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 1.9658 - gen_gan_loss: 0.3517 - gen_l1_loss: 0.0161 - disc_loss: 0.4275 - accuracy: 0.9681 - SSIM_loss: 0.0371 - val_accuracy: 0.9616 - val_SSIM_loss: 0.0175
# Epoch 85/200
# 360/360 [==============================] - 103s 286ms/step - gen_total_loss: 1.9665 - gen_gan_loss: 0.3520 - gen_l1_loss: 0.0161 - disc_loss: 0.4271 - accuracy: 0.9734 - SSIM_loss: 0.0371 - val_accuracy: 0.9686 - val_SSIM_loss: 0.0204
# Epoch 86/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 1.9362 - gen_gan_loss: 0.3508 - gen_l1_loss: 0.0159 - disc_loss: 0.4288 - accuracy: 0.9713 - SSIM_loss: 0.0368 - val_accuracy: 0.9797 - val_SSIM_loss: 0.0204
# Epoch 87/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 1.9485 - gen_gan_loss: 0.3524 - gen_l1_loss: 0.0160 - disc_loss: 0.4265 - accuracy: 0.9732 - SSIM_loss: 0.0369 - val_accuracy: 0.9803 - val_SSIM_loss: 0.0179
# Epoch 88/200
# 360/360 [==============================] - 102s 285ms/step - gen_total_loss: 1.9501 - gen_gan_loss: 0.3533 - gen_l1_loss: 0.0160 - disc_loss: 0.4264 - accuracy: 0.9734 - SSIM_loss: 0.0370 - val_accuracy: 0.9693 - val_SSIM_loss: 0.0191
# Epoch 89/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 1.9739 - gen_gan_loss: 0.3544 - gen_l1_loss: 0.0162 - disc_loss: 0.4259 - accuracy: 0.9744 - SSIM_loss: 0.0375 - val_accuracy: 0.9685 - val_SSIM_loss: 0.0211
# Epoch 90/200
# 360/360 [==============================] - 85s 237ms/step - gen_total_loss: 1.9688 - gen_gan_loss: 0.3529 - gen_l1_loss: 0.0162 - disc_loss: 0.4273 - accuracy: 0.9745 - SSIM_loss: 0.0375 - val_accuracy: 0.9795 - val_SSIM_loss: 0.0195
# Epoch 91/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9496 - gen_gan_loss: 0.3546 - gen_l1_loss: 0.0160 - disc_loss: 0.4254 - accuracy: 0.9743 - SSIM_loss: 0.0371 - val_accuracy: 0.9803 - val_SSIM_loss: 0.0200
# Epoch 92/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9470 - gen_gan_loss: 0.3549 - gen_l1_loss: 0.0159 - disc_loss: 0.4253 - accuracy: 0.9721 - SSIM_loss: 0.0369 - val_accuracy: 0.9850 - val_SSIM_loss: 0.0219
# Epoch 93/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 1.9484 - gen_gan_loss: 0.3553 - gen_l1_loss: 0.0159 - disc_loss: 0.4252 - accuracy: 0.9728 - SSIM_loss: 0.0370 - val_accuracy: 0.9868 - val_SSIM_loss: 0.0213
# Epoch 94/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 1.9515 - gen_gan_loss: 0.3439 - gen_l1_loss: 0.0161 - disc_loss: 0.4414 - accuracy: 0.9736 - SSIM_loss: 0.0372 - val_accuracy: 0.9840 - val_SSIM_loss: 0.0215
# Epoch 95/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 1.9542 - gen_gan_loss: 0.3535 - gen_l1_loss: 0.0160 - disc_loss: 0.4267 - accuracy: 0.9731 - SSIM_loss: 0.0371 - val_accuracy: 0.9834 - val_SSIM_loss: 0.0213
# Epoch 96/200
# 360/360 [==============================] - 103s 287ms/step - gen_total_loss: 1.9184 - gen_gan_loss: 0.3541 - gen_l1_loss: 0.0156 - disc_loss: 0.4256 - accuracy: 0.9733 - SSIM_loss: 0.0364 - val_accuracy: 0.9820 - val_SSIM_loss: 0.0231
# Epoch 97/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 1.9488 - gen_gan_loss: 0.3562 - gen_l1_loss: 0.0159 - disc_loss: 0.4253 - accuracy: 0.9741 - SSIM_loss: 0.0370 - val_accuracy: 0.9873 - val_SSIM_loss: 0.0226
# Epoch 98/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 1.9602 - gen_gan_loss: 0.3543 - gen_l1_loss: 0.0161 - disc_loss: 0.4265 - accuracy: 0.9751 - SSIM_loss: 0.0374 - val_accuracy: 0.9864 - val_SSIM_loss: 0.0200
# Epoch 99/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 1.9310 - gen_gan_loss: 0.3522 - gen_l1_loss: 0.0158 - disc_loss: 0.4287 - accuracy: 0.9729 - SSIM_loss: 0.0367 - val_accuracy: 0.9850 - val_SSIM_loss: 0.0226
# Epoch 100/200
# 360/360 [==============================] - 75s 207ms/step - gen_total_loss: 1.9196 - gen_gan_loss: 0.3488 - gen_l1_loss: 0.0157 - disc_loss: 0.4308 - accuracy: 0.9751 - SSIM_loss: 0.0366 - val_accuracy: 0.9803 - val_SSIM_loss: 0.0222
# Epoch 101/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.9594 - gen_gan_loss: 0.3561 - gen_l1_loss: 0.0160 - disc_loss: 0.4248 - accuracy: 0.9748 - SSIM_loss: 0.0372 - val_accuracy: 0.9807 - val_SSIM_loss: 0.0221
# Epoch 102/200
# 360/360 [==============================] - 72s 199ms/step - gen_total_loss: 1.9438 - gen_gan_loss: 0.3574 - gen_l1_loss: 0.0159 - disc_loss: 0.4244 - accuracy: 0.9752 - SSIM_loss: 0.0369 - val_accuracy: 0.9813 - val_SSIM_loss: 0.0214
# Epoch 103/200
# 360/360 [==============================] - 71s 198ms/step - gen_total_loss: 1.9215 - gen_gan_loss: 0.3572 - gen_l1_loss: 0.0156 - disc_loss: 0.4240 - accuracy: 0.9764 - SSIM_loss: 0.0365 - val_accuracy: 0.9604 - val_SSIM_loss: 0.0221
# Epoch 104/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.9622 - gen_gan_loss: 0.3589 - gen_l1_loss: 0.0160 - disc_loss: 0.4233 - accuracy: 0.9763 - SSIM_loss: 0.0371 - val_accuracy: 0.9880 - val_SSIM_loss: 0.0225
# Epoch 105/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 1.9114 - gen_gan_loss: 0.3542 - gen_l1_loss: 0.0156 - disc_loss: 0.4272 - accuracy: 0.9770 - SSIM_loss: 0.0364 - val_accuracy: 0.9794 - val_SSIM_loss: 0.0235
# Epoch 106/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 1.9539 - gen_gan_loss: 0.3584 - gen_l1_loss: 0.0160 - disc_loss: 0.4238 - accuracy: 0.9757 - SSIM_loss: 0.0370 - val_accuracy: 0.9876 - val_SSIM_loss: 0.0220
# Epoch 107/200
# 360/360 [==============================] - 97s 271ms/step - gen_total_loss: 1.9406 - gen_gan_loss: 0.3590 - gen_l1_loss: 0.0158 - disc_loss: 0.4231 - accuracy: 0.9769 - SSIM_loss: 0.0368 - val_accuracy: 0.9780 - val_SSIM_loss: 0.0229
# Epoch 108/200
# 360/360 [==============================] - 104s 289ms/step - gen_total_loss: 1.9417 - gen_gan_loss: 0.3595 - gen_l1_loss: 0.0158 - disc_loss: 0.4234 - accuracy: 0.9761 - SSIM_loss: 0.0368 - val_accuracy: 0.9887 - val_SSIM_loss: 0.0205
# Epoch 109/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 1.9137 - gen_gan_loss: 0.3586 - gen_l1_loss: 0.0156 - disc_loss: 0.4234 - accuracy: 0.9772 - SSIM_loss: 0.0364 - val_accuracy: 0.9795 - val_SSIM_loss: 0.0229
# Epoch 110/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 1.9508 - gen_gan_loss: 0.3602 - gen_l1_loss: 0.0159 - disc_loss: 0.4226 - accuracy: 0.9765 - SSIM_loss: 0.0370 - val_accuracy: 0.9858 - val_SSIM_loss: 0.0224
# Epoch 111/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 1.9098 - gen_gan_loss: 0.3582 - gen_l1_loss: 0.0155 - disc_loss: 0.4239 - accuracy: 0.9770 - SSIM_loss: 0.0364 - val_accuracy: 0.9745 - val_SSIM_loss: 0.0214
# Epoch 112/200
# 360/360 [==============================] - 75s 207ms/step - gen_total_loss: 1.9445 - gen_gan_loss: 0.3605 - gen_l1_loss: 0.0158 - disc_loss: 0.4225 - accuracy: 0.9749 - SSIM_loss: 0.0369 - val_accuracy: 0.9839 - val_SSIM_loss: 0.0227
# Epoch 113/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9291 - gen_gan_loss: 0.3601 - gen_l1_loss: 0.0157 - disc_loss: 0.4232 - accuracy: 0.9768 - SSIM_loss: 0.0367 - val_accuracy: 0.9872 - val_SSIM_loss: 0.0213
# Epoch 114/200
# 360/360 [==============================] - 80s 222ms/step - gen_total_loss: 1.9428 - gen_gan_loss: 0.3612 - gen_l1_loss: 0.0158 - disc_loss: 0.4224 - accuracy: 0.9756 - SSIM_loss: 0.0369 - val_accuracy: 0.9872 - val_SSIM_loss: 0.0227
# Epoch 115/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 1.9373 - gen_gan_loss: 0.3608 - gen_l1_loss: 0.0158 - disc_loss: 0.4225 - accuracy: 0.9765 - SSIM_loss: 0.0369 - val_accuracy: 0.9764 - val_SSIM_loss: 0.0209
# Epoch 116/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 1.9071 - gen_gan_loss: 0.3470 - gen_l1_loss: 0.0156 - disc_loss: 0.4425 - accuracy: 0.9775 - SSIM_loss: 0.0365 - val_accuracy: 0.9880 - val_SSIM_loss: 0.0234
# Epoch 117/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 1.9009 - gen_gan_loss: 0.3340 - gen_l1_loss: 0.0157 - disc_loss: 0.4413 - accuracy: 0.9775 - SSIM_loss: 0.0365 - val_accuracy: 0.9856 - val_SSIM_loss: 0.0227
# Epoch 118/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 1.9404 - gen_gan_loss: 0.3543 - gen_l1_loss: 0.0159 - disc_loss: 0.4262 - accuracy: 0.9776 - SSIM_loss: 0.0369 - val_accuracy: 0.9874 - val_SSIM_loss: 0.0227
# Epoch 119/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 1.9088 - gen_gan_loss: 0.3585 - gen_l1_loss: 0.0155 - disc_loss: 0.4237 - accuracy: 0.9772 - SSIM_loss: 0.0363 - val_accuracy: 0.9864 - val_SSIM_loss: 0.0242
# Epoch 120/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 1.9192 - gen_gan_loss: 0.3596 - gen_l1_loss: 0.0156 - disc_loss: 0.4232 - accuracy: 0.9776 - SSIM_loss: 0.0366 - val_accuracy: 0.9813 - val_SSIM_loss: 0.0206
# Epoch 121/200
# 360/360 [==============================] - 89s 248ms/step - gen_total_loss: 1.9370 - gen_gan_loss: 0.3609 - gen_l1_loss: 0.0158 - disc_loss: 0.4225 - accuracy: 0.9771 - SSIM_loss: 0.0368 - val_accuracy: 0.9816 - val_SSIM_loss: 0.0230
# Epoch 122/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9353 - gen_gan_loss: 0.3617 - gen_l1_loss: 0.0157 - disc_loss: 0.4219 - accuracy: 0.9776 - SSIM_loss: 0.0367 - val_accuracy: 0.9846 - val_SSIM_loss: 0.0232
# Epoch 123/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9034 - gen_gan_loss: 0.3614 - gen_l1_loss: 0.0154 - disc_loss: 0.4219 - accuracy: 0.9775 - SSIM_loss: 0.0362 - val_accuracy: 0.9852 - val_SSIM_loss: 0.0230
# Epoch 124/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 1.9375 - gen_gan_loss: 0.3621 - gen_l1_loss: 0.0158 - disc_loss: 0.4219 - accuracy: 0.9777 - SSIM_loss: 0.0369 - val_accuracy: 0.9851 - val_SSIM_loss: 0.0239
# Epoch 125/200
# 360/360 [==============================] - 95s 265ms/step - gen_total_loss: 1.9131 - gen_gan_loss: 0.3617 - gen_l1_loss: 0.0155 - disc_loss: 0.4223 - accuracy: 0.9777 - SSIM_loss: 0.0363 - val_accuracy: 0.9872 - val_SSIM_loss: 0.0229
# Epoch 126/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 1.9269 - gen_gan_loss: 0.3622 - gen_l1_loss: 0.0156 - disc_loss: 0.4219 - accuracy: 0.9776 - SSIM_loss: 0.0367 - val_accuracy: 0.9858 - val_SSIM_loss: 0.02263623 - gen_l1_loss: 0.0157 - disc_loss: 0.421
# Epoch 127/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 1.9468 - gen_gan_loss: 0.3629 - gen_l1_loss: 0.0158 - disc_loss: 0.4212 - accuracy: 0.9777 - SSIM_loss: 0.0370 - val_accuracy: 0.9862 - val_SSIM_loss: 0.0227
# Epoch 128/200
# 360/360 [==============================] - 96s 268ms/step - gen_total_loss: 1.9018 - gen_gan_loss: 0.3621 - gen_l1_loss: 0.0154 - disc_loss: 0.4219 - accuracy: 0.9779 - SSIM_loss: 0.0362 - val_accuracy: 0.9856 - val_SSIM_loss: 0.0229
# Epoch 129/200
# 360/360 [==============================] - 96s 266ms/step - gen_total_loss: 1.9089 - gen_gan_loss: 0.3621 - gen_l1_loss: 0.0155 - disc_loss: 0.4218 - accuracy: 0.9780 - SSIM_loss: 0.0363 - val_accuracy: 0.9876 - val_SSIM_loss: 0.0241
# Epoch 130/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 1.9333 - gen_gan_loss: 0.3631 - gen_l1_loss: 0.0157 - disc_loss: 0.4211 - accuracy: 0.9777 - SSIM_loss: 0.0369 - val_accuracy: 0.9835 - val_SSIM_loss: 0.0230
# Epoch 131/200
# 360/360 [==============================] - 75s 209ms/step - gen_total_loss: 1.9104 - gen_gan_loss: 0.3623 - gen_l1_loss: 0.0155 - disc_loss: 0.4223 - accuracy: 0.9780 - SSIM_loss: 0.0363 - val_accuracy: 0.9859 - val_SSIM_loss: 0.0232
# Epoch 132/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9158 - gen_gan_loss: 0.3631 - gen_l1_loss: 0.0155 - disc_loss: 0.4213 - accuracy: 0.9779 - SSIM_loss: 0.0365 - val_accuracy: 0.9843 - val_SSIM_loss: 0.0236
# Epoch 133/200
# 360/360 [==============================] - 77s 213ms/step - gen_total_loss: 1.9262 - gen_gan_loss: 0.3640 - gen_l1_loss: 0.0156 - disc_loss: 0.4207 - accuracy: 0.9776 - SSIM_loss: 0.0368 - val_accuracy: 0.9845 - val_SSIM_loss: 0.0231
# Epoch 134/200
# 360/360 [==============================] - 102s 282ms/step - gen_total_loss: 1.9435 - gen_gan_loss: 0.3637 - gen_l1_loss: 0.0158 - disc_loss: 0.4214 - accuracy: 0.9782 - SSIM_loss: 0.0369 - val_accuracy: 0.9866 - val_SSIM_loss: 0.0233
# Epoch 135/200
# 360/360 [==============================] - 96s 267ms/step - gen_total_loss: 1.9185 - gen_gan_loss: 0.3623 - gen_l1_loss: 0.0156 - disc_loss: 0.4231 - accuracy: 0.9782 - SSIM_loss: 0.0365 - val_accuracy: 0.9853 - val_SSIM_loss: 0.0242
# Epoch 136/200
# 360/360 [==============================] - 97s 268ms/step - gen_total_loss: 1.8860 - gen_gan_loss: 0.3463 - gen_l1_loss: 0.0154 - disc_loss: 0.4361 - accuracy: 0.9780 - SSIM_loss: 0.0363 - val_accuracy: 0.9752 - val_SSIM_loss: 0.0238
# Epoch 137/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 1.9059 - gen_gan_loss: 0.3608 - gen_l1_loss: 0.0155 - disc_loss: 0.4223 - accuracy: 0.9782 - SSIM_loss: 0.0364 - val_accuracy: 0.9862 - val_SSIM_loss: 0.0231
# Epoch 138/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 1.9368 - gen_gan_loss: 0.3640 - gen_l1_loss: 0.0157 - disc_loss: 0.4210 - accuracy: 0.9778 - SSIM_loss: 0.0369 - val_accuracy: 0.9842 - val_SSIM_loss: 0.0241
# Epoch 139/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 1.8991 - gen_gan_loss: 0.3625 - gen_l1_loss: 0.0154 - disc_loss: 0.4214 - accuracy: 0.9778 - SSIM_loss: 0.0362 - val_accuracy: 0.9814 - val_SSIM_loss: 0.0238
# Epoch 140/200
# 360/360 [==============================] - 93s 258ms/step - gen_total_loss: 1.9078 - gen_gan_loss: 0.3638 - gen_l1_loss: 0.0154 - disc_loss: 0.4207 - accuracy: 0.9778 - SSIM_loss: 0.0365 - val_accuracy: 0.9877 - val_SSIM_loss: 0.0240
# Epoch 141/200
# 360/360 [==============================] - 74s 204ms/step - gen_total_loss: 1.9112 - gen_gan_loss: 0.3637 - gen_l1_loss: 0.0155 - disc_loss: 0.4208 - accuracy: 0.9773 - SSIM_loss: 0.0363 - val_accuracy: 0.9866 - val_SSIM_loss: 0.0226
# Epoch 142/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9102 - gen_gan_loss: 0.3643 - gen_l1_loss: 0.0155 - disc_loss: 0.4206 - accuracy: 0.9779 - SSIM_loss: 0.0364 - val_accuracy: 0.9800 - val_SSIM_loss: 0.0244
# Epoch 143/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.9115 - gen_gan_loss: 0.3641 - gen_l1_loss: 0.0155 - disc_loss: 0.4208 - accuracy: 0.9780 - SSIM_loss: 0.0364 - val_accuracy: 0.9863 - val_SSIM_loss: 0.0227
# Epoch 144/200
# 360/360 [==============================] - 73s 203ms/step - gen_total_loss: 1.9145 - gen_gan_loss: 0.3646 - gen_l1_loss: 0.0155 - disc_loss: 0.4205 - accuracy: 0.9783 - SSIM_loss: 0.0364 - val_accuracy: 0.9816 - val_SSIM_loss: 0.0232
# Epoch 145/200
# 360/360 [==============================] - 73s 204ms/step - gen_total_loss: 1.9102 - gen_gan_loss: 0.3649 - gen_l1_loss: 0.0155 - disc_loss: 0.4203 - accuracy: 0.9777 - SSIM_loss: 0.0365 - val_accuracy: 0.9829 - val_SSIM_loss: 0.0239
# Epoch 146/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.9278 - gen_gan_loss: 0.3650 - gen_l1_loss: 0.0156 - disc_loss: 0.4204 - accuracy: 0.9777 - SSIM_loss: 0.0367 - val_accuracy: 0.9818 - val_SSIM_loss: 0.0236
# Epoch 147/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.8878 - gen_gan_loss: 0.3643 - gen_l1_loss: 0.0152 - disc_loss: 0.4207 - accuracy: 0.9781 - SSIM_loss: 0.0360 - val_accuracy: 0.9788 - val_SSIM_loss: 0.0230
# Epoch 148/200
# 360/360 [==============================] - 73s 203ms/step - gen_total_loss: 1.8897 - gen_gan_loss: 0.3546 - gen_l1_loss: 0.0154 - disc_loss: 0.4348 - accuracy: 0.9784 - SSIM_loss: 0.0362 - val_accuracy: 0.9823 - val_SSIM_loss: 0.0239
# Epoch 149/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.8967 - gen_gan_loss: 0.3383 - gen_l1_loss: 0.0156 - disc_loss: 0.4396 - accuracy: 0.9784 - SSIM_loss: 0.0365 - val_accuracy: 0.9819 - val_SSIM_loss: 0.0245
# Epoch 150/200
# 360/360 [==============================] - 73s 204ms/step - gen_total_loss: 1.8911 - gen_gan_loss: 0.3555 - gen_l1_loss: 0.0154 - disc_loss: 0.4267 - accuracy: 0.9784 - SSIM_loss: 0.0362 - val_accuracy: 0.9846 - val_SSIM_loss: 0.0230
# Epoch 151/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9120 - gen_gan_loss: 0.3601 - gen_l1_loss: 0.0155 - disc_loss: 0.4230 - accuracy: 0.9783 - SSIM_loss: 0.0365 - val_accuracy: 0.9874 - val_SSIM_loss: 0.0242
# Epoch 152/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9077 - gen_gan_loss: 0.3622 - gen_l1_loss: 0.0155 - disc_loss: 0.4220 - accuracy: 0.9779 - SSIM_loss: 0.0363 - val_accuracy: 0.9885 - val_SSIM_loss: 0.0240
# Epoch 153/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.8929 - gen_gan_loss: 0.3632 - gen_l1_loss: 0.0153 - disc_loss: 0.4210 - accuracy: 0.9780 - SSIM_loss: 0.0362 - val_accuracy: 0.9831 - val_SSIM_loss: 0.0236
# Epoch 154/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9153 - gen_gan_loss: 0.3643 - gen_l1_loss: 0.0155 - disc_loss: 0.4208 - accuracy: 0.9782 - SSIM_loss: 0.0364 - val_accuracy: 0.9875 - val_SSIM_loss: 0.0233
# Epoch 155/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.9058 - gen_gan_loss: 0.3646 - gen_l1_loss: 0.0154 - disc_loss: 0.4205 - accuracy: 0.9781 - SSIM_loss: 0.0364 - val_accuracy: 0.9829 - val_SSIM_loss: 0.0232
# Epoch 156/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9055 - gen_gan_loss: 0.3649 - gen_l1_loss: 0.0154 - disc_loss: 0.4204 - accuracy: 0.9782 - SSIM_loss: 0.0363 - val_accuracy: 0.9822 - val_SSIM_loss: 0.0236
# Epoch 157/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.9108 - gen_gan_loss: 0.3647 - gen_l1_loss: 0.0155 - disc_loss: 0.4208 - accuracy: 0.9786 - SSIM_loss: 0.0364 - val_accuracy: 0.9790 - val_SSIM_loss: 0.0235
# Epoch 158/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9051 - gen_gan_loss: 0.3653 - gen_l1_loss: 0.0154 - disc_loss: 0.4200 - accuracy: 0.9787 - SSIM_loss: 0.0364 - val_accuracy: 0.9852 - val_SSIM_loss: 0.0242
# Epoch 159/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.8950 - gen_gan_loss: 0.3650 - gen_l1_loss: 0.0153 - disc_loss: 0.4205 - accuracy: 0.9784 - SSIM_loss: 0.0361 - val_accuracy: 0.9800 - val_SSIM_loss: 0.0240
# Epoch 160/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.9006 - gen_gan_loss: 0.3662 - gen_l1_loss: 0.0153 - disc_loss: 0.4196 - accuracy: 0.9784 - SSIM_loss: 0.0362 - val_accuracy: 0.9828 - val_SSIM_loss: 0.0254
# Epoch 161/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.9133 - gen_gan_loss: 0.3658 - gen_l1_loss: 0.0155 - disc_loss: 0.4198 - accuracy: 0.9783 - SSIM_loss: 0.0364 - val_accuracy: 0.9816 - val_SSIM_loss: 0.0247
# Epoch 162/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.8998 - gen_gan_loss: 0.3664 - gen_l1_loss: 0.0153 - disc_loss: 0.4198 - accuracy: 0.9788 - SSIM_loss: 0.0363 - val_accuracy: 0.9850 - val_SSIM_loss: 0.0237
# Epoch 163/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.8842 - gen_gan_loss: 0.3494 - gen_l1_loss: 0.0153 - disc_loss: 0.4913 - accuracy: 0.9781 - SSIM_loss: 0.0363 - val_accuracy: 0.9827 - val_SSIM_loss: 0.0234
# Epoch 164/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.8570 - gen_gan_loss: 0.3185 - gen_l1_loss: 0.0154 - disc_loss: 0.4521 - accuracy: 0.9780 - SSIM_loss: 0.0363 - val_accuracy: 0.9869 - val_SSIM_loss: 0.0246
# Epoch 165/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.8850 - gen_gan_loss: 0.3456 - gen_l1_loss: 0.0154 - disc_loss: 0.4336 - accuracy: 0.9780 - SSIM_loss: 0.0362 - val_accuracy: 0.9802 - val_SSIM_loss: 0.0242
# Epoch 166/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.8701 - gen_gan_loss: 0.3583 - gen_l1_loss: 0.0151 - disc_loss: 0.4251 - accuracy: 0.9782 - SSIM_loss: 0.0357 - val_accuracy: 0.9810 - val_SSIM_loss: 0.0245
# Epoch 167/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9220 - gen_gan_loss: 0.3634 - gen_l1_loss: 0.0156 - disc_loss: 0.4214 - accuracy: 0.9781 - SSIM_loss: 0.0366 - val_accuracy: 0.9877 - val_SSIM_loss: 0.0244
# Epoch 168/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.8879 - gen_gan_loss: 0.3640 - gen_l1_loss: 0.0152 - disc_loss: 0.4212 - accuracy: 0.9783 - SSIM_loss: 0.0360 - val_accuracy: 0.9864 - val_SSIM_loss: 0.0231
# Epoch 169/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.8830 - gen_gan_loss: 0.3638 - gen_l1_loss: 0.0152 - disc_loss: 0.4213 - accuracy: 0.9788 - SSIM_loss: 0.0359 - val_accuracy: 0.9875 - val_SSIM_loss: 0.0262
# Epoch 170/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9134 - gen_gan_loss: 0.3658 - gen_l1_loss: 0.0155 - disc_loss: 0.4196 - accuracy: 0.9777 - SSIM_loss: 0.0364 - val_accuracy: 0.9823 - val_SSIM_loss: 0.0254
# Epoch 171/200
# 360/360 [==============================] - 74s 205ms/step - gen_total_loss: 1.8674 - gen_gan_loss: 0.3652 - gen_l1_loss: 0.0150 - disc_loss: 0.4202 - accuracy: 0.9782 - SSIM_loss: 0.0357 - val_accuracy: 0.9817 - val_SSIM_loss: 0.0242
# Epoch 172/200
# 360/360 [==============================] - 76s 210ms/step - gen_total_loss: 1.8938 - gen_gan_loss: 0.3656 - gen_l1_loss: 0.0153 - disc_loss: 0.4199 - accuracy: 0.9781 - SSIM_loss: 0.0361 - val_accuracy: 0.9785 - val_SSIM_loss: 0.0242
# Epoch 173/200
# 360/360 [==============================] - 72s 199ms/step - gen_total_loss: 1.9230 - gen_gan_loss: 0.3669 - gen_l1_loss: 0.0156 - disc_loss: 0.4192 - accuracy: 0.9776 - SSIM_loss: 0.0366 - val_accuracy: 0.9874 - val_SSIM_loss: 0.0243
# Epoch 174/200
# 360/360 [==============================] - 73s 204ms/step - gen_total_loss: 1.8727 - gen_gan_loss: 0.3656 - gen_l1_loss: 0.0151 - disc_loss: 0.4200 - accuracy: 0.9781 - SSIM_loss: 0.0358 - val_accuracy: 0.9790 - val_SSIM_loss: 0.0250
# Epoch 175/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.9192 - gen_gan_loss: 0.3672 - gen_l1_loss: 0.0155 - disc_loss: 0.4192 - accuracy: 0.9782 - SSIM_loss: 0.0366 - val_accuracy: 0.9839 - val_SSIM_loss: 0.0244
# Epoch 176/200
# 360/360 [==============================] - 73s 201ms/step - gen_total_loss: 1.8721 - gen_gan_loss: 0.3659 - gen_l1_loss: 0.0151 - disc_loss: 0.4199 - accuracy: 0.9783 - SSIM_loss: 0.0358 - val_accuracy: 0.9879 - val_SSIM_loss: 0.0246
# Epoch 177/200
# 360/360 [==============================] - 72s 199ms/step - gen_total_loss: 1.9034 - gen_gan_loss: 0.3671 - gen_l1_loss: 0.0154 - disc_loss: 0.4192 - accuracy: 0.9781 - SSIM_loss: 0.0363 - val_accuracy: 0.9785 - val_SSIM_loss: 0.0252
# Epoch 178/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.8821 - gen_gan_loss: 0.3656 - gen_l1_loss: 0.0152 - disc_loss: 0.4203 - accuracy: 0.9785 - SSIM_loss: 0.0359 - val_accuracy: 0.9811 - val_SSIM_loss: 0.0245
# Epoch 179/200
# 360/360 [==============================] - 74s 205ms/step - gen_total_loss: 1.9120 - gen_gan_loss: 0.3668 - gen_l1_loss: 0.0155 - disc_loss: 0.4197 - accuracy: 0.9781 - SSIM_loss: 0.0364 - val_accuracy: 0.9864 - val_SSIM_loss: 0.0244
# Epoch 180/200
# 360/360 [==============================] - 74s 207ms/step - gen_total_loss: 1.9021 - gen_gan_loss: 0.3670 - gen_l1_loss: 0.0154 - disc_loss: 0.4196 - accuracy: 0.9779 - SSIM_loss: 0.0363 - val_accuracy: 0.9851 - val_SSIM_loss: 0.0261
# Epoch 181/200
# 360/360 [==============================] - 73s 202ms/step - gen_total_loss: 1.8836 - gen_gan_loss: 0.3669 - gen_l1_loss: 0.0152 - disc_loss: 0.4193 - accuracy: 0.9785 - SSIM_loss: 0.0359 - val_accuracy: 0.9829 - val_SSIM_loss: 0.0243
# Epoch 182/200
# 360/360 [==============================] - 72s 201ms/step - gen_total_loss: 1.8192 - gen_gan_loss: 0.3200 - gen_l1_loss: 0.0150 - disc_loss: 0.4790 - accuracy: 0.9792 - SSIM_loss: 0.0357 - val_accuracy: 0.9865 - val_SSIM_loss: 0.0255
# Epoch 183/200
# 360/360 [==============================] - 72s 200ms/step - gen_total_loss: 1.8825 - gen_gan_loss: 0.3455 - gen_l1_loss: 0.0154 - disc_loss: 0.4333 - accuracy: 0.9783 - SSIM_loss: 0.0362 - val_accuracy: 0.9873 - val_SSIM_loss: 0.0244
# Epoch 184/200
# 360/360 [==============================] - 80s 223ms/step - gen_total_loss: 1.8835 - gen_gan_loss: 0.3580 - gen_l1_loss: 0.0153 - disc_loss: 0.4250 - accuracy: 0.9786 - SSIM_loss: 0.0361 - val_accuracy: 0.9809 - val_SSIM_loss: 0.0248
# Epoch 185/200
# 360/360 [==============================] - 78s 217ms/step - gen_total_loss: 1.8625 - gen_gan_loss: 0.3616 - gen_l1_loss: 0.0150 - disc_loss: 0.4223 - accuracy: 0.9787 - SSIM_loss: 0.0356 - val_accuracy: 0.9814 - val_SSIM_loss: 0.0245
# Epoch 186/200
# 360/360 [==============================] - 79s 219ms/step - gen_total_loss: 1.9000 - gen_gan_loss: 0.3639 - gen_l1_loss: 0.0154 - disc_loss: 0.4210 - accuracy: 0.9785 - SSIM_loss: 0.0362 - val_accuracy: 0.9858 - val_SSIM_loss: 0.0257
# Epoch 187/200
# 360/360 [==============================] - 80s 221ms/step - gen_total_loss: 1.8825 - gen_gan_loss: 0.3652 - gen_l1_loss: 0.0152 - disc_loss: 0.4201 - accuracy: 0.9785 - SSIM_loss: 0.0360 - val_accuracy: 0.9808 - val_SSIM_loss: 0.0255
# Epoch 188/200
# 360/360 [==============================] - 79s 219ms/step - gen_total_loss: 1.8757 - gen_gan_loss: 0.3652 - gen_l1_loss: 0.0151 - disc_loss: 0.4203 - accuracy: 0.9785 - SSIM_loss: 0.0358 - val_accuracy: 0.9808 - val_SSIM_loss: 0.0255
# Epoch 189/200
# 360/360 [==============================] - 79s 221ms/step - gen_total_loss: 1.9043 - gen_gan_loss: 0.3660 - gen_l1_loss: 0.0154 - disc_loss: 0.4199 - accuracy: 0.9780 - SSIM_loss: 0.0362 - val_accuracy: 0.9819 - val_SSIM_loss: 0.0251
# Epoch 190/200
# 360/360 [==============================] - 80s 221ms/step - gen_total_loss: 1.8946 - gen_gan_loss: 0.3923 - gen_l1_loss: 0.0150 - disc_loss: 0.5924 - accuracy: 0.9794 - SSIM_loss: 0.0359 - val_accuracy: 0.9847 - val_SSIM_loss: 0.0265
# Epoch 191/200
# 360/360 [==============================] - 79s 220ms/step - gen_total_loss: 1.8121 - gen_gan_loss: 0.3029 - gen_l1_loss: 0.0151 - disc_loss: 0.4662 - accuracy: 0.9793 - SSIM_loss: 0.0357 - val_accuracy: 0.9872 - val_SSIM_loss: 0.0256
# Epoch 192/200
# 360/360 [==============================] - 80s 222ms/step - gen_total_loss: 1.8314 - gen_gan_loss: 0.3098 - gen_l1_loss: 0.0152 - disc_loss: 0.4584 - accuracy: 0.9787 - SSIM_loss: 0.0361 - val_accuracy: 0.9873 - val_SSIM_loss: 0.0261
# Epoch 193/200
# 360/360 [==============================] - 80s 222ms/step - gen_total_loss: 1.8168 - gen_gan_loss: 0.3138 - gen_l1_loss: 0.0150 - disc_loss: 0.4544 - accuracy: 0.9790 - SSIM_loss: 0.0356 - val_accuracy: 0.9824 - val_SSIM_loss: 0.0268
# Epoch 194/200
# 360/360 [==============================] - 80s 222ms/step - gen_total_loss: 1.8321 - gen_gan_loss: 0.3192 - gen_l1_loss: 0.0151 - disc_loss: 0.4504 - accuracy: 0.9788 - SSIM_loss: 0.0358 - val_accuracy: 0.9862 - val_SSIM_loss: 0.0256
# Epoch 195/200
# 360/360 [==============================] - 80s 221ms/step - gen_total_loss: 1.8280 - gen_gan_loss: 0.3249 - gen_l1_loss: 0.0150 - disc_loss: 0.4518 - accuracy: 0.9786 - SSIM_loss: 0.0356 - val_accuracy: 0.9827 - val_SSIM_loss: 0.0258
# Epoch 196/200
# 360/360 [==============================] - 79s 219ms/step - gen_total_loss: 1.8629 - gen_gan_loss: 0.3290 - gen_l1_loss: 0.0153 - disc_loss: 0.4433 - accuracy: 0.9786 - SSIM_loss: 0.0362 - val_accuracy: 0.9873 - val_SSIM_loss: 0.0257
# Epoch 197/200
# 360/360 [==============================] - 80s 221ms/step - gen_total_loss: 1.8264 - gen_gan_loss: 0.3329 - gen_l1_loss: 0.0149 - disc_loss: 0.4407 - accuracy: 0.9790 - SSIM_loss: 0.0353 - val_accuracy: 0.9791 - val_SSIM_loss: 0.0255
# Epoch 198/200
# 360/360 [==============================] - 79s 220ms/step - gen_total_loss: 1.8508 - gen_gan_loss: 0.3366 - gen_l1_loss: 0.0151 - disc_loss: 0.4385 - accuracy: 0.9782 - SSIM_loss: 0.0359 - val_accuracy: 0.9797 - val_SSIM_loss: 0.0257
# Epoch 199/200
# 360/360 [==============================] - 78s 218ms/step - gen_total_loss: 1.8571 - gen_gan_loss: 0.3400 - gen_l1_loss: 0.0152 - disc_loss: 0.4358 - accuracy: 0.9787 - SSIM_loss: 0.0357 - val_accuracy: 0.9866 - val_SSIM_loss: 0.0245
# Epoch 200/200
# 360/360 [==============================] - 75s 207ms/step - gen_total_loss: 1.8335 - gen_gan_loss: 0.3431 - gen_l1_loss: 0.0149 - disc_loss: 0.4343 - accuracy: 0.9787 - SSIM_loss: 0.0354 - val_accuracy: 0.9880 - val_SSIM_loss: 0.0245
