# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()
import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns
from datetime import datetime
import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='default_model_v1'
    
    __changes__="Default model"
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    
    __normalization__='[-1,1]'
    
    @staticmethod
    def discriminator():
        def main():
            last_img = Input(shape=image_shape)
            first_img = Input(shape=image_shape)

            # Concatenate image and conditioning image by channels to produce input
            combined_imgs = Concatenate(axis=-1)([last_img, first_img])

            d1 = Conv2D(32, (3, 3), strides=(2,2), padding='same')(combined_imgs) 
            d1 = Activation('relu')(d1) 
            d2 = Conv2D(64, (3, 3), strides=(2,2), padding='same')(d1)
            d2 = Activation('relu')(d2) 
            d3 = Conv2D(128, (3, 3), strides=(2,2), padding='same')(d2)
            d3 = Activation('relu')(d3) 

            validity = Conv2D(1, (3, 3), strides=(2,2), padding='same')(d3)

            model = Model([last_img, first_img], validity)
            return model
        return main()
    
    @staticmethod
    def generator():
        latent_dim = 128
        def encoder(input_tensor, n_filters, kernel_size=4, strides=2,batchnorm=True, dropout=True):
            initializer = tf.random_normal_initializer(0., 0.02)
            # first layer
            x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer="he_normal",
                   padding="same", strides=strides)(input_tensor)

            if batchnorm:
                x = BatchNormalization()(x)
            if dropout:
                x = Dropout(0.5)(x)
            x = LeakyReLU(alpha=0.2)(x)
            return x

        def decoder(input_tensor, skip_in,  n_filters, kernel_size=4, strides=2,batchnorm=True, dropout=True):
            initializer = tf.random_normal_initializer(0., 0.02)
            x = Conv2DTranspose(n_filters, kernel_size=kernel_size, padding='same', strides=strides, kernel_initializer=initializer)(input_tensor)
            if batchnorm:
                x = BatchNormalization()(x)
            if dropout:
                x = Dropout(0.5)(x)
            x = Concatenate()([x, skip_in])
            x = LeakyReLU(alpha=0.2)(x)
            return x

        def main():
            inputs = Input(shape=image_shape)

            e1 = encoder(inputs, 32, batchnorm=False)
            e2 = encoder(e1, 64)
            e3 = encoder(e2, 128)
            e4 = encoder(e3, 128)

            b = Conv2D(128, kernel_size=4, strides=2, padding='same')(e4)
            b = LeakyReLU(alpha=0.2)(b)

            u1 = decoder(b,e4, 128)
            u2 = decoder(u1,e3, 128, dropout=False)
            u3 = decoder(u2,e2, 64, dropout=False)
            u4 = decoder(u3,e1, 32, dropout=False)

            classify = Conv2DTranspose(3, kernel_size=2,  strides=(2,2), activation='tanh')(u4)
            model = Model(inputs=inputs, outputs=classify, name='Generator')
            return model
        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        LAMBDA = 100
        def generator_loss(disc_generated_output, gen_output, target): # https://arxiv.org/abs/1611.07004
            gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

            # mean absolute error
            l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

            total_gen_loss = gan_loss + (LAMBDA * l1_loss)

            return total_gen_loss, gan_loss, l1_loss

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss

        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__)
# Out:
# train_x (30, 128, 128, 3) float32 -1.0 1.0
# train_y (30, 128, 128, 3) float32 -1.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss(disc_generated_output, gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(gen_total_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'gen_total_loss':gen_total_loss,
                'gen_gan_loss':gen_gan_loss,
                'gen_l1_loss':gen_l1_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')
file_writer = tf.summary.create_file_writer(log_dir + "/plots/")

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - gen_total_loss: 87.8388 - gen_gan_loss: 0.7012 - gen_l1_loss: 0.8714 - disc_loss: 1.4112 - accuracy: 0.3225 - SSIM_loss: 0.9925WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/360 [..............................] - ETA: 1:15 - gen_total_loss: 87.2041 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.8651 - disc_loss: 1.3920 - accuracy: 0.3259 - SSIM_loss: 0.9922WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1022s vs `on_train_batch_end` time: 0.3201s). Check your callbacks.
# 360/360 [==============================] - 84s 234ms/step - gen_total_loss: 29.2189 - gen_gan_loss: 3.2341 - gen_l1_loss: 0.2598 - disc_loss: 0.4334 - accuracy: 0.4405 - SSIM_loss: 0.7498 - val_accuracy: 0.4409 - val_SSIM_loss: 0.0739
# Epoch 2/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 8.0523 - gen_gan_loss: 1.2733 - gen_l1_loss: 0.0678 - disc_loss: 1.0711 - accuracy: 0.4715 - SSIM_loss: 0.2275 - val_accuracy: 0.7177 - val_SSIM_loss: 0.0595
# Epoch 3/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 6.3120 - gen_gan_loss: 0.9845 - gen_l1_loss: 0.0533 - disc_loss: 1.2236 - accuracy: 0.4826 - SSIM_loss: 0.1217 - val_accuracy: 0.7146 - val_SSIM_loss: 0.0614
# Epoch 4/200
# 360/360 [==============================] - 157s 437ms/step - gen_total_loss: 5.7612 - gen_gan_loss: 0.8956 - gen_l1_loss: 0.0487 - disc_loss: 1.2711 - accuracy: 0.4823 - SSIM_loss: 0.0948 - val_accuracy: 0.7365 - val_SSIM_loss: 0.0850
# Epoch 5/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 5.4770 - gen_gan_loss: 0.8787 - gen_l1_loss: 0.0460 - disc_loss: 1.2793 - accuracy: 0.4809 - SSIM_loss: 0.0865 - val_accuracy: 0.7109 - val_SSIM_loss: 0.1639
# Epoch 6/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 5.1670 - gen_gan_loss: 0.8566 - gen_l1_loss: 0.0431 - disc_loss: 1.3026 - accuracy: 0.4852 - SSIM_loss: 0.0821 - val_accuracy: 0.7515 - val_SSIM_loss: 0.1767
# Epoch 7/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 4.9173 - gen_gan_loss: 0.8283 - gen_l1_loss: 0.0409 - disc_loss: 1.3084 - accuracy: 0.4918 - SSIM_loss: 0.0773 - val_accuracy: 0.5358 - val_SSIM_loss: 0.1507
# Epoch 8/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 4.7465 - gen_gan_loss: 0.8100 - gen_l1_loss: 0.0394 - disc_loss: 1.3164 - accuracy: 0.5026 - SSIM_loss: 0.0741 - val_accuracy: 0.5516 - val_SSIM_loss: 0.1573
# Epoch 9/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 4.5717 - gen_gan_loss: 0.8021 - gen_l1_loss: 0.0377 - disc_loss: 1.3182 - accuracy: 0.5145 - SSIM_loss: 0.0713 - val_accuracy: 0.5599 - val_SSIM_loss: 0.1675
# Epoch 10/200
# 360/360 [==============================] - 159s 443ms/step - gen_total_loss: 4.4855 - gen_gan_loss: 0.8002 - gen_l1_loss: 0.0369 - disc_loss: 1.3196 - accuracy: 0.5261 - SSIM_loss: 0.0697 - val_accuracy: 0.6147 - val_SSIM_loss: 0.1494
# Epoch 11/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 4.3774 - gen_gan_loss: 0.7973 - gen_l1_loss: 0.0358 - disc_loss: 1.3233 - accuracy: 0.5346 - SSIM_loss: 0.0680 - val_accuracy: 0.7205 - val_SSIM_loss: 0.1515
# Epoch 12/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 4.2645 - gen_gan_loss: 0.7890 - gen_l1_loss: 0.0348 - disc_loss: 1.3302 - accuracy: 0.5441 - SSIM_loss: 0.0664 - val_accuracy: 0.6611 - val_SSIM_loss: 0.1314
# Epoch 13/200
# 360/360 [==============================] - 159s 442ms/step - gen_total_loss: 4.2288 - gen_gan_loss: 0.7941 - gen_l1_loss: 0.0343 - disc_loss: 1.3187 - accuracy: 0.5559 - SSIM_loss: 0.0656 - val_accuracy: 0.6636 - val_SSIM_loss: 0.1401
# Epoch 14/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 4.1492 - gen_gan_loss: 0.7937 - gen_l1_loss: 0.0336 - disc_loss: 1.3216 - accuracy: 0.5653 - SSIM_loss: 0.0642 - val_accuracy: 0.6981 - val_SSIM_loss: 0.1573
# Epoch 15/200
# 360/360 [==============================] - 158s 439ms/step - gen_total_loss: 4.0846 - gen_gan_loss: 0.7958 - gen_l1_loss: 0.0329 - disc_loss: 1.3184 - accuracy: 0.5716 - SSIM_loss: 0.0631 - val_accuracy: 0.5114 - val_SSIM_loss: 0.1419
# Epoch 16/200
# 360/360 [==============================] - 159s 442ms/step - gen_total_loss: 4.0258 - gen_gan_loss: 0.8051 - gen_l1_loss: 0.0322 - disc_loss: 1.3181 - accuracy: 0.5787 - SSIM_loss: 0.0621 - val_accuracy: 0.6637 - val_SSIM_loss: 0.1297
# Epoch 17/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 4.0069 - gen_gan_loss: 0.8074 - gen_l1_loss: 0.0320 - disc_loss: 1.3116 - accuracy: 0.5922 - SSIM_loss: 0.0614 - val_accuracy: 0.8030 - val_SSIM_loss: 0.1080
# Epoch 18/200
# 360/360 [==============================] - 153s 425ms/step - gen_total_loss: 3.9098 - gen_gan_loss: 0.8141 - gen_l1_loss: 0.0310 - disc_loss: 1.3077 - accuracy: 0.6007 - SSIM_loss: 0.0600 - val_accuracy: 0.7309 - val_SSIM_loss: 0.1141
# Epoch 19/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 3.8771 - gen_gan_loss: 0.8093 - gen_l1_loss: 0.0307 - disc_loss: 1.3121 - accuracy: 0.6103 - SSIM_loss: 0.0594 - val_accuracy: 0.7167 - val_SSIM_loss: 0.1250
# Epoch 20/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 3.9050 - gen_gan_loss: 0.8309 - gen_l1_loss: 0.0307 - disc_loss: 1.2986 - accuracy: 0.6122 - SSIM_loss: 0.0591 - val_accuracy: 0.6794 - val_SSIM_loss: 0.1311
# Epoch 21/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 3.8388 - gen_gan_loss: 0.8362 - gen_l1_loss: 0.0300 - disc_loss: 1.2943 - accuracy: 0.6187 - SSIM_loss: 0.0581 - val_accuracy: 0.7519 - val_SSIM_loss: 0.1235
# Epoch 22/200
# 360/360 [==============================] - 159s 442ms/step - gen_total_loss: 3.7956 - gen_gan_loss: 0.8465 - gen_l1_loss: 0.0295 - disc_loss: 1.2886 - accuracy: 0.6235 - SSIM_loss: 0.0573 - val_accuracy: 0.7002 - val_SSIM_loss: 0.1149
# Epoch 23/200
# 360/360 [==============================] - 153s 425ms/step - gen_total_loss: 3.7705 - gen_gan_loss: 0.8621 - gen_l1_loss: 0.0291 - disc_loss: 1.2910 - accuracy: 0.6192 - SSIM_loss: 0.0565 - val_accuracy: 0.6109 - val_SSIM_loss: 0.1151
# Epoch 24/200
# 360/360 [==============================] - 152s 422ms/step - gen_total_loss: 3.6974 - gen_gan_loss: 0.8311 - gen_l1_loss: 0.0287 - disc_loss: 1.2858 - accuracy: 0.6468 - SSIM_loss: 0.0558 - val_accuracy: 0.6665 - val_SSIM_loss: 0.1071
# Epoch 25/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 3.6880 - gen_gan_loss: 0.8703 - gen_l1_loss: 0.0282 - disc_loss: 1.2735 - accuracy: 0.6359 - SSIM_loss: 0.0551 - val_accuracy: 0.6649 - val_SSIM_loss: 0.1136
# Epoch 26/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 3.6956 - gen_gan_loss: 0.9018 - gen_l1_loss: 0.0279 - disc_loss: 1.2578 - accuracy: 0.6330 - SSIM_loss: 0.0545 - val_accuracy: 0.8116 - val_SSIM_loss: 0.0938
# Epoch 27/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 3.6719 - gen_gan_loss: 0.8735 - gen_l1_loss: 0.0280 - disc_loss: 1.2719 - accuracy: 0.6544 - SSIM_loss: 0.0544 - val_accuracy: 0.7001 - val_SSIM_loss: 0.0957
# Epoch 28/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 3.6645 - gen_gan_loss: 0.9246 - gen_l1_loss: 0.0274 - disc_loss: 1.2443 - accuracy: 0.6333 - SSIM_loss: 0.0534 - val_accuracy: 0.7354 - val_SSIM_loss: 0.0843
# Epoch 29/200
# 360/360 [==============================] - 151s 419ms/step - gen_total_loss: 3.6614 - gen_gan_loss: 0.9462 - gen_l1_loss: 0.0272 - disc_loss: 1.2343 - accuracy: 0.6154 - SSIM_loss: 0.0531 - val_accuracy: 0.7859 - val_SSIM_loss: 0.0881
# Epoch 30/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 3.6085 - gen_gan_loss: 0.9363 - gen_l1_loss: 0.0267 - disc_loss: 1.2394 - accuracy: 0.6081 - SSIM_loss: 0.0524 - val_accuracy: 0.6710 - val_SSIM_loss: 0.0838
# Epoch 31/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 3.5942 - gen_gan_loss: 0.9528 - gen_l1_loss: 0.0264 - disc_loss: 1.2358 - accuracy: 0.6074 - SSIM_loss: 0.0518 - val_accuracy: 0.8410 - val_SSIM_loss: 0.0757
# Epoch 32/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 3.5950 - gen_gan_loss: 0.9990 - gen_l1_loss: 0.0260 - disc_loss: 1.2063 - accuracy: 0.5923 - SSIM_loss: 0.0508 - val_accuracy: 0.8115 - val_SSIM_loss: 0.0824
# Epoch 33/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 3.6532 - gen_gan_loss: 1.0286 - gen_l1_loss: 0.0262 - disc_loss: 1.1966 - accuracy: 0.5553 - SSIM_loss: 0.0511 - val_accuracy: 0.6894 - val_SSIM_loss: 0.0674
# Epoch 34/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 3.5843 - gen_gan_loss: 1.0127 - gen_l1_loss: 0.0257 - disc_loss: 1.2095 - accuracy: 0.5657 - SSIM_loss: 0.0501 - val_accuracy: 0.5399 - val_SSIM_loss: 0.0724
# Epoch 35/200
# 360/360 [==============================] - 153s 426ms/step - gen_total_loss: 3.5967 - gen_gan_loss: 1.0367 - gen_l1_loss: 0.0256 - disc_loss: 1.2035 - accuracy: 0.5445 - SSIM_loss: 0.0499 - val_accuracy: 0.7142 - val_SSIM_loss: 0.0703
# Epoch 36/200
# 360/360 [==============================] - 155s 432ms/step - gen_total_loss: 3.5431 - gen_gan_loss: 0.9969 - gen_l1_loss: 0.0255 - disc_loss: 1.2088 - accuracy: 0.6017 - SSIM_loss: 0.0494 - val_accuracy: 0.7112 - val_SSIM_loss: 0.0698
# Epoch 37/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 3.5613 - gen_gan_loss: 1.0648 - gen_l1_loss: 0.0250 - disc_loss: 1.1830 - accuracy: 0.5848 - SSIM_loss: 0.0489 - val_accuracy: 0.7197 - val_SSIM_loss: 0.0693
# Epoch 38/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 3.6269 - gen_gan_loss: 1.1268 - gen_l1_loss: 0.0250 - disc_loss: 1.1602 - accuracy: 0.5470 - SSIM_loss: 0.0490 - val_accuracy: 0.6041 - val_SSIM_loss: 0.0668
# Epoch 39/200
# 360/360 [==============================] - 158s 438ms/step - gen_total_loss: 3.6648 - gen_gan_loss: 1.1740 - gen_l1_loss: 0.0249 - disc_loss: 1.1401 - accuracy: 0.5091 - SSIM_loss: 0.0486 - val_accuracy: 0.3774 - val_SSIM_loss: 0.0644
# Epoch 40/200
# 360/360 [==============================] - 152s 423ms/step - gen_total_loss: 3.5449 - gen_gan_loss: 1.0853 - gen_l1_loss: 0.0246 - disc_loss: 1.1882 - accuracy: 0.5094 - SSIM_loss: 0.0481 - val_accuracy: 0.3161 - val_SSIM_loss: 0.0602
# Epoch 41/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 3.5496 - gen_gan_loss: 1.1488 - gen_l1_loss: 0.0240 - disc_loss: 1.1533 - accuracy: 0.5180 - SSIM_loss: 0.0474 - val_accuracy: 0.4494 - val_SSIM_loss: 0.0641
# Epoch 42/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 3.5848 - gen_gan_loss: 1.1615 - gen_l1_loss: 0.0242 - disc_loss: 1.1841 - accuracy: 0.4948 - SSIM_loss: 0.0474 - val_accuracy: 0.4862 - val_SSIM_loss: 0.0617
# Epoch 43/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 3.6935 - gen_gan_loss: 1.2515 - gen_l1_loss: 0.0244 - disc_loss: 1.1215 - accuracy: 0.4911 - SSIM_loss: 0.0478 - val_accuracy: 0.4849 - val_SSIM_loss: 0.0616
# Epoch 44/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 3.6339 - gen_gan_loss: 1.2383 - gen_l1_loss: 0.0240 - disc_loss: 1.1428 - accuracy: 0.4906 - SSIM_loss: 0.0473 - val_accuracy: 0.3972 - val_SSIM_loss: 0.0590
# Epoch 45/200
# 360/360 [==============================] - 153s 425ms/step - gen_total_loss: 3.5836 - gen_gan_loss: 1.2156 - gen_l1_loss: 0.0237 - disc_loss: 1.1371 - accuracy: 0.5652 - SSIM_loss: 0.0468 - val_accuracy: 0.4222 - val_SSIM_loss: 0.0595
# Epoch 46/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 3.6934 - gen_gan_loss: 1.2928 - gen_l1_loss: 0.0240 - disc_loss: 1.1127 - accuracy: 0.5830 - SSIM_loss: 0.0472 - val_accuracy: 0.5113 - val_SSIM_loss: 0.0594
# Epoch 47/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 3.7046 - gen_gan_loss: 1.3710 - gen_l1_loss: 0.0233 - disc_loss: 1.0902 - accuracy: 0.5501 - SSIM_loss: 0.0468 - val_accuracy: 0.6057 - val_SSIM_loss: 0.0615
# Epoch 48/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 3.6301 - gen_gan_loss: 1.2878 - gen_l1_loss: 0.0234 - disc_loss: 1.1344 - accuracy: 0.5385 - SSIM_loss: 0.0469 - val_accuracy: 0.5943 - val_SSIM_loss: 0.0602
# Epoch 49/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 3.7096 - gen_gan_loss: 1.3843 - gen_l1_loss: 0.0233 - disc_loss: 1.0864 - accuracy: 0.4980 - SSIM_loss: 0.0469 - val_accuracy: 0.4037 - val_SSIM_loss: 0.0629
# Epoch 50/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 3.7239 - gen_gan_loss: 1.3902 - gen_l1_loss: 0.0233 - disc_loss: 1.0899 - accuracy: 0.5075 - SSIM_loss: 0.0473 - val_accuracy: 0.4717 - val_SSIM_loss: 0.0642
# Epoch 51/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 3.7523 - gen_gan_loss: 1.4215 - gen_l1_loss: 0.0233 - disc_loss: 1.0786 - accuracy: 0.5169 - SSIM_loss: 0.0471 - val_accuracy: 0.4520 - val_SSIM_loss: 0.0625
# Epoch 52/200
# 360/360 [==============================] - 155s 432ms/step - gen_total_loss: 3.8188 - gen_gan_loss: 1.4746 - gen_l1_loss: 0.0234 - disc_loss: 1.0584 - accuracy: 0.5275 - SSIM_loss: 0.0486 - val_accuracy: 0.3993 - val_SSIM_loss: 0.0623
# Epoch 53/200
# 360/360 [==============================] - 155s 432ms/step - gen_total_loss: 3.8293 - gen_gan_loss: 1.4675 - gen_l1_loss: 0.0236 - disc_loss: 1.0603 - accuracy: 0.5365 - SSIM_loss: 0.0488 - val_accuracy: 0.4611 - val_SSIM_loss: 0.0669
# Epoch 54/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 3.6842 - gen_gan_loss: 1.3595 - gen_l1_loss: 0.0232 - disc_loss: 1.1544 - accuracy: 0.5496 - SSIM_loss: 0.0477 - val_accuracy: 0.4405 - val_SSIM_loss: 0.0625
# Epoch 55/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 3.4382 - gen_gan_loss: 1.1793 - gen_l1_loss: 0.0226 - disc_loss: 1.1488 - accuracy: 0.5550 - SSIM_loss: 0.0454 - val_accuracy: 0.4978 - val_SSIM_loss: 0.0593
# Epoch 56/200
# 360/360 [==============================] - 154s 429ms/step - gen_total_loss: 3.6828 - gen_gan_loss: 1.3984 - gen_l1_loss: 0.0228 - disc_loss: 1.0759 - accuracy: 0.5517 - SSIM_loss: 0.0466 - val_accuracy: 0.5017 - val_SSIM_loss: 0.0634
# Epoch 57/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 3.6616 - gen_gan_loss: 1.4323 - gen_l1_loss: 0.0223 - disc_loss: 1.0710 - accuracy: 0.5495 - SSIM_loss: 0.0464 - val_accuracy: 0.6214 - val_SSIM_loss: 0.0701
# Epoch 58/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 3.6733 - gen_gan_loss: 1.4413 - gen_l1_loss: 0.0223 - disc_loss: 1.0688 - accuracy: 0.5771 - SSIM_loss: 0.0467 - val_accuracy: 0.6249 - val_SSIM_loss: 0.0654
# Epoch 59/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 3.8174 - gen_gan_loss: 1.4938 - gen_l1_loss: 0.0232 - disc_loss: 1.0436 - accuracy: 0.5735 - SSIM_loss: 0.0486 - val_accuracy: 0.6080 - val_SSIM_loss: 0.0671
# Epoch 60/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 3.7724 - gen_gan_loss: 1.5137 - gen_l1_loss: 0.0226 - disc_loss: 1.0427 - accuracy: 0.5819 - SSIM_loss: 0.0476 - val_accuracy: 0.5152 - val_SSIM_loss: 0.0656
# Epoch 61/200
# 360/360 [==============================] - 151s 419ms/step - gen_total_loss: 3.7963 - gen_gan_loss: 1.5180 - gen_l1_loss: 0.0228 - disc_loss: 1.0405 - accuracy: 0.5871 - SSIM_loss: 0.0480 - val_accuracy: 0.5750 - val_SSIM_loss: 0.0685
# Epoch 62/200
# 360/360 [==============================] - 158s 438ms/step - gen_total_loss: 3.8184 - gen_gan_loss: 1.5380 - gen_l1_loss: 0.0228 - disc_loss: 1.0379 - accuracy: 0.5866 - SSIM_loss: 0.0483 - val_accuracy: 0.5304 - val_SSIM_loss: 0.0665
# Epoch 63/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 3.7347 - gen_gan_loss: 1.4789 - gen_l1_loss: 0.0226 - disc_loss: 1.0603 - accuracy: 0.5884 - SSIM_loss: 0.0476 - val_accuracy: 0.6449 - val_SSIM_loss: 0.0649
# Epoch 64/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 3.7386 - gen_gan_loss: 1.5162 - gen_l1_loss: 0.0222 - disc_loss: 1.0451 - accuracy: 0.6076 - SSIM_loss: 0.0467 - val_accuracy: 0.5634 - val_SSIM_loss: 0.0711
# Epoch 65/200
# 360/360 [==============================] - 154s 429ms/step - gen_total_loss: 3.8720 - gen_gan_loss: 1.5801 - gen_l1_loss: 0.0229 - disc_loss: 1.0289 - accuracy: 0.5827 - SSIM_loss: 0.0488 - val_accuracy: 0.6291 - val_SSIM_loss: 0.0689
# Epoch 66/200
# 360/360 [==============================] - 152s 423ms/step - gen_total_loss: 3.8755 - gen_gan_loss: 1.5961 - gen_l1_loss: 0.0228 - disc_loss: 1.0173 - accuracy: 0.5820 - SSIM_loss: 0.0495 - val_accuracy: 0.5583 - val_SSIM_loss: 0.0671
# Epoch 67/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 3.2363 - gen_gan_loss: 1.0645 - gen_l1_loss: 0.0217 - disc_loss: 1.2653 - accuracy: 0.6017 - SSIM_loss: 0.0440 - val_accuracy: 0.7469 - val_SSIM_loss: 0.0642
# Epoch 68/200
# 360/360 [==============================] - 157s 437ms/step - gen_total_loss: 3.5686 - gen_gan_loss: 1.4275 - gen_l1_loss: 0.0214 - disc_loss: 1.0530 - accuracy: 0.6146 - SSIM_loss: 0.0444 - val_accuracy: 0.4577 - val_SSIM_loss: 0.0655
# Epoch 69/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 3.4766 - gen_gan_loss: 1.3153 - gen_l1_loss: 0.0216 - disc_loss: 1.1221 - accuracy: 0.6381 - SSIM_loss: 0.0449 - val_accuracy: 0.7035 - val_SSIM_loss: 0.0589
# Epoch 70/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 3.5931 - gen_gan_loss: 1.3988 - gen_l1_loss: 0.0219 - disc_loss: 1.0718 - accuracy: 0.6441 - SSIM_loss: 0.0459 - val_accuracy: 0.6690 - val_SSIM_loss: 0.0693
# Epoch 71/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 3.7509 - gen_gan_loss: 1.5298 - gen_l1_loss: 0.0222 - disc_loss: 1.0214 - accuracy: 0.6259 - SSIM_loss: 0.0484 - val_accuracy: 0.5431 - val_SSIM_loss: 0.0710
# Epoch 72/200
# 360/360 [==============================] - 149s 414ms/step - gen_total_loss: 3.6788 - gen_gan_loss: 1.4865 - gen_l1_loss: 0.0219 - disc_loss: 1.0425 - accuracy: 0.6340 - SSIM_loss: 0.0476 - val_accuracy: 0.7230 - val_SSIM_loss: 0.0702
# Epoch 73/200
# 360/360 [==============================] - 158s 439ms/step - gen_total_loss: 3.7992 - gen_gan_loss: 1.5774 - gen_l1_loss: 0.0222 - disc_loss: 1.0102 - accuracy: 0.6298 - SSIM_loss: 0.0488 - val_accuracy: 0.5464 - val_SSIM_loss: 0.0719
# Epoch 74/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 3.8205 - gen_gan_loss: 1.5860 - gen_l1_loss: 0.0223 - disc_loss: 1.0182 - accuracy: 0.6335 - SSIM_loss: 0.0484 - val_accuracy: 0.7209 - val_SSIM_loss: 0.0666
# Epoch 75/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 3.5924 - gen_gan_loss: 1.4599 - gen_l1_loss: 0.0213 - disc_loss: 1.0596 - accuracy: 0.6591 - SSIM_loss: 0.0455 - val_accuracy: 0.5661 - val_SSIM_loss: 0.0644
# Epoch 76/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 3.7539 - gen_gan_loss: 1.5766 - gen_l1_loss: 0.0218 - disc_loss: 1.0213 - accuracy: 0.6552 - SSIM_loss: 0.0470 - val_accuracy: 0.5806 - val_SSIM_loss: 0.0679
# Epoch 77/200
# 360/360 [==============================] - 152s 424ms/step - gen_total_loss: 3.6821 - gen_gan_loss: 1.5579 - gen_l1_loss: 0.0212 - disc_loss: 1.0342 - accuracy: 0.6710 - SSIM_loss: 0.0456 - val_accuracy: 0.6889 - val_SSIM_loss: 0.0677
# Epoch 78/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.8281 - gen_gan_loss: 1.6257 - gen_l1_loss: 0.0220 - disc_loss: 1.0126 - accuracy: 0.6793 - SSIM_loss: 0.0478 - val_accuracy: 0.6643 - val_SSIM_loss: 0.0725
# Epoch 79/200
# 360/360 [==============================] - 63s 176ms/step - gen_total_loss: 3.7817 - gen_gan_loss: 1.6026 - gen_l1_loss: 0.0218 - disc_loss: 1.0122 - accuracy: 0.6874 - SSIM_loss: 0.0482 - val_accuracy: 0.7528 - val_SSIM_loss: 0.0686
# Epoch 80/200
# 360/360 [==============================] - 67s 186ms/step - gen_total_loss: 3.7522 - gen_gan_loss: 1.5868 - gen_l1_loss: 0.0217 - disc_loss: 1.0163 - accuracy: 0.7017 - SSIM_loss: 0.0476 - val_accuracy: 0.7060 - val_SSIM_loss: 0.0705
# Epoch 81/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 3.7156 - gen_gan_loss: 1.5876 - gen_l1_loss: 0.0213 - disc_loss: 1.0156 - accuracy: 0.6959 - SSIM_loss: 0.0468 - val_accuracy: 0.7685 - val_SSIM_loss: 0.0699
# Epoch 82/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 3.7480 - gen_gan_loss: 1.6232 - gen_l1_loss: 0.0212 - disc_loss: 1.0088 - accuracy: 0.7130 - SSIM_loss: 0.0472 - val_accuracy: 0.6867 - val_SSIM_loss: 0.0741
# Epoch 83/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.8344 - gen_gan_loss: 1.6430 - gen_l1_loss: 0.0219 - disc_loss: 0.9980 - accuracy: 0.7106 - SSIM_loss: 0.0489 - val_accuracy: 0.8292 - val_SSIM_loss: 0.0687
# Epoch 84/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.1566 - gen_gan_loss: 1.1334 - gen_l1_loss: 0.0202 - disc_loss: 1.2424 - accuracy: 0.7105 - SSIM_loss: 0.0417 - val_accuracy: 0.7525 - val_SSIM_loss: 0.0652
# Epoch 85/200
# 360/360 [==============================] - 98s 271ms/step - gen_total_loss: 3.6334 - gen_gan_loss: 1.5836 - gen_l1_loss: 0.0205 - disc_loss: 1.0166 - accuracy: 0.6690 - SSIM_loss: 0.0442 - val_accuracy: 0.7551 - val_SSIM_loss: 0.0716
# Epoch 86/200
# 360/360 [==============================] - 98s 271ms/step - gen_total_loss: 3.7649 - gen_gan_loss: 1.6132 - gen_l1_loss: 0.0215 - disc_loss: 1.0041 - accuracy: 0.6713 - SSIM_loss: 0.0478 - val_accuracy: 0.5573 - val_SSIM_loss: 0.0713
# Epoch 87/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 3.7454 - gen_gan_loss: 1.6238 - gen_l1_loss: 0.0212 - disc_loss: 0.9997 - accuracy: 0.6553 - SSIM_loss: 0.0474 - val_accuracy: 0.6531 - val_SSIM_loss: 0.0706
# Epoch 88/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.5798 - gen_gan_loss: 1.4839 - gen_l1_loss: 0.0210 - disc_loss: 1.0978 - accuracy: 0.6617 - SSIM_loss: 0.0460 - val_accuracy: 0.7951 - val_SSIM_loss: 0.0586
# Epoch 89/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.4024 - gen_gan_loss: 1.3848 - gen_l1_loss: 0.0202 - disc_loss: 1.0722 - accuracy: 0.6584 - SSIM_loss: 0.0428 - val_accuracy: 0.6722 - val_SSIM_loss: 0.0720
# Epoch 90/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.4447 - gen_gan_loss: 1.4206 - gen_l1_loss: 0.0202 - disc_loss: 1.0816 - accuracy: 0.6439 - SSIM_loss: 0.0439 - val_accuracy: 0.6938 - val_SSIM_loss: 0.0656
# Epoch 91/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 3.6341 - gen_gan_loss: 1.5840 - gen_l1_loss: 0.0205 - disc_loss: 1.0222 - accuracy: 0.6450 - SSIM_loss: 0.0451 - val_accuracy: 0.6451 - val_SSIM_loss: 0.0699
# Epoch 92/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.5533 - gen_gan_loss: 1.5216 - gen_l1_loss: 0.0203 - disc_loss: 1.0497 - accuracy: 0.6489 - SSIM_loss: 0.0443 - val_accuracy: 0.4895 - val_SSIM_loss: 0.0676
# Epoch 93/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 3.6695 - gen_gan_loss: 1.6130 - gen_l1_loss: 0.0206 - disc_loss: 1.0092 - accuracy: 0.6417 - SSIM_loss: 0.0454 - val_accuracy: 0.7198 - val_SSIM_loss: 0.0687
# Epoch 94/200
# 360/360 [==============================] - 97s 271ms/step - gen_total_loss: 3.7260 - gen_gan_loss: 1.6474 - gen_l1_loss: 0.0208 - disc_loss: 0.9968 - accuracy: 0.6507 - SSIM_loss: 0.0470 - val_accuracy: 0.7414 - val_SSIM_loss: 0.0706
# Epoch 95/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.7271 - gen_gan_loss: 1.6576 - gen_l1_loss: 0.0207 - disc_loss: 0.9968 - accuracy: 0.6648 - SSIM_loss: 0.0470 - val_accuracy: 0.6822 - val_SSIM_loss: 0.0704
# Epoch 96/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.8159 - gen_gan_loss: 1.6881 - gen_l1_loss: 0.0213 - disc_loss: 0.9923 - accuracy: 0.6752 - SSIM_loss: 0.0481 - val_accuracy: 0.7809 - val_SSIM_loss: 0.0762
# Epoch 97/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.7079 - gen_gan_loss: 1.6383 - gen_l1_loss: 0.0207 - disc_loss: 1.0003 - accuracy: 0.6841 - SSIM_loss: 0.0468 - val_accuracy: 0.7166 - val_SSIM_loss: 0.0699
# Epoch 98/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 3.7480 - gen_gan_loss: 1.6868 - gen_l1_loss: 0.0206 - disc_loss: 1.0056 - accuracy: 0.7051 - SSIM_loss: 0.0460 - val_accuracy: 0.6459 - val_SSIM_loss: 0.0675
# Epoch 99/200
# 360/360 [==============================] - 103s 286ms/step - gen_total_loss: 3.7932 - gen_gan_loss: 1.6912 - gen_l1_loss: 0.0210 - disc_loss: 0.9894 - accuracy: 0.7008 - SSIM_loss: 0.0483 - val_accuracy: 0.6934 - val_SSIM_loss: 0.0740
# Epoch 100/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.7988 - gen_gan_loss: 1.6938 - gen_l1_loss: 0.0211 - disc_loss: 0.9861 - accuracy: 0.7076 - SSIM_loss: 0.0482 - val_accuracy: 0.7750 - val_SSIM_loss: 0.0732
# Epoch 101/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.7717 - gen_gan_loss: 1.6900 - gen_l1_loss: 0.0208 - disc_loss: 0.9904 - accuracy: 0.7111 - SSIM_loss: 0.0475 - val_accuracy: 0.5592 - val_SSIM_loss: 0.0762
# Epoch 102/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.6095 - gen_gan_loss: 1.5906 - gen_l1_loss: 0.0202 - disc_loss: 1.0299 - accuracy: 0.7159 - SSIM_loss: 0.0445 - val_accuracy: 0.6426 - val_SSIM_loss: 0.0652
# Epoch 103/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.7691 - gen_gan_loss: 1.7117 - gen_l1_loss: 0.0206 - disc_loss: 0.9879 - accuracy: 0.7019 - SSIM_loss: 0.0469 - val_accuracy: 0.6491 - val_SSIM_loss: 0.0732
# Epoch 104/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 2.8924 - gen_gan_loss: 0.9660 - gen_l1_loss: 0.0193 - disc_loss: 1.3374 - accuracy: 0.7353 - SSIM_loss: 0.0404 - val_accuracy: 0.7928 - val_SSIM_loss: 0.0594
# Epoch 105/200
# 360/360 [==============================] - 102s 284ms/step - gen_total_loss: 3.3513 - gen_gan_loss: 1.4073 - gen_l1_loss: 0.0194 - disc_loss: 1.0822 - accuracy: 0.6976 - SSIM_loss: 0.0414 - val_accuracy: 0.6452 - val_SSIM_loss: 0.0692
# Epoch 106/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.6189 - gen_gan_loss: 1.6276 - gen_l1_loss: 0.0199 - disc_loss: 1.0088 - accuracy: 0.6893 - SSIM_loss: 0.0446 - val_accuracy: 0.7083 - val_SSIM_loss: 0.0709
# Epoch 107/200
# 360/360 [==============================] - 101s 279ms/step - gen_total_loss: 3.7311 - gen_gan_loss: 1.6883 - gen_l1_loss: 0.0204 - disc_loss: 0.9931 - accuracy: 0.7061 - SSIM_loss: 0.0462 - val_accuracy: 0.7511 - val_SSIM_loss: 0.0728
# Epoch 108/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.7361 - gen_gan_loss: 1.7093 - gen_l1_loss: 0.0203 - disc_loss: 0.9862 - accuracy: 0.7162 - SSIM_loss: 0.0466 - val_accuracy: 0.6964 - val_SSIM_loss: 0.0716
# Epoch 109/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.7614 - gen_gan_loss: 1.7094 - gen_l1_loss: 0.0205 - disc_loss: 0.9870 - accuracy: 0.7039 - SSIM_loss: 0.0471 - val_accuracy: 0.7151 - val_SSIM_loss: 0.0705
# Epoch 110/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.7770 - gen_gan_loss: 1.7356 - gen_l1_loss: 0.0204 - disc_loss: 0.9865 - accuracy: 0.6940 - SSIM_loss: 0.0471 - val_accuracy: 0.6902 - val_SSIM_loss: 0.0777
# Epoch 111/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 3.2664 - gen_gan_loss: 1.2875 - gen_l1_loss: 0.0198 - disc_loss: 1.1542 - accuracy: 0.7084 - SSIM_loss: 0.0437 - val_accuracy: 0.7247 - val_SSIM_loss: 0.0615
# Epoch 112/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 2.8865 - gen_gan_loss: 1.0312 - gen_l1_loss: 0.0186 - disc_loss: 1.2320 - accuracy: 0.7314 - SSIM_loss: 0.0393 - val_accuracy: 0.7635 - val_SSIM_loss: 0.0591
# Epoch 113/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.2313 - gen_gan_loss: 1.3541 - gen_l1_loss: 0.0188 - disc_loss: 1.0938 - accuracy: 0.7437 - SSIM_loss: 0.0397 - val_accuracy: 0.7888 - val_SSIM_loss: 0.0659
# Epoch 114/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.6558 - gen_gan_loss: 1.6810 - gen_l1_loss: 0.0197 - disc_loss: 1.0094 - accuracy: 0.7586 - SSIM_loss: 0.0436 - val_accuracy: 0.8327 - val_SSIM_loss: 0.0683
# Epoch 115/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.6598 - gen_gan_loss: 1.6887 - gen_l1_loss: 0.0197 - disc_loss: 1.0062 - accuracy: 0.7452 - SSIM_loss: 0.0448 - val_accuracy: 0.7868 - val_SSIM_loss: 0.0743
# Epoch 116/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 3.7396 - gen_gan_loss: 1.7161 - gen_l1_loss: 0.0202 - disc_loss: 0.9946 - accuracy: 0.7398 - SSIM_loss: 0.0465 - val_accuracy: 0.8089 - val_SSIM_loss: 0.0711
# Epoch 117/200
# 360/360 [==============================] - 103s 287ms/step - gen_total_loss: 3.7318 - gen_gan_loss: 1.7394 - gen_l1_loss: 0.0199 - disc_loss: 0.9880 - accuracy: 0.7382 - SSIM_loss: 0.0464 - val_accuracy: 0.7125 - val_SSIM_loss: 0.0710
# Epoch 118/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.7882 - gen_gan_loss: 1.7551 - gen_l1_loss: 0.0203 - disc_loss: 0.9847 - accuracy: 0.7495 - SSIM_loss: 0.0470 - val_accuracy: 0.8684 - val_SSIM_loss: 0.0709
# Epoch 119/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.7678 - gen_gan_loss: 1.7373 - gen_l1_loss: 0.0203 - disc_loss: 0.9895 - accuracy: 0.7464 - SSIM_loss: 0.0467 - val_accuracy: 0.8038 - val_SSIM_loss: 0.0712
# Epoch 120/200
# 360/360 [==============================] - 98s 271ms/step - gen_total_loss: 3.7823 - gen_gan_loss: 1.7494 - gen_l1_loss: 0.0203 - disc_loss: 0.9822 - accuracy: 0.7474 - SSIM_loss: 0.0478 - val_accuracy: 0.8338 - val_SSIM_loss: 0.0789
# Epoch 121/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.6328 - gen_gan_loss: 1.6694 - gen_l1_loss: 0.0196 - disc_loss: 1.0024 - accuracy: 0.7530 - SSIM_loss: 0.0454 - val_accuracy: 0.7619 - val_SSIM_loss: 0.0717
# Epoch 122/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 3.4747 - gen_gan_loss: 1.5354 - gen_l1_loss: 0.0194 - disc_loss: 1.2665 - accuracy: 0.7710 - SSIM_loss: 0.0447 - val_accuracy: 0.8416 - val_SSIM_loss: 0.0585
# Epoch 123/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 3.2924 - gen_gan_loss: 1.4332 - gen_l1_loss: 0.0186 - disc_loss: 1.0562 - accuracy: 0.7676 - SSIM_loss: 0.0401 - val_accuracy: 0.8379 - val_SSIM_loss: 0.0668
# Epoch 124/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.5627 - gen_gan_loss: 1.6673 - gen_l1_loss: 0.0190 - disc_loss: 1.0132 - accuracy: 0.7550 - SSIM_loss: 0.0425 - val_accuracy: 0.8272 - val_SSIM_loss: 0.0704
# Epoch 125/200
# 360/360 [==============================] - 98s 271ms/step - gen_total_loss: 3.7331 - gen_gan_loss: 1.7479 - gen_l1_loss: 0.0199 - disc_loss: 0.9880 - accuracy: 0.7531 - SSIM_loss: 0.0458 - val_accuracy: 0.7211 - val_SSIM_loss: 0.0708
# Epoch 126/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.7474 - gen_gan_loss: 1.7727 - gen_l1_loss: 0.0197 - disc_loss: 0.9807 - accuracy: 0.7352 - SSIM_loss: 0.0463 - val_accuracy: 0.6716 - val_SSIM_loss: 0.0745
# Epoch 127/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.1066 - gen_gan_loss: 1.2323 - gen_l1_loss: 0.0187 - disc_loss: 1.2664 - accuracy: 0.7336 - SSIM_loss: 0.0418 - val_accuracy: 0.7324 - val_SSIM_loss: 0.0586
# Epoch 128/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 2.9733 - gen_gan_loss: 1.1876 - gen_l1_loss: 0.0179 - disc_loss: 1.1486 - accuracy: 0.7453 - SSIM_loss: 0.0379 - val_accuracy: 0.7531 - val_SSIM_loss: 0.0649
# Epoch 129/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 3.5276 - gen_gan_loss: 1.6378 - gen_l1_loss: 0.0189 - disc_loss: 1.0190 - accuracy: 0.7291 - SSIM_loss: 0.0418 - val_accuracy: 0.6619 - val_SSIM_loss: 0.0672
# Epoch 130/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.2271 - gen_gan_loss: 1.3916 - gen_l1_loss: 0.0184 - disc_loss: 1.0775 - accuracy: 0.7237 - SSIM_loss: 0.0400 - val_accuracy: 0.6890 - val_SSIM_loss: 0.0658
# Epoch 131/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.5968 - gen_gan_loss: 1.6997 - gen_l1_loss: 0.0190 - disc_loss: 1.0018 - accuracy: 0.7103 - SSIM_loss: 0.0430 - val_accuracy: 0.8018 - val_SSIM_loss: 0.0694
# Epoch 132/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.7198 - gen_gan_loss: 1.7625 - gen_l1_loss: 0.0196 - disc_loss: 0.9882 - accuracy: 0.7048 - SSIM_loss: 0.0453 - val_accuracy: 0.7383 - val_SSIM_loss: 0.0750
# Epoch 133/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.6858 - gen_gan_loss: 1.7484 - gen_l1_loss: 0.0194 - disc_loss: 0.9933 - accuracy: 0.7071 - SSIM_loss: 0.0448 - val_accuracy: 0.7376 - val_SSIM_loss: 0.0754
# Epoch 134/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 3.7936 - gen_gan_loss: 1.8004 - gen_l1_loss: 0.0199 - disc_loss: 0.9796 - accuracy: 0.7040 - SSIM_loss: 0.0466 - val_accuracy: 0.6755 - val_SSIM_loss: 0.0701
# Epoch 135/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 3.7643 - gen_gan_loss: 1.7881 - gen_l1_loss: 0.0198 - disc_loss: 0.9829 - accuracy: 0.7049 - SSIM_loss: 0.0462 - val_accuracy: 0.6885 - val_SSIM_loss: 0.0761
# Epoch 136/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.4561 - gen_gan_loss: 1.5609 - gen_l1_loss: 0.0190 - disc_loss: 1.0850 - accuracy: 0.7052 - SSIM_loss: 0.0437 - val_accuracy: 0.6361 - val_SSIM_loss: 0.0620
# Epoch 137/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.5051 - gen_gan_loss: 1.6660 - gen_l1_loss: 0.0184 - disc_loss: 1.0082 - accuracy: 0.7024 - SSIM_loss: 0.0414 - val_accuracy: 0.7134 - val_SSIM_loss: 0.0706
# Epoch 138/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.6975 - gen_gan_loss: 1.7669 - gen_l1_loss: 0.0193 - disc_loss: 0.9933 - accuracy: 0.6918 - SSIM_loss: 0.0441 - val_accuracy: 0.6835 - val_SSIM_loss: 0.0695
# Epoch 139/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.7378 - gen_gan_loss: 1.8135 - gen_l1_loss: 0.0192 - disc_loss: 0.9811 - accuracy: 0.6969 - SSIM_loss: 0.0448 - val_accuracy: 0.7374 - val_SSIM_loss: 0.0737
# Epoch 140/200
# 360/360 [==============================] - 101s 279ms/step - gen_total_loss: 3.7612 - gen_gan_loss: 1.8081 - gen_l1_loss: 0.0195 - disc_loss: 0.9801 - accuracy: 0.6817 - SSIM_loss: 0.0460 - val_accuracy: 0.6579 - val_SSIM_loss: 0.0741
# Epoch 141/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 3.6940 - gen_gan_loss: 1.7792 - gen_l1_loss: 0.0191 - disc_loss: 0.9936 - accuracy: 0.6811 - SSIM_loss: 0.0443 - val_accuracy: 0.7335 - val_SSIM_loss: 0.0744
# Epoch 142/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.7452 - gen_gan_loss: 1.8161 - gen_l1_loss: 0.0193 - disc_loss: 0.9785 - accuracy: 0.6845 - SSIM_loss: 0.0456 - val_accuracy: 0.6614 - val_SSIM_loss: 0.0723
# Epoch 143/200
# 360/360 [==============================] - 98s 271ms/step - gen_total_loss: 3.7548 - gen_gan_loss: 1.8137 - gen_l1_loss: 0.0194 - disc_loss: 0.9827 - accuracy: 0.6805 - SSIM_loss: 0.0453 - val_accuracy: 0.6491 - val_SSIM_loss: 0.0762
# Epoch 144/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.5405 - gen_gan_loss: 1.6700 - gen_l1_loss: 0.0187 - disc_loss: 1.0229 - accuracy: 0.6787 - SSIM_loss: 0.0426 - val_accuracy: 0.7239 - val_SSIM_loss: 0.0713
# Epoch 145/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.7380 - gen_gan_loss: 1.8062 - gen_l1_loss: 0.0193 - disc_loss: 0.9860 - accuracy: 0.6810 - SSIM_loss: 0.0450 - val_accuracy: 0.7862 - val_SSIM_loss: 0.0758
# Epoch 146/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.7806 - gen_gan_loss: 1.8272 - gen_l1_loss: 0.0195 - disc_loss: 0.9727 - accuracy: 0.6938 - SSIM_loss: 0.0469 - val_accuracy: 0.5936 - val_SSIM_loss: 0.0754
# Epoch 147/200
# 360/360 [==============================] - 103s 285ms/step - gen_total_loss: 2.8458 - gen_gan_loss: 1.0547 - gen_l1_loss: 0.0179 - disc_loss: 1.3011 - accuracy: 0.7008 - SSIM_loss: 0.0401 - val_accuracy: 0.7938 - val_SSIM_loss: 0.0609
# Epoch 148/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 2.5471 - gen_gan_loss: 0.8322 - gen_l1_loss: 0.0171 - disc_loss: 1.2767 - accuracy: 0.7154 - SSIM_loss: 0.0364 - val_accuracy: 0.5631 - val_SSIM_loss: 0.0570
# Epoch 149/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 2.8648 - gen_gan_loss: 1.1312 - gen_l1_loss: 0.0173 - disc_loss: 1.1517 - accuracy: 0.7031 - SSIM_loss: 0.0367 - val_accuracy: 0.6686 - val_SSIM_loss: 0.0636
# Epoch 150/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.2611 - gen_gan_loss: 1.5028 - gen_l1_loss: 0.0176 - disc_loss: 1.0554 - accuracy: 0.7164 - SSIM_loss: 0.0380 - val_accuracy: 0.7956 - val_SSIM_loss: 0.0675
# Epoch 151/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.5212 - gen_gan_loss: 1.6997 - gen_l1_loss: 0.0182 - disc_loss: 1.0039 - accuracy: 0.7142 - SSIM_loss: 0.0415 - val_accuracy: 0.8172 - val_SSIM_loss: 0.0704
# Epoch 152/200
# 360/360 [==============================] - 100s 276ms/step - gen_total_loss: 3.6531 - gen_gan_loss: 1.7836 - gen_l1_loss: 0.0187 - disc_loss: 0.9841 - accuracy: 0.7059 - SSIM_loss: 0.0438 - val_accuracy: 0.7566 - val_SSIM_loss: 0.0707
# Epoch 153/200
# 360/360 [==============================] - 101s 282ms/step - gen_total_loss: 3.7324 - gen_gan_loss: 1.8351 - gen_l1_loss: 0.0190 - disc_loss: 0.9773 - accuracy: 0.6956 - SSIM_loss: 0.0447 - val_accuracy: 0.6329 - val_SSIM_loss: 0.0735
# Epoch 154/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.5239 - gen_gan_loss: 1.6757 - gen_l1_loss: 0.0185 - disc_loss: 1.0169 - accuracy: 0.6971 - SSIM_loss: 0.0427 - val_accuracy: 0.6939 - val_SSIM_loss: 0.0704
# Epoch 155/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.6039 - gen_gan_loss: 1.7765 - gen_l1_loss: 0.0183 - disc_loss: 0.9985 - accuracy: 0.7051 - SSIM_loss: 0.0421 - val_accuracy: 0.7937 - val_SSIM_loss: 0.0690
# Epoch 156/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.4758 - gen_gan_loss: 1.6377 - gen_l1_loss: 0.0184 - disc_loss: 1.0314 - accuracy: 0.7149 - SSIM_loss: 0.0414 - val_accuracy: 0.7649 - val_SSIM_loss: 0.0692
# Epoch 157/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.7222 - gen_gan_loss: 1.8326 - gen_l1_loss: 0.0189 - disc_loss: 0.9763 - accuracy: 0.7092 - SSIM_loss: 0.0446 - val_accuracy: 0.7264 - val_SSIM_loss: 0.0758
# Epoch 158/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 3.7615 - gen_gan_loss: 1.8557 - gen_l1_loss: 0.0191 - disc_loss: 0.9729 - accuracy: 0.7067 - SSIM_loss: 0.0453 - val_accuracy: 0.7082 - val_SSIM_loss: 0.0747
# Epoch 159/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 3.7576 - gen_gan_loss: 1.8581 - gen_l1_loss: 0.0190 - disc_loss: 0.9715 - accuracy: 0.7073 - SSIM_loss: 0.0455 - val_accuracy: 0.7566 - val_SSIM_loss: 0.0734
# Epoch 160/200
# 360/360 [==============================] - 97s 269ms/step - gen_total_loss: 3.8151 - gen_gan_loss: 1.8426 - gen_l1_loss: 0.0197 - disc_loss: 0.9721 - accuracy: 0.7051 - SSIM_loss: 0.0472 - val_accuracy: 0.7900 - val_SSIM_loss: 0.0761
# Epoch 161/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.7573 - gen_gan_loss: 1.8309 - gen_l1_loss: 0.0193 - disc_loss: 0.9714 - accuracy: 0.7153 - SSIM_loss: 0.0466 - val_accuracy: 0.6250 - val_SSIM_loss: 0.0760
# Epoch 162/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.7274 - gen_gan_loss: 1.8429 - gen_l1_loss: 0.0188 - disc_loss: 0.9746 - accuracy: 0.7141 - SSIM_loss: 0.0454 - val_accuracy: 0.5383 - val_SSIM_loss: 0.0772
# Epoch 163/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.7837 - gen_gan_loss: 1.8591 - gen_l1_loss: 0.0192 - disc_loss: 0.9652 - accuracy: 0.7027 - SSIM_loss: 0.0468 - val_accuracy: 0.7040 - val_SSIM_loss: 0.0798
# Epoch 164/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 3.7942 - gen_gan_loss: 1.8566 - gen_l1_loss: 0.0194 - disc_loss: 0.9645 - accuracy: 0.6875 - SSIM_loss: 0.0475 - val_accuracy: 0.6136 - val_SSIM_loss: 0.0752
# Epoch 165/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 3.6840 - gen_gan_loss: 1.7936 - gen_l1_loss: 0.0189 - disc_loss: 0.9817 - accuracy: 0.6849 - SSIM_loss: 0.0450 - val_accuracy: 0.6038 - val_SSIM_loss: 0.0725
# Epoch 166/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.7745 - gen_gan_loss: 1.8555 - gen_l1_loss: 0.0192 - disc_loss: 0.9685 - accuracy: 0.6843 - SSIM_loss: 0.0458 - val_accuracy: 0.7036 - val_SSIM_loss: 0.0788
# Epoch 167/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.7977 - gen_gan_loss: 1.8854 - gen_l1_loss: 0.0191 - disc_loss: 0.9624 - accuracy: 0.6761 - SSIM_loss: 0.0467 - val_accuracy: 0.6750 - val_SSIM_loss: 0.0789
# Epoch 168/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.5239 - gen_gan_loss: 1.6911 - gen_l1_loss: 0.0183 - disc_loss: 1.0203 - accuracy: 0.6827 - SSIM_loss: 0.0424 - val_accuracy: 0.6020 - val_SSIM_loss: 0.0761
# Epoch 169/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.7663 - gen_gan_loss: 1.8755 - gen_l1_loss: 0.0189 - disc_loss: 0.9656 - accuracy: 0.6888 - SSIM_loss: 0.0459 - val_accuracy: 0.6876 - val_SSIM_loss: 0.0768
# Epoch 170/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 3.5172 - gen_gan_loss: 1.7111 - gen_l1_loss: 0.0181 - disc_loss: 1.0092 - accuracy: 0.6932 - SSIM_loss: 0.0422 - val_accuracy: 0.6419 - val_SSIM_loss: 0.0766
# Epoch 171/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 3.7302 - gen_gan_loss: 1.8700 - gen_l1_loss: 0.0186 - disc_loss: 0.9670 - accuracy: 0.7048 - SSIM_loss: 0.0443 - val_accuracy: 0.6263 - val_SSIM_loss: 0.0750
# Epoch 172/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 3.7642 - gen_gan_loss: 1.8659 - gen_l1_loss: 0.0190 - disc_loss: 0.9695 - accuracy: 0.7033 - SSIM_loss: 0.0456 - val_accuracy: 0.6247 - val_SSIM_loss: 0.0769
# Epoch 173/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 3.7350 - gen_gan_loss: 1.8669 - gen_l1_loss: 0.0187 - disc_loss: 0.9696 - accuracy: 0.7046 - SSIM_loss: 0.0452 - val_accuracy: 0.6492 - val_SSIM_loss: 0.0762
# Epoch 174/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.8142 - gen_gan_loss: 1.8925 - gen_l1_loss: 0.0192 - disc_loss: 0.9642 - accuracy: 0.6894 - SSIM_loss: 0.0465 - val_accuracy: 0.7928 - val_SSIM_loss: 0.0751
# Epoch 175/200
# 360/360 [==============================] - 98s 271ms/step - gen_total_loss: 3.8109 - gen_gan_loss: 1.9028 - gen_l1_loss: 0.0191 - disc_loss: 0.9627 - accuracy: 0.6841 - SSIM_loss: 0.0462 - val_accuracy: 0.6035 - val_SSIM_loss: 0.0767
# Epoch 176/200
# 360/360 [==============================] - 101s 279ms/step - gen_total_loss: 3.7826 - gen_gan_loss: 1.8986 - gen_l1_loss: 0.0188 - disc_loss: 0.9607 - accuracy: 0.6782 - SSIM_loss: 0.0461 - val_accuracy: 0.6413 - val_SSIM_loss: 0.0776
# Epoch 177/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.6543 - gen_gan_loss: 1.8197 - gen_l1_loss: 0.0183 - disc_loss: 0.9869 - accuracy: 0.6802 - SSIM_loss: 0.0435 - val_accuracy: 0.6497 - val_SSIM_loss: 0.0742
# Epoch 178/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.5476 - gen_gan_loss: 1.7819 - gen_l1_loss: 0.0177 - disc_loss: 0.9952 - accuracy: 0.6892 - SSIM_loss: 0.0412 - val_accuracy: 0.6395 - val_SSIM_loss: 0.0771
# Epoch 179/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.7859 - gen_gan_loss: 1.8933 - gen_l1_loss: 0.0189 - disc_loss: 0.9629 - accuracy: 0.7027 - SSIM_loss: 0.0457 - val_accuracy: 0.6246 - val_SSIM_loss: 0.0796
# Epoch 180/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.8585 - gen_gan_loss: 1.9158 - gen_l1_loss: 0.0194 - disc_loss: 0.9553 - accuracy: 0.7093 - SSIM_loss: 0.0474 - val_accuracy: 0.6495 - val_SSIM_loss: 0.0816
# Epoch 181/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 3.8220 - gen_gan_loss: 1.9069 - gen_l1_loss: 0.0192 - disc_loss: 0.9543 - accuracy: 0.7043 - SSIM_loss: 0.0472 - val_accuracy: 0.6632 - val_SSIM_loss: 0.0796
# Epoch 182/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 3.3289 - gen_gan_loss: 1.5141 - gen_l1_loss: 0.0181 - disc_loss: 1.1332 - accuracy: 0.7161 - SSIM_loss: 0.0436 - val_accuracy: 0.8328 - val_SSIM_loss: 0.0628
# Epoch 183/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 2.5985 - gen_gan_loss: 0.9396 - gen_l1_loss: 0.0166 - disc_loss: 1.2231 - accuracy: 0.7400 - SSIM_loss: 0.0359 - val_accuracy: 0.7881 - val_SSIM_loss: 0.0637
# Epoch 184/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 2.9762 - gen_gan_loss: 1.3036 - gen_l1_loss: 0.0167 - disc_loss: 1.0938 - accuracy: 0.7471 - SSIM_loss: 0.0363 - val_accuracy: 0.7898 - val_SSIM_loss: 0.0632
# Epoch 185/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 3.3051 - gen_gan_loss: 1.6166 - gen_l1_loss: 0.0169 - disc_loss: 1.0338 - accuracy: 0.7333 - SSIM_loss: 0.0372 - val_accuracy: 0.7244 - val_SSIM_loss: 0.0655
# Epoch 186/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.3892 - gen_gan_loss: 1.6844 - gen_l1_loss: 0.0170 - disc_loss: 1.0276 - accuracy: 0.7226 - SSIM_loss: 0.0380 - val_accuracy: 0.6617 - val_SSIM_loss: 0.0693
# Epoch 187/200
# 360/360 [==============================] - 100s 276ms/step - gen_total_loss: 3.5542 - gen_gan_loss: 1.8250 - gen_l1_loss: 0.0173 - disc_loss: 0.9967 - accuracy: 0.7215 - SSIM_loss: 0.0395 - val_accuracy: 0.7007 - val_SSIM_loss: 0.0683
# Epoch 188/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 3.5664 - gen_gan_loss: 1.8195 - gen_l1_loss: 0.0175 - disc_loss: 0.9963 - accuracy: 0.7255 - SSIM_loss: 0.0401 - val_accuracy: 0.6961 - val_SSIM_loss: 0.0729
# Epoch 189/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 3.6336 - gen_gan_loss: 1.8693 - gen_l1_loss: 0.0176 - disc_loss: 0.9831 - accuracy: 0.7204 - SSIM_loss: 0.0414 - val_accuracy: 0.7529 - val_SSIM_loss: 0.0745
# Epoch 190/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 3.2800 - gen_gan_loss: 1.5466 - gen_l1_loss: 0.0173 - disc_loss: 1.1038 - accuracy: 0.7289 - SSIM_loss: 0.0399 - val_accuracy: 0.7919 - val_SSIM_loss: 0.0622
# Epoch 191/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.0637 - gen_gan_loss: 1.4015 - gen_l1_loss: 0.0166 - disc_loss: 1.0860 - accuracy: 0.7124 - SSIM_loss: 0.0364 - val_accuracy: 0.5740 - val_SSIM_loss: 0.0667
# Epoch 192/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.6098 - gen_gan_loss: 1.8590 - gen_l1_loss: 0.0175 - disc_loss: 0.9907 - accuracy: 0.6986 - SSIM_loss: 0.0402 - val_accuracy: 0.7191 - val_SSIM_loss: 0.0684
# Epoch 193/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 3.6602 - gen_gan_loss: 1.8937 - gen_l1_loss: 0.0177 - disc_loss: 0.9783 - accuracy: 0.6971 - SSIM_loss: 0.0411 - val_accuracy: 0.6617 - val_SSIM_loss: 0.0737
# Epoch 194/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 3.6645 - gen_gan_loss: 1.8963 - gen_l1_loss: 0.0177 - disc_loss: 0.9793 - accuracy: 0.6978 - SSIM_loss: 0.0419 - val_accuracy: 0.7912 - val_SSIM_loss: 0.0756
# Epoch 195/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 3.7633 - gen_gan_loss: 1.9544 - gen_l1_loss: 0.0181 - disc_loss: 0.9667 - accuracy: 0.6985 - SSIM_loss: 0.0435 - val_accuracy: 0.6323 - val_SSIM_loss: 0.0779
# Epoch 196/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 3.7671 - gen_gan_loss: 1.9513 - gen_l1_loss: 0.0182 - disc_loss: 0.9660 - accuracy: 0.7064 - SSIM_loss: 0.0442 - val_accuracy: 0.6285 - val_SSIM_loss: 0.0761
# Epoch 197/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 3.7337 - gen_gan_loss: 1.9093 - gen_l1_loss: 0.0182 - disc_loss: 0.9734 - accuracy: 0.7122 - SSIM_loss: 0.0441 - val_accuracy: 0.6787 - val_SSIM_loss: 0.0765
# Epoch 198/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 3.8515 - gen_gan_loss: 1.9746 - gen_l1_loss: 0.0188 - disc_loss: 0.9549 - accuracy: 0.7073 - SSIM_loss: 0.0464 - val_accuracy: 0.6666 - val_SSIM_loss: 0.0798
# Epoch 199/200
# 360/360 [==============================] - 100s 276ms/step - gen_total_loss: 3.8470 - gen_gan_loss: 1.9642 - gen_l1_loss: 0.0188 - disc_loss: 0.9513 - accuracy: 0.7007 - SSIM_loss: 0.0467 - val_accuracy: 0.6593 - val_SSIM_loss: 0.0787
# Epoch 200/200
# 360/360 [==============================] - 101s 282ms/step - gen_total_loss: 3.9102 - gen_gan_loss: 1.9897 - gen_l1_loss: 0.0192 - disc_loss: 0.9474 - accuracy: 0.7051 - SSIM_loss: 0.0476 - val_accuracy: 0.7040 - val_SSIM_loss: 0.0810
