# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()

import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns

import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='Pix2Pix_model_v1'
    __changes__="Changed to a pix2pix model in order to test a greater network for generator and discriminator. Generator: U-Net, Discriminator: PatchGAN"
    
    __normalization__='[-1,1]'
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    
    @staticmethod
    def discriminator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def main():
            
            initializer = tf.random_normal_initializer(0., 0.02)

            inp = tf.keras.layers.Input(shape=image_shape, name='input_image')
            tar = tf.keras.layers.Input(shape=image_shape, name='target_image')

            x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

            down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
            down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
            down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

            zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
            conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                        kernel_initializer=initializer,
                                        use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

            batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

            leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

            zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

            last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                        kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

            return tf.keras.Model(inputs=[inp, tar], outputs=last)
        
        
        return main()
    
    @staticmethod
    def generator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def upsample(filters, size, apply_dropout=False):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                            padding='same',
                                            kernel_initializer=initializer,
                                            use_bias=False))

            result.add(tf.keras.layers.BatchNormalization())

            if apply_dropout:
                result.add(tf.keras.layers.Dropout(0.5))

            result.add(tf.keras.layers.ReLU())

            return result

        def main():
            inputs = tf.keras.layers.Input(shape=image_shape)

            down_stack = [
                downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
                downsample(128, 4), # (bs, 64, 64, 128)
                downsample(256, 4), # (bs, 32, 32, 256)
                downsample(512, 4), # (bs, 16, 16, 512)
                downsample(512, 4), # (bs, 8, 8, 512)
                downsample(512, 4), # (bs, 4, 4, 512)
                downsample(512, 4), # (bs, 2, 2, 512)
                #downsample(512, 4), # (bs, 1, 1, 512)
            ]

            up_stack = [
                upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
                upsample(512, 4), # (bs, 16, 16, 1024)
                upsample(256, 4), # (bs, 32, 32, 512)
                upsample(128, 4), # (bs, 64, 64, 256)
                upsample(64, 4), # (bs, 128, 128, 128)
            ]

            initializer = tf.random_normal_initializer(0., 0.02)
            last = tf.keras.layers.Conv2DTranspose(3, 4,
                                                 strides=2,
                                                 padding='same',
                                                 kernel_initializer=initializer,
                                                 activation='tanh') # (bs, 256, 256, 3)

            x = inputs

            # Downsampling through the model
            skips = []
            for down in down_stack:
                x = down(x)
                skips.append(x)

            skips = reversed(skips[:-1])

            # Upsampling and establishing the skip connections
            for up, skip in zip(up_stack, skips):
                x = up(x)
                x = tf.keras.layers.Concatenate()([x, skip])

            x = last(x)

            return tf.keras.Model(inputs=inputs, outputs=x)
        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        LAMBDA = 100
        def generator_loss(disc_generated_output, gen_output, target): # https://arxiv.org/abs/1611.07004
            gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

            # mean absolute error
            l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

            total_gen_loss = gan_loss + (LAMBDA * l1_loss)

            return total_gen_loss, gan_loss, l1_loss

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss

        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__)
# Out:
# train_x (30, 128, 128, 3) float32 -1.0 1.0
# train_y (30, 128, 128, 3) float32 -1.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss(disc_generated_output, gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(gen_total_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'gen_total_loss':gen_total_loss,
                'gen_gan_loss':gen_gan_loss,
                'gen_l1_loss':gen_l1_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - gen_total_loss: 102.1633 - gen_gan_loss: 1.2427 - gen_l1_loss: 1.0092 - disc_loss: 1.7365 - accuracy: 0.1967 - SSIM_loss: 1.0020WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/360 [..............................] - ETA: 1:00 - gen_total_loss: 97.4716 - gen_gan_loss: 1.6467 - gen_l1_loss: 0.9582 - disc_loss: 2.6334 - accuracy: 0.2019 - SSIM_loss: 0.9918WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1151s vs `on_train_batch_end` time: 0.2192s). Check your callbacks.
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.8581 - gen_gan_loss: 1.1629 - gen_l1_loss: 0.0970 - disc_loss: 1.1462 - accuracy: 0.2830 - SSIM_loss: 0.1373gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 10.8457 - gen_gan_loss: 1.1619 - gen_l1_loss: 0.0968 - disc_loss: 1.1462 - accuracy: 0.2830 - SSIM_loss: 0.1373 - val_accuracy: 0.4747 - val_SSIM_loss: 0.0801
# Epoch 2/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.5200 - gen_gan_loss: 0.8875 - gen_l1_loss: 0.0463 - disc_loss: 1.2856 - accuracy: 0.3402 - SSIM_loss: 0.0720gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 5.5166 - gen_gan_loss: 0.8872 - gen_l1_loss: 0.0463 - disc_loss: 1.2857 - accuracy: 0.3402 - SSIM_loss: 0.0720 - val_accuracy: 0.3032 - val_SSIM_loss: 0.1600
# Epoch 3/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.0319 - gen_gan_loss: 0.8899 - gen_l1_loss: 0.0414 - disc_loss: 1.2612 - accuracy: 0.3763 - SSIM_loss: 0.0660gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 5.0282 - gen_gan_loss: 0.8906 - gen_l1_loss: 0.0414 - disc_loss: 1.2604 - accuracy: 0.3763 - SSIM_loss: 0.0660 - val_accuracy: 0.4295 - val_SSIM_loss: 0.0773
# Epoch 4/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.7555 - gen_gan_loss: 0.8717 - gen_l1_loss: 0.0388 - disc_loss: 1.2652 - accuracy: 0.4354 - SSIM_loss: 0.0627gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 4.7542 - gen_gan_loss: 0.8714 - gen_l1_loss: 0.0388 - disc_loss: 1.2653 - accuracy: 0.4354 - SSIM_loss: 0.0627 - val_accuracy: 0.4351 - val_SSIM_loss: 0.0977
# Epoch 5/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.5453 - gen_gan_loss: 0.8669 - gen_l1_loss: 0.0368 - disc_loss: 1.2700 - accuracy: 0.4420 - SSIM_loss: 0.0598gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 4.5426 - gen_gan_loss: 0.8674 - gen_l1_loss: 0.0368 - disc_loss: 1.2696 - accuracy: 0.4420 - SSIM_loss: 0.0598 - val_accuracy: 0.3220 - val_SSIM_loss: 0.1477
# Epoch 6/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.3450 - gen_gan_loss: 0.8711 - gen_l1_loss: 0.0347 - disc_loss: 1.2611 - accuracy: 0.3977 - SSIM_loss: 0.0571gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 4.3453 - gen_gan_loss: 0.8703 - gen_l1_loss: 0.0348 - disc_loss: 1.2610 - accuracy: 0.3977 - SSIM_loss: 0.0571 - val_accuracy: 0.4866 - val_SSIM_loss: 0.0716
# Epoch 7/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.0967 - gen_gan_loss: 0.8730 - gen_l1_loss: 0.0322 - disc_loss: 1.2655 - accuracy: 0.3974 - SSIM_loss: 0.0542gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 4.0974 - gen_gan_loss: 0.8747 - gen_l1_loss: 0.0322 - disc_loss: 1.2653 - accuracy: 0.3974 - SSIM_loss: 0.0542 - val_accuracy: 0.5177 - val_SSIM_loss: 0.0623
# Epoch 8/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 3.9558 - gen_gan_loss: 0.8716 - gen_l1_loss: 0.0308 - disc_loss: 1.2676 - accuracy: 0.3808 - SSIM_loss: 0.0524gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 3.9584 - gen_gan_loss: 0.8726 - gen_l1_loss: 0.0309 - disc_loss: 1.2680 - accuracy: 0.3808 - SSIM_loss: 0.0524 - val_accuracy: 0.1893 - val_SSIM_loss: 0.0654
# Epoch 9/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 3.7522 - gen_gan_loss: 0.8860 - gen_l1_loss: 0.0287 - disc_loss: 1.2569 - accuracy: 0.3784 - SSIM_loss: 0.0495gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 329ms/step - gen_total_loss: 3.7537 - gen_gan_loss: 0.8858 - gen_l1_loss: 0.0287 - disc_loss: 1.2565 - accuracy: 0.3784 - SSIM_loss: 0.0495 - val_accuracy: 0.6530 - val_SSIM_loss: 0.0663
# Epoch 10/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 3.6030 - gen_gan_loss: 0.8967 - gen_l1_loss: 0.0271 - disc_loss: 1.2549 - accuracy: 0.4083 - SSIM_loss: 0.0471gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 3.6045 - gen_gan_loss: 0.8990 - gen_l1_loss: 0.0271 - disc_loss: 1.2556 - accuracy: 0.4083 - SSIM_loss: 0.0471 - val_accuracy: 0.3473 - val_SSIM_loss: 0.0852
# Epoch 11/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 3.7726 - gen_gan_loss: 0.9738 - gen_l1_loss: 0.0280 - disc_loss: 1.1960 - accuracy: 0.4010 - SSIM_loss: 0.0485gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 3.7731 - gen_gan_loss: 0.9733 - gen_l1_loss: 0.0280 - disc_loss: 1.1957 - accuracy: 0.4010 - SSIM_loss: 0.0485 - val_accuracy: 0.7141 - val_SSIM_loss: 0.0696
# Epoch 12/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 3.5526 - gen_gan_loss: 0.9829 - gen_l1_loss: 0.0257 - disc_loss: 1.1844 - accuracy: 0.4260 - SSIM_loss: 0.0452gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 3.5541 - gen_gan_loss: 0.9831 - gen_l1_loss: 0.0257 - disc_loss: 1.1838 - accuracy: 0.4260 - SSIM_loss: 0.0452 - val_accuracy: 0.4387 - val_SSIM_loss: 0.0945
# Epoch 13/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 3.7503 - gen_gan_loss: 1.0856 - gen_l1_loss: 0.0266 - disc_loss: 1.1145 - accuracy: 0.4582 - SSIM_loss: 0.0466gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 334ms/step - gen_total_loss: 3.7486 - gen_gan_loss: 1.0847 - gen_l1_loss: 0.0266 - disc_loss: 1.1144 - accuracy: 0.4582 - SSIM_loss: 0.0466 - val_accuracy: 0.5163 - val_SSIM_loss: 0.0725
# Epoch 14/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.0417 - gen_gan_loss: 1.2164 - gen_l1_loss: 0.0283 - disc_loss: 1.0655 - accuracy: 0.4898 - SSIM_loss: 0.0486gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 4.0417 - gen_gan_loss: 1.2160 - gen_l1_loss: 0.0283 - disc_loss: 1.0655 - accuracy: 0.4898 - SSIM_loss: 0.0486 - val_accuracy: 0.8670 - val_SSIM_loss: 0.1224
# Epoch 15/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.3770 - gen_gan_loss: 1.3693 - gen_l1_loss: 0.0301 - disc_loss: 0.9283 - accuracy: 0.5012 - SSIM_loss: 0.0513gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 334ms/step - gen_total_loss: 4.3740 - gen_gan_loss: 1.3668 - gen_l1_loss: 0.0301 - disc_loss: 0.9296 - accuracy: 0.5012 - SSIM_loss: 0.0513 - val_accuracy: 0.7241 - val_SSIM_loss: 0.0533
# Epoch 16/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.8053 - gen_gan_loss: 1.4886 - gen_l1_loss: 0.0332 - disc_loss: 0.9202 - accuracy: 0.5518 - SSIM_loss: 0.0546gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 4.8050 - gen_gan_loss: 1.4883 - gen_l1_loss: 0.0332 - disc_loss: 0.9196 - accuracy: 0.5518 - SSIM_loss: 0.0546 - val_accuracy: 0.3792 - val_SSIM_loss: 0.0599
# Epoch 17/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.8393 - gen_gan_loss: 1.5978 - gen_l1_loss: 0.0324 - disc_loss: 0.8342 - accuracy: 0.5319 - SSIM_loss: 0.0544gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 4.8366 - gen_gan_loss: 1.5981 - gen_l1_loss: 0.0324 - disc_loss: 0.8345 - accuracy: 0.5319 - SSIM_loss: 0.0544 - val_accuracy: 0.8128 - val_SSIM_loss: 0.0701
# Epoch 18/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.2889 - gen_gan_loss: 1.8293 - gen_l1_loss: 0.0346 - disc_loss: 0.7325 - accuracy: 0.5624 - SSIM_loss: 0.0576gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 5.2879 - gen_gan_loss: 1.8266 - gen_l1_loss: 0.0346 - disc_loss: 0.7325 - accuracy: 0.5624 - SSIM_loss: 0.0576 - val_accuracy: 0.5121 - val_SSIM_loss: 0.0574
# Epoch 19/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 4.8570 - gen_gan_loss: 1.7120 - gen_l1_loss: 0.0314 - disc_loss: 0.8259 - accuracy: 0.6513 - SSIM_loss: 0.0536gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 328ms/step - gen_total_loss: 4.8603 - gen_gan_loss: 1.7163 - gen_l1_loss: 0.0314 - disc_loss: 0.8290 - accuracy: 0.6513 - SSIM_loss: 0.0536 - val_accuracy: 0.6895 - val_SSIM_loss: 0.0835
# Epoch 20/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.5402 - gen_gan_loss: 1.9630 - gen_l1_loss: 0.0358 - disc_loss: 0.6795 - accuracy: 0.6254 - SSIM_loss: 0.0588gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 5.5387 - gen_gan_loss: 1.9642 - gen_l1_loss: 0.0357 - disc_loss: 0.6796 - accuracy: 0.6254 - SSIM_loss: 0.0588 - val_accuracy: 0.5348 - val_SSIM_loss: 0.0628
# Epoch 21/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.5518 - gen_gan_loss: 2.1264 - gen_l1_loss: 0.0343 - disc_loss: 0.6724 - accuracy: 0.6814 - SSIM_loss: 0.0567gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 5.5553 - gen_gan_loss: 2.1285 - gen_l1_loss: 0.0343 - disc_loss: 0.6722 - accuracy: 0.6814 - SSIM_loss: 0.0567 - val_accuracy: 0.7302 - val_SSIM_loss: 0.0692
# Epoch 22/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.3926 - gen_gan_loss: 2.1104 - gen_l1_loss: 0.0328 - disc_loss: 0.6634 - accuracy: 0.6639 - SSIM_loss: 0.0551gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 334ms/step - gen_total_loss: 5.3893 - gen_gan_loss: 2.1094 - gen_l1_loss: 0.0328 - disc_loss: 0.6623 - accuracy: 0.6639 - SSIM_loss: 0.0551 - val_accuracy: 0.7467 - val_SSIM_loss: 0.0508
# Epoch 23/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.5154 - gen_gan_loss: 2.1392 - gen_l1_loss: 0.0338 - disc_loss: 0.6588 - accuracy: 0.7025 - SSIM_loss: 0.0567gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 5.5211 - gen_gan_loss: 2.1453 - gen_l1_loss: 0.0338 - disc_loss: 0.6614 - accuracy: 0.7025 - SSIM_loss: 0.0567 - val_accuracy: 0.6683 - val_SSIM_loss: 0.0592
# Epoch 24/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.9688 - gen_gan_loss: 2.8541 - gen_l1_loss: 0.0411 - disc_loss: 0.4436 - accuracy: 0.7147 - SSIM_loss: 0.0652gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 6.9602 - gen_gan_loss: 2.8504 - gen_l1_loss: 0.0411 - disc_loss: 0.4441 - accuracy: 0.7147 - SSIM_loss: 0.0652 - val_accuracy: 0.8931 - val_SSIM_loss: 0.0559
# Epoch 25/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.8420 - gen_gan_loss: 2.6579 - gen_l1_loss: 0.0418 - disc_loss: 0.5390 - accuracy: 0.7777 - SSIM_loss: 0.0669gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 329ms/step - gen_total_loss: 6.8355 - gen_gan_loss: 2.6553 - gen_l1_loss: 0.0418 - disc_loss: 0.5386 - accuracy: 0.7777 - SSIM_loss: 0.0669 - val_accuracy: 0.7666 - val_SSIM_loss: 0.0862
# Epoch 26/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.8023 - gen_gan_loss: 2.3118 - gen_l1_loss: 0.0349 - disc_loss: 0.6518 - accuracy: 0.7981 - SSIM_loss: 0.0586gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 5.7983 - gen_gan_loss: 2.3079 - gen_l1_loss: 0.0349 - disc_loss: 0.6519 - accuracy: 0.7981 - SSIM_loss: 0.0586 - val_accuracy: 0.4703 - val_SSIM_loss: 0.0594
# Epoch 27/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.0153 - gen_gan_loss: 2.3985 - gen_l1_loss: 0.0362 - disc_loss: 0.5748 - accuracy: 0.7803 - SSIM_loss: 0.0601gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 6.0140 - gen_gan_loss: 2.3993 - gen_l1_loss: 0.0361 - disc_loss: 0.5795 - accuracy: 0.7803 - SSIM_loss: 0.0601 - val_accuracy: 0.8507 - val_SSIM_loss: 0.0679
# Epoch 28/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.4317 - gen_gan_loss: 2.2476 - gen_l1_loss: 0.0318 - disc_loss: 0.6493 - accuracy: 0.8190 - SSIM_loss: 0.0547gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 5.4356 - gen_gan_loss: 2.2493 - gen_l1_loss: 0.0319 - disc_loss: 0.6480 - accuracy: 0.8190 - SSIM_loss: 0.0547 - val_accuracy: 0.8802 - val_SSIM_loss: 0.0523
# Epoch 29/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.8340 - gen_gan_loss: 2.5028 - gen_l1_loss: 0.0333 - disc_loss: 0.5773 - accuracy: 0.8255 - SSIM_loss: 0.0561gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 5.8251 - gen_gan_loss: 2.4972 - gen_l1_loss: 0.0333 - disc_loss: 0.5789 - accuracy: 0.8255 - SSIM_loss: 0.0561 - val_accuracy: 0.8295 - val_SSIM_loss: 0.0646
# Epoch 30/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.7959 - gen_gan_loss: 2.4303 - gen_l1_loss: 0.0337 - disc_loss: 0.5690 - accuracy: 0.8407 - SSIM_loss: 0.0562gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 5.7896 - gen_gan_loss: 2.4266 - gen_l1_loss: 0.0336 - disc_loss: 0.5689 - accuracy: 0.8407 - SSIM_loss: 0.0562 - val_accuracy: 0.8627 - val_SSIM_loss: 0.0556
# Epoch 31/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.7936 - gen_gan_loss: 2.5188 - gen_l1_loss: 0.0327 - disc_loss: 0.5402 - accuracy: 0.8085 - SSIM_loss: 0.0547gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 5.7948 - gen_gan_loss: 2.5220 - gen_l1_loss: 0.0327 - disc_loss: 0.5402 - accuracy: 0.8085 - SSIM_loss: 0.0547 - val_accuracy: 0.8015 - val_SSIM_loss: 0.0483
# Epoch 32/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 5.7085 - gen_gan_loss: 2.5182 - gen_l1_loss: 0.0319 - disc_loss: 0.5844 - accuracy: 0.8494 - SSIM_loss: 0.0540gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 334ms/step - gen_total_loss: 5.7095 - gen_gan_loss: 2.5186 - gen_l1_loss: 0.0319 - disc_loss: 0.5831 - accuracy: 0.8494 - SSIM_loss: 0.0540 - val_accuracy: 0.5168 - val_SSIM_loss: 0.0572
# Epoch 33/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.1023 - gen_gan_loss: 2.7215 - gen_l1_loss: 0.0338 - disc_loss: 0.4720 - accuracy: 0.8604 - SSIM_loss: 0.0561gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 6.0971 - gen_gan_loss: 2.7161 - gen_l1_loss: 0.0338 - disc_loss: 0.4730 - accuracy: 0.8604 - SSIM_loss: 0.0561 - val_accuracy: 0.8865 - val_SSIM_loss: 0.0566
# Epoch 34/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.2181 - gen_gan_loss: 2.8571 - gen_l1_loss: 0.0336 - disc_loss: 0.4706 - accuracy: 0.8090 - SSIM_loss: 0.0565gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 329ms/step - gen_total_loss: 6.2187 - gen_gan_loss: 2.8565 - gen_l1_loss: 0.0336 - disc_loss: 0.4700 - accuracy: 0.8090 - SSIM_loss: 0.0565 - val_accuracy: 0.8871 - val_SSIM_loss: 0.0657
# Epoch 35/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.8451 - gen_gan_loss: 2.9542 - gen_l1_loss: 0.0389 - disc_loss: 0.4486 - accuracy: 0.8649 - SSIM_loss: 0.0662gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 6.8585 - gen_gan_loss: 2.9619 - gen_l1_loss: 0.0390 - disc_loss: 0.4474 - accuracy: 0.8649 - SSIM_loss: 0.0662 - val_accuracy: 0.8970 - val_SSIM_loss: 0.1294
# Epoch 36/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.6241 - gen_gan_loss: 3.8148 - gen_l1_loss: 0.0481 - disc_loss: 0.2868 - accuracy: 0.8186 - SSIM_loss: 0.0816gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 8.6334 - gen_gan_loss: 3.8186 - gen_l1_loss: 0.0481 - disc_loss: 0.2860 - accuracy: 0.8186 - SSIM_loss: 0.0816 - val_accuracy: 0.6358 - val_SSIM_loss: 0.1249
# Epoch 37/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.0969 - gen_gan_loss: 2.8354 - gen_l1_loss: 0.0326 - disc_loss: 0.5494 - accuracy: 0.8373 - SSIM_loss: 0.0579gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 6.1022 - gen_gan_loss: 2.8355 - gen_l1_loss: 0.0327 - disc_loss: 0.5482 - accuracy: 0.8373 - SSIM_loss: 0.0579 - val_accuracy: 0.8748 - val_SSIM_loss: 0.0574
# Epoch 38/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.1679 - gen_gan_loss: 2.9475 - gen_l1_loss: 0.0322 - disc_loss: 0.4615 - accuracy: 0.8459 - SSIM_loss: 0.0545gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 6.1671 - gen_gan_loss: 2.9431 - gen_l1_loss: 0.0322 - disc_loss: 0.4619 - accuracy: 0.8459 - SSIM_loss: 0.0545 - val_accuracy: 0.8129 - val_SSIM_loss: 0.0517
# Epoch 39/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.4009 - gen_gan_loss: 3.0471 - gen_l1_loss: 0.0335 - disc_loss: 0.3979 - accuracy: 0.8663 - SSIM_loss: 0.0564gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 6.4052 - gen_gan_loss: 3.0495 - gen_l1_loss: 0.0336 - disc_loss: 0.3969 - accuracy: 0.8663 - SSIM_loss: 0.0564 - val_accuracy: 0.8173 - val_SSIM_loss: 0.0637
# Epoch 40/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.2536 - gen_gan_loss: 2.9337 - gen_l1_loss: 0.0332 - disc_loss: 0.5406 - accuracy: 0.8699 - SSIM_loss: 0.0564gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 6.2492 - gen_gan_loss: 2.9274 - gen_l1_loss: 0.0332 - disc_loss: 0.5419 - accuracy: 0.8699 - SSIM_loss: 0.0564 - val_accuracy: 0.8862 - val_SSIM_loss: 0.0625
# Epoch 41/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.3942 - gen_gan_loss: 3.4441 - gen_l1_loss: 0.0395 - disc_loss: 0.2929 - accuracy: 0.8416 - SSIM_loss: 0.0678gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 7.3829 - gen_gan_loss: 3.4376 - gen_l1_loss: 0.0395 - disc_loss: 0.2935 - accuracy: 0.8416 - SSIM_loss: 0.0678 - val_accuracy: 0.3699 - val_SSIM_loss: 0.0530
# Epoch 42/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.9692 - gen_gan_loss: 3.4990 - gen_l1_loss: 0.0347 - disc_loss: 0.3487 - accuracy: 0.8664 - SSIM_loss: 0.0578gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 6.9761 - gen_gan_loss: 3.5004 - gen_l1_loss: 0.0348 - disc_loss: 0.3478 - accuracy: 0.8664 - SSIM_loss: 0.0578 - val_accuracy: 0.8468 - val_SSIM_loss: 0.0552
# Epoch 43/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.4596 - gen_gan_loss: 3.6281 - gen_l1_loss: 0.0383 - disc_loss: 0.3482 - accuracy: 0.8555 - SSIM_loss: 0.0648gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 7.4647 - gen_gan_loss: 3.6336 - gen_l1_loss: 0.0383 - disc_loss: 0.3490 - accuracy: 0.8555 - SSIM_loss: 0.0648 - val_accuracy: 0.8584 - val_SSIM_loss: 0.0710
# Epoch 44/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.1793 - gen_gan_loss: 3.4674 - gen_l1_loss: 0.0371 - disc_loss: 0.3646 - accuracy: 0.8587 - SSIM_loss: 0.0604gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 7.1731 - gen_gan_loss: 3.4648 - gen_l1_loss: 0.0371 - disc_loss: 0.3641 - accuracy: 0.8587 - SSIM_loss: 0.0604 - val_accuracy: 0.8203 - val_SSIM_loss: 0.0631
# Epoch 45/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.1257 - gen_gan_loss: 3.5765 - gen_l1_loss: 0.0355 - disc_loss: 0.3522 - accuracy: 0.8549 - SSIM_loss: 0.0593gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 7.1198 - gen_gan_loss: 3.5753 - gen_l1_loss: 0.0354 - disc_loss: 0.3526 - accuracy: 0.8549 - SSIM_loss: 0.0593 - val_accuracy: 0.8978 - val_SSIM_loss: 0.0575
# Epoch 46/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.0486 - gen_gan_loss: 3.5263 - gen_l1_loss: 0.0352 - disc_loss: 0.3639 - accuracy: 0.8435 - SSIM_loss: 0.0591gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 7.0550 - gen_gan_loss: 3.5301 - gen_l1_loss: 0.0352 - disc_loss: 0.3632 - accuracy: 0.8435 - SSIM_loss: 0.0591 - val_accuracy: 0.8911 - val_SSIM_loss: 0.0542
# Epoch 47/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.0231 - gen_gan_loss: 3.5363 - gen_l1_loss: 0.0349 - disc_loss: 0.3130 - accuracy: 0.8406 - SSIM_loss: 0.0587gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 7.0228 - gen_gan_loss: 3.5366 - gen_l1_loss: 0.0349 - disc_loss: 0.3123 - accuracy: 0.8406 - SSIM_loss: 0.0587 - val_accuracy: 0.8729 - val_SSIM_loss: 0.0520
# Epoch 48/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.2119 - gen_gan_loss: 3.6993 - gen_l1_loss: 0.0351 - disc_loss: 0.3327 - accuracy: 0.8587 - SSIM_loss: 0.0581gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 7.2138 - gen_gan_loss: 3.7022 - gen_l1_loss: 0.0351 - disc_loss: 0.3320 - accuracy: 0.8587 - SSIM_loss: 0.0581 - val_accuracy: 0.5546 - val_SSIM_loss: 0.0607
# Epoch 49/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.4794 - gen_gan_loss: 3.9512 - gen_l1_loss: 0.0353 - disc_loss: 0.2879 - accuracy: 0.8599 - SSIM_loss: 0.0582gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 7.4786 - gen_gan_loss: 3.9512 - gen_l1_loss: 0.0353 - disc_loss: 0.2872 - accuracy: 0.8599 - SSIM_loss: 0.0582 - val_accuracy: 0.8571 - val_SSIM_loss: 0.0562
# Epoch 50/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.9956 - gen_gan_loss: 3.6687 - gen_l1_loss: 0.0333 - disc_loss: 0.3577 - accuracy: 0.8663 - SSIM_loss: 0.0570gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 6.9970 - gen_gan_loss: 3.6676 - gen_l1_loss: 0.0333 - disc_loss: 0.3570 - accuracy: 0.8663 - SSIM_loss: 0.0570 - val_accuracy: 0.2436 - val_SSIM_loss: 0.0667
# Epoch 51/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 6.6526 - gen_gan_loss: 3.4376 - gen_l1_loss: 0.0321 - disc_loss: 0.3896 - accuracy: 0.8567 - SSIM_loss: 0.0557gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 6.6522 - gen_gan_loss: 3.4362 - gen_l1_loss: 0.0322 - disc_loss: 0.3887 - accuracy: 0.8567 - SSIM_loss: 0.0557 - val_accuracy: 0.7529 - val_SSIM_loss: 0.0597
# Epoch 52/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.7366 - gen_gan_loss: 3.9704 - gen_l1_loss: 0.0377 - disc_loss: 0.3163 - accuracy: 0.8572 - SSIM_loss: 0.0615gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 7.7276 - gen_gan_loss: 3.9642 - gen_l1_loss: 0.0376 - disc_loss: 0.3163 - accuracy: 0.8572 - SSIM_loss: 0.0615 - val_accuracy: 0.8094 - val_SSIM_loss: 0.0577
# Epoch 53/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.2866 - gen_gan_loss: 3.9255 - gen_l1_loss: 0.0336 - disc_loss: 0.3002 - accuracy: 0.8699 - SSIM_loss: 0.0578gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 7.2879 - gen_gan_loss: 3.9263 - gen_l1_loss: 0.0336 - disc_loss: 0.2996 - accuracy: 0.8699 - SSIM_loss: 0.0578 - val_accuracy: 0.8708 - val_SSIM_loss: 0.0626
# Epoch 54/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.2568 - gen_gan_loss: 3.7491 - gen_l1_loss: 0.0351 - disc_loss: 0.3592 - accuracy: 0.8708 - SSIM_loss: 0.0597gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 329ms/step - gen_total_loss: 7.2506 - gen_gan_loss: 3.7445 - gen_l1_loss: 0.0351 - disc_loss: 0.3590 - accuracy: 0.8708 - SSIM_loss: 0.0597 - val_accuracy: 0.8436 - val_SSIM_loss: 0.0538
# Epoch 55/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.5355 - gen_gan_loss: 4.9531 - gen_l1_loss: 0.0458 - disc_loss: 0.1201 - accuracy: 0.8250 - SSIM_loss: 0.0726gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 327ms/step - gen_total_loss: 9.5377 - gen_gan_loss: 4.9553 - gen_l1_loss: 0.0458 - disc_loss: 0.1198 - accuracy: 0.8250 - SSIM_loss: 0.0726 - val_accuracy: 0.8703 - val_SSIM_loss: 0.0639
# Epoch 56/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.9662 - gen_gan_loss: 4.9994 - gen_l1_loss: 0.0397 - disc_loss: 0.1809 - accuracy: 0.8258 - SSIM_loss: 0.0677gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.9782 - gen_gan_loss: 5.0089 - gen_l1_loss: 0.0397 - disc_loss: 0.1804 - accuracy: 0.8258 - SSIM_loss: 0.0677 - val_accuracy: 0.8602 - val_SSIM_loss: 0.0752
# Epoch 57/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.0840 - gen_gan_loss: 5.9209 - gen_l1_loss: 0.0416 - disc_loss: 0.1132 - accuracy: 0.8438 - SSIM_loss: 0.0692gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 10.0894 - gen_gan_loss: 5.9232 - gen_l1_loss: 0.0417 - disc_loss: 0.1129 - accuracy: 0.8438 - SSIM_loss: 0.0692 - val_accuracy: 0.7628 - val_SSIM_loss: 0.0554
# Epoch 58/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.3409 - gen_gan_loss: 3.9866 - gen_l1_loss: 0.0335 - disc_loss: 0.4491 - accuracy: 0.8711 - SSIM_loss: 0.0582gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 329ms/step - gen_total_loss: 7.3469 - gen_gan_loss: 3.9919 - gen_l1_loss: 0.0336 - disc_loss: 0.4479 - accuracy: 0.8711 - SSIM_loss: 0.0582 - val_accuracy: 0.8427 - val_SSIM_loss: 0.0691
# Epoch 59/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.1328 - gen_gan_loss: 3.8641 - gen_l1_loss: 0.0327 - disc_loss: 0.3557 - accuracy: 0.8502 - SSIM_loss: 0.0557gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 7.1305 - gen_gan_loss: 3.8643 - gen_l1_loss: 0.0327 - disc_loss: 0.3548 - accuracy: 0.8502 - SSIM_loss: 0.0557 - val_accuracy: 0.7657 - val_SSIM_loss: 0.0519
# Epoch 60/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.0018 - gen_gan_loss: 3.7220 - gen_l1_loss: 0.0328 - disc_loss: 0.3709 - accuracy: 0.8439 - SSIM_loss: 0.0558gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 327ms/step - gen_total_loss: 6.9988 - gen_gan_loss: 3.7158 - gen_l1_loss: 0.0328 - disc_loss: 0.3708 - accuracy: 0.8439 - SSIM_loss: 0.0558 - val_accuracy: 0.4983 - val_SSIM_loss: 0.0632
# Epoch 61/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.3062 - gen_gan_loss: 4.4154 - gen_l1_loss: 0.0389 - disc_loss: 0.2002 - accuracy: 0.8591 - SSIM_loss: 0.0648gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 8.3006 - gen_gan_loss: 4.4097 - gen_l1_loss: 0.0389 - disc_loss: 0.2001 - accuracy: 0.8591 - SSIM_loss: 0.0648 - val_accuracy: 0.9070 - val_SSIM_loss: 0.0509
# Epoch 62/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.4950 - gen_gan_loss: 5.0198 - gen_l1_loss: 0.0448 - disc_loss: 0.2099 - accuracy: 0.8456 - SSIM_loss: 0.0878gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 9.4787 - gen_gan_loss: 5.0075 - gen_l1_loss: 0.0447 - disc_loss: 0.2155 - accuracy: 0.8456 - SSIM_loss: 0.0878 - val_accuracy: 0.8991 - val_SSIM_loss: 0.0535
# Epoch 63/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.1665 - gen_gan_loss: 4.4879 - gen_l1_loss: 0.0368 - disc_loss: 0.2339 - accuracy: 0.8626 - SSIM_loss: 0.0625gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 8.1662 - gen_gan_loss: 4.4874 - gen_l1_loss: 0.0368 - disc_loss: 0.2333 - accuracy: 0.8626 - SSIM_loss: 0.0625 - val_accuracy: 0.8863 - val_SSIM_loss: 0.0573
# Epoch 64/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.0073 - gen_gan_loss: 4.4333 - gen_l1_loss: 0.0357 - disc_loss: 0.2686 - accuracy: 0.8603 - SSIM_loss: 0.0587gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 8.0133 - gen_gan_loss: 4.4409 - gen_l1_loss: 0.0357 - disc_loss: 0.2683 - accuracy: 0.8603 - SSIM_loss: 0.0587 - val_accuracy: 0.8663 - val_SSIM_loss: 0.0575
# Epoch 65/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.6685 - gen_gan_loss: 4.1741 - gen_l1_loss: 0.0349 - disc_loss: 0.3455 - accuracy: 0.8427 - SSIM_loss: 0.0578gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 329ms/step - gen_total_loss: 7.6635 - gen_gan_loss: 4.1716 - gen_l1_loss: 0.0349 - disc_loss: 0.3450 - accuracy: 0.8427 - SSIM_loss: 0.0578 - val_accuracy: 0.8156 - val_SSIM_loss: 0.0614
# Epoch 66/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.9781 - gen_gan_loss: 4.2526 - gen_l1_loss: 0.0373 - disc_loss: 0.2587 - accuracy: 0.8644 - SSIM_loss: 0.0602gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 334ms/step - gen_total_loss: 7.9779 - gen_gan_loss: 4.2555 - gen_l1_loss: 0.0372 - disc_loss: 0.2595 - accuracy: 0.8644 - SSIM_loss: 0.0602 - val_accuracy: 0.7770 - val_SSIM_loss: 0.0721
# Epoch 67/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.7081 - gen_gan_loss: 4.1502 - gen_l1_loss: 0.0356 - disc_loss: 0.3088 - accuracy: 0.8757 - SSIM_loss: 0.0590gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 121s 336ms/step - gen_total_loss: 7.7095 - gen_gan_loss: 4.1543 - gen_l1_loss: 0.0356 - disc_loss: 0.3081 - accuracy: 0.8757 - SSIM_loss: 0.0590 - val_accuracy: 0.8647 - val_SSIM_loss: 0.0598
# Epoch 68/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.4637 - gen_gan_loss: 4.0151 - gen_l1_loss: 0.0345 - disc_loss: 0.3364 - accuracy: 0.8621 - SSIM_loss: 0.0578gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 7.4701 - gen_gan_loss: 4.0238 - gen_l1_loss: 0.0345 - disc_loss: 0.3355 - accuracy: 0.8621 - SSIM_loss: 0.0578 - val_accuracy: 0.8739 - val_SSIM_loss: 0.0696
# Epoch 69/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.6985 - gen_gan_loss: 4.1654 - gen_l1_loss: 0.0353 - disc_loss: 0.2518 - accuracy: 0.8634 - SSIM_loss: 0.0595gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 7.6947 - gen_gan_loss: 4.1656 - gen_l1_loss: 0.0353 - disc_loss: 0.2525 - accuracy: 0.8634 - SSIM_loss: 0.0595 - val_accuracy: 0.8717 - val_SSIM_loss: 0.0570
# Epoch 70/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.5024 - gen_gan_loss: 4.6734 - gen_l1_loss: 0.0383 - disc_loss: 0.2658 - accuracy: 0.8546 - SSIM_loss: 0.0610gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 328ms/step - gen_total_loss: 8.4992 - gen_gan_loss: 4.6689 - gen_l1_loss: 0.0383 - disc_loss: 0.2654 - accuracy: 0.8546 - SSIM_loss: 0.0610 - val_accuracy: 0.8371 - val_SSIM_loss: 0.0620
# Epoch 71/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.3632 - gen_gan_loss: 4.5831 - gen_l1_loss: 0.0378 - disc_loss: 0.1949 - accuracy: 0.8672 - SSIM_loss: 0.0605gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 8.3608 - gen_gan_loss: 4.5823 - gen_l1_loss: 0.0378 - disc_loss: 0.1944 - accuracy: 0.8672 - SSIM_loss: 0.0605 - val_accuracy: 0.8169 - val_SSIM_loss: 0.0587
# Epoch 72/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.2042 - gen_gan_loss: 4.4620 - gen_l1_loss: 0.0374 - disc_loss: 0.2058 - accuracy: 0.8316 - SSIM_loss: 0.0643gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.1932 - gen_gan_loss: 4.4538 - gen_l1_loss: 0.0374 - disc_loss: 0.2061 - accuracy: 0.8316 - SSIM_loss: 0.0643 - val_accuracy: 0.8969 - val_SSIM_loss: 0.0636
# Epoch 73/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.9972 - gen_gan_loss: 4.3464 - gen_l1_loss: 0.0365 - disc_loss: 0.2762 - accuracy: 0.8348 - SSIM_loss: 0.0623gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 332ms/step - gen_total_loss: 7.9868 - gen_gan_loss: 4.3375 - gen_l1_loss: 0.0365 - disc_loss: 0.2776 - accuracy: 0.8348 - SSIM_loss: 0.0623 - val_accuracy: 0.8774 - val_SSIM_loss: 0.0621
# Epoch 74/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.3817 - gen_gan_loss: 4.6495 - gen_l1_loss: 0.0373 - disc_loss: 0.2489 - accuracy: 0.8309 - SSIM_loss: 0.0603gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 8.3703 - gen_gan_loss: 4.6425 - gen_l1_loss: 0.0373 - disc_loss: 0.2490 - accuracy: 0.8309 - SSIM_loss: 0.0603 - val_accuracy: 0.5699 - val_SSIM_loss: 0.0633
# Epoch 75/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.1263 - gen_gan_loss: 4.3336 - gen_l1_loss: 0.0379 - disc_loss: 0.2935 - accuracy: 0.8494 - SSIM_loss: 0.0609gan monitori shapes, (21, 128, 128, 3) (21, 128, 128, 3) (21, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 8.1159 - gen_gan_loss: 4.3267 - gen_l1_loss: 0.0379 - disc_loss: 0.2934 - accuracy: 0.8494 - SSIM_loss: 0.0609 - val_accuracy: 0.8643 - val_SSIM_loss: 0.0584
# Epoch 76/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.3814 - gen_gan_loss: 4.6805 - gen_l1_loss: 0.0370 - disc_loss: 0.1742 - accuracy: 0.8474 - SSIM_loss: 0.0608gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 8.3816 - gen_gan_loss: 4.6820 - gen_l1_loss: 0.0370 - disc_loss: 0.1738 - accuracy: 0.8474 - SSIM_loss: 0.0608 - val_accuracy: 0.8639 - val_SSIM_loss: 0.0667
# Epoch 77/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.4511 - gen_gan_loss: 4.8288 - gen_l1_loss: 0.0362 - disc_loss: 0.2696 - accuracy: 0.8586 - SSIM_loss: 0.0595gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.4429 - gen_gan_loss: 4.8238 - gen_l1_loss: 0.0362 - disc_loss: 0.2694 - accuracy: 0.8586 - SSIM_loss: 0.0595 - val_accuracy: 0.8645 - val_SSIM_loss: 0.0594
# Epoch 78/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.5210 - gen_gan_loss: 4.7266 - gen_l1_loss: 0.0379 - disc_loss: 0.2302 - accuracy: 0.8635 - SSIM_loss: 0.0614gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 8.5178 - gen_gan_loss: 4.7260 - gen_l1_loss: 0.0379 - disc_loss: 0.2297 - accuracy: 0.8635 - SSIM_loss: 0.0614 - val_accuracy: 0.8456 - val_SSIM_loss: 0.0493
# Epoch 79/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.6836 - gen_gan_loss: 4.8953 - gen_l1_loss: 0.0379 - disc_loss: 0.1769 - accuracy: 0.8526 - SSIM_loss: 0.0613gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 8.6776 - gen_gan_loss: 4.8914 - gen_l1_loss: 0.0379 - disc_loss: 0.1766 - accuracy: 0.8526 - SSIM_loss: 0.0613 - val_accuracy: 0.8810 - val_SSIM_loss: 0.0513
# Epoch 80/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.7377 - gen_gan_loss: 5.0429 - gen_l1_loss: 0.0369 - disc_loss: 0.2081 - accuracy: 0.8606 - SSIM_loss: 0.0594gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 8.7417 - gen_gan_loss: 5.0499 - gen_l1_loss: 0.0369 - disc_loss: 0.2117 - accuracy: 0.8606 - SSIM_loss: 0.0594 - val_accuracy: 0.8066 - val_SSIM_loss: 0.0529
# Epoch 81/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.2240 - gen_gan_loss: 4.5911 - gen_l1_loss: 0.0363 - disc_loss: 0.3054 - accuracy: 0.8472 - SSIM_loss: 0.0590gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.2331 - gen_gan_loss: 4.5982 - gen_l1_loss: 0.0363 - disc_loss: 0.3046 - accuracy: 0.8472 - SSIM_loss: 0.0590 - val_accuracy: 0.9081 - val_SSIM_loss: 0.0512
# Epoch 82/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.1711 - gen_gan_loss: 4.5062 - gen_l1_loss: 0.0366 - disc_loss: 0.2859 - accuracy: 0.8526 - SSIM_loss: 0.0606gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.1731 - gen_gan_loss: 4.5067 - gen_l1_loss: 0.0367 - disc_loss: 0.2851 - accuracy: 0.8526 - SSIM_loss: 0.0606 - val_accuracy: 0.8376 - val_SSIM_loss: 0.0623
# Epoch 83/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.3517 - gen_gan_loss: 5.3481 - gen_l1_loss: 0.0400 - disc_loss: 0.0982 - accuracy: 0.8571 - SSIM_loss: 0.0632gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 9.3471 - gen_gan_loss: 5.3401 - gen_l1_loss: 0.0401 - disc_loss: 0.0983 - accuracy: 0.8571 - SSIM_loss: 0.0632 - val_accuracy: 0.8794 - val_SSIM_loss: 0.0544
# Epoch 84/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.9092 - gen_gan_loss: 4.8253 - gen_l1_loss: 0.0408 - disc_loss: 0.2802 - accuracy: 0.8594 - SSIM_loss: 0.0645gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.9052 - gen_gan_loss: 4.8230 - gen_l1_loss: 0.0408 - disc_loss: 0.2795 - accuracy: 0.8594 - SSIM_loss: 0.0645 - val_accuracy: 0.8730 - val_SSIM_loss: 0.0577
# Epoch 85/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.1863 - gen_gan_loss: 4.5273 - gen_l1_loss: 0.0366 - disc_loss: 0.2807 - accuracy: 0.8710 - SSIM_loss: 0.0596gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 118s 329ms/step - gen_total_loss: 8.1845 - gen_gan_loss: 4.5263 - gen_l1_loss: 0.0366 - disc_loss: 0.2800 - accuracy: 0.8710 - SSIM_loss: 0.0596 - val_accuracy: 0.8742 - val_SSIM_loss: 0.0556
# Epoch 86/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.4456 - gen_gan_loss: 4.8314 - gen_l1_loss: 0.0361 - disc_loss: 0.2517 - accuracy: 0.8669 - SSIM_loss: 0.0589gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.4620 - gen_gan_loss: 4.8467 - gen_l1_loss: 0.0362 - disc_loss: 0.2531 - accuracy: 0.8669 - SSIM_loss: 0.0589 - val_accuracy: 0.8421 - val_SSIM_loss: 0.0590
# Epoch 87/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.5568 - gen_gan_loss: 5.5385 - gen_l1_loss: 0.0402 - disc_loss: 0.1009 - accuracy: 0.8738 - SSIM_loss: 0.0630gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 333ms/step - gen_total_loss: 9.5695 - gen_gan_loss: 5.5489 - gen_l1_loss: 0.0402 - disc_loss: 0.1006 - accuracy: 0.8738 - SSIM_loss: 0.0630 - val_accuracy: 0.8419 - val_SSIM_loss: 0.0747
# Epoch 88/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.8213 - gen_gan_loss: 5.6596 - gen_l1_loss: 0.0416 - disc_loss: 0.1635 - accuracy: 0.8520 - SSIM_loss: 0.0646gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 9.8114 - gen_gan_loss: 5.6513 - gen_l1_loss: 0.0416 - disc_loss: 0.1634 - accuracy: 0.8520 - SSIM_loss: 0.0646 - val_accuracy: 0.8974 - val_SSIM_loss: 0.0563
# Epoch 89/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.3203 - gen_gan_loss: 4.7033 - gen_l1_loss: 0.0362 - disc_loss: 0.2668 - accuracy: 0.8439 - SSIM_loss: 0.0601gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 331ms/step - gen_total_loss: 8.3361 - gen_gan_loss: 4.7177 - gen_l1_loss: 0.0362 - disc_loss: 0.2662 - accuracy: 0.8439 - SSIM_loss: 0.0601 - val_accuracy: 0.8579 - val_SSIM_loss: 0.0656
# Epoch 90/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.4720 - gen_gan_loss: 4.9671 - gen_l1_loss: 0.0350 - disc_loss: 0.2698 - accuracy: 0.8447 - SSIM_loss: 0.0576gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 8.4733 - gen_gan_loss: 4.9679 - gen_l1_loss: 0.0351 - disc_loss: 0.2691 - accuracy: 0.8447 - SSIM_loss: 0.0576 - val_accuracy: 0.8397 - val_SSIM_loss: 0.0545
# Epoch 91/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.1190 - gen_gan_loss: 4.7241 - gen_l1_loss: 0.0339 - disc_loss: 0.2198 - accuracy: 0.8423 - SSIM_loss: 0.0570gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 332ms/step - gen_total_loss: 8.1262 - gen_gan_loss: 4.7311 - gen_l1_loss: 0.0340 - disc_loss: 0.2208 - accuracy: 0.8423 - SSIM_loss: 0.0570 - val_accuracy: 0.9054 - val_SSIM_loss: 0.0511
# Epoch 92/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 7.9691 - gen_gan_loss: 4.6421 - gen_l1_loss: 0.0333 - disc_loss: 0.2191 - accuracy: 0.8560 - SSIM_loss: 0.0563gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 120s 334ms/step - gen_total_loss: 7.9832 - gen_gan_loss: 4.6506 - gen_l1_loss: 0.0333 - disc_loss: 0.2186 - accuracy: 0.8560 - SSIM_loss: 0.0563 - val_accuracy: 0.7669 - val_SSIM_loss: 0.0868
# Epoch 93/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.6515 - gen_gan_loss: 5.1584 - gen_l1_loss: 0.0349 - disc_loss: 0.1483 - accuracy: 0.8445 - SSIM_loss: 0.0577gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 119s 330ms/step - gen_total_loss: 8.6545 - gen_gan_loss: 5.1614 - gen_l1_loss: 0.0349 - disc_loss: 0.1498 - accuracy: 0.8445 - SSIM_loss: 0.0577 - val_accuracy: 0.8933 - val_SSIM_loss: 0.0550
# Epoch 94/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.3369 - gen_gan_loss: 4.8151 - gen_l1_loss: 0.0352 - disc_loss: 0.2329 - accuracy: 0.8624 - SSIM_loss: 0.0587gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# ...
# 360/360 [==============================] - 88s 246ms/step - gen_total_loss: 9.6791 - gen_gan_loss: 6.2010 - gen_l1_loss: 0.0348 - disc_loss: 0.1476 - accuracy: 0.8757 - SSIM_loss: 0.0572 - val_accuracy: 0.8935 - val_SSIM_loss: 0.0589
# Epoch 170/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.8621 - gen_gan_loss: 5.5750 - gen_l1_loss: 0.0329 - disc_loss: 0.1918 - accuracy: 0.8835 - SSIM_loss: 0.0548gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 91s 251ms/step - gen_total_loss: 8.8649 - gen_gan_loss: 5.5771 - gen_l1_loss: 0.0329 - disc_loss: 0.1913 - accuracy: 0.8835 - SSIM_loss: 0.0548 - val_accuracy: 0.9096 - val_SSIM_loss: 0.0594
# Epoch 171/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.2816 - gen_gan_loss: 5.8626 - gen_l1_loss: 0.0342 - disc_loss: 0.1462 - accuracy: 0.8767 - SSIM_loss: 0.0566gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 9.2854 - gen_gan_loss: 5.8666 - gen_l1_loss: 0.0342 - disc_loss: 0.1458 - accuracy: 0.8767 - SSIM_loss: 0.0566 - val_accuracy: 0.8731 - val_SSIM_loss: 0.0545
# Epoch 172/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.8574 - gen_gan_loss: 6.2625 - gen_l1_loss: 0.0359 - disc_loss: 0.1387 - accuracy: 0.8624 - SSIM_loss: 0.0588gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 9.8580 - gen_gan_loss: 6.2605 - gen_l1_loss: 0.0360 - disc_loss: 0.1384 - accuracy: 0.8624 - SSIM_loss: 0.0588 - val_accuracy: 0.8806 - val_SSIM_loss: 0.0632
# Epoch 173/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.6939 - gen_gan_loss: 6.0830 - gen_l1_loss: 0.0361 - disc_loss: 0.1637 - accuracy: 0.8651 - SSIM_loss: 0.0600gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 88s 246ms/step - gen_total_loss: 9.7019 - gen_gan_loss: 6.0900 - gen_l1_loss: 0.0361 - disc_loss: 0.1641 - accuracy: 0.8651 - SSIM_loss: 0.0600 - val_accuracy: 0.8966 - val_SSIM_loss: 0.0538
# Epoch 174/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.4007 - gen_gan_loss: 6.5441 - gen_l1_loss: 0.0386 - disc_loss: 0.1071 - accuracy: 0.8794 - SSIM_loss: 0.0635gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 248ms/step - gen_total_loss: 10.3982 - gen_gan_loss: 6.5402 - gen_l1_loss: 0.0386 - disc_loss: 0.1069 - accuracy: 0.8794 - SSIM_loss: 0.0635 - val_accuracy: 0.8512 - val_SSIM_loss: 0.0558
# Epoch 175/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.1493 - gen_gan_loss: 5.6469 - gen_l1_loss: 0.0350 - disc_loss: 0.1856 - accuracy: 0.8762 - SSIM_loss: 0.0584gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 247ms/step - gen_total_loss: 9.1624 - gen_gan_loss: 5.6606 - gen_l1_loss: 0.0350 - disc_loss: 0.1851 - accuracy: 0.8762 - SSIM_loss: 0.0584 - val_accuracy: 0.8401 - val_SSIM_loss: 0.0651
# Epoch 176/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.7949 - gen_gan_loss: 6.1692 - gen_l1_loss: 0.0363 - disc_loss: 0.1973 - accuracy: 0.8849 - SSIM_loss: 0.0585gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 9.7815 - gen_gan_loss: 6.1584 - gen_l1_loss: 0.0362 - disc_loss: 0.1973 - accuracy: 0.8849 - SSIM_loss: 0.0585 - val_accuracy: 0.8907 - val_SSIM_loss: 0.0566
# Epoch 177/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.0858 - gen_gan_loss: 5.6649 - gen_l1_loss: 0.0342 - disc_loss: 0.1284 - accuracy: 0.8797 - SSIM_loss: 0.0589gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 9.0829 - gen_gan_loss: 5.6624 - gen_l1_loss: 0.0342 - disc_loss: 0.1281 - accuracy: 0.8797 - SSIM_loss: 0.0589 - val_accuracy: 0.8675 - val_SSIM_loss: 0.0644
# Epoch 178/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.9592 - gen_gan_loss: 6.9605 - gen_l1_loss: 0.0400 - disc_loss: 0.0739 - accuracy: 0.8690 - SSIM_loss: 0.0634gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 10.9584 - gen_gan_loss: 6.9611 - gen_l1_loss: 0.0400 - disc_loss: 0.0737 - accuracy: 0.8690 - SSIM_loss: 0.0634 - val_accuracy: 0.8211 - val_SSIM_loss: 0.0632
# Epoch 179/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.0256 - gen_gan_loss: 6.2994 - gen_l1_loss: 0.0373 - disc_loss: 0.1381 - accuracy: 0.8738 - SSIM_loss: 0.0617gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 247ms/step - gen_total_loss: 10.0196 - gen_gan_loss: 6.2916 - gen_l1_loss: 0.0373 - disc_loss: 0.1380 - accuracy: 0.8738 - SSIM_loss: 0.0617 - val_accuracy: 0.8939 - val_SSIM_loss: 0.0569
# Epoch 180/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.2527 - gen_gan_loss: 6.4081 - gen_l1_loss: 0.0384 - disc_loss: 0.0951 - accuracy: 0.8783 - SSIM_loss: 0.0629gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 91s 252ms/step - gen_total_loss: 10.2506 - gen_gan_loss: 6.4083 - gen_l1_loss: 0.0384 - disc_loss: 0.0950 - accuracy: 0.8783 - SSIM_loss: 0.0629 - val_accuracy: 0.8699 - val_SSIM_loss: 0.0604
# Epoch 181/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.8178 - gen_gan_loss: 6.7200 - gen_l1_loss: 0.0410 - disc_loss: 0.0787 - accuracy: 0.8758 - SSIM_loss: 0.0644gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 10.8109 - gen_gan_loss: 6.7155 - gen_l1_loss: 0.0410 - disc_loss: 0.0786 - accuracy: 0.8758 - SSIM_loss: 0.0644 - val_accuracy: 0.8790 - val_SSIM_loss: 0.0623
# Epoch 182/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.6134 - gen_gan_loss: 5.8418 - gen_l1_loss: 0.0377 - disc_loss: 0.2038 - accuracy: 0.8666 - SSIM_loss: 0.0615gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 247ms/step - gen_total_loss: 9.6149 - gen_gan_loss: 5.8443 - gen_l1_loss: 0.0377 - disc_loss: 0.2033 - accuracy: 0.8666 - SSIM_loss: 0.0615 - val_accuracy: 0.8726 - val_SSIM_loss: 0.0695
# Epoch 183/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.5893 - gen_gan_loss: 6.5941 - gen_l1_loss: 0.0400 - disc_loss: 0.0704 - accuracy: 0.8606 - SSIM_loss: 0.0619gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 88s 244ms/step - gen_total_loss: 10.5815 - gen_gan_loss: 6.5888 - gen_l1_loss: 0.0399 - disc_loss: 0.0703 - accuracy: 0.8606 - SSIM_loss: 0.0619 - val_accuracy: 0.8607 - val_SSIM_loss: 0.0696
# Epoch 184/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.6775 - gen_gan_loss: 6.7219 - gen_l1_loss: 0.0396 - disc_loss: 0.1111 - accuracy: 0.8658 - SSIM_loss: 0.0621gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 248ms/step - gen_total_loss: 10.6726 - gen_gan_loss: 6.7196 - gen_l1_loss: 0.0395 - disc_loss: 0.1108 - accuracy: 0.8658 - SSIM_loss: 0.0621 - val_accuracy: 0.8633 - val_SSIM_loss: 0.0647
# Epoch 185/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.1748 - gen_gan_loss: 6.3996 - gen_l1_loss: 0.0378 - disc_loss: 0.1507 - accuracy: 0.8658 - SSIM_loss: 0.0625gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 92s 256ms/step - gen_total_loss: 10.1767 - gen_gan_loss: 6.3999 - gen_l1_loss: 0.0378 - disc_loss: 0.1503 - accuracy: 0.8658 - SSIM_loss: 0.0625 - val_accuracy: 0.8781 - val_SSIM_loss: 0.0588
# Epoch 186/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.3263 - gen_gan_loss: 6.6272 - gen_l1_loss: 0.0370 - disc_loss: 0.0656 - accuracy: 0.8707 - SSIM_loss: 0.0618gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 91s 252ms/step - gen_total_loss: 10.3369 - gen_gan_loss: 6.6381 - gen_l1_loss: 0.0370 - disc_loss: 0.0654 - accuracy: 0.8707 - SSIM_loss: 0.0618 - val_accuracy: 0.9000 - val_SSIM_loss: 0.0622
# Epoch 187/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.5049 - gen_gan_loss: 6.9986 - gen_l1_loss: 0.0351 - disc_loss: 0.0514 - accuracy: 0.8697 - SSIM_loss: 0.0602gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 10.5008 - gen_gan_loss: 6.9941 - gen_l1_loss: 0.0351 - disc_loss: 0.0513 - accuracy: 0.8697 - SSIM_loss: 0.0602 - val_accuracy: 0.8722 - val_SSIM_loss: 0.0562
# Epoch 188/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.7765 - gen_gan_loss: 6.1437 - gen_l1_loss: 0.0363 - disc_loss: 0.2361 - accuracy: 0.8718 - SSIM_loss: 0.0609gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 91s 251ms/step - gen_total_loss: 9.7882 - gen_gan_loss: 6.1554 - gen_l1_loss: 0.0363 - disc_loss: 0.2368 - accuracy: 0.8718 - SSIM_loss: 0.0609 - val_accuracy: 0.8977 - val_SSIM_loss: 0.0550
# Epoch 189/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.9709 - gen_gan_loss: 6.4249 - gen_l1_loss: 0.0355 - disc_loss: 0.0991 - accuracy: 0.8881 - SSIM_loss: 0.0614gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 88s 245ms/step - gen_total_loss: 9.9627 - gen_gan_loss: 6.4178 - gen_l1_loss: 0.0354 - disc_loss: 0.0990 - accuracy: 0.8881 - SSIM_loss: 0.0614 - val_accuracy: 0.9066 - val_SSIM_loss: 0.0609
# Epoch 190/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.4434 - gen_gan_loss: 6.1701 - gen_l1_loss: 0.0327 - disc_loss: 0.1594 - accuracy: 0.8791 - SSIM_loss: 0.0566gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 88s 245ms/step - gen_total_loss: 9.4360 - gen_gan_loss: 6.1620 - gen_l1_loss: 0.0327 - disc_loss: 0.1593 - accuracy: 0.8791 - SSIM_loss: 0.0566 - val_accuracy: 0.8991 - val_SSIM_loss: 0.0548
# Epoch 191/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.5993 - gen_gan_loss: 6.3110 - gen_l1_loss: 0.0329 - disc_loss: 0.1303 - accuracy: 0.8776 - SSIM_loss: 0.0558gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 91s 253ms/step - gen_total_loss: 9.6094 - gen_gan_loss: 6.3202 - gen_l1_loss: 0.0329 - disc_loss: 0.1299 - accuracy: 0.8776 - SSIM_loss: 0.0558 - val_accuracy: 0.8464 - val_SSIM_loss: 0.0562
# Epoch 192/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.3052 - gen_gan_loss: 6.1451 - gen_l1_loss: 0.0316 - disc_loss: 0.1402 - accuracy: 0.8615 - SSIM_loss: 0.0542gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 247ms/step - gen_total_loss: 9.3212 - gen_gan_loss: 6.1618 - gen_l1_loss: 0.0316 - disc_loss: 0.1399 - accuracy: 0.8615 - SSIM_loss: 0.0542 - val_accuracy: 0.8738 - val_SSIM_loss: 0.0576
# Epoch 193/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.2781 - gen_gan_loss: 6.1090 - gen_l1_loss: 0.0317 - disc_loss: 0.1573 - accuracy: 0.8778 - SSIM_loss: 0.0537gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 9.2964 - gen_gan_loss: 6.1269 - gen_l1_loss: 0.0317 - disc_loss: 0.1570 - accuracy: 0.8778 - SSIM_loss: 0.0537 - val_accuracy: 0.8980 - val_SSIM_loss: 0.0577
# Epoch 194/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.0698 - gen_gan_loss: 5.9442 - gen_l1_loss: 0.0313 - disc_loss: 0.1891 - accuracy: 0.8777 - SSIM_loss: 0.0537gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 9.0617 - gen_gan_loss: 5.9324 - gen_l1_loss: 0.0313 - disc_loss: 0.1901 - accuracy: 0.8777 - SSIM_loss: 0.0537 - val_accuracy: 0.8649 - val_SSIM_loss: 0.0544
# Epoch 195/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.3842 - gen_gan_loss: 6.0581 - gen_l1_loss: 0.0333 - disc_loss: 0.1281 - accuracy: 0.8676 - SSIM_loss: 0.0566 - ETA: 9s - gen_total_loss: 9.3594 - gen_gan_loss: 6.0450 - gen_l1_loss: 0.0331 - disc_loss: 0.gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 91s 252ms/step - gen_total_loss: 9.3746 - gen_gan_loss: 6.0486 - gen_l1_loss: 0.0333 - disc_loss: 0.1282 - accuracy: 0.8676 - SSIM_loss: 0.0566 - val_accuracy: 0.8789 - val_SSIM_loss: 0.0596
# Epoch 196/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 10.1602 - gen_gan_loss: 6.8725 - gen_l1_loss: 0.0329 - disc_loss: 0.0438 - accuracy: 0.8586 - SSIM_loss: 0.0556gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 248ms/step - gen_total_loss: 10.1671 - gen_gan_loss: 6.8759 - gen_l1_loss: 0.0329 - disc_loss: 0.0437 - accuracy: 0.8586 - SSIM_loss: 0.0556 - val_accuracy: 0.8621 - val_SSIM_loss: 0.0587
# Epoch 197/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.7981 - gen_gan_loss: 6.5557 - gen_l1_loss: 0.0324 - disc_loss: 0.0949 - accuracy: 0.8676 - SSIM_loss: 0.0557gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 91s 253ms/step - gen_total_loss: 9.8069 - gen_gan_loss: 6.5618 - gen_l1_loss: 0.0325 - disc_loss: 0.0947 - accuracy: 0.8676 - SSIM_loss: 0.0557 - val_accuracy: 0.8905 - val_SSIM_loss: 0.0571
# Epoch 198/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.5285 - gen_gan_loss: 6.4109 - gen_l1_loss: 0.0312 - disc_loss: 0.0981 - accuracy: 0.8797 - SSIM_loss: 0.0539gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 9.5158 - gen_gan_loss: 6.3984 - gen_l1_loss: 0.0312 - disc_loss: 0.0990 - accuracy: 0.8797 - SSIM_loss: 0.0539 - val_accuracy: 0.8547 - val_SSIM_loss: 0.0528
# Epoch 199/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 8.7512 - gen_gan_loss: 5.5876 - gen_l1_loss: 0.0316 - disc_loss: 0.2963 - accuracy: 0.8753 - SSIM_loss: 0.0549gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 246ms/step - gen_total_loss: 8.7579 - gen_gan_loss: 5.5947 - gen_l1_loss: 0.0316 - disc_loss: 0.2955 - accuracy: 0.8753 - SSIM_loss: 0.0549 - val_accuracy: 0.8476 - val_SSIM_loss: 0.0529
# Epoch 200/200
# 360/360 [==============================] - ETA: 0s - gen_total_loss: 9.8219 - gen_gan_loss: 6.4629 - gen_l1_loss: 0.0336 - disc_loss: 0.1040 - accuracy: 0.8878 - SSIM_loss: 0.0578gan monitori shapes, (30, 128, 128, 3) (30, 128, 128, 3) (30, 128, 128, 3)
# 360/360 [==============================] - 89s 248ms/step - gen_total_loss: 9.8224 - gen_gan_loss: 6.4639 - gen_l1_loss: 0.0336 - disc_loss: 0.1038 - accuracy: 0.8878 - SSIM_loss: 0.0578 - val_accuracy: 0.8789 - val_SSIM_loss: 0.0617
