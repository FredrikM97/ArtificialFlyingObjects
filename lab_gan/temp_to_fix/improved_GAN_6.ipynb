# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()
import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns
from datetime import datetime
import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='Pix2Pix_model_v4'
    __changes__="Changed to a pix2pix model in order to test a greater network for generator and discriminator. Generator: U-Net, Discriminator: PatchGAN. Changed Discriminator optimizer to SGD. Running with wasserstein_loss"
    
    __normalization__='[-1,1]'
    __jitter__= False
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
    
    @staticmethod
    def discriminator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def main():
            
            initializer = tf.random_normal_initializer(0., 0.02)

            inp = tf.keras.layers.Input(shape=image_shape, name='input_image')
            tar = tf.keras.layers.Input(shape=image_shape, name='target_image')

            x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

            down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
            down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
            down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

            zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
            conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                        kernel_initializer=initializer,
                                        use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

            batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

            leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

            zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

            last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                        kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

            return tf.keras.Model(inputs=[inp, tar], outputs=last)
        
        
        return main()
    
    @staticmethod
    def generator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def upsample(filters, size, apply_dropout=False):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                            padding='same',
                                            kernel_initializer=initializer,
                                            use_bias=False))

            result.add(tf.keras.layers.BatchNormalization())

            if apply_dropout:
                result.add(tf.keras.layers.Dropout(0.5))

            result.add(tf.keras.layers.ReLU())

            return result

        def main():
            inputs = tf.keras.layers.Input(shape=image_shape)

            down_stack = [
                downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
                downsample(128, 4), # (bs, 64, 64, 128)
                downsample(256, 4), # (bs, 32, 32, 256)
                downsample(512, 4), # (bs, 16, 16, 512)
                downsample(512, 4), # (bs, 8, 8, 512)
                downsample(512, 4), # (bs, 4, 4, 512)
                downsample(512, 4), # (bs, 2, 2, 512)
                #downsample(512, 4), # (bs, 1, 1, 512)
            ]

            up_stack = [
                upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
                upsample(512, 4), # (bs, 16, 16, 1024)
                upsample(256, 4), # (bs, 32, 32, 512)
                upsample(128, 4), # (bs, 64, 64, 256)
                upsample(64, 4), # (bs, 128, 128, 128)
            ]

            initializer = tf.random_normal_initializer(0., 0.02)
            last = tf.keras.layers.Conv2DTranspose(3, 4,
                                                 strides=2,
                                                 padding='same',
                                                 kernel_initializer=initializer,
                                                 activation='tanh') # (bs, 256, 256, 3)

            x = inputs

            # Downsampling through the model
            skips = []
            for down in down_stack:
                x = down(x)
                skips.append(x)

            skips = reversed(skips[:-1])

            # Upsampling and establishing the skip connections
            for up, skip in zip(up_stack, skips):
                x = up(x)
                x = tf.keras.layers.Concatenate()([x, skip])

            x = last(x)

            return tf.keras.Model(inputs=inputs, outputs=x)
        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        LAMBDA = 100
        
        def generator_loss(gen_output, target): # https://arxiv.org/abs/1611.07004
            return wasserstein_loss(gen_output,target)

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss
        
        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__, jitter=architecture.__jitter__)
# Out:
# train_x (30, 128, 128, 3) float32 -1.0 1.0
# train_y (30, 128, 128, 3) float32 -1.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            wasser_loss = self.g_loss(gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(wasser_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'wasser_loss':wasser_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')
file_writer = tf.summary.create_file_writer(log_dir + "/plots/")

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - wasser_loss: 0.0248 - disc_loss: 1.7724 - accuracy: 0.4326 - SSIM_loss: 0.9964WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 360/360 [==============================] - 120s 334ms/step - wasser_loss: -0.9156 - disc_loss: 0.1047 - accuracy: 0.4713 - SSIM_loss: 1.7706 - val_accuracy: 0.3932 - val_SSIM_loss: 1.8198
# Epoch 2/200
# 360/360 [==============================] - 122s 338ms/step - wasser_loss: -0.9731 - disc_loss: 0.0033 - accuracy: 0.3722 - SSIM_loss: 1.8199 - val_accuracy: 0.2667 - val_SSIM_loss: 1.8112
# Epoch 3/200
# 360/360 [==============================] - 122s 339ms/step - wasser_loss: -0.9854 - disc_loss: 0.0017 - accuracy: 0.3345 - SSIM_loss: 1.8236 - val_accuracy: 0.4075 - val_SSIM_loss: 1.8092
# Epoch 4/200
# 360/360 [==============================] - 121s 336ms/step - wasser_loss: -0.9897 - disc_loss: 0.0011 - accuracy: 0.3318 - SSIM_loss: 1.8223 - val_accuracy: 0.2133 - val_SSIM_loss: 1.8096
# Epoch 5/200
# 360/360 [==============================] - 117s 325ms/step - wasser_loss: -0.9915 - disc_loss: 8.5608e-04 - accuracy: 0.3451 - SSIM_loss: 1.8197 - val_accuracy: 0.2937 - val_SSIM_loss: 1.8068
# Epoch 6/200
# 360/360 [==============================] - 117s 324ms/step - wasser_loss: -0.9921 - disc_loss: 6.8358e-04 - accuracy: 0.3409 - SSIM_loss: 1.8173 - val_accuracy: 0.2410 - val_SSIM_loss: 1.8080
# Epoch 7/200
# 360/360 [==============================] - 116s 322ms/step - wasser_loss: -0.9930 - disc_loss: 5.6857e-04 - accuracy: 0.3438 - SSIM_loss: 1.8140 - val_accuracy: 0.3329 - val_SSIM_loss: 1.8023
# Epoch 8/200
# 360/360 [==============================] - 114s 317ms/step - wasser_loss: -0.9938 - disc_loss: 4.8680e-04 - accuracy: 0.3420 - SSIM_loss: 1.8107 - val_accuracy: 0.3648 - val_SSIM_loss: 1.8018
# Epoch 9/200
# 360/360 [==============================] - 116s 322ms/step - wasser_loss: -0.9943 - disc_loss: 4.2396e-04 - accuracy: 0.3602 - SSIM_loss: 1.8084 - val_accuracy: 0.2732 - val_SSIM_loss: 1.8041
# Epoch 10/200
# 360/360 [==============================] - 113s 315ms/step - wasser_loss: -0.9947 - disc_loss: 3.7303e-04 - accuracy: 0.3709 - SSIM_loss: 1.8075 - val_accuracy: 0.4154 - val_SSIM_loss: 1.8034
# Epoch 11/200
# 360/360 [==============================] - 115s 319ms/step - wasser_loss: -0.9949 - disc_loss: 3.3435e-04 - accuracy: 0.3785 - SSIM_loss: 1.8065 - val_accuracy: 0.4159 - val_SSIM_loss: 1.8081
# Epoch 12/200
# 360/360 [==============================] - 113s 315ms/step - wasser_loss: -0.9910 - disc_loss: 2.9783e-04 - accuracy: 0.4221 - SSIM_loss: 1.8109 - val_accuracy: 0.2632 - val_SSIM_loss: 1.8062
# Epoch 13/200
# 360/360 [==============================] - 117s 325ms/step - wasser_loss: -0.9942 - disc_loss: 2.7287e-04 - accuracy: 0.3706 - SSIM_loss: 1.8078 - val_accuracy: 0.3325 - val_SSIM_loss: 1.8058
# Epoch 14/200
# 360/360 [==============================] - 114s 318ms/step - wasser_loss: -0.9949 - disc_loss: 2.5201e-04 - accuracy: 0.3589 - SSIM_loss: 1.8062 - val_accuracy: 0.3056 - val_SSIM_loss: 1.8042
# Epoch 15/200
# 360/360 [==============================] - 114s 316ms/step - wasser_loss: -0.9951 - disc_loss: 2.3233e-04 - accuracy: 0.3610 - SSIM_loss: 1.8059 - val_accuracy: 0.2454 - val_SSIM_loss: 1.8039
# Epoch 16/200
# 360/360 [==============================] - 115s 319ms/step - wasser_loss: -0.9951 - disc_loss: 2.1500e-04 - accuracy: 0.3784 - SSIM_loss: 1.8062 - val_accuracy: 0.4485 - val_SSIM_loss: 1.8030
# Epoch 17/200
# 360/360 [==============================] - 115s 319ms/step - wasser_loss: -0.9952 - disc_loss: 2.0096e-04 - accuracy: 0.3917 - SSIM_loss: 1.8058 - val_accuracy: 0.4103 - val_SSIM_loss: 1.8043
# Epoch 18/200
# 360/360 [==============================] - 116s 322ms/step - wasser_loss: -0.9952 - disc_loss: 1.8875e-04 - accuracy: 0.4048 - SSIM_loss: 1.8053 - val_accuracy: 0.4137 - val_SSIM_loss: 1.8053
# Epoch 19/200
# 360/360 [==============================] - 114s 317ms/step - wasser_loss: -0.9953 - disc_loss: 1.7708e-04 - accuracy: 0.4221 - SSIM_loss: 1.8057 - val_accuracy: 0.4286 - val_SSIM_loss: 1.8041
# Epoch 20/200
# 360/360 [==============================] - 114s 315ms/step - wasser_loss: -0.9953 - disc_loss: 1.6625e-04 - accuracy: 0.4437 - SSIM_loss: 1.8055 - val_accuracy: 0.3870 - val_SSIM_loss: 1.8037
# Epoch 21/200
# 360/360 [==============================] - 114s 317ms/step - wasser_loss: -0.9932 - disc_loss: 1.5775e-04 - accuracy: 0.4709 - SSIM_loss: 1.8076 - val_accuracy: 0.8530 - val_SSIM_loss: 1.8158
# Epoch 22/200
# 360/360 [==============================] - 116s 321ms/step - wasser_loss: -0.9934 - disc_loss: 1.4723e-04 - accuracy: 0.5378 - SSIM_loss: 1.8100 - val_accuracy: 0.2899 - val_SSIM_loss: 1.8050
# Epoch 23/200
# 360/360 [==============================] - 114s 317ms/step - wasser_loss: -0.9952 - disc_loss: 1.4164e-04 - accuracy: 0.5125 - SSIM_loss: 1.8060 - val_accuracy: 0.4154 - val_SSIM_loss: 1.8056
# Epoch 24/200
# 360/360 [==============================] - 114s 316ms/step - wasser_loss: -0.9953 - disc_loss: 1.3647e-04 - accuracy: 0.5356 - SSIM_loss: 1.8053 - val_accuracy: 0.4474 - val_SSIM_loss: 1.8052
# Epoch 25/200
# 360/360 [==============================] - 114s 317ms/step - wasser_loss: -0.9953 - disc_loss: 1.2970e-04 - accuracy: 0.5560 - SSIM_loss: 1.8056 - val_accuracy: 0.4606 - val_SSIM_loss: 1.8041
# Epoch 26/200
# 360/360 [==============================] - 116s 322ms/step - wasser_loss: -0.9953 - disc_loss: 1.2397e-04 - accuracy: 0.5825 - SSIM_loss: 1.8057 - val_accuracy: 0.5214 - val_SSIM_loss: 1.8042
# Epoch 27/200
# 360/360 [==============================] - 115s 320ms/step - wasser_loss: -0.9940 - disc_loss: 1.1816e-04 - accuracy: 0.6192 - SSIM_loss: 1.8078 - val_accuracy: 0.5602 - val_SSIM_loss: 1.8053
# Epoch 28/200
# 360/360 [==============================] - 113s 314ms/step - wasser_loss: -0.9953 - disc_loss: 1.1385e-04 - accuracy: 0.6409 - SSIM_loss: 1.8055 - val_accuracy: 0.5685 - val_SSIM_loss: 1.8047
# Epoch 29/200
# 360/360 [==============================] - 114s 316ms/step - wasser_loss: -0.9953 - disc_loss: 1.0970e-04 - accuracy: 0.6715 - SSIM_loss: 1.8057 - val_accuracy: 0.5974 - val_SSIM_loss: 1.8057
# Epoch 30/200
# 360/360 [==============================] - 135s 376ms/step - wasser_loss: -0.9953 - disc_loss: 1.0574e-04 - accuracy: 0.6983 - SSIM_loss: 1.8053 - val_accuracy: 0.6172 - val_SSIM_loss: 1.8055
# Epoch 31/200
# 360/360 [==============================] - 146s 404ms/step - wasser_loss: -0.9953 - disc_loss: 1.0178e-04 - accuracy: 0.7113 - SSIM_loss: 1.8058 - val_accuracy: 0.7515 - val_SSIM_loss: 1.8038
# Epoch 32/200
# 360/360 [==============================] - 149s 414ms/step - wasser_loss: -0.9953 - disc_loss: 9.8198e-05 - accuracy: 0.7291 - SSIM_loss: 1.8055 - val_accuracy: 0.6371 - val_SSIM_loss: 1.8038
# Epoch 33/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9953 - disc_loss: 9.4851e-05 - accuracy: 0.7507 - SSIM_loss: 1.8058 - val_accuracy: 0.7454 - val_SSIM_loss: 1.8028
# Epoch 34/200
# 360/360 [==============================] - 148s 412ms/step - wasser_loss: -0.9952 - disc_loss: 9.1588e-05 - accuracy: 0.7697 - SSIM_loss: 1.8058 - val_accuracy: 0.6544 - val_SSIM_loss: 1.8066
# Epoch 35/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9949 - disc_loss: 8.8898e-05 - accuracy: 0.7461 - SSIM_loss: 1.8062 - val_accuracy: 0.6604 - val_SSIM_loss: 1.8032
# Epoch 36/200
# 360/360 [==============================] - 146s 407ms/step - wasser_loss: -0.9951 - disc_loss: 8.6397e-05 - accuracy: 0.7472 - SSIM_loss: 1.8056 - val_accuracy: 0.7330 - val_SSIM_loss: 1.8049
# Epoch 37/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.
# 360/360 [==============================] - 148s 412ms/step - wasser_loss: -0.9954 - disc_loss: 2.9073e-05 - accuracy: 0.8653 - SSIM_loss: 1.8062 - val_accuracy: 0.8531 - val_SSIM_loss: 1.8043
# Epoch 98/200
# 360/360 [==============================] - 146s 404ms/step - wasser_loss: -0.9954 - disc_loss: 2.8918e-05 - accuracy: 0.8664 - SSIM_loss: 1.8067 - val_accuracy: 0.8525 - val_SSIM_loss: 1.8054
# Epoch 99/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 2.8626e-05 - accuracy: 0.8658 - SSIM_loss: 1.8062 - val_accuracy: 0.8500 - val_SSIM_loss: 1.8033
# Epoch 100/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 2.8480e-05 - accuracy: 0.8664 - SSIM_loss: 1.8062 - val_accuracy: 0.8554 - val_SSIM_loss: 1.8038
# Epoch 101/200
# 360/360 [==============================] - 148s 410ms/step - wasser_loss: -0.9954 - disc_loss: 2.7821e-05 - accuracy: 0.8673 - SSIM_loss: 1.8066 - val_accuracy: 0.8546 - val_SSIM_loss: 1.8046
# Epoch 102/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9954 - disc_loss: 2.7676e-05 - accuracy: 0.8674 - SSIM_loss: 1.8062 - val_accuracy: 0.8553 - val_SSIM_loss: 1.8045
# Epoch 103/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9953 - disc_loss: 2.7585e-05 - accuracy: 0.8666 - SSIM_loss: 1.8058 - val_accuracy: 0.8554 - val_SSIM_loss: 1.8036
# Epoch 104/200
# 360/360 [==============================] - 149s 414ms/step - wasser_loss: -0.9954 - disc_loss: 2.7079e-05 - accuracy: 0.8667 - SSIM_loss: 1.8069 - val_accuracy: 0.8547 - val_SSIM_loss: 1.8034
# Epoch 105/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 2.6893e-05 - accuracy: 0.8672 - SSIM_loss: 1.8060 - val_accuracy: 0.8568 - val_SSIM_loss: 1.8052
# Epoch 106/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 2.6483e-05 - accuracy: 0.8679 - SSIM_loss: 1.8069 - val_accuracy: 0.8557 - val_SSIM_loss: 1.8052
# Epoch 107/200
# 360/360 [==============================] - 149s 415ms/step - wasser_loss: -0.9953 - disc_loss: 2.6365e-05 - accuracy: 0.8672 - SSIM_loss: 1.8059 - val_accuracy: 0.8554 - val_SSIM_loss: 1.8042
# Epoch 108/200
# 360/360 [==============================] - 147s 410ms/step - wasser_loss: -0.9954 - disc_loss: 2.6070e-05 - accuracy: 0.8671 - SSIM_loss: 1.8063 - val_accuracy: 0.8547 - val_SSIM_loss: 1.8042
# Epoch 109/200
# 360/360 [==============================] - 145s 403ms/step - wasser_loss: -0.9954 - disc_loss: 2.5702e-05 - accuracy: 0.8671 - SSIM_loss: 1.8069 - val_accuracy: 0.8559 - val_SSIM_loss: 1.8037
# Epoch 110/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 2.5760e-05 - accuracy: 0.8668 - SSIM_loss: 1.8058 - val_accuracy: 0.8566 - val_SSIM_loss: 1.8062
# Epoch 111/200
# 360/360 [==============================] - 151s 420ms/step - wasser_loss: -0.9954 - disc_loss: 2.5188e-05 - accuracy: 0.8673 - SSIM_loss: 1.8068 - val_accuracy: 0.8569 - val_SSIM_loss: 1.8040
# Epoch 112/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9953 - disc_loss: 2.5090e-05 - accuracy: 0.8671 - SSIM_loss: 1.8066 - val_accuracy: 0.8524 - val_SSIM_loss: 1.8040
# Epoch 113/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 2.4825e-05 - accuracy: 0.8672 - SSIM_loss: 1.8064 - val_accuracy: 0.8550 - val_SSIM_loss: 1.8043
# Epoch 114/200
# 360/360 [==============================] - 148s 412ms/step - wasser_loss: -0.9953 - disc_loss: 2.4651e-05 - accuracy: 0.8670 - SSIM_loss: 1.8063 - val_accuracy: 0.8545 - val_SSIM_loss: 1.8037
# Epoch 115/200
# 360/360 [==============================] - 148s 410ms/step - wasser_loss: -0.9954 - disc_loss: 2.4350e-05 - accuracy: 0.8679 - SSIM_loss: 1.8062 - val_accuracy: 0.8556 - val_SSIM_loss: 1.8048
# Epoch 116/200
# 360/360 [==============================] - 145s 403ms/step - wasser_loss: -0.9954 - disc_loss: 2.4055e-05 - accuracy: 0.8674 - SSIM_loss: 1.8068 - val_accuracy: 0.8548 - val_SSIM_loss: 1.8029
# Epoch 117/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9953 - disc_loss: 2.4093e-05 - accuracy: 0.8675 - SSIM_loss: 1.8060 - val_accuracy: 0.8530 - val_SSIM_loss: 1.8046
# Epoch 118/200
# 360/360 [==============================] - 150s 416ms/step - wasser_loss: -0.9954 - disc_loss: 2.3524e-05 - accuracy: 0.8677 - SSIM_loss: 1.8070 - val_accuracy: 0.8546 - val_SSIM_loss: 1.8044
# Epoch 119/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 2.3658e-05 - accuracy: 0.8673 - SSIM_loss: 1.8059 - val_accuracy: 0.8554 - val_SSIM_loss: 1.8036
# Epoch 120/200
# 360/360 [==============================] - 145s 404ms/step - wasser_loss: -0.9954 - disc_loss: 2.3292e-05 - accuracy: 0.8684 - SSIM_loss: 1.8066 - val_accuracy: 0.8581 - val_SSIM_loss: 1.8067
# Epoch 121/200
# 360/360 [==============================] - 149s 413ms/step - wasser_loss: -0.9954 - disc_loss: 2.3233e-05 - accuracy: 0.8684 - SSIM_loss: 1.8064 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8056
# Epoch 122/200
# 360/360 [==============================] - 146s 404ms/step - wasser_loss: -0.9954 - disc_loss: 2.2626e-05 - accuracy: 0.8689 - SSIM_loss: 1.8068 - val_accuracy: 0.8565 - val_SSIM_loss: 1.8042
# Epoch 123/200
# 360/360 [==============================] - 147s 407ms/step - wasser_loss: -0.9954 - disc_loss: 2.2736e-05 - accuracy: 0.8684 - SSIM_loss: 1.8066 - val_accuracy: 0.8575 - val_SSIM_loss: 1.8052
# Epoch 124/200
# 360/360 [==============================] - 148s 410ms/step - wasser_loss: -0.9953 - disc_loss: 2.2645e-05 - accuracy: 0.8682 - SSIM_loss: 1.8063 - val_accuracy: 0.8563 - val_SSIM_loss: 1.8040
# Epoch 125/200
# 360/360 [==============================] - 150s 418ms/step - wasser_loss: -0.9953 - disc_loss: 2.2492e-05 - accuracy: 0.8682 - SSIM_loss: 1.8058 - val_accuracy: 0.8563 - val_SSIM_loss: 1.8042
# Epoch 126/200
# 360/360 [==============================] - 145s 403ms/step - wasser_loss: -0.9954 - disc_loss: 2.2023e-05 - accuracy: 0.8688 - SSIM_loss: 1.8069 - val_accuracy: 0.8575 - val_SSIM_loss: 1.8061
# Epoch 127/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 2.1837e-05 - accuracy: 0.8686 - SSIM_loss: 1.8067 - val_accuracy: 0.8547 - val_SSIM_loss: 1.8042
# Epoch 128/200
# 360/360 [==============================] - 150s 418ms/step - wasser_loss: -0.9954 - disc_loss: 2.1865e-05 - accuracy: 0.8684 - SSIM_loss: 1.8064 - val_accuracy: 0.8560 - val_SSIM_loss: 1.8058
# Epoch 129/200
# 360/360 [==============================] - 145s 403ms/step - wasser_loss: -0.9954 - disc_loss: 2.1604e-05 - accuracy: 0.8688 - SSIM_loss: 1.8064 - val_accuracy: 0.8563 - val_SSIM_loss: 1.8049
# Epoch 130/200
# 360/360 [==============================] - 144s 399ms/step - wasser_loss: -0.9954 - disc_loss: 2.1490e-05 - accuracy: 0.8685 - SSIM_loss: 1.8063 - val_accuracy: 0.8559 - val_SSIM_loss: 1.8042
# Epoch 131/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9954 - disc_loss: 2.1115e-05 - accuracy: 0.8687 - SSIM_loss: 1.8070 - val_accuracy: 0.8572 - val_SSIM_loss: 1.8051
# Epoch 132/200
# 360/360 [==============================] - 148s 412ms/step - wasser_loss: -0.9953 - disc_loss: 2.1329e-05 - accuracy: 0.8682 - SSIM_loss: 1.8061 - val_accuracy: 0.8553 - val_SSIM_loss: 1.8032
# Epoch 133/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 2.0742e-05 - accuracy: 0.8687 - SSIM_loss: 1.8062 - val_accuracy: 0.8583 - val_SSIM_loss: 1.8058
# Epoch 134/200
# 360/360 [==============================] - 147s 407ms/step - wasser_loss: -0.9954 - disc_loss: 2.0688e-05 - accuracy: 0.8690 - SSIM_loss: 1.8069 - val_accuracy: 0.8569 - val_SSIM_loss: 1.8045
# Epoch 135/200
# 360/360 [==============================] - 148s 412ms/step - wasser_loss: -0.9954 - disc_loss: 2.0659e-05 - accuracy: 0.8688 - SSIM_loss: 1.8063 - val_accuracy: 0.8566 - val_SSIM_loss: 1.8042
# Epoch 136/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 2.0507e-05 - accuracy: 0.8685 - SSIM_loss: 1.8064 - val_accuracy: 0.8569 - val_SSIM_loss: 1.8052
# Epoch 137/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 2.0233e-05 - accuracy: 0.8684 - SSIM_loss: 1.8061 - val_accuracy: 0.8571 - val_SSIM_loss: 1.8040
# Epoch 138/200
# 360/360 [==============================] - 148s 410ms/step - wasser_loss: -0.9954 - disc_loss: 2.0036e-05 - accuracy: 0.8691 - SSIM_loss: 1.8067 - val_accuracy: 0.8567 - val_SSIM_loss: 1.8054
# Epoch 139/200
# 360/360 [==============================] - 147s 407ms/step - wasser_loss: -0.9954 - disc_loss: 2.0067e-05 - accuracy: 0.8686 - SSIM_loss: 1.8064 - val_accuracy: 0.8566 - val_SSIM_loss: 1.8053
# Epoch 140/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9954 - disc_loss: 1.9744e-05 - accuracy: 0.8691 - SSIM_loss: 1.8069 - val_accuracy: 0.8567 - val_SSIM_loss: 1.8050
# Epoch 141/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 1.9664e-05 - accuracy: 0.8689 - SSIM_loss: 1.8066 - val_accuracy: 0.8582 - val_SSIM_loss: 1.8063
# Epoch 142/200
# 360/360 [==============================] - 149s 415ms/step - wasser_loss: -0.9954 - disc_loss: 1.9571e-05 - accuracy: 0.8686 - SSIM_loss: 1.8060 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8056
# Epoch 143/200
# 360/360 [==============================] - 146s 407ms/step - wasser_loss: -0.9954 - disc_loss: 1.9355e-05 - accuracy: 0.8691 - SSIM_loss: 1.8067 - val_accuracy: 0.8575 - val_SSIM_loss: 1.8046
# Epoch 144/200
# 360/360 [==============================] - 146s 404ms/step - wasser_loss: -0.9954 - disc_loss: 1.9194e-05 - accuracy: 0.8685 - SSIM_loss: 1.8064 - val_accuracy: 0.8576 - val_SSIM_loss: 1.8043
# Epoch 145/200
# 360/360 [==============================] - 149s 415ms/step - wasser_loss: -0.9954 - disc_loss: 1.9060e-05 - accuracy: 0.8691 - SSIM_loss: 1.8066 - val_accuracy: 0.8575 - val_SSIM_loss: 1.8051
# Epoch 146/200
# 360/360 [==============================] - 149s 413ms/step - wasser_loss: -0.9954 - disc_loss: 1.9051e-05 - accuracy: 0.8688 - SSIM_loss: 1.8062 - val_accuracy: 0.8571 - val_SSIM_loss: 1.8039
# Epoch 147/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 1.8854e-05 - accuracy: 0.8685 - SSIM_loss: 1.8063 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8047
# Epoch 148/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 1.8703e-05 - accuracy: 0.8686 - SSIM_loss: 1.8062 - val_accuracy: 0.8583 - val_SSIM_loss: 1.8053
# Epoch 149/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.8470e-05 - accuracy: 0.8697 - SSIM_loss: 1.8072 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8051
# Epoch 150/200
# 360/360 [==============================] - 145s 403ms/step - wasser_loss: -0.9954 - disc_loss: 1.8526e-05 - accuracy: 0.8689 - SSIM_loss: 1.8062 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8049
# Epoch 151/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9953 - disc_loss: 1.8457e-05 - accuracy: 0.8684 - SSIM_loss: 1.8061 - val_accuracy: 0.8580 - val_SSIM_loss: 1.8051
# Epoch 152/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 1.8110e-05 - accuracy: 0.8694 - SSIM_loss: 1.8070 - val_accuracy: 0.8580 - val_SSIM_loss: 1.8048
# Epoch 153/200
# 360/360 [==============================] - 148s 412ms/step - wasser_loss: -0.9954 - disc_loss: 1.8026e-05 - accuracy: 0.8692 - SSIM_loss: 1.8064 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8049
# Epoch 154/200
# 360/360 [==============================] - 146s 407ms/step - wasser_loss: -0.9954 - disc_loss: 1.7742e-05 - accuracy: 0.8694 - SSIM_loss: 1.8070 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8046
# Epoch 155/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 1.7948e-05 - accuracy: 0.8686 - SSIM_loss: 1.8063 - val_accuracy: 0.8586 - val_SSIM_loss: 1.8057
# Epoch 156/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.7801e-05 - accuracy: 0.8691 - SSIM_loss: 1.8060 - val_accuracy: 0.8586 - val_SSIM_loss: 1.8058
# Epoch 157/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 1.7544e-05 - accuracy: 0.8691 - SSIM_loss: 1.8067 - val_accuracy: 0.8585 - val_SSIM_loss: 1.8050
# Epoch 158/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9953 - disc_loss: 1.7522e-05 - accuracy: 0.8690 - SSIM_loss: 1.8063 - val_accuracy: 0.8583 - val_SSIM_loss: 1.8052
# Epoch 159/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9954 - disc_loss: 1.7291e-05 - accuracy: 0.8696 - SSIM_loss: 1.8072 - val_accuracy: 0.8591 - val_SSIM_loss: 1.8056
# Epoch 160/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.7368e-05 - accuracy: 0.8687 - SSIM_loss: 1.8059 - val_accuracy: 0.8572 - val_SSIM_loss: 1.8042
# Epoch 161/200
# 360/360 [==============================] - 145s 403ms/step - wasser_loss: -0.9954 - disc_loss: 1.7127e-05 - accuracy: 0.8693 - SSIM_loss: 1.8067 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8055
# Epoch 162/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9954 - disc_loss: 1.6902e-05 - accuracy: 0.8694 - SSIM_loss: 1.8066 - val_accuracy: 0.8575 - val_SSIM_loss: 1.8042
# Epoch 163/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.6961e-05 - accuracy: 0.8687 - SSIM_loss: 1.8063 - val_accuracy: 0.8568 - val_SSIM_loss: 1.8052
# Epoch 164/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9954 - disc_loss: 1.6844e-05 - accuracy: 0.8692 - SSIM_loss: 1.8066 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8053
# Epoch 165/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 1.6642e-05 - accuracy: 0.8693 - SSIM_loss: 1.8065 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8054
# Epoch 166/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9954 - disc_loss: 1.6633e-05 - accuracy: 0.8692 - SSIM_loss: 1.8066 - val_accuracy: 0.8573 - val_SSIM_loss: 1.8046
# Epoch 167/200
# 360/360 [==============================] - 147s 410ms/step - wasser_loss: -0.9954 - disc_loss: 1.6484e-05 - accuracy: 0.8690 - SSIM_loss: 1.8064 - val_accuracy: 0.8566 - val_SSIM_loss: 1.8048
# Epoch 168/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 1.6407e-05 - accuracy: 0.8688 - SSIM_loss: 1.8062 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8051
# Epoch 169/200
# 360/360 [==============================] - 149s 414ms/step - wasser_loss: -0.9954 - disc_loss: 1.6275e-05 - accuracy: 0.8697 - SSIM_loss: 1.8070 - val_accuracy: 0.8570 - val_SSIM_loss: 1.8051
# Epoch 170/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.6198e-05 - accuracy: 0.8690 - SSIM_loss: 1.8062 - val_accuracy: 0.8580 - val_SSIM_loss: 1.8047
# Epoch 171/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9954 - disc_loss: 1.6119e-05 - accuracy: 0.8693 - SSIM_loss: 1.8066 - val_accuracy: 0.8584 - val_SSIM_loss: 1.8057
# Epoch 172/200
# 360/360 [==============================] - 148s 410ms/step - wasser_loss: -0.9953 - disc_loss: 1.6104e-05 - accuracy: 0.8687 - SSIM_loss: 1.8058 - val_accuracy: 0.8565 - val_SSIM_loss: 1.8042
# Epoch 173/200
# 360/360 [==============================] - 145s 403ms/step - wasser_loss: -0.9954 - disc_loss: 1.5779e-05 - accuracy: 0.8695 - SSIM_loss: 1.8070 - val_accuracy: 0.8575 - val_SSIM_loss: 1.8046
# Epoch 174/200
# 360/360 [==============================] - 147s 407ms/step - wasser_loss: -0.9954 - disc_loss: 1.5783e-05 - accuracy: 0.8693 - SSIM_loss: 1.8064 - val_accuracy: 0.8592 - val_SSIM_loss: 1.8050
# Epoch 175/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 1.5797e-05 - accuracy: 0.8693 - SSIM_loss: 1.8065 - val_accuracy: 0.8586 - val_SSIM_loss: 1.8056
# Epoch 176/200
# 360/360 [==============================] - 148s 410ms/step - wasser_loss: -0.9954 - disc_loss: 1.5497e-05 - accuracy: 0.8695 - SSIM_loss: 1.8067 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8053
# Epoch 177/200
# 360/360 [==============================] - 148s 410ms/step - wasser_loss: -0.9954 - disc_loss: 1.5621e-05 - accuracy: 0.8691 - SSIM_loss: 1.8066 - val_accuracy: 0.8561 - val_SSIM_loss: 1.8040
# Epoch 178/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 1.5406e-05 - accuracy: 0.8694 - SSIM_loss: 1.8063 - val_accuracy: 0.8587 - val_SSIM_loss: 1.8054
# Epoch 179/200
# 360/360 [==============================] - 147s 409ms/step - wasser_loss: -0.9954 - disc_loss: 1.5454e-05 - accuracy: 0.8690 - SSIM_loss: 1.8061 - val_accuracy: 0.8581 - val_SSIM_loss: 1.8055
# Epoch 180/200
# 360/360 [==============================] - 146s 404ms/step - wasser_loss: -0.9954 - disc_loss: 1.5194e-05 - accuracy: 0.8692 - SSIM_loss: 1.8069 - val_accuracy: 0.8575 - val_SSIM_loss: 1.8050
# Epoch 181/200
# 360/360 [==============================] - 147s 410ms/step - wasser_loss: -0.9954 - disc_loss: 1.5165e-05 - accuracy: 0.8697 - SSIM_loss: 1.8067 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8055
# Epoch 182/200
# 360/360 [==============================] - 146s 404ms/step - wasser_loss: -0.9954 - disc_loss: 1.5070e-05 - accuracy: 0.8692 - SSIM_loss: 1.8064 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8045
# Epoch 183/200
# 360/360 [==============================] - 147s 410ms/step - wasser_loss: -0.9954 - disc_loss: 1.4986e-05 - accuracy: 0.8691 - SSIM_loss: 1.8066 - val_accuracy: 0.8571 - val_SSIM_loss: 1.8051
# Epoch 184/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 1.4947e-05 - accuracy: 0.8691 - SSIM_loss: 1.8061 - val_accuracy: 0.8574 - val_SSIM_loss: 1.8041
# Epoch 185/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.4781e-05 - accuracy: 0.8696 - SSIM_loss: 1.8070 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8049
# Epoch 186/200
# 360/360 [==============================] - 149s 413ms/step - wasser_loss: -0.9954 - disc_loss: 1.4854e-05 - accuracy: 0.8691 - SSIM_loss: 1.8063 - val_accuracy: 0.8573 - val_SSIM_loss: 1.8055
# Epoch 187/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 1.4712e-05 - accuracy: 0.8691 - SSIM_loss: 1.8062 - val_accuracy: 0.8576 - val_SSIM_loss: 1.8052
# Epoch 188/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.4657e-05 - accuracy: 0.8696 - SSIM_loss: 1.8069 - val_accuracy: 0.8581 - val_SSIM_loss: 1.8053
# Epoch 189/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9954 - disc_loss: 1.4481e-05 - accuracy: 0.8693 - SSIM_loss: 1.8065 - val_accuracy: 0.8567 - val_SSIM_loss: 1.8040
# Epoch 190/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9954 - disc_loss: 1.4448e-05 - accuracy: 0.8691 - SSIM_loss: 1.8061 - val_accuracy: 0.8578 - val_SSIM_loss: 1.8038
# Epoch 191/200
# 360/360 [==============================] - 148s 411ms/step - wasser_loss: -0.9954 - disc_loss: 1.4379e-05 - accuracy: 0.8693 - SSIM_loss: 1.8069 - val_accuracy: 0.8589 - val_SSIM_loss: 1.8070
# Epoch 192/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 1.4214e-05 - accuracy: 0.8693 - SSIM_loss: 1.8065 - val_accuracy: 0.8589 - val_SSIM_loss: 1.8049
# Epoch 193/200
# 360/360 [==============================] - 149s 414ms/step - wasser_loss: -0.9954 - disc_loss: 1.4179e-05 - accuracy: 0.8692 - SSIM_loss: 1.8068 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8042
# Epoch 194/200
# 360/360 [==============================] - 145s 402ms/step - wasser_loss: -0.9953 - disc_loss: 1.4215e-05 - accuracy: 0.8691 - SSIM_loss: 1.8059 - val_accuracy: 0.8577 - val_SSIM_loss: 1.8059
# Epoch 195/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 1.4037e-05 - accuracy: 0.8693 - SSIM_loss: 1.8065 - val_accuracy: 0.8587 - val_SSIM_loss: 1.8058
# Epoch 196/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 1.3960e-05 - accuracy: 0.8692 - SSIM_loss: 1.8066 - val_accuracy: 0.8586 - val_SSIM_loss: 1.8045
# Epoch 197/200
# 360/360 [==============================] - 146s 405ms/step - wasser_loss: -0.9954 - disc_loss: 1.3955e-05 - accuracy: 0.8693 - SSIM_loss: 1.8062 - val_accuracy: 0.8572 - val_SSIM_loss: 1.8038
# Epoch 198/200
# 360/360 [==============================] - 147s 407ms/step - wasser_loss: -0.9954 - disc_loss: 1.3939e-05 - accuracy: 0.8693 - SSIM_loss: 1.8066 - val_accuracy: 0.8589 - val_SSIM_loss: 1.8044
# Epoch 199/200
# 360/360 [==============================] - 147s 408ms/step - wasser_loss: -0.9954 - disc_loss: 1.3625e-05 - accuracy: 0.8696 - SSIM_loss: 1.8067 - val_accuracy: 0.8582 - val_SSIM_loss: 1.8043
# Epoch 200/200
# 360/360 [==============================] - 146s 406ms/step - wasser_loss: -0.9954 - disc_loss: 1.3718e-05 - accuracy: 0.8692 - SSIM_loss: 1.8064 - val_accuracy: 0.8584 - val_SSIM_loss: 1.8057
