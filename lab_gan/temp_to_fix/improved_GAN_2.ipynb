# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()

import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns
from datetime import datetime
import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='default_model_v2'
    __changes__="Change from tanh to sigmoid and changing distribution to 0-1 instead of -1 and 1"
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    
    __normalization__='[-1,1]'
    
    @staticmethod
    def discriminator():
        def main():
            last_img = Input(shape=image_shape)
            first_img = Input(shape=image_shape)

            # Concatenate image and conditioning image by channels to produce input
            combined_imgs = Concatenate(axis=-1)([last_img, first_img])

            d1 = Conv2D(32, (3, 3), strides=(2,2), padding='same')(combined_imgs) 
            d1 = Activation('relu')(d1) 
            d2 = Conv2D(64, (3, 3), strides=(2,2), padding='same')(d1)
            d2 = Activation('relu')(d2) 
            d3 = Conv2D(128, (3, 3), strides=(2,2), padding='same')(d2)
            d3 = Activation('relu')(d3) 

            validity = Conv2D(1, (3, 3), strides=(2,2), padding='same')(d3)

            model = Model([last_img, first_img], validity)
            return model
        
        return main()
    
    @staticmethod
    def generator():
        latent_dim = 128
        def encoder(input_tensor, n_filters, kernel_size=4, strides=2,batchnorm=True, dropout=True):
            initializer = tf.random_normal_initializer(0., 0.02)
            # first layer
            x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer="he_normal",
                   padding="same", strides=strides)(input_tensor)

            if batchnorm:
                x = BatchNormalization()(x)
            if dropout:
                x = Dropout(0.5)(x)
            x = LeakyReLU(alpha=0.2)(x)
            return x

        def decoder(input_tensor, skip_in,  n_filters, kernel_size=4, strides=2,batchnorm=True, dropout=True):
            initializer = tf.random_normal_initializer(0., 0.02)
            x = Conv2DTranspose(n_filters, kernel_size=kernel_size, padding='same', strides=strides, kernel_initializer=initializer)(input_tensor)
            if batchnorm:
                x = BatchNormalization()(x)
            if dropout:
                x = Dropout(0.5)(x)
            x = Concatenate()([x, skip_in])
            x = LeakyReLU(alpha=0.2)(x)
            return x

        def main():
            inputs = Input(shape=image_shape)

            e1 = encoder(inputs, 32, batchnorm=False)
            e2 = encoder(e1, 64)
            e3 = encoder(e2, 128)
            e4 = encoder(e3, 128)

            b = Conv2D(128, kernel_size=4, strides=2, padding='same')(e4)
            b = LeakyReLU(alpha=0.2)(b)

            u1 = decoder(b,e4, 128)
            u2 = decoder(u1,e3, 128, dropout=False)
            u3 = decoder(u2,e2, 64, dropout=False)
            u4 = decoder(u3,e1, 32, dropout=False)

            classify = Conv2DTranspose(3, kernel_size=2,  strides=(2,2), activation='sigmoid')(u4)
            model = Model(inputs=inputs, outputs=classify, name='Generator')
            
            return model
        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        LAMBDA = 100
        def generator_loss(disc_generated_output, gen_output, target): # https://arxiv.org/abs/1611.07004
            gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

            # mean absolute error
            l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

            total_gen_loss = gan_loss + (LAMBDA * l1_loss)

            return total_gen_loss, gan_loss, l1_loss

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss

        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
from tensorflow.keras.utils import plot_model

plot_model(architecture.generator(), to_file='derasp.png')
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
import os
import pydot
pydot.Dot.create(pydot.Dot())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/miniconda3/envs/lab/lib/python3.8/site-packages/pydot.py in create(self, prog, format, encoding)
#    1911         try:
# -> 1912             stdout_data, stderr_data, process = call_graphviz(
#    1913                 program=prog,
#
# ~/miniconda3/envs/lab/lib/python3.8/site-packages/pydot.py in call_graphviz(program, arguments, working_dir, **kwargs)
#     128
# --> 129     process = subprocess.Popen(
#     130         program_with_args,
#
# ~/miniconda3/envs/lab/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# ~/miniconda3/envs/lab/lib/python3.8/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1701                         err_msg = os.strerror(errno_num)
# -> 1702                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1703                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-01f3f366b7a4> in <module>
#       1 import os
#       2 import pydot
# ----> 3 pydot.Dot.create(pydot.Dot())
#
# ~/miniconda3/envs/lab/lib/python3.8/site-packages/pydot.py in create(self, prog, format, encoding)
#    1920                 args[1] = '"{prog}" not found in path.'.format(
#    1921                     prog=prog)
# -> 1922                 raise OSError(*args)
#    1923             else:
#    1924                 raise
#
# FileNotFoundError: [Errno 2] "dot" not found in path.

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__)
# Out:
# train_x (30, 128, 128, 3) float32 -1.0 1.0
# train_y (30, 128, 128, 3) float32 -1.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss(disc_generated_output, gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(gen_total_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'gen_total_loss':gen_total_loss,
                'gen_gan_loss':gen_gan_loss,
                'gen_l1_loss':gen_l1_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')
file_writer = tf.summary.create_file_writer(log_dir + "/plots/")

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - gen_total_loss: 59.5151 - gen_gan_loss: 0.6725 - gen_l1_loss: 0.5884 - disc_loss: 1.3914 - accuracy: 0.3659 - SSIM_loss: 0.9146WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/360 [..............................] - ETA: 1:11 - gen_total_loss: 58.6601 - gen_gan_loss: 0.6547 - gen_l1_loss: 0.5801 - disc_loss: 1.3823 - accuracy: 0.3656 - SSIM_loss: 0.9130WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0861s vs `on_train_batch_end` time: 0.3088s). Check your callbacks.
# 360/360 [==============================] - 105s 293ms/step - gen_total_loss: 32.3420 - gen_gan_loss: 3.8913 - gen_l1_loss: 0.2845 - disc_loss: 0.3678 - accuracy: 0.4448 - SSIM_loss: 0.6893 - val_accuracy: 0.5315 - val_SSIM_loss: 0.1761
# Epoch 2/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 17.7188 - gen_gan_loss: 3.5869 - gen_l1_loss: 0.1413 - disc_loss: 0.7777 - accuracy: 0.4196 - SSIM_loss: 0.2570 - val_accuracy: 0.5094 - val_SSIM_loss: 0.1772
# Epoch 3/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 18.0356 - gen_gan_loss: 4.7971 - gen_l1_loss: 0.1324 - disc_loss: 0.8470 - accuracy: 0.4279 - SSIM_loss: 0.2243 - val_accuracy: 0.5204 - val_SSIM_loss: 0.1969
# Epoch 4/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 18.7411 - gen_gan_loss: 5.3027 - gen_l1_loss: 0.1344 - disc_loss: 0.8789 - accuracy: 0.4316 - SSIM_loss: 0.2053 - val_accuracy: 0.4750 - val_SSIM_loss: 0.1920
# Epoch 5/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 18.9312 - gen_gan_loss: 5.4528 - gen_l1_loss: 0.1348 - disc_loss: 0.8869 - accuracy: 0.4246 - SSIM_loss: 0.1887 - val_accuracy: 0.4467 - val_SSIM_loss: 0.1856
# Epoch 6/200
# 360/360 [==============================] - 159s 441ms/step - gen_total_loss: 19.4173 - gen_gan_loss: 5.3767 - gen_l1_loss: 0.1404 - disc_loss: 0.8792 - accuracy: 0.4268 - SSIM_loss: 0.1798 - val_accuracy: 0.4377 - val_SSIM_loss: 0.2007
# Epoch 7/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 19.8299 - gen_gan_loss: 4.8636 - gen_l1_loss: 0.1497 - disc_loss: 0.8889 - accuracy: 0.4303 - SSIM_loss: 0.1773 - val_accuracy: 0.4529 - val_SSIM_loss: 0.1892
# Epoch 8/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 20.1780 - gen_gan_loss: 4.4962 - gen_l1_loss: 0.1568 - disc_loss: 0.8905 - accuracy: 0.4401 - SSIM_loss: 0.1787 - val_accuracy: 0.3698 - val_SSIM_loss: 0.1942
# Epoch 9/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 20.4777 - gen_gan_loss: 4.4776 - gen_l1_loss: 0.1600 - disc_loss: 0.8903 - accuracy: 0.4532 - SSIM_loss: 0.1801 - val_accuracy: 0.3030 - val_SSIM_loss: 0.1949
# Epoch 10/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 20.6505 - gen_gan_loss: 4.4923 - gen_l1_loss: 0.1616 - disc_loss: 0.8909 - accuracy: 0.4686 - SSIM_loss: 0.1825 - val_accuracy: 0.3818 - val_SSIM_loss: 0.1949
# Epoch 11/200
# 360/360 [==============================] - 158s 438ms/step - gen_total_loss: 20.7810 - gen_gan_loss: 4.4286 - gen_l1_loss: 0.1635 - disc_loss: 0.8925 - accuracy: 0.4814 - SSIM_loss: 0.1835 - val_accuracy: 0.3857 - val_SSIM_loss: 0.1990
# Epoch 12/200
# 360/360 [==============================] - 159s 440ms/step - gen_total_loss: 20.8859 - gen_gan_loss: 4.3748 - gen_l1_loss: 0.1651 - disc_loss: 0.8936 - accuracy: 0.4917 - SSIM_loss: 0.1851 - val_accuracy: 0.3135 - val_SSIM_loss: 0.2002
# Epoch 13/200
# 360/360 [==============================] - 159s 441ms/step - gen_total_loss: 20.9499 - gen_gan_loss: 4.3383 - gen_l1_loss: 0.1661 - disc_loss: 0.8940 - accuracy: 0.5031 - SSIM_loss: 0.1851 - val_accuracy: 0.4192 - val_SSIM_loss: 0.1989
# Epoch 14/200
# 360/360 [==============================] - 160s 444ms/step - gen_total_loss: 21.0620 - gen_gan_loss: 4.3668 - gen_l1_loss: 0.1670 - disc_loss: 0.8922 - accuracy: 0.5176 - SSIM_loss: 0.1861 - val_accuracy: 0.2798 - val_SSIM_loss: 0.2032
# Epoch 15/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 21.1656 - gen_gan_loss: 4.4138 - gen_l1_loss: 0.1675 - disc_loss: 0.8916 - accuracy: 0.5386 - SSIM_loss: 0.1864 - val_accuracy: 0.2979 - val_SSIM_loss: 0.2043
# Epoch 16/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 21.2773 - gen_gan_loss: 4.4279 - gen_l1_loss: 0.1685 - disc_loss: 0.8901 - accuracy: 0.5572 - SSIM_loss: 0.1874 - val_accuracy: 0.3741 - val_SSIM_loss: 0.2034
# Epoch 17/200
# 360/360 [==============================] - 158s 440ms/step - gen_total_loss: 21.1374 - gen_gan_loss: 4.4112 - gen_l1_loss: 0.1673 - disc_loss: 0.8940 - accuracy: 0.5749 - SSIM_loss: 0.1856 - val_accuracy: 0.4099 - val_SSIM_loss: 0.2059
# Epoch 18/200
# 360/360 [==============================] - 157s 437ms/step - gen_total_loss: 21.3674 - gen_gan_loss: 4.4803 - gen_l1_loss: 0.1689 - disc_loss: 0.8883 - accuracy: 0.5915 - SSIM_loss: 0.1872 - val_accuracy: 0.3974 - val_SSIM_loss: 0.2054
# Epoch 19/200
# 360/360 [==============================] - 157s 437ms/step - gen_total_loss: 21.5523 - gen_gan_loss: 4.5593 - gen_l1_loss: 0.1699 - disc_loss: 0.8866 - accuracy: 0.6088 - SSIM_loss: 0.1885 - val_accuracy: 0.4306 - val_SSIM_loss: 0.2022
# Epoch 20/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 21.5640 - gen_gan_loss: 4.5716 - gen_l1_loss: 0.1699 - disc_loss: 0.8875 - accuracy: 0.6265 - SSIM_loss: 0.1864 - val_accuracy: 0.6097 - val_SSIM_loss: 0.1992
# Epoch 21/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 21.7450 - gen_gan_loss: 4.6336 - gen_l1_loss: 0.1711 - disc_loss: 0.8870 - accuracy: 0.6384 - SSIM_loss: 0.1878 - val_accuracy: 0.6475 - val_SSIM_loss: 0.2009
# Epoch 22/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 21.8389 - gen_gan_loss: 4.6658 - gen_l1_loss: 0.1717 - disc_loss: 0.8864 - accuracy: 0.6582 - SSIM_loss: 0.1875 - val_accuracy: 0.6826 - val_SSIM_loss: 0.2057
# Epoch 23/200
# 360/360 [==============================] - 159s 441ms/step - gen_total_loss: 22.0089 - gen_gan_loss: 4.7171 - gen_l1_loss: 0.1729 - disc_loss: 0.8860 - accuracy: 0.6723 - SSIM_loss: 0.1879 - val_accuracy: 0.8228 - val_SSIM_loss: 0.2040
# Epoch 24/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 22.1672 - gen_gan_loss: 4.7853 - gen_l1_loss: 0.1738 - disc_loss: 0.8862 - accuracy: 0.6825 - SSIM_loss: 0.1881 - val_accuracy: 0.8261 - val_SSIM_loss: 0.2052
# Epoch 25/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 22.4097 - gen_gan_loss: 4.8675 - gen_l1_loss: 0.1754 - disc_loss: 0.8849 - accuracy: 0.6997 - SSIM_loss: 0.1874 - val_accuracy: 0.8047 - val_SSIM_loss: 0.2057
# Epoch 26/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 22.6259 - gen_gan_loss: 4.9894 - gen_l1_loss: 0.1764 - disc_loss: 0.8836 - accuracy: 0.7131 - SSIM_loss: 0.1884 - val_accuracy: 0.8574 - val_SSIM_loss: 0.2031
# Epoch 27/200
# 360/360 [==============================] - 152s 421ms/step - gen_total_loss: 22.8402 - gen_gan_loss: 5.1829 - gen_l1_loss: 0.1766 - disc_loss: 0.8852 - accuracy: 0.7232 - SSIM_loss: 0.1885 - val_accuracy: 0.8815 - val_SSIM_loss: 0.2083
# Epoch 28/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 22.9989 - gen_gan_loss: 5.2739 - gen_l1_loss: 0.1773 - disc_loss: 0.8826 - accuracy: 0.7374 - SSIM_loss: 0.1887 - val_accuracy: 0.8630 - val_SSIM_loss: 0.2049
# Epoch 29/200
# 360/360 [==============================] - 158s 440ms/step - gen_total_loss: 23.3327 - gen_gan_loss: 5.5617 - gen_l1_loss: 0.1777 - disc_loss: 0.8840 - accuracy: 0.7407 - SSIM_loss: 0.1888 - val_accuracy: 0.9149 - val_SSIM_loss: 0.2089
# Epoch 30/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 23.6482 - gen_gan_loss: 5.7777 - gen_l1_loss: 0.1787 - disc_loss: 0.8825 - accuracy: 0.7491 - SSIM_loss: 0.1906 - val_accuracy: 0.9179 - val_SSIM_loss: 0.2062
# Epoch 31/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 23.7020 - gen_gan_loss: 5.8838 - gen_l1_loss: 0.1782 - disc_loss: 0.8842 - accuracy: 0.7543 - SSIM_loss: 0.1899 - val_accuracy: 0.9199 - val_SSIM_loss: 0.2092
# Epoch 32/200
# 360/360 [==============================] - 153s 425ms/step - gen_total_loss: 23.9874 - gen_gan_loss: 6.1280 - gen_l1_loss: 0.1786 - disc_loss: 0.8830 - accuracy: 0.7620 - SSIM_loss: 0.1896 - val_accuracy: 0.9211 - val_SSIM_loss: 0.2008
# Epoch 33/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 24.3101 - gen_gan_loss: 6.3630 - gen_l1_loss: 0.1795 - disc_loss: 0.8823 - accuracy: 0.7655 - SSIM_loss: 0.1915 - val_accuracy: 0.9370 - val_SSIM_loss: 0.2079
# Epoch 34/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 24.5903 - gen_gan_loss: 6.6319 - gen_l1_loss: 0.1796 - disc_loss: 0.8829 - accuracy: 0.7647 - SSIM_loss: 0.1916 - val_accuracy: 0.9247 - val_SSIM_loss: 0.2090
# Epoch 35/200
# 360/360 [==============================] - 158s 440ms/step - gen_total_loss: 24.8830 - gen_gan_loss: 6.8821 - gen_l1_loss: 0.1800 - disc_loss: 0.8829 - accuracy: 0.7574 - SSIM_loss: 0.1927 - val_accuracy: 0.9158 - val_SSIM_loss: 0.2095
# Epoch 36/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 24.8848 - gen_gan_loss: 6.9504 - gen_l1_loss: 0.1793 - disc_loss: 0.8856 - accuracy: 0.7652 - SSIM_loss: 0.1907 - val_accuracy: 0.9430 - val_SSIM_loss: 0.2044
# Epoch 37/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 25.3415 - gen_gan_loss: 7.3206 - gen_l1_loss: 0.1802 - disc_loss: 0.8826 - accuracy: 0.7553 - SSIM_loss: 0.1927 - val_accuracy: 0.9247 - val_SSIM_loss: 0.2082
# Epoch 38/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 25.5080 - gen_gan_loss: 7.5182 - gen_l1_loss: 0.1799 - disc_loss: 0.8838 - accuracy: 0.7521 - SSIM_loss: 0.1917 - val_accuracy: 0.8859 - val_SSIM_loss: 0.2044
# Epoch 39/200
# 360/360 [==============================] - 155s 432ms/step - gen_total_loss: 25.8151 - gen_gan_loss: 7.7506 - gen_l1_loss: 0.1806 - disc_loss: 0.8814 - accuracy: 0.7503 - SSIM_loss: 0.1928 - val_accuracy: 0.9014 - val_SSIM_loss: 0.2048
# Epoch 40/200
# 360/360 [==============================] - 157s 435ms/step - gen_total_loss: 26.1736 - gen_gan_loss: 8.0684 - gen_l1_loss: 0.1811 - disc_loss: 0.8796 - accuracy: 0.7485 - SSIM_loss: 0.1938 - val_accuracy: 0.8930 - val_SSIM_loss: 0.2077
# Epoch 41/200
# 360/360 [==============================] - 158s 438ms/step - gen_total_loss: 26.2366 - gen_gan_loss: 8.2236 - gen_l1_loss: 0.1801 - disc_loss: 0.8809 - accuracy: 0.7430 - SSIM_loss: 0.1928 - val_accuracy: 0.8781 - val_SSIM_loss: 0.2049
# Epoch 42/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 26.5243 - gen_gan_loss: 8.4435 - gen_l1_loss: 0.1808 - disc_loss: 0.8815 - accuracy: 0.7407 - SSIM_loss: 0.1939 - val_accuracy: 0.9049 - val_SSIM_loss: 0.2064
# Epoch 43/200
# 360/360 [==============================] - 153s 425ms/step - gen_total_loss: 26.7291 - gen_gan_loss: 8.6651 - gen_l1_loss: 0.1806 - disc_loss: 0.8807 - accuracy: 0.7387 - SSIM_loss: 0.1944 - val_accuracy: 0.8508 - val_SSIM_loss: 0.2086
# Epoch 44/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 27.0723 - gen_gan_loss: 9.0019 - gen_l1_loss: 0.1807 - disc_loss: 0.8809 - accuracy: 0.7428 - SSIM_loss: 0.1932 - val_accuracy: 0.8547 - val_SSIM_loss: 0.2072
# Epoch 45/200
# 360/360 [==============================] - 155s 430ms/step - gen_total_loss: 27.2953 - gen_gan_loss: 9.1987 - gen_l1_loss: 0.1810 - disc_loss: 0.8797 - accuracy: 0.7451 - SSIM_loss: 0.1935 - val_accuracy: 0.9103 - val_SSIM_loss: 0.2096
# Epoch 46/200
# 360/360 [==============================] - 157s 437ms/step - gen_total_loss: 27.5540 - gen_gan_loss: 9.4807 - gen_l1_loss: 0.1807 - disc_loss: 0.8805 - accuracy: 0.7465 - SSIM_loss: 0.1947 - val_accuracy: 0.8775 - val_SSIM_loss: 0.2114
# Epoch 47/200
# 360/360 [==============================] - 159s 441ms/step - gen_total_loss: 27.7713 - gen_gan_loss: 9.6319 - gen_l1_loss: 0.1814 - disc_loss: 0.8798 - accuracy: 0.7493 - SSIM_loss: 0.1945 - val_accuracy: 0.8739 - val_SSIM_loss: 0.2088
# Epoch 48/200
# 360/360 [==============================] - 153s 425ms/step - gen_total_loss: 28.0737 - gen_gan_loss: 9.9279 - gen_l1_loss: 0.1815 - disc_loss: 0.8791 - accuracy: 0.7379 - SSIM_loss: 0.1953 - val_accuracy: 0.8533 - val_SSIM_loss: 0.2100
# Epoch 49/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 28.3116 - gen_gan_loss: 10.2072 - gen_l1_loss: 0.1810 - disc_loss: 0.8804 - accuracy: 0.7378 - SSIM_loss: 0.1926 - val_accuracy: 0.8807 - val_SSIM_loss: 0.2094
# Epoch 50/200
# 360/360 [==============================] - 155s 432ms/step - gen_total_loss: 28.9670 - gen_gan_loss: 10.7074 - gen_l1_loss: 0.1826 - disc_loss: 0.8788 - accuracy: 0.7334 - SSIM_loss: 0.1956 - val_accuracy: 0.8565 - val_SSIM_loss: 0.2089
# Epoch 51/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 28.3528 - gen_gan_loss: 10.2947 - gen_l1_loss: 0.1806 - disc_loss: 0.8813 - accuracy: 0.7356 - SSIM_loss: 0.1908 - val_accuracy: 0.8760 - val_SSIM_loss: 0.2098
# Epoch 52/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 29.3508 - gen_gan_loss: 11.1677 - gen_l1_loss: 0.1818 - disc_loss: 0.8799 - accuracy: 0.7480 - SSIM_loss: 0.1952 - val_accuracy: 0.8969 - val_SSIM_loss: 0.2092
# Epoch 53/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 29.4939 - gen_gan_loss: 11.2598 - gen_l1_loss: 0.1823 - disc_loss: 0.8766 - accuracy: 0.7407 - SSIM_loss: 0.1958 - val_accuracy: 0.8460 - val_SSIM_loss: 0.2108
# Epoch 54/200
# 360/360 [==============================] - 155s 432ms/step - gen_total_loss: 29.4830 - gen_gan_loss: 11.3410 - gen_l1_loss: 0.1814 - disc_loss: 0.8795 - accuracy: 0.7379 - SSIM_loss: 0.1949 - val_accuracy: 0.8530 - val_SSIM_loss: 0.2101
# Epoch 55/200
# 360/360 [==============================] - 153s 426ms/step - gen_total_loss: 29.8559 - gen_gan_loss: 11.6116 - gen_l1_loss: 0.1824 - disc_loss: 0.8774 - accuracy: 0.7375 - SSIM_loss: 0.1957 - val_accuracy: 0.8583 - val_SSIM_loss: 0.2083
# Epoch 56/200
# 360/360 [==============================] - 154s 429ms/step - gen_total_loss: 30.1479 - gen_gan_loss: 11.9876 - gen_l1_loss: 0.1816 - disc_loss: 0.8798 - accuracy: 0.7305 - SSIM_loss: 0.1956 - val_accuracy: 0.8584 - val_SSIM_loss: 0.2104
# Epoch 57/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 30.3266 - gen_gan_loss: 12.1266 - gen_l1_loss: 0.1820 - disc_loss: 0.8797 - accuracy: 0.7172 - SSIM_loss: 0.1963 - val_accuracy: 0.8038 - val_SSIM_loss: 0.2103
# Epoch 58/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 30.6593 - gen_gan_loss: 12.4335 - gen_l1_loss: 0.1823 - disc_loss: 0.8798 - accuracy: 0.7084 - SSIM_loss: 0.1976 - val_accuracy: 0.8249 - val_SSIM_loss: 0.2095
# Epoch 59/200
# 360/360 [==============================] - 158s 438ms/step - gen_total_loss: 30.7270 - gen_gan_loss: 12.5371 - gen_l1_loss: 0.1819 - disc_loss: 0.8772 - accuracy: 0.6995 - SSIM_loss: 0.1971 - val_accuracy: 0.8645 - val_SSIM_loss: 0.2138
# Epoch 60/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 30.7806 - gen_gan_loss: 12.6009 - gen_l1_loss: 0.1818 - disc_loss: 0.8800 - accuracy: 0.7078 - SSIM_loss: 0.1960 - val_accuracy: 0.8045 - val_SSIM_loss: 0.2099
# Epoch 61/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 31.2213 - gen_gan_loss: 12.8969 - gen_l1_loss: 0.1832 - disc_loss: 0.8762 - accuracy: 0.7045 - SSIM_loss: 0.1983 - val_accuracy: 0.8598 - val_SSIM_loss: 0.2104
# Epoch 62/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 31.2703 - gen_gan_loss: 13.1554 - gen_l1_loss: 0.1811 - disc_loss: 0.9191 - accuracy: 0.7281 - SSIM_loss: 0.1955 - val_accuracy: 0.8484 - val_SSIM_loss: 0.2069
# Epoch 63/200
# 360/360 [==============================] - 153s 424ms/step - gen_total_loss: 32.4281 - gen_gan_loss: 14.1808 - gen_l1_loss: 0.1825 - disc_loss: 0.8811 - accuracy: 0.7269 - SSIM_loss: 0.1987 - val_accuracy: 0.8702 - val_SSIM_loss: 0.2152
# Epoch 64/200
# 360/360 [==============================] - 156s 433ms/step - gen_total_loss: 32.3818 - gen_gan_loss: 14.1804 - gen_l1_loss: 0.1820 - disc_loss: 0.8795 - accuracy: 0.7313 - SSIM_loss: 0.1991 - val_accuracy: 0.9090 - val_SSIM_loss: 0.2113
# Epoch 65/200
# 360/360 [==============================] - 155s 429ms/step - gen_total_loss: 32.8460 - gen_gan_loss: 14.5933 - gen_l1_loss: 0.1825 - disc_loss: 0.8784 - accuracy: 0.7090 - SSIM_loss: 0.2001 - val_accuracy: 0.8231 - val_SSIM_loss: 0.2153
# Epoch 66/200
# 360/360 [==============================] - 157s 436ms/step - gen_total_loss: 33.2432 - gen_gan_loss: 14.9771 - gen_l1_loss: 0.1827 - disc_loss: 0.8768 - accuracy: 0.7184 - SSIM_loss: 0.2000 - val_accuracy: 0.8693 - val_SSIM_loss: 0.2157
# Epoch 67/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 33.0790 - gen_gan_loss: 14.7617 - gen_l1_loss: 0.1832 - disc_loss: 0.8774 - accuracy: 0.7262 - SSIM_loss: 0.2013 - val_accuracy: 0.9291 - val_SSIM_loss: 0.2128
# Epoch 68/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 33.2106 - gen_gan_loss: 14.9698 - gen_l1_loss: 0.1824 - disc_loss: 0.8778 - accuracy: 0.7374 - SSIM_loss: 0.1998 - val_accuracy: 0.9170 - val_SSIM_loss: 0.2125
# Epoch 69/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 33.4412 - gen_gan_loss: 15.1660 - gen_l1_loss: 0.1828 - disc_loss: 0.8777 - accuracy: 0.7388 - SSIM_loss: 0.2008 - val_accuracy: 0.8942 - val_SSIM_loss: 0.2120
# Epoch 70/200
# 360/360 [==============================] - 159s 441ms/step - gen_total_loss: 33.6897 - gen_gan_loss: 15.4305 - gen_l1_loss: 0.1826 - disc_loss: 0.8783 - accuracy: 0.7409 - SSIM_loss: 0.2000 - val_accuracy: 0.9319 - val_SSIM_loss: 0.2136
# Epoch 71/200
# 360/360 [==============================] - 156s 434ms/step - gen_total_loss: 33.9329 - gen_gan_loss: 15.7053 - gen_l1_loss: 0.1823 - disc_loss: 0.8772 - accuracy: 0.7390 - SSIM_loss: 0.2002 - val_accuracy: 0.9140 - val_SSIM_loss: 0.2143
# Epoch 72/200
# 360/360 [==============================] - 155s 432ms/step - gen_total_loss: 34.4192 - gen_gan_loss: 16.1312 - gen_l1_loss: 0.1829 - disc_loss: 0.8772 - accuracy: 0.7371 - SSIM_loss: 0.2013 - val_accuracy: 0.9234 - val_SSIM_loss: 0.2145
# Epoch 73/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 34.6908 - gen_gan_loss: 16.3677 - gen_l1_loss: 0.1832 - disc_loss: 0.8766 - accuracy: 0.7312 - SSIM_loss: 0.2016 - val_accuracy: 0.9179 - val_SSIM_loss: 0.2131
# Epoch 74/200
# 360/360 [==============================] - 153s 424ms/step - gen_total_loss: 34.6465 - gen_gan_loss: 16.4225 - gen_l1_loss: 0.1822 - disc_loss: 0.8772 - accuracy: 0.7293 - SSIM_loss: 0.2002 - val_accuracy: 0.9000 - val_SSIM_loss: 0.2155
# Epoch 75/200
# 360/360 [==============================] - 156s 432ms/step - gen_total_loss: 35.3162 - gen_gan_loss: 17.0065 - gen_l1_loss: 0.1831 - disc_loss: 0.8772 - accuracy: 0.7194 - SSIM_loss: 0.2023 - val_accuracy: 0.8978 - val_SSIM_loss: 0.2139
# Epoch 76/200
# 360/360 [==============================] - 159s 441ms/step - gen_total_loss: 35.2691 - gen_gan_loss: 16.9307 - gen_l1_loss: 0.1834 - disc_loss: 0.8934 - accuracy: 0.7077 - SSIM_loss: 0.2023 - val_accuracy: 0.7295 - val_SSIM_loss: 0.2164
# Epoch 77/200
# 360/360 [==============================] - 135s 374ms/step - gen_total_loss: 35.9236 - gen_gan_loss: 17.6711 - gen_l1_loss: 0.1825 - disc_loss: 0.8811 - accuracy: 0.6867 - SSIM_loss: 0.2020 - val_accuracy: 0.8725 - val_SSIM_loss: 0.2101
# Epoch 78/200
# 360/360 [==============================] - 64s 178ms/step - gen_total_loss: 36.0233 - gen_gan_loss: 17.7436 - gen_l1_loss: 0.1828 - disc_loss: 0.8775 - accuracy: 0.6666 - SSIM_loss: 0.2015 - val_accuracy: 0.8460 - val_SSIM_loss: 0.2158
# Epoch 79/200
# 360/360 [==============================] - 65s 180ms/step - gen_total_loss: 36.5357 - gen_gan_loss: 18.1760 - gen_l1_loss: 0.1836 - disc_loss: 0.8752 - accuracy: 0.6494 - SSIM_loss: 0.2039 - val_accuracy: 0.8002 - val_SSIM_loss: 0.2167
# Epoch 80/200
# 360/360 [==============================] - 93s 259ms/step - gen_total_loss: 36.8224 - gen_gan_loss: 18.5723 - gen_l1_loss: 0.1825 - disc_loss: 0.8776 - accuracy: 0.6715 - SSIM_loss: 0.2011 - val_accuracy: 0.8651 - val_SSIM_loss: 0.2110
# Epoch 81/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 37.2824 - gen_gan_loss: 19.0389 - gen_l1_loss: 0.1824 - disc_loss: 0.8770 - accuracy: 0.6860 - SSIM_loss: 0.2016 - val_accuracy: 0.8917 - val_SSIM_loss: 0.2151
# Epoch 82/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 37.4489 - gen_gan_loss: 19.1554 - gen_l1_loss: 0.1829 - disc_loss: 0.8756 - accuracy: 0.6663 - SSIM_loss: 0.2016 - val_accuracy: 0.7566 - val_SSIM_loss: 0.2148
# Epoch 83/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 37.5240 - gen_gan_loss: 19.2389 - gen_l1_loss: 0.1829 - disc_loss: 0.8779 - accuracy: 0.5992 - SSIM_loss: 0.2024 - val_accuracy: 0.6880 - val_SSIM_loss: 0.2159
# Epoch 84/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 38.1000 - gen_gan_loss: 19.7442 - gen_l1_loss: 0.1836 - disc_loss: 0.8750 - accuracy: 0.6023 - SSIM_loss: 0.2035 - val_accuracy: 0.6882 - val_SSIM_loss: 0.2148
# Epoch 85/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 38.8541 - gen_gan_loss: 20.5226 - gen_l1_loss: 0.1833 - disc_loss: 0.8767 - accuracy: 0.5880 - SSIM_loss: 0.2030 - val_accuracy: 0.5585 - val_SSIM_loss: 0.2169
# Epoch 86/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 39.7351 - gen_gan_loss: 21.4594 - gen_l1_loss: 0.1828 - disc_loss: 0.8771 - accuracy: 0.5722 - SSIM_loss: 0.2035 - val_accuracy: 0.5996 - val_SSIM_loss: 0.2162
# Epoch 87/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 39.2843 - gen_gan_loss: 21.0072 - gen_l1_loss: 0.1828 - disc_loss: 0.8742 - accuracy: 0.5925 - SSIM_loss: 0.2015 - val_accuracy: 0.6232 - val_SSIM_loss: 0.2077
# Epoch 88/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 39.8994 - gen_gan_loss: 21.6927 - gen_l1_loss: 0.1821 - disc_loss: 0.8798 - accuracy: 0.5828 - SSIM_loss: 0.2011 - val_accuracy: 0.6849 - val_SSIM_loss: 0.2086
# Epoch 89/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 41.2481 - gen_gan_loss: 22.7967 - gen_l1_loss: 0.1845 - disc_loss: 0.8717 - accuracy: 0.5790 - SSIM_loss: 0.2042 - val_accuracy: 0.6737 - val_SSIM_loss: 0.2078
# Epoch 90/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 41.4438 - gen_gan_loss: 23.2700 - gen_l1_loss: 0.1817 - disc_loss: 0.8788 - accuracy: 0.5774 - SSIM_loss: 0.2025 - val_accuracy: 0.6892 - val_SSIM_loss: 0.2112
# Epoch 91/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 40.9820 - gen_gan_loss: 22.6462 - gen_l1_loss: 0.1834 - disc_loss: 0.8754 - accuracy: 0.5696 - SSIM_loss: 0.2033 - val_accuracy: 0.5581 - val_SSIM_loss: 0.2127
# Epoch 92/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 41.1014 - gen_gan_loss: 22.8457 - gen_l1_loss: 0.1826 - disc_loss: 0.8755 - accuracy: 0.5601 - SSIM_loss: 0.2027 - val_accuracy: 0.5877 - val_SSIM_loss: 0.2110
# Epoch 93/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 42.5224 - gen_gan_loss: 24.2318 - gen_l1_loss: 0.1829 - disc_loss: 0.8759 - accuracy: 0.5454 - SSIM_loss: 0.2038 - val_accuracy: 0.5785 - val_SSIM_loss: 0.2107
# Epoch 94/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 40.9600 - gen_gan_loss: 22.6981 - gen_l1_loss: 0.1826 - disc_loss: 0.8930 - accuracy: 0.5341 - SSIM_loss: 0.2024 - val_accuracy: 0.6248 - val_SSIM_loss: 0.2089
# Epoch 95/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 41.1936 - gen_gan_loss: 22.9720 - gen_l1_loss: 0.1822 - disc_loss: 0.8764 - accuracy: 0.5450 - SSIM_loss: 0.2009 - val_accuracy: 0.5945 - val_SSIM_loss: 0.2089
# Epoch 96/200
# 360/360 [==============================] - 101s 282ms/step - gen_total_loss: 42.2778 - gen_gan_loss: 24.0391 - gen_l1_loss: 0.1824 - disc_loss: 0.8771 - accuracy: 0.5151 - SSIM_loss: 0.2023 - val_accuracy: 0.5938 - val_SSIM_loss: 0.2083
# Epoch 97/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 42.5954 - gen_gan_loss: 24.2619 - gen_l1_loss: 0.1833 - disc_loss: 0.8744 - accuracy: 0.5011 - SSIM_loss: 0.2033 - val_accuracy: 0.5439 - val_SSIM_loss: 0.2124
# Epoch 98/200
# 360/360 [==============================] - 97s 270ms/step - gen_total_loss: 43.4628 - gen_gan_loss: 25.1442 - gen_l1_loss: 0.1832 - disc_loss: 0.8755 - accuracy: 0.4565 - SSIM_loss: 0.2042 - val_accuracy: 0.4814 - val_SSIM_loss: 0.2106
# Epoch 99/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 43.5201 - gen_gan_loss: 25.2159 - gen_l1_loss: 0.1830 - disc_loss: 0.8746 - accuracy: 0.4478 - SSIM_loss: 0.2035 - val_accuracy: 0.5001 - val_SSIM_loss: 0.2120
# Epoch 100/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 43.5796 - gen_gan_loss: 25.3495 - gen_l1_loss: 0.1823 - disc_loss: 0.8774 - accuracy: 0.4419 - SSIM_loss: 0.2028 - val_accuracy: 0.4466 - val_SSIM_loss: 0.2169
# Epoch 101/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 44.6683 - gen_gan_loss: 26.2681 - gen_l1_loss: 0.1840 - disc_loss: 0.8745 - accuracy: 0.4239 - SSIM_loss: 0.2060 - val_accuracy: 0.4168 - val_SSIM_loss: 0.2164
# Epoch 102/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 44.4204 - gen_gan_loss: 26.1145 - gen_l1_loss: 0.1831 - disc_loss: 0.8757 - accuracy: 0.4218 - SSIM_loss: 0.2035 - val_accuracy: 0.4052 - val_SSIM_loss: 0.2145
# Epoch 103/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 45.0168 - gen_gan_loss: 26.6989 - gen_l1_loss: 0.1832 - disc_loss: 0.8749 - accuracy: 0.4100 - SSIM_loss: 0.2053 - val_accuracy: 0.4081 - val_SSIM_loss: 0.2191
# Epoch 104/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 45.1579 - gen_gan_loss: 26.8050 - gen_l1_loss: 0.1835 - disc_loss: 0.8751 - accuracy: 0.3983 - SSIM_loss: 0.2057 - val_accuracy: 0.4041 - val_SSIM_loss: 0.2143
# Epoch 105/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 45.7967 - gen_gan_loss: 27.4086 - gen_l1_loss: 0.1839 - disc_loss: 0.8728 - accuracy: 0.4056 - SSIM_loss: 0.2062 - val_accuracy: 0.4424 - val_SSIM_loss: 0.2191
# Epoch 106/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 45.8148 - gen_gan_loss: 27.5541 - gen_l1_loss: 0.1826 - disc_loss: 0.8771 - accuracy: 0.4005 - SSIM_loss: 0.2049 - val_accuracy: 0.4921 - val_SSIM_loss: 0.2096
# Epoch 107/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 45.9006 - gen_gan_loss: 27.5841 - gen_l1_loss: 0.1832 - disc_loss: 0.8744 - accuracy: 0.3981 - SSIM_loss: 0.2044 - val_accuracy: 0.4081 - val_SSIM_loss: 0.2138
# Epoch 108/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 45.6280 - gen_gan_loss: 27.2905 - gen_l1_loss: 0.1834 - disc_loss: 0.8753 - accuracy: 0.4027 - SSIM_loss: 0.2059 - val_accuracy: 0.4709 - val_SSIM_loss: 0.2116
# Epoch 109/200
# 360/360 [==============================] - 103s 286ms/step - gen_total_loss: 46.0265 - gen_gan_loss: 27.7552 - gen_l1_loss: 0.1827 - disc_loss: 0.8752 - accuracy: 0.4263 - SSIM_loss: 0.2041 - val_accuracy: 0.4711 - val_SSIM_loss: 0.2128
# Epoch 110/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 46.4959 - gen_gan_loss: 28.1863 - gen_l1_loss: 0.1831 - disc_loss: 0.8755 - accuracy: 0.4286 - SSIM_loss: 0.2071 - val_accuracy: 0.4603 - val_SSIM_loss: 0.2120
# Epoch 111/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 44.9888 - gen_gan_loss: 26.6940 - gen_l1_loss: 0.1829 - disc_loss: 0.8768 - accuracy: 0.4061 - SSIM_loss: 0.2049 - val_accuracy: 0.4028 - val_SSIM_loss: 0.2128
# Epoch 112/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 46.3137 - gen_gan_loss: 27.8367 - gen_l1_loss: 0.1848 - disc_loss: 0.8708 - accuracy: 0.3651 - SSIM_loss: 0.2096 - val_accuracy: 0.3528 - val_SSIM_loss: 0.2099
# Epoch 113/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 46.7524 - gen_gan_loss: 28.4147 - gen_l1_loss: 0.1834 - disc_loss: 0.8733 - accuracy: 0.3411 - SSIM_loss: 0.2070 - val_accuracy: 0.3711 - val_SSIM_loss: 0.2141
# Epoch 114/200
# 360/360 [==============================] - 101s 279ms/step - gen_total_loss: 47.2974 - gen_gan_loss: 29.0484 - gen_l1_loss: 0.1825 - disc_loss: 0.8770 - accuracy: 0.3605 - SSIM_loss: 0.2059 - val_accuracy: 0.4407 - val_SSIM_loss: 0.2120
# Epoch 115/200
# 360/360 [==============================] - 102s 282ms/step - gen_total_loss: 47.1187 - gen_gan_loss: 28.7532 - gen_l1_loss: 0.1837 - disc_loss: 0.8738 - accuracy: 0.3698 - SSIM_loss: 0.2068 - val_accuracy: 0.4280 - val_SSIM_loss: 0.2103
# Epoch 116/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 48.1681 - gen_gan_loss: 29.9530 - gen_l1_loss: 0.1822 - disc_loss: 0.8759 - accuracy: 0.3858 - SSIM_loss: 0.2051 - val_accuracy: 0.4503 - val_SSIM_loss: 0.2119
# Epoch 117/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 48.9344 - gen_gan_loss: 30.5483 - gen_l1_loss: 0.1839 - disc_loss: 0.8742 - accuracy: 0.4037 - SSIM_loss: 0.2062 - val_accuracy: 0.4428 - val_SSIM_loss: 0.2082
# Epoch 118/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 47.8202 - gen_gan_loss: 29.5182 - gen_l1_loss: 0.1830 - disc_loss: 0.8744 - accuracy: 0.4180 - SSIM_loss: 0.2058 - val_accuracy: 0.4451 - val_SSIM_loss: 0.2093
# Epoch 119/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 47.1000 - gen_gan_loss: 28.8422 - gen_l1_loss: 0.1826 - disc_loss: 0.8759 - accuracy: 0.4233 - SSIM_loss: 0.2066 - val_accuracy: 0.4972 - val_SSIM_loss: 0.2103
# Epoch 120/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 48.0188 - gen_gan_loss: 29.7398 - gen_l1_loss: 0.1828 - disc_loss: 0.8741 - accuracy: 0.4333 - SSIM_loss: 0.2068 - val_accuracy: 0.4703 - val_SSIM_loss: 0.2088
# Epoch 121/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 47.6835 - gen_gan_loss: 29.3784 - gen_l1_loss: 0.1831 - disc_loss: 0.8738 - accuracy: 0.4548 - SSIM_loss: 0.2060 - val_accuracy: 0.5021 - val_SSIM_loss: 0.2102
# Epoch 122/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 49.2607 - gen_gan_loss: 30.8844 - gen_l1_loss: 0.1838 - disc_loss: 0.8715 - accuracy: 0.4535 - SSIM_loss: 0.2067 - val_accuracy: 0.5107 - val_SSIM_loss: 0.2136
# Epoch 123/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 49.5420 - gen_gan_loss: 31.2434 - gen_l1_loss: 0.1830 - disc_loss: 0.8753 - accuracy: 0.4604 - SSIM_loss: 0.2057 - val_accuracy: 0.6026 - val_SSIM_loss: 0.2139
# Epoch 124/200
# 360/360 [==============================] - 98s 272ms/step - gen_total_loss: 48.9510 - gen_gan_loss: 30.6653 - gen_l1_loss: 0.1829 - disc_loss: 0.8740 - accuracy: 0.4813 - SSIM_loss: 0.2051 - val_accuracy: 0.5426 - val_SSIM_loss: 0.2106
# Epoch 125/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 49.5358 - gen_gan_loss: 31.2862 - gen_l1_loss: 0.1825 - disc_loss: 0.8750 - accuracy: 0.4786 - SSIM_loss: 0.2044 - val_accuracy: 0.5772 - val_SSIM_loss: 0.2126
# Epoch 126/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 50.5831 - gen_gan_loss: 32.2209 - gen_l1_loss: 0.1836 - disc_loss: 0.8729 - accuracy: 0.4963 - SSIM_loss: 0.2059 - val_accuracy: 0.5875 - val_SSIM_loss: 0.2146
# Epoch 127/200
# 360/360 [==============================] - 101s 282ms/step - gen_total_loss: 50.6620 - gen_gan_loss: 32.4476 - gen_l1_loss: 0.1821 - disc_loss: 0.8752 - accuracy: 0.4925 - SSIM_loss: 0.2039 - val_accuracy: 0.5572 - val_SSIM_loss: 0.2098
# Epoch 128/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 52.1157 - gen_gan_loss: 33.8081 - gen_l1_loss: 0.1831 - disc_loss: 0.8735 - accuracy: 0.4895 - SSIM_loss: 0.2055 - val_accuracy: 0.5699 - val_SSIM_loss: 0.2129
# Epoch 129/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 52.2754 - gen_gan_loss: 33.9286 - gen_l1_loss: 0.1835 - disc_loss: 0.8743 - accuracy: 0.4911 - SSIM_loss: 0.2053 - val_accuracy: 0.5907 - val_SSIM_loss: 0.2110
# Epoch 130/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 52.3928 - gen_gan_loss: 34.0997 - gen_l1_loss: 0.1829 - disc_loss: 0.8744 - accuracy: 0.4801 - SSIM_loss: 0.2048 - val_accuracy: 0.5070 - val_SSIM_loss: 0.2135
# Epoch 131/200
# 360/360 [==============================] - 98s 274ms/step - gen_total_loss: 53.5668 - gen_gan_loss: 35.2783 - gen_l1_loss: 0.1829 - disc_loss: 0.8737 - accuracy: 0.4663 - SSIM_loss: 0.2046 - val_accuracy: 0.4881 - val_SSIM_loss: 0.2122
# Epoch 132/200
# 360/360 [==============================] - 100s 276ms/step - gen_total_loss: 53.8725 - gen_gan_loss: 35.6539 - gen_l1_loss: 0.1822 - disc_loss: 0.8759 - accuracy: 0.4719 - SSIM_loss: 0.2038 - val_accuracy: 0.5632 - val_SSIM_loss: 0.2145
# Epoch 133/200
# 360/360 [==============================] - 103s 287ms/step - gen_total_loss: 54.2304 - gen_gan_loss: 35.9339 - gen_l1_loss: 0.1830 - disc_loss: 0.8737 - accuracy: 0.4833 - SSIM_loss: 0.2048 - val_accuracy: 0.5533 - val_SSIM_loss: 0.2131
# Epoch 134/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 54.7211 - gen_gan_loss: 36.3680 - gen_l1_loss: 0.1835 - disc_loss: 0.8774 - accuracy: 0.4908 - SSIM_loss: 0.2061 - val_accuracy: 0.6055 - val_SSIM_loss: 0.2123
# Epoch 135/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 55.2527 - gen_gan_loss: 36.8875 - gen_l1_loss: 0.1837 - disc_loss: 0.8739 - accuracy: 0.4829 - SSIM_loss: 0.2067 - val_accuracy: 0.5143 - val_SSIM_loss: 0.2158
# Epoch 136/200
# 360/360 [==============================] - 98s 271ms/step - gen_total_loss: 56.2767 - gen_gan_loss: 38.0064 - gen_l1_loss: 0.1827 - disc_loss: 0.8759 - accuracy: 0.4546 - SSIM_loss: 0.2051 - val_accuracy: 0.5210 - val_SSIM_loss: 0.2132
# Epoch 137/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 55.5814 - gen_gan_loss: 37.1785 - gen_l1_loss: 0.1840 - disc_loss: 0.8713 - accuracy: 0.4532 - SSIM_loss: 0.2069 - val_accuracy: 0.4596 - val_SSIM_loss: 0.2150
# Epoch 138/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 57.4647 - gen_gan_loss: 39.1438 - gen_l1_loss: 0.1832 - disc_loss: 0.8731 - accuracy: 0.4390 - SSIM_loss: 0.2066 - val_accuracy: 0.4903 - val_SSIM_loss: 0.2164
# Epoch 139/200
# 360/360 [==============================] - 101s 282ms/step - gen_total_loss: 57.3682 - gen_gan_loss: 39.0701 - gen_l1_loss: 0.1830 - disc_loss: 0.8731 - accuracy: 0.4452 - SSIM_loss: 0.2062 - val_accuracy: 0.5064 - val_SSIM_loss: 0.2165
# Epoch 140/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 57.9039 - gen_gan_loss: 39.5803 - gen_l1_loss: 0.1832 - disc_loss: 0.8726 - accuracy: 0.4434 - SSIM_loss: 0.2067 - val_accuracy: 0.4835 - val_SSIM_loss: 0.2143
# Epoch 141/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 57.8083 - gen_gan_loss: 39.4792 - gen_l1_loss: 0.1833 - disc_loss: 0.8741 - accuracy: 0.4482 - SSIM_loss: 0.2061 - val_accuracy: 0.5266 - val_SSIM_loss: 0.2128
# Epoch 142/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 58.3719 - gen_gan_loss: 40.0970 - gen_l1_loss: 0.1827 - disc_loss: 0.8755 - accuracy: 0.4553 - SSIM_loss: 0.2052 - val_accuracy: 0.4999 - val_SSIM_loss: 0.2155
# Epoch 143/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 58.3203 - gen_gan_loss: 39.8505 - gen_l1_loss: 0.1847 - disc_loss: 0.8699 - accuracy: 0.4598 - SSIM_loss: 0.2063 - val_accuracy: 0.5226 - val_SSIM_loss: 0.2146
# Epoch 144/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 58.8460 - gen_gan_loss: 40.5990 - gen_l1_loss: 0.1825 - disc_loss: 0.8739 - accuracy: 0.4885 - SSIM_loss: 0.2041 - val_accuracy: 0.5676 - val_SSIM_loss: 0.2158
# Epoch 145/200
# 360/360 [==============================] - 104s 289ms/step - gen_total_loss: 58.7851 - gen_gan_loss: 40.5306 - gen_l1_loss: 0.1825 - disc_loss: 0.8749 - accuracy: 0.5048 - SSIM_loss: 0.2047 - val_accuracy: 0.5922 - val_SSIM_loss: 0.2146
# Epoch 146/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 59.8340 - gen_gan_loss: 41.4348 - gen_l1_loss: 0.1840 - disc_loss: 0.8692 - accuracy: 0.5185 - SSIM_loss: 0.2067 - val_accuracy: 0.5805 - val_SSIM_loss: 0.2153
# Epoch 147/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 59.5012 - gen_gan_loss: 41.2544 - gen_l1_loss: 0.1825 - disc_loss: 0.8753 - accuracy: 0.5250 - SSIM_loss: 0.2046 - val_accuracy: 0.6309 - val_SSIM_loss: 0.2143
# Epoch 148/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 59.3924 - gen_gan_loss: 41.1146 - gen_l1_loss: 0.1828 - disc_loss: 0.8735 - accuracy: 0.5364 - SSIM_loss: 0.2040 - val_accuracy: 0.6601 - val_SSIM_loss: 0.2108
# Epoch 149/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 59.7772 - gen_gan_loss: 41.4025 - gen_l1_loss: 0.1837 - disc_loss: 0.8696 - accuracy: 0.5503 - SSIM_loss: 0.2052 - val_accuracy: 0.6297 - val_SSIM_loss: 0.2110
# Epoch 150/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 59.1763 - gen_gan_loss: 40.9184 - gen_l1_loss: 0.1826 - disc_loss: 0.8726 - accuracy: 0.5495 - SSIM_loss: 0.2039 - val_accuracy: 0.6255 - val_SSIM_loss: 0.2165
# Epoch 151/200
# 360/360 [==============================] - 102s 284ms/step - gen_total_loss: 60.1016 - gen_gan_loss: 41.7272 - gen_l1_loss: 0.1837 - disc_loss: 0.8711 - accuracy: 0.5598 - SSIM_loss: 0.2062 - val_accuracy: 0.6571 - val_SSIM_loss: 0.2135
# Epoch 152/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 60.3384 - gen_gan_loss: 41.9666 - gen_l1_loss: 0.1837 - disc_loss: 0.8738 - accuracy: 0.5622 - SSIM_loss: 0.2065 - val_accuracy: 0.6412 - val_SSIM_loss: 0.2137
# Epoch 153/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 62.3062 - gen_gan_loss: 44.0385 - gen_l1_loss: 0.1827 - disc_loss: 0.8749 - accuracy: 0.5543 - SSIM_loss: 0.2054 - val_accuracy: 0.6320 - val_SSIM_loss: 0.2137
# Epoch 154/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 62.1481 - gen_gan_loss: 43.9303 - gen_l1_loss: 0.1822 - disc_loss: 0.8769 - accuracy: 0.5648 - SSIM_loss: 0.2031 - val_accuracy: 0.6167 - val_SSIM_loss: 0.2143
# Epoch 155/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 62.5899 - gen_gan_loss: 44.2367 - gen_l1_loss: 0.1835 - disc_loss: 0.8701 - accuracy: 0.5611 - SSIM_loss: 0.2068 - val_accuracy: 0.6359 - val_SSIM_loss: 0.2137
# Epoch 156/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 64.8733 - gen_gan_loss: 46.5930 - gen_l1_loss: 0.1828 - disc_loss: 0.8749 - accuracy: 0.5655 - SSIM_loss: 0.2052 - val_accuracy: 0.6716 - val_SSIM_loss: 0.2118
# Epoch 157/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 64.6219 - gen_gan_loss: 46.2602 - gen_l1_loss: 0.1836 - disc_loss: 0.8698 - accuracy: 0.5724 - SSIM_loss: 0.2051 - val_accuracy: 0.6428 - val_SSIM_loss: 0.2136
# Epoch 158/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 64.3013 - gen_gan_loss: 46.0518 - gen_l1_loss: 0.1825 - disc_loss: 0.8752 - accuracy: 0.5742 - SSIM_loss: 0.2048 - val_accuracy: 0.6548 - val_SSIM_loss: 0.2133
# Epoch 159/200
# 360/360 [==============================] - 98s 274ms/step - gen_total_loss: 65.0142 - gen_gan_loss: 46.7112 - gen_l1_loss: 0.1830 - disc_loss: 0.8721 - accuracy: 0.5780 - SSIM_loss: 0.2050 - val_accuracy: 0.6666 - val_SSIM_loss: 0.2131
# Epoch 160/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 65.7412 - gen_gan_loss: 47.4265 - gen_l1_loss: 0.1831 - disc_loss: 0.8779 - accuracy: 0.5586 - SSIM_loss: 0.2050 - val_accuracy: 0.5654 - val_SSIM_loss: 0.2138
# Epoch 161/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 66.2424 - gen_gan_loss: 47.8105 - gen_l1_loss: 0.1843 - disc_loss: 0.8722 - accuracy: 0.5377 - SSIM_loss: 0.2077 - val_accuracy: 0.6129 - val_SSIM_loss: 0.2156
# Epoch 162/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 67.7918 - gen_gan_loss: 49.5191 - gen_l1_loss: 0.1827 - disc_loss: 0.8738 - accuracy: 0.5301 - SSIM_loss: 0.2059 - val_accuracy: 0.5902 - val_SSIM_loss: 0.2137
# Epoch 163/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 66.4681 - gen_gan_loss: 48.0805 - gen_l1_loss: 0.1839 - disc_loss: 0.8726 - accuracy: 0.5344 - SSIM_loss: 0.2069 - val_accuracy: 0.5693 - val_SSIM_loss: 0.2115
# Epoch 164/200
# 360/360 [==============================] - 101s 279ms/step - gen_total_loss: 64.6973 - gen_gan_loss: 46.3952 - gen_l1_loss: 0.1830 - disc_loss: 0.8724 - accuracy: 0.5484 - SSIM_loss: 0.2060 - val_accuracy: 0.6670 - val_SSIM_loss: 0.2120
# Epoch 165/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 64.6179 - gen_gan_loss: 46.2136 - gen_l1_loss: 0.1840 - disc_loss: 0.8727 - accuracy: 0.5425 - SSIM_loss: 0.2081 - val_accuracy: 0.5960 - val_SSIM_loss: 0.2166
# Epoch 166/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 65.3730 - gen_gan_loss: 46.9693 - gen_l1_loss: 0.1840 - disc_loss: 0.8722 - accuracy: 0.5278 - SSIM_loss: 0.2087 - val_accuracy: 0.5397 - val_SSIM_loss: 0.2139
# Epoch 167/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 66.9706 - gen_gan_loss: 48.6516 - gen_l1_loss: 0.1832 - disc_loss: 0.8741 - accuracy: 0.5188 - SSIM_loss: 0.2069 - val_accuracy: 0.5508 - val_SSIM_loss: 0.2154
# Epoch 168/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 66.3573 - gen_gan_loss: 47.9067 - gen_l1_loss: 0.1845 - disc_loss: 0.8709 - accuracy: 0.5239 - SSIM_loss: 0.2080 - val_accuracy: 0.5779 - val_SSIM_loss: 0.2151
# Epoch 169/200
# 360/360 [==============================] - 102s 284ms/step - gen_total_loss: 64.1676 - gen_gan_loss: 45.9599 - gen_l1_loss: 0.1821 - disc_loss: 0.9674 - accuracy: 0.5341 - SSIM_loss: 0.2041 - val_accuracy: 0.5562 - val_SSIM_loss: 0.1979
# Epoch 170/200
# 360/360 [==============================] - 102s 284ms/step - gen_total_loss: 63.2573 - gen_gan_loss: 44.8482 - gen_l1_loss: 0.1841 - disc_loss: 0.8727 - accuracy: 0.5294 - SSIM_loss: 0.2003 - val_accuracy: 0.5560 - val_SSIM_loss: 0.2146
# Epoch 171/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 65.2097 - gen_gan_loss: 46.8492 - gen_l1_loss: 0.1836 - disc_loss: 0.8791 - accuracy: 0.5430 - SSIM_loss: 0.2054 - val_accuracy: 0.6011 - val_SSIM_loss: 0.2173
# Epoch 172/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 67.3072 - gen_gan_loss: 48.9199 - gen_l1_loss: 0.1839 - disc_loss: 0.8763 - accuracy: 0.5335 - SSIM_loss: 0.2080 - val_accuracy: 0.5592 - val_SSIM_loss: 0.2168
# Epoch 173/200
# 360/360 [==============================] - 99s 276ms/step - gen_total_loss: 67.6906 - gen_gan_loss: 49.2540 - gen_l1_loss: 0.1844 - disc_loss: 0.8750 - accuracy: 0.5062 - SSIM_loss: 0.2105 - val_accuracy: 0.5238 - val_SSIM_loss: 0.2174
# Epoch 174/200
# 360/360 [==============================] - 100s 276ms/step - gen_total_loss: 66.7163 - gen_gan_loss: 48.2929 - gen_l1_loss: 0.1842 - disc_loss: 0.8763 - accuracy: 0.5021 - SSIM_loss: 0.2100 - val_accuracy: 0.5203 - val_SSIM_loss: 0.2169
# Epoch 175/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 67.0746 - gen_gan_loss: 48.6553 - gen_l1_loss: 0.1842 - disc_loss: 0.8744 - accuracy: 0.5224 - SSIM_loss: 0.2091 - val_accuracy: 0.5660 - val_SSIM_loss: 0.2149
# Epoch 176/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 67.4608 - gen_gan_loss: 49.0955 - gen_l1_loss: 0.1837 - disc_loss: 0.8752 - accuracy: 0.5306 - SSIM_loss: 0.2085 - val_accuracy: 0.5635 - val_SSIM_loss: 0.2160
# Epoch 177/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 67.9329 - gen_gan_loss: 49.5083 - gen_l1_loss: 0.1842 - disc_loss: 0.8710 - accuracy: 0.5353 - SSIM_loss: 0.2098 - val_accuracy: 0.5666 - val_SSIM_loss: 0.2163
# Epoch 178/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 67.9698 - gen_gan_loss: 49.5800 - gen_l1_loss: 0.1839 - disc_loss: 0.8743 - accuracy: 0.5410 - SSIM_loss: 0.2087 - val_accuracy: 0.5840 - val_SSIM_loss: 0.2170
# Epoch 179/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 67.8981 - gen_gan_loss: 49.5416 - gen_l1_loss: 0.1836 - disc_loss: 0.8728 - accuracy: 0.5514 - SSIM_loss: 0.2080 - val_accuracy: 0.5641 - val_SSIM_loss: 0.2163
# Epoch 180/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 68.4572 - gen_gan_loss: 50.1241 - gen_l1_loss: 0.1833 - disc_loss: 0.8735 - accuracy: 0.5538 - SSIM_loss: 0.2078 - val_accuracy: 0.6039 - val_SSIM_loss: 0.2151
# Epoch 181/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 67.6263 - gen_gan_loss: 49.2489 - gen_l1_loss: 0.1838 - disc_loss: 0.8724 - accuracy: 0.5519 - SSIM_loss: 0.2091 - val_accuracy: 0.6053 - val_SSIM_loss: 0.2177
# Epoch 182/200
# 360/360 [==============================] - 102s 283ms/step - gen_total_loss: 67.3264 - gen_gan_loss: 48.9941 - gen_l1_loss: 0.1833 - disc_loss: 0.8737 - accuracy: 0.5572 - SSIM_loss: 0.2074 - val_accuracy: 0.5955 - val_SSIM_loss: 0.2151
# Epoch 183/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 67.1287 - gen_gan_loss: 48.7750 - gen_l1_loss: 0.1835 - disc_loss: 0.8721 - accuracy: 0.5567 - SSIM_loss: 0.2073 - val_accuracy: 0.6132 - val_SSIM_loss: 0.2117
# Epoch 184/200
# 360/360 [==============================] - 100s 278ms/step - gen_total_loss: 68.2602 - gen_gan_loss: 49.9447 - gen_l1_loss: 0.1832 - disc_loss: 0.8718 - accuracy: 0.5527 - SSIM_loss: 0.2071 - val_accuracy: 0.5682 - val_SSIM_loss: 0.2141
# Epoch 185/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 67.3827 - gen_gan_loss: 48.9783 - gen_l1_loss: 0.1840 - disc_loss: 0.8708 - accuracy: 0.5472 - SSIM_loss: 0.2076 - val_accuracy: 0.5682 - val_SSIM_loss: 0.2125
# Epoch 186/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 66.5831 - gen_gan_loss: 48.2097 - gen_l1_loss: 0.1837 - disc_loss: 0.8721 - accuracy: 0.5564 - SSIM_loss: 0.2084 - val_accuracy: 0.6039 - val_SSIM_loss: 0.2167
# Epoch 187/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 67.9559 - gen_gan_loss: 49.6460 - gen_l1_loss: 0.1831 - disc_loss: 0.8717 - accuracy: 0.5619 - SSIM_loss: 0.2083 - val_accuracy: 0.5855 - val_SSIM_loss: 0.2161
# Epoch 188/200
# 360/360 [==============================] - 102s 284ms/step - gen_total_loss: 68.6255 - gen_gan_loss: 50.2388 - gen_l1_loss: 0.1839 - disc_loss: 0.8725 - accuracy: 0.5571 - SSIM_loss: 0.2083 - val_accuracy: 0.5818 - val_SSIM_loss: 0.2143
# Epoch 189/200
# 360/360 [==============================] - 98s 274ms/step - gen_total_loss: 67.8009 - gen_gan_loss: 49.4044 - gen_l1_loss: 0.1840 - disc_loss: 0.8726 - accuracy: 0.5610 - SSIM_loss: 0.2080 - val_accuracy: 0.6179 - val_SSIM_loss: 0.2137
# Epoch 190/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 67.1459 - gen_gan_loss: 48.7254 - gen_l1_loss: 0.1842 - disc_loss: 0.8721 - accuracy: 0.5630 - SSIM_loss: 0.2079 - val_accuracy: 0.5552 - val_SSIM_loss: 0.2118
# Epoch 191/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 67.4361 - gen_gan_loss: 49.1691 - gen_l1_loss: 0.1827 - disc_loss: 0.8734 - accuracy: 0.5637 - SSIM_loss: 0.2059 - val_accuracy: 0.5642 - val_SSIM_loss: 0.2149
# Epoch 192/200
# 360/360 [==============================] - 97s 271ms/step - gen_total_loss: 67.2272 - gen_gan_loss: 48.8931 - gen_l1_loss: 0.1833 - disc_loss: 0.8733 - accuracy: 0.5539 - SSIM_loss: 0.2073 - val_accuracy: 0.5946 - val_SSIM_loss: 0.2156
# Epoch 193/200
# 360/360 [==============================] - 101s 279ms/step - gen_total_loss: 69.5184 - gen_gan_loss: 51.0819 - gen_l1_loss: 0.1844 - disc_loss: 0.8713 - accuracy: 0.5504 - SSIM_loss: 0.2087 - val_accuracy: 0.5587 - val_SSIM_loss: 0.2106
# Epoch 194/200
# 360/360 [==============================] - 103s 286ms/step - gen_total_loss: 69.3029 - gen_gan_loss: 51.0381 - gen_l1_loss: 0.1826 - disc_loss: 0.8739 - accuracy: 0.5482 - SSIM_loss: 0.2054 - val_accuracy: 0.5752 - val_SSIM_loss: 0.2146
# Epoch 195/200
# 360/360 [==============================] - 98s 273ms/step - gen_total_loss: 68.6802 - gen_gan_loss: 50.2768 - gen_l1_loss: 0.1840 - disc_loss: 0.8703 - accuracy: 0.5519 - SSIM_loss: 0.2071 - val_accuracy: 0.6032 - val_SSIM_loss: 0.2141
# Epoch 196/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 69.6639 - gen_gan_loss: 51.4192 - gen_l1_loss: 0.1824 - disc_loss: 0.8747 - accuracy: 0.5563 - SSIM_loss: 0.2049 - val_accuracy: 0.5994 - val_SSIM_loss: 0.2132
# Epoch 197/200
# 360/360 [==============================] - 99s 274ms/step - gen_total_loss: 69.6240 - gen_gan_loss: 51.2759 - gen_l1_loss: 0.1835 - disc_loss: 0.8725 - accuracy: 0.5549 - SSIM_loss: 0.2062 - val_accuracy: 0.5666 - val_SSIM_loss: 0.2132
# Epoch 198/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 69.2252 - gen_gan_loss: 50.8871 - gen_l1_loss: 0.1834 - disc_loss: 0.8733 - accuracy: 0.5490 - SSIM_loss: 0.2067 - val_accuracy: 0.5534 - val_SSIM_loss: 0.2134
# Epoch 199/200
# 360/360 [==============================] - 99s 275ms/step - gen_total_loss: 70.0114 - gen_gan_loss: 51.6182 - gen_l1_loss: 0.1839 - disc_loss: 0.8701 - accuracy: 0.5531 - SSIM_loss: 0.2066 - val_accuracy: 0.6094 - val_SSIM_loss: 0.2124
# Epoch 200/200
# 360/360 [==============================] - 92s 255ms/step - gen_total_loss: 70.1784 - gen_gan_loss: 51.8480 - gen_l1_loss: 0.1833 - disc_loss: 0.8733 - accuracy: 0.5512 - SSIM_loss: 0.2074 - val_accuracy: 0.5551 - val_SSIM_loss: 0.2154
