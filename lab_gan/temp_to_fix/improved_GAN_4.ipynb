# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()
import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns
from datetime import datetime
import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='Pix2Pix_model_v2'
    __changes__="Changed to a pix2pix model in order to test a greater network for generator and discriminator. Generator: U-Net, Discriminator: PatchGAN. Changed Discriminator optimizer to SGD"
    
    __normalization__='[-1,1]'
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.SGD(learning_rate=2e-4)
    
    @staticmethod
    def discriminator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def main():
            
            initializer = tf.random_normal_initializer(0., 0.02)

            inp = tf.keras.layers.Input(shape=image_shape, name='input_image')
            tar = tf.keras.layers.Input(shape=image_shape, name='target_image')

            x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

            down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
            down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
            down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

            zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
            conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                        kernel_initializer=initializer,
                                        use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

            batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

            leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

            zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

            last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                        kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

            return tf.keras.Model(inputs=[inp, tar], outputs=last)
        
        
        return main()
    
    @staticmethod
    def generator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def upsample(filters, size, apply_dropout=False):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                            padding='same',
                                            kernel_initializer=initializer,
                                            use_bias=False))

            result.add(tf.keras.layers.BatchNormalization())

            if apply_dropout:
                result.add(tf.keras.layers.Dropout(0.5))

            result.add(tf.keras.layers.ReLU())

            return result

        def main():
            inputs = tf.keras.layers.Input(shape=image_shape)

            down_stack = [
                downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
                downsample(128, 4), # (bs, 64, 64, 128)
                downsample(256, 4), # (bs, 32, 32, 256)
                downsample(512, 4), # (bs, 16, 16, 512)
                downsample(512, 4), # (bs, 8, 8, 512)
                downsample(512, 4), # (bs, 4, 4, 512)
                downsample(512, 4), # (bs, 2, 2, 512)
                #downsample(512, 4), # (bs, 1, 1, 512)
            ]

            up_stack = [
                upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
                upsample(512, 4), # (bs, 16, 16, 1024)
                upsample(256, 4), # (bs, 32, 32, 512)
                upsample(128, 4), # (bs, 64, 64, 256)
                upsample(64, 4), # (bs, 128, 128, 128)
            ]

            initializer = tf.random_normal_initializer(0., 0.02)
            last = tf.keras.layers.Conv2DTranspose(3, 4,
                                                 strides=2,
                                                 padding='same',
                                                 kernel_initializer=initializer,
                                                 activation='tanh') # (bs, 256, 256, 3)

            x = inputs

            # Downsampling through the model
            skips = []
            for down in down_stack:
                x = down(x)
                skips.append(x)

            skips = reversed(skips[:-1])

            # Upsampling and establishing the skip connections
            for up, skip in zip(up_stack, skips):
                x = up(x)
                x = tf.keras.layers.Concatenate()([x, skip])

            x = last(x)

            return tf.keras.Model(inputs=inputs, outputs=x)
        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        LAMBDA = 100
        def generator_loss(disc_generated_output, gen_output, target): # https://arxiv.org/abs/1611.07004
            gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

            # mean absolute error
            l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

            total_gen_loss = gan_loss + (LAMBDA * l1_loss)

            return total_gen_loss, gan_loss, l1_loss

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss

        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__)
# Out:
# train_x (30, 128, 128, 3) float32 -1.0 1.0
# train_y (30, 128, 128, 3) float32 -1.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss(disc_generated_output, gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(gen_total_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'gen_total_loss':gen_total_loss,
                'gen_gan_loss':gen_gan_loss,
                'gen_l1_loss':gen_l1_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')
file_writer = tf.summary.create_file_writer(log_dir + "/plots/")

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - gen_total_loss: 101.0597 - gen_gan_loss: 0.5846 - gen_l1_loss: 1.0048 - disc_loss: 1.8360 - accuracy: 0.1929 - SSIM_loss: 1.0017WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/360 [..............................] - ETA: 1:08 - gen_total_loss: 96.7980 - gen_gan_loss: 0.8414 - gen_l1_loss: 0.9596 - disc_loss: 1.8332 - accuracy: 0.1951 - SSIM_loss: 0.9933WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1050s vs `on_train_batch_end` time: 0.2739s). Check your callbacks.
# 360/360 [==============================] - 149s 415ms/step - gen_total_loss: 10.7761 - gen_gan_loss: 1.2574 - gen_l1_loss: 0.0952 - disc_loss: 1.3252 - accuracy: 0.2798 - SSIM_loss: 0.1359 - val_accuracy: 0.5330 - val_SSIM_loss: 0.0744
# Epoch 2/200
# 360/360 [==============================] - 94s 261ms/step - gen_total_loss: 6.0705 - gen_gan_loss: 0.9959 - gen_l1_loss: 0.0507 - disc_loss: 1.3735 - accuracy: 0.3301 - SSIM_loss: 0.0777 - val_accuracy: 0.3134 - val_SSIM_loss: 0.0983
# Epoch 3/200
# 360/360 [==============================] - 148s 411ms/step - gen_total_loss: 4.8751 - gen_gan_loss: 0.8264 - gen_l1_loss: 0.0405 - disc_loss: 1.3779 - accuracy: 0.3412 - SSIM_loss: 0.0649 - val_accuracy: 0.2255 - val_SSIM_loss: 0.0804
# Epoch 4/200
# 360/360 [==============================] - 149s 414ms/step - gen_total_loss: 4.3428 - gen_gan_loss: 0.7988 - gen_l1_loss: 0.0354 - disc_loss: 1.3851 - accuracy: 0.3546 - SSIM_loss: 0.0585 - val_accuracy: 0.2182 - val_SSIM_loss: 0.0765
# Epoch 5/200
# 360/360 [==============================] - 95s 264ms/step - gen_total_loss: 3.9578 - gen_gan_loss: 0.7896 - gen_l1_loss: 0.0317 - disc_loss: 1.3746 - accuracy: 0.3651 - SSIM_loss: 0.0540 - val_accuracy: 0.1758 - val_SSIM_loss: 0.0571
# Epoch 6/200
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 3.6492 - gen_gan_loss: 0.7879 - gen_l1_loss: 0.0286 - disc_loss: 1.3765 - accuracy: 0.3757 - SSIM_loss: 0.0501 - val_accuracy: 0.7951 - val_SSIM_loss: 0.0457
# Epoch 7/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 3.3865 - gen_gan_loss: 0.7716 - gen_l1_loss: 0.0261 - disc_loss: 1.3883 - accuracy: 0.4074 - SSIM_loss: 0.0470 - val_accuracy: 0.3554 - val_SSIM_loss: 0.0638
# Epoch 8/200
# 360/360 [==============================] - 92s 255ms/step - gen_total_loss: 3.2226 - gen_gan_loss: 0.7537 - gen_l1_loss: 0.0247 - disc_loss: 1.3827 - accuracy: 0.4008 - SSIM_loss: 0.0447 - val_accuracy: 0.6462 - val_SSIM_loss: 0.0768
# Epoch 9/200
# 360/360 [==============================] - 100s 279ms/step - gen_total_loss: 3.0348 - gen_gan_loss: 0.7452 - gen_l1_loss: 0.0229 - disc_loss: 1.3883 - accuracy: 0.4348 - SSIM_loss: 0.0423 - val_accuracy: 0.5393 - val_SSIM_loss: 0.0756
# Epoch 10/200
# 360/360 [==============================] - 109s 302ms/step - gen_total_loss: 2.9218 - gen_gan_loss: 0.7399 - gen_l1_loss: 0.0218 - disc_loss: 1.3862 - accuracy: 0.4500 - SSIM_loss: 0.0406 - val_accuracy: 0.2838 - val_SSIM_loss: 0.0609
# Epoch 11/200
# 360/360 [==============================] - 103s 287ms/step - gen_total_loss: 2.8396 - gen_gan_loss: 0.7416 - gen_l1_loss: 0.0210 - disc_loss: 1.3859 - accuracy: 0.4507 - SSIM_loss: 0.0393 - val_accuracy: 0.5405 - val_SSIM_loss: 0.0499
# Epoch 12/200
# 360/360 [==============================] - 105s 292ms/step - gen_total_loss: 2.8308 - gen_gan_loss: 0.7374 - gen_l1_loss: 0.0209 - disc_loss: 1.3808 - accuracy: 0.4606 - SSIM_loss: 0.0389 - val_accuracy: 0.4018 - val_SSIM_loss: 0.0831
# Epoch 13/200
# 360/360 [==============================] - 101s 280ms/step - gen_total_loss: 2.6258 - gen_gan_loss: 0.7337 - gen_l1_loss: 0.0189 - disc_loss: 1.3832 - accuracy: 0.4477 - SSIM_loss: 0.0360 - val_accuracy: 0.1646 - val_SSIM_loss: 0.0590
# Epoch 14/200
# 360/360 [==============================] - 101s 281ms/step - gen_total_loss: 2.6113 - gen_gan_loss: 0.7311 - gen_l1_loss: 0.0188 - disc_loss: 1.3827 - accuracy: 0.4652 - SSIM_loss: 0.0356 - val_accuracy: 0.3143 - val_SSIM_loss: 0.0660
# Epoch 15/200
# 360/360 [==============================] - 100s 277ms/step - gen_total_loss: 2.5778 - gen_gan_loss: 0.7302 - gen_l1_loss: 0.0185 - disc_loss: 1.3857 - accuracy: 0.4701 - SSIM_loss: 0.0350 - val_accuracy: 0.3165 - val_SSIM_loss: 0.0458
# Epoch 16/200
# 360/360 [==============================] - 112s 311ms/step - gen_total_loss: 2.4851 - gen_gan_loss: 0.7306 - gen_l1_loss: 0.0175 - disc_loss: 1.3828 - accuracy: 0.4588 - SSIM_loss: 0.0336 - val_accuracy: 0.6732 - val_SSIM_loss: 0.0611
# Epoch 17/200
# 360/360 [==============================] - 154s 427ms/step - gen_total_loss: 2.3776 - gen_gan_loss: 0.7259 - gen_l1_loss: 0.0165 - disc_loss: 1.3859 - accuracy: 0.4551 - SSIM_loss: 0.0319 - val_accuracy: 0.5310 - val_SSIM_loss: 0.0679
# Epoch 18/200
# 360/360 [==============================] - 155s 431ms/step - gen_total_loss: 2.3451 - gen_gan_loss: 0.7256 - gen_l1_loss: 0.0162 - disc_loss: 1.3826 - accuracy: 0.4711 - SSIM_loss: 0.0312 - val_accuracy: 0.3652 - val_SSIM_loss: 0.0543
# Epoch 19/200
# 360/360 [==============================] - 147s 408ms/step - gen_total_loss: 2.3996 - gen_gan_loss: 0.7260 - gen_l1_loss: 0.0167 - disc_loss: 1.3811 - accuracy: 0.4522 - SSIM_loss: 0.0316 - val_accuracy: 0.4319 - val_SSIM_loss: 0.0684
# Epoch 20/200
# 360/360 [==============================] - 150s 417ms/step - gen_total_loss: 2.2627 - gen_gan_loss: 0.7225 - gen_l1_loss: 0.0154 - disc_loss: 1.3818 - accuracy: 0.4690 - SSIM_loss: 0.0298 - val_accuracy: 0.2620 - val_SSIM_loss: 0.0567
# Epoch 21/200
# 360/360 [==============================] - 149s 415ms/step - gen_total_loss: 2.2779 - gen_gan_loss: 0.7275 - gen_l1_loss: 0.0155 - disc_loss: 1.3823 - accuracy: 0.4898 - SSIM_loss: 0.0299 - val_accuracy: 0.2827 - val_SSIM_loss: 0.0765
# Epoch 22/200
# 360/360 [==============================] - 149s 413ms/step - gen_total_loss: 2.2027 - gen_gan_loss: 0.7213 - gen_l1_loss: 0.0148 - disc_loss: 1.3827 - accuracy: 0.4785 - SSIM_loss: 0.0288 - val_accuracy: 0.3560 - val_SSIM_loss: 0.0771
# Epoch 23/200
# 360/360 [==============================] - 149s 413ms/step - gen_total_loss: 2.2160 - gen_gan_loss: 0.7223 - gen_l1_loss: 0.0149 - disc_loss: 1.3823 - accuracy: 0.4812 - SSIM_loss: 0.0287 - val_accuracy: 0.3654 - val_SSIM_loss: 0.0544
# Epoch 24/200
# 360/360 [==============================] - 150s 416ms/step - gen_total_loss: 2.1752 - gen_gan_loss: 0.7214 - gen_l1_loss: 0.0145 - disc_loss: 1.3808 - accuracy: 0.4944 - SSIM_loss: 0.0281 - val_accuracy: 0.6188 - val_SSIM_loss: 0.0834
# Epoch 25/200
# 360/360 [==============================] - 150s 417ms/step - gen_total_loss: 2.1048 - gen_gan_loss: 0.7187 - gen_l1_loss: 0.0139 - disc_loss: 1.3826 - accuracy: 0.5298 - SSIM_loss: 0.0270 - val_accuracy: 0.3212 - val_SSIM_loss: 0.0859
# Epoch 26/200
# 360/360 [==============================] - 145s 404ms/step - gen_total_loss: 2.1497 - gen_gan_loss: 0.7183 - gen_l1_loss: 0.0143 - disc_loss: 1.3812 - accuracy: 0.5052 - SSIM_loss: 0.0274 - val_accuracy: 0.5503 - val_SSIM_loss: 0.0611
# Epoch 27/200
# 360/360 [==============================] - 149s 413ms/step - gen_total_loss: 2.0235 - gen_gan_loss: 0.7146 - gen_l1_loss: 0.0131 - disc_loss: 1.3841 - accuracy: 0.5198 - SSIM_loss: 0.0259 - val_accuracy: 0.3635 - val_SSIM_loss: 0.0545
# Epoch 28/200
# 360/360 [==============================] - 149s 413ms/step - gen_total_loss: 2.0049 - gen_gan_loss: 0.7167 - gen_l1_loss: 0.0129 - disc_loss: 1.3825 - accuracy: 0.5239 - SSIM_loss: 0.0255 - val_accuracy: 0.7357 - val_SSIM_loss: 0.0488
# Epoch 29/200
# 360/360 [==============================] - 146s 407ms/step - gen_total_loss: 2.0258 - gen_gan_loss: 0.7160 - gen_l1_loss: 0.0131 - disc_loss: 1.3809 - accuracy: 0.5413 - SSIM_loss: 0.0256 - val_accuracy: 0.6193 - val_SSIM_loss: 0.0739
# Epoch 30/200
# 360/360 [==============================] - 150s 416ms/step - gen_total_loss: 1.9555 - gen_gan_loss: 0.7161 - gen_l1_loss: 0.0124 - disc_loss: 1.3815 - accuracy: 0.5632 - SSIM_loss: 0.0246 - val_accuracy: 0.6251 - val_SSIM_loss: 0.0466
# Epoch 31/200
# 360/360 [==============================] - 150s 416ms/step - gen_total_loss: 1.8951 - gen_gan_loss: 0.7149 - gen_l1_loss: 0.0118 - disc_loss: 1.3819 - accuracy: 0.5725 - SSIM_loss: 0.0238 - val_accuracy: 0.7129 - val_SSIM_loss: 0.0418
# Epoch 32/200
# 360/360 [==============================] - 149s 413ms/step - gen_total_loss: 1.9509 - gen_gan_loss: 0.7145 - gen_l1_loss: 0.0124 - disc_loss: 1.3817 - accuracy: 0.5926 - SSIM_loss: 0.0245 - val_accuracy: 0.4031 - val_SSIM_loss: 0.0549
# Epoch 33/200
# 360/360 [==============================] - 147s 408ms/step - gen_total_loss: 1.9725 - gen_gan_loss: 0.7156 - gen_l1_loss: 0.0126 - disc_loss: 1.3817 - accuracy: 0.6268 - SSIM_loss: 0.0246 - val_accuracy: 0.4065 - val_SSIM_loss: 0.0622
# Epoch 34/200
# 360/360 [==============================] - 150s 417ms/step - gen_total_loss: 1.8708 - gen_gan_loss: 0.7122 - gen_l1_loss: 0.0116 - disc_loss: 1.3830 - accuracy: 0.6461 - SSIM_loss: 0.0233 - val_accuracy: 0.5753 - val_SSIM_loss: 0.0619
# Epoch 35/200
# 360/360 [==============================] - 149s 415ms/step - gen_total_loss: 1.8219 - gen_gan_loss: 0.7127 - gen_l1_loss: 0.0111 - disc_loss: 1.3831 - accuracy: 0.6353 - SSIM_loss: 0.0226 - val_accuracy: 0.7078 - val_SSIM_loss: 0.0577
# Epoch 36/200
# 360/360 [==============================] - 145s 403ms/step - gen_total_loss: 1.8586 - gen_gan_loss: 0.7117 - gen_l1_loss: 0.0115 - disc_loss: 1.3826 - accuracy: 0.6587 - SSIM_loss: 0.0230 - val_accuracy: 0.6642 - val_SSIM_loss: 0.0561
# Epoch 37/200
# 360/360 [==============================] - 149s 414ms/step - gen_total_loss: 1.8356 - gen_gan_loss: 0.7129 - gen_l1_loss: 0.0112 - disc_loss: 1.3802 - accuracy: 0.6750 - SSIM_loss: 0.0227 - val_accuracy: 0.5672 - val_SSIM_loss: 0.0533
# Epoch 38/200
# 360/360 [==============================] - 150s 417ms/step - gen_total_loss: 1.8430 - gen_gan_loss: 0.7125 - gen_l1_loss: 0.0113 - disc_loss: 1.3808 - accuracy: 0.6822 - SSIM_loss: 0.0226 - val_accuracy: 0.7461 - val_SSIM_loss: 0.0573
# Epoch 39/200
# 360/360 [==============================] - 173s 481ms/step - gen_total_loss: 1.7967 - gen_gan_loss: 0.7126 - gen_l1_loss: 0.0108 - disc_loss: 1.3833 - accuracy: 0.6962 - SSIM_loss: 0.0219 - val_accuracy: 0.4097 - val_SSIM_loss: 0.0460
# Epoch 40/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.7379 - gen_gan_loss: 0.7097 - gen_l1_loss: 0.0103 - disc_loss: 1.3835 - accuracy: 0.7118 - SSIM_loss: 0.0212 - val_accuracy: 0.7306 - val_SSIM_loss: 0.0642
# Epoch 41/200
# 360/360 [==============================] - 208s 579ms/step - gen_total_loss: 1.7210 - gen_gan_loss: 0.7100 - gen_l1_loss: 0.0101 - disc_loss: 1.3807 - accuracy: 0.7203 - SSIM_loss: 0.0209 - val_accuracy: 0.4579 - val_SSIM_loss: 0.0457
# Epoch 42/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 1.7172 - gen_gan_loss: 0.7106 - gen_l1_loss: 0.0101 - disc_loss: 1.3831 - accuracy: 0.7367 - SSIM_loss: 0.0208 - val_accuracy: 0.4526 - val_SSIM_loss: 0.0704
# Epoch 43/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.7059 - gen_gan_loss: 0.7108 - gen_l1_loss: 0.0100 - disc_loss: 1.3802 - accuracy: 0.7639 - SSIM_loss: 0.0205 - val_accuracy: 0.7407 - val_SSIM_loss: 0.0603
# Epoch 44/200
# 360/360 [==============================] - 204s 566ms/step - gen_total_loss: 1.7047 - gen_gan_loss: 0.7110 - gen_l1_loss: 0.0099 - disc_loss: 1.3815 - accuracy: 0.7546 - SSIM_loss: 0.0205 - val_accuracy: 0.7763 - val_SSIM_loss: 0.0572
# Epoch 45/200
# 360/360 [==============================] - 208s 579ms/step - gen_total_loss: 1.7834 - gen_gan_loss: 0.7123 - gen_l1_loss: 0.0107 - disc_loss: 1.3820 - accuracy: 0.7648 - SSIM_loss: 0.0215 - val_accuracy: 0.8249 - val_SSIM_loss: 0.0512
# Epoch 46/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.7238 - gen_gan_loss: 0.7117 - gen_l1_loss: 0.0101 - disc_loss: 1.3825 - accuracy: 0.7847 - SSIM_loss: 0.0206 - val_accuracy: 0.8397 - val_SSIM_loss: 0.0596
# Epoch 47/200
# 360/360 [==============================] - 202s 561ms/step - gen_total_loss: 1.6754 - gen_gan_loss: 0.7105 - gen_l1_loss: 0.0096 - disc_loss: 1.3835 - accuracy: 0.8010 - SSIM_loss: 0.0201 - val_accuracy: 0.7377 - val_SSIM_loss: 0.0548
# Epoch 48/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.6380 - gen_gan_loss: 0.7096 - gen_l1_loss: 0.0093 - disc_loss: 1.3809 - accuracy: 0.7944 - SSIM_loss: 0.0195 - val_accuracy: 0.4244 - val_SSIM_loss: 0.0529
# Epoch 49/200
# 360/360 [==============================] - 205s 570ms/step - gen_total_loss: 1.6053 - gen_gan_loss: 0.7090 - gen_l1_loss: 0.0090 - disc_loss: 1.3828 - accuracy: 0.8068 - SSIM_loss: 0.0190 - val_accuracy: 0.6922 - val_SSIM_loss: 0.0545
# Epoch 50/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.6104 - gen_gan_loss: 0.7090 - gen_l1_loss: 0.0090 - disc_loss: 1.3829 - accuracy: 0.8187 - SSIM_loss: 0.0191 - val_accuracy: 0.6292 - val_SSIM_loss: 0.0636
# Epoch 51/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.5986 - gen_gan_loss: 0.7089 - gen_l1_loss: 0.0089 - disc_loss: 1.3802 - accuracy: 0.8241 - SSIM_loss: 0.0189 - val_accuracy: 0.5357 - val_SSIM_loss: 0.0555
# Epoch 52/200
# 360/360 [==============================] - 202s 561ms/step - gen_total_loss: 1.6134 - gen_gan_loss: 0.7096 - gen_l1_loss: 0.0090 - disc_loss: 1.3825 - accuracy: 0.8264 - SSIM_loss: 0.0191 - val_accuracy: 0.8594 - val_SSIM_loss: 0.0596
# Epoch 53/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.6163 - gen_gan_loss: 0.7100 - gen_l1_loss: 0.0091 - disc_loss: 1.3812 - accuracy: 0.8264 - SSIM_loss: 0.0191 - val_accuracy: 0.8931 - val_SSIM_loss: 0.0593
# Epoch 54/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 1.5987 - gen_gan_loss: 0.7095 - gen_l1_loss: 0.0089 - disc_loss: 1.3809 - accuracy: 0.8389 - SSIM_loss: 0.0187 - val_accuracy: 0.8376 - val_SSIM_loss: 0.0590
# Epoch 55/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.5874 - gen_gan_loss: 0.7098 - gen_l1_loss: 0.0088 - disc_loss: 1.3803 - accuracy: 0.8413 - SSIM_loss: 0.0186 - val_accuracy: 0.9209 - val_SSIM_loss: 0.0640
# Epoch 56/200
# 360/360 [==============================] - 208s 579ms/step - gen_total_loss: 1.5273 - gen_gan_loss: 0.7077 - gen_l1_loss: 0.0082 - disc_loss: 1.3824 - accuracy: 0.8516 - SSIM_loss: 0.0178 - val_accuracy: 0.6144 - val_SSIM_loss: 0.0533
# Epoch 57/200
# 360/360 [==============================] - 204s 566ms/step - gen_total_loss: 1.5464 - gen_gan_loss: 0.7099 - gen_l1_loss: 0.0084 - disc_loss: 1.3809 - accuracy: 0.8527 - SSIM_loss: 0.0179 - val_accuracy: 0.5898 - val_SSIM_loss: 0.0529
# Epoch 58/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 1.5989 - gen_gan_loss: 0.7122 - gen_l1_loss: 0.0089 - disc_loss: 1.3797 - accuracy: 0.8425 - SSIM_loss: 0.0186 - val_accuracy: 0.7087 - val_SSIM_loss: 0.0559
# Epoch 59/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 1.5152 - gen_gan_loss: 0.7087 - gen_l1_loss: 0.0081 - disc_loss: 1.3831 - accuracy: 0.8542 - SSIM_loss: 0.0175 - val_accuracy: 0.8337 - val_SSIM_loss: 0.0568
# Epoch 60/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.5933 - gen_gan_loss: 0.7108 - gen_l1_loss: 0.0088 - disc_loss: 1.3798 - accuracy: 0.8590 - SSIM_loss: 0.0185 - val_accuracy: 0.7826 - val_SSIM_loss: 0.0534
# Epoch 61/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.5305 - gen_gan_loss: 0.7088 - gen_l1_loss: 0.0082 - disc_loss: 1.3814 - accuracy: 0.8668 - SSIM_loss: 0.0176 - val_accuracy: 0.6033 - val_SSIM_loss: 0.0583
# Epoch 62/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 1.5151 - gen_gan_loss: 0.7086 - gen_l1_loss: 0.0081 - disc_loss: 1.3816 - accuracy: 0.8721 - SSIM_loss: 0.0173 - val_accuracy: 0.4537 - val_SSIM_loss: 0.0447
# Epoch 63/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 1.5161 - gen_gan_loss: 0.7088 - gen_l1_loss: 0.0081 - disc_loss: 1.3803 - accuracy: 0.8677 - SSIM_loss: 0.0174 - val_accuracy: 0.8827 - val_SSIM_loss: 0.0564
# Epoch 64/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 1.5358 - gen_gan_loss: 0.7102 - gen_l1_loss: 0.0083 - disc_loss: 1.3810 - accuracy: 0.8720 - SSIM_loss: 0.0176 - val_accuracy: 0.6030 - val_SSIM_loss: 0.0469
# Epoch 65/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.5058 - gen_gan_loss: 0.7105 - gen_l1_loss: 0.0080 - disc_loss: 1.3785 - accuracy: 0.8770 - SSIM_loss: 0.0171 - val_accuracy: 0.9221 - val_SSIM_loss: 0.0577
# Epoch 66/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.4836 - gen_gan_loss: 0.7092 - gen_l1_loss: 0.0077 - disc_loss: 1.3810 - accuracy: 0.8843 - SSIM_loss: 0.0168 - val_accuracy: 0.8124 - val_SSIM_loss: 0.0526
# Epoch 67/200
# 360/360 [==============================] - 203s 563ms/step - gen_total_loss: 1.4597 - gen_gan_loss: 0.7108 - gen_l1_loss: 0.0075 - disc_loss: 1.3820 - accuracy: 0.8931 - SSIM_loss: 0.0164 - val_accuracy: 0.8055 - val_SSIM_loss: 0.0572
# Epoch 68/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.4520 - gen_gan_loss: 0.7091 - gen_l1_loss: 0.0074 - disc_loss: 1.3816 - accuracy: 0.8923 - SSIM_loss: 0.0163 - val_accuracy: 0.7427 - val_SSIM_loss: 0.0508
# Epoch 69/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 1.4873 - gen_gan_loss: 0.7113 - gen_l1_loss: 0.0078 - disc_loss: 1.3802 - accuracy: 0.8912 - SSIM_loss: 0.0168 - val_accuracy: 0.8954 - val_SSIM_loss: 0.0584
# Epoch 70/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.4227 - gen_gan_loss: 0.7091 - gen_l1_loss: 0.0071 - disc_loss: 1.3796 - accuracy: 0.9101 - SSIM_loss: 0.0159 - val_accuracy: 0.7591 - val_SSIM_loss: 0.0519
# Epoch 71/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.4108 - gen_gan_loss: 0.7102 - gen_l1_loss: 0.0070 - disc_loss: 1.3817 - accuracy: 0.9096 - SSIM_loss: 0.0156 - val_accuracy: 0.8759 - val_SSIM_loss: 0.0480
# Epoch 72/200
# 360/360 [==============================] - 203s 563ms/step - gen_total_loss: 1.3989 - gen_gan_loss: 0.7104 - gen_l1_loss: 0.0069 - disc_loss: 1.3813 - accuracy: 0.9046 - SSIM_loss: 0.0154 - val_accuracy: 0.4752 - val_SSIM_loss: 0.0441
# Epoch 73/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 1.4890 - gen_gan_loss: 0.7114 - gen_l1_loss: 0.0078 - disc_loss: 1.3787 - accuracy: 0.9023 - SSIM_loss: 0.0167 - val_accuracy: 0.9290 - val_SSIM_loss: 0.0583
# Epoch 74/200
# 360/360 [==============================] - 205s 568ms/step - gen_total_loss: 1.4412 - gen_gan_loss: 0.7129 - gen_l1_loss: 0.0073 - disc_loss: 1.3796 - accuracy: 0.9112 - SSIM_loss: 0.0160 - val_accuracy: 0.8431 - val_SSIM_loss: 0.0596
# Epoch 75/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 1.4356 - gen_gan_loss: 0.7119 - gen_l1_loss: 0.0072 - disc_loss: 1.3787 - accuracy: 0.9102 - SSIM_loss: 0.0159 - val_accuracy: 0.9321 - val_SSIM_loss: 0.0613
# Epoch 76/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.4019 - gen_gan_loss: 0.7107 - gen_l1_loss: 0.0069 - disc_loss: 1.3794 - accuracy: 0.9173 - SSIM_loss: 0.0154 - val_accuracy: 0.5366 - val_SSIM_loss: 0.0468
# Epoch 77/200
# 360/360 [==============================] - 203s 563ms/step - gen_total_loss: 1.4406 - gen_gan_loss: 0.7133 - gen_l1_loss: 0.0073 - disc_loss: 1.3806 - accuracy: 0.9228 - SSIM_loss: 0.0160 - val_accuracy: 0.7200 - val_SSIM_loss: 0.0545
# Epoch 78/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 1.4348 - gen_gan_loss: 0.7155 - gen_l1_loss: 0.0072 - disc_loss: 1.3776 - accuracy: 0.9159 - SSIM_loss: 0.0158 - val_accuracy: 0.9255 - val_SSIM_loss: 0.0589
# Epoch 79/200
# 360/360 [==============================] - 205s 568ms/step - gen_total_loss: 1.4320 - gen_gan_loss: 0.7148 - gen_l1_loss: 0.0072 - disc_loss: 1.3783 - accuracy: 0.9224 - SSIM_loss: 0.0158 - val_accuracy: 0.9343 - val_SSIM_loss: 0.0592
# Epoch 80/200
# 360/360 [==============================] - 208s 579ms/step - gen_total_loss: 1.4269 - gen_gan_loss: 0.7151 - gen_l1_loss: 0.0071 - disc_loss: 1.3778 - accuracy: 0.9208 - SSIM_loss: 0.0157 - val_accuracy: 0.8349 - val_SSIM_loss: 0.0531
# Epoch 81/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.3965 - gen_gan_loss: 0.7165 - gen_l1_loss: 0.0068 - disc_loss: 1.3774 - accuracy: 0.9225 - SSIM_loss: 0.0152 - val_accuracy: 0.8098 - val_SSIM_loss: 0.0560
# Epoch 82/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 1.4117 - gen_gan_loss: 0.7183 - gen_l1_loss: 0.0069 - disc_loss: 1.3784 - accuracy: 0.9228 - SSIM_loss: 0.0154 - val_accuracy: 0.9317 - val_SSIM_loss: 0.0554
# Epoch 83/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.3759 - gen_gan_loss: 0.7169 - gen_l1_loss: 0.0066 - disc_loss: 1.3773 - accuracy: 0.9291 - SSIM_loss: 0.0150 - val_accuracy: 0.9375 - val_SSIM_loss: 0.0572
# Epoch 84/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 1.3850 - gen_gan_loss: 0.7181 - gen_l1_loss: 0.0067 - disc_loss: 1.3757 - accuracy: 0.9334 - SSIM_loss: 0.0149 - val_accuracy: 0.9185 - val_SSIM_loss: 0.0573
# Epoch 85/200
# 360/360 [==============================] - 207s 574ms/step - gen_total_loss: 1.4065 - gen_gan_loss: 0.7201 - gen_l1_loss: 0.0069 - disc_loss: 1.3763 - accuracy: 0.9356 - SSIM_loss: 0.0153 - val_accuracy: 0.8946 - val_SSIM_loss: 0.0582
# Epoch 86/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.4024 - gen_gan_loss: 0.7228 - gen_l1_loss: 0.0068 - disc_loss: 1.3739 - accuracy: 0.9342 - SSIM_loss: 0.0153 - val_accuracy: 0.9364 - val_SSIM_loss: 0.0573
# Epoch 87/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 1.3792 - gen_gan_loss: 0.7235 - gen_l1_loss: 0.0066 - disc_loss: 1.3733 - accuracy: 0.9356 - SSIM_loss: 0.0149 - val_accuracy: 0.9503 - val_SSIM_loss: 0.0587
# Epoch 88/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.3914 - gen_gan_loss: 0.7267 - gen_l1_loss: 0.0066 - disc_loss: 1.3702 - accuracy: 0.9296 - SSIM_loss: 0.0151 - val_accuracy: 0.9408 - val_SSIM_loss: 0.0611
# Epoch 89/200
# 360/360 [==============================] - 204s 566ms/step - gen_total_loss: 1.3881 - gen_gan_loss: 0.7268 - gen_l1_loss: 0.0066 - disc_loss: 1.3720 - accuracy: 0.9411 - SSIM_loss: 0.0150 - val_accuracy: 0.9228 - val_SSIM_loss: 0.0559
# Epoch 90/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.3869 - gen_gan_loss: 0.7301 - gen_l1_loss: 0.0066 - disc_loss: 1.3697 - accuracy: 0.9422 - SSIM_loss: 0.0149 - val_accuracy: 0.9235 - val_SSIM_loss: 0.0565
# Epoch 91/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.3909 - gen_gan_loss: 0.7350 - gen_l1_loss: 0.0066 - disc_loss: 1.3662 - accuracy: 0.9450 - SSIM_loss: 0.0149 - val_accuracy: 0.9335 - val_SSIM_loss: 0.0506
# Epoch 92/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 1.4109 - gen_gan_loss: 0.7410 - gen_l1_loss: 0.0067 - disc_loss: 1.3652 - accuracy: 0.9440 - SSIM_loss: 0.0153 - val_accuracy: 0.9501 - val_SSIM_loss: 0.0552
# Epoch 93/200
# 360/360 [==============================] - 208s 579ms/step - gen_total_loss: 1.3845 - gen_gan_loss: 0.7444 - gen_l1_loss: 0.0064 - disc_loss: 1.3619 - accuracy: 0.9466 - SSIM_loss: 0.0147 - val_accuracy: 0.9577 - val_SSIM_loss: 0.0633
# Epoch 94/200
# 360/360 [==============================] - 202s 561ms/step - gen_total_loss: 1.4112 - gen_gan_loss: 0.7476 - gen_l1_loss: 0.0066 - disc_loss: 1.3783 - accuracy: 0.9462 - SSIM_loss: 0.0152 - val_accuracy: 0.8592 - val_SSIM_loss: 0.0516
# Epoch 95/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.4011 - gen_gan_loss: 0.7415 - gen_l1_loss: 0.0066 - disc_loss: 1.3595 - accuracy: 0.9481 - SSIM_loss: 0.0149 - val_accuracy: 0.6249 - val_SSIM_loss: 0.0447
# Epoch 96/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.4482 - gen_gan_loss: 0.7563 - gen_l1_loss: 0.0069 - disc_loss: 1.3479 - accuracy: 0.9512 - SSIM_loss: 0.0156 - val_accuracy: 0.9561 - val_SSIM_loss: 0.0579
# Epoch 97/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 1.4461 - gen_gan_loss: 0.7649 - gen_l1_loss: 0.0068 - disc_loss: 1.3495 - accuracy: 0.9518 - SSIM_loss: 0.0154 - val_accuracy: 0.9475 - val_SSIM_loss: 0.0588
# Epoch 98/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.4671 - gen_gan_loss: 0.7757 - gen_l1_loss: 0.0069 - disc_loss: 1.3435 - accuracy: 0.9511 - SSIM_loss: 0.0157 - val_accuracy: 0.8993 - val_SSIM_loss: 0.0587
# Epoch 99/200
# 360/360 [==============================] - 202s 561ms/step - gen_total_loss: 1.4469 - gen_gan_loss: 0.7782 - gen_l1_loss: 0.0067 - disc_loss: 1.3496 - accuracy: 0.9502 - SSIM_loss: 0.0154 - val_accuracy: 0.9276 - val_SSIM_loss: 0.0579
# Epoch 100/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.4548 - gen_gan_loss: 0.7827 - gen_l1_loss: 0.0067 - disc_loss: 1.3449 - accuracy: 0.9500 - SSIM_loss: 0.0155 - val_accuracy: 0.9465 - val_SSIM_loss: 0.0565
# Epoch 101/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.5094 - gen_gan_loss: 0.7896 - gen_l1_loss: 0.0072 - disc_loss: 1.3406 - accuracy: 0.9516 - SSIM_loss: 0.0163 - val_accuracy: 0.9533 - val_SSIM_loss: 0.0570
# Epoch 102/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.5056 - gen_gan_loss: 0.7949 - gen_l1_loss: 0.0071 - disc_loss: 1.3393 - accuracy: 0.9487 - SSIM_loss: 0.0161 - val_accuracy: 0.9435 - val_SSIM_loss: 0.0561
# Epoch 103/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.4989 - gen_gan_loss: 0.7944 - gen_l1_loss: 0.0070 - disc_loss: 1.3590 - accuracy: 0.9558 - SSIM_loss: 0.0161 - val_accuracy: 0.9283 - val_SSIM_loss: 0.0555
# Epoch 104/200
# 360/360 [==============================] - 205s 568ms/step - gen_total_loss: 1.5261 - gen_gan_loss: 0.8136 - gen_l1_loss: 0.0071 - disc_loss: 1.3173 - accuracy: 0.9581 - SSIM_loss: 0.0164 - val_accuracy: 0.9403 - val_SSIM_loss: 0.0609
# Epoch 105/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.5052 - gen_gan_loss: 0.8142 - gen_l1_loss: 0.0069 - disc_loss: 1.3323 - accuracy: 0.9562 - SSIM_loss: 0.0160 - val_accuracy: 0.9471 - val_SSIM_loss: 0.0613
# Epoch 106/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.5630 - gen_gan_loss: 0.8240 - gen_l1_loss: 0.0074 - disc_loss: 1.3121 - accuracy: 0.9543 - SSIM_loss: 0.0168 - val_accuracy: 0.8663 - val_SSIM_loss: 0.0570
# Epoch 107/200
# 360/360 [==============================] - 207s 574ms/step - gen_total_loss: 1.5391 - gen_gan_loss: 0.8228 - gen_l1_loss: 0.0072 - disc_loss: 1.3284 - accuracy: 0.9538 - SSIM_loss: 0.0164 - val_accuracy: 0.8187 - val_SSIM_loss: 0.0550
# Epoch 108/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.5606 - gen_gan_loss: 0.8354 - gen_l1_loss: 0.0073 - disc_loss: 1.3170 - accuracy: 0.9543 - SSIM_loss: 0.0165 - val_accuracy: 0.9347 - val_SSIM_loss: 0.0585
# Epoch 109/200
# 360/360 [==============================] - 202s 561ms/step - gen_total_loss: 1.6017 - gen_gan_loss: 0.8461 - gen_l1_loss: 0.0076 - disc_loss: 1.3097 - accuracy: 0.9559 - SSIM_loss: 0.0171 - val_accuracy: 0.9199 - val_SSIM_loss: 0.0471
# Epoch 110/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.6055 - gen_gan_loss: 0.8481 - gen_l1_loss: 0.0076 - disc_loss: 1.3045 - accuracy: 0.9564 - SSIM_loss: 0.0173 - val_accuracy: 0.9198 - val_SSIM_loss: 0.0563
# Epoch 111/200
# 360/360 [==============================] - 205s 569ms/step - gen_total_loss: 1.6349 - gen_gan_loss: 0.8656 - gen_l1_loss: 0.0077 - disc_loss: 1.3009 - accuracy: 0.9570 - SSIM_loss: 0.0174 - val_accuracy: 0.8432 - val_SSIM_loss: 0.0478
# Epoch 112/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.6550 - gen_gan_loss: 0.8813 - gen_l1_loss: 0.0077 - disc_loss: 1.2924 - accuracy: 0.9570 - SSIM_loss: 0.0175 - val_accuracy: 0.6259 - val_SSIM_loss: 0.0452
# Epoch 113/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.6231 - gen_gan_loss: 0.8785 - gen_l1_loss: 0.0074 - disc_loss: 1.2990 - accuracy: 0.9546 - SSIM_loss: 0.0171 - val_accuracy: 0.8006 - val_SSIM_loss: 0.0514
# Epoch 114/200
# 360/360 [==============================] - 201s 560ms/step - gen_total_loss: 1.7263 - gen_gan_loss: 0.9083 - gen_l1_loss: 0.0082 - disc_loss: 1.2619 - accuracy: 0.9550 - SSIM_loss: 0.0183 - val_accuracy: 0.9604 - val_SSIM_loss: 0.0590
# Epoch 115/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.7206 - gen_gan_loss: 0.9191 - gen_l1_loss: 0.0080 - disc_loss: 1.2819 - accuracy: 0.9566 - SSIM_loss: 0.0180 - val_accuracy: 0.9449 - val_SSIM_loss: 0.0639
# Epoch 116/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.6856 - gen_gan_loss: 0.9010 - gen_l1_loss: 0.0078 - disc_loss: 1.2775 - accuracy: 0.9571 - SSIM_loss: 0.0177 - val_accuracy: 0.9487 - val_SSIM_loss: 0.0550
# Epoch 117/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.7635 - gen_gan_loss: 0.9453 - gen_l1_loss: 0.0082 - disc_loss: 1.2555 - accuracy: 0.9560 - SSIM_loss: 0.0184 - val_accuracy: 0.9048 - val_SSIM_loss: 0.0525
# Epoch 118/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.7581 - gen_gan_loss: 0.9366 - gen_l1_loss: 0.0082 - disc_loss: 1.2741 - accuracy: 0.9560 - SSIM_loss: 0.0185 - val_accuracy: 0.9415 - val_SSIM_loss: 0.0618
# Epoch 119/200
# 360/360 [==============================] - 202s 560ms/step - gen_total_loss: 1.7662 - gen_gan_loss: 0.9360 - gen_l1_loss: 0.0083 - disc_loss: 1.2588 - accuracy: 0.9577 - SSIM_loss: 0.0186 - val_accuracy: 0.9486 - val_SSIM_loss: 0.0713
# Epoch 120/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.7626 - gen_gan_loss: 0.9413 - gen_l1_loss: 0.0082 - disc_loss: 1.2613 - accuracy: 0.9548 - SSIM_loss: 0.0184 - val_accuracy: 0.9153 - val_SSIM_loss: 0.0555
# Epoch 121/200
# 360/360 [==============================] - 205s 571ms/step - gen_total_loss: 1.8007 - gen_gan_loss: 0.9545 - gen_l1_loss: 0.0085 - disc_loss: 1.2554 - accuracy: 0.9503 - SSIM_loss: 0.0188 - val_accuracy: 0.9368 - val_SSIM_loss: 0.0575
# Epoch 122/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 1.7865 - gen_gan_loss: 0.9450 - gen_l1_loss: 0.0084 - disc_loss: 1.2485 - accuracy: 0.9510 - SSIM_loss: 0.0188 - val_accuracy: 0.9156 - val_SSIM_loss: 0.0521
# Epoch 123/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.8085 - gen_gan_loss: 0.9686 - gen_l1_loss: 0.0084 - disc_loss: 1.2455 - accuracy: 0.9544 - SSIM_loss: 0.0187 - val_accuracy: 0.9264 - val_SSIM_loss: 0.0485
# Epoch 124/200
# 360/360 [==============================] - 204s 566ms/step - gen_total_loss: 1.7759 - gen_gan_loss: 0.9575 - gen_l1_loss: 0.0082 - disc_loss: 1.2514 - accuracy: 0.9538 - SSIM_loss: 0.0186 - val_accuracy: 0.9533 - val_SSIM_loss: 0.0581
# Epoch 125/200
# 360/360 [==============================] - 209s 579ms/step - gen_total_loss: 1.9035 - gen_gan_loss: 1.0219 - gen_l1_loss: 0.0088 - disc_loss: 1.2088 - accuracy: 0.9509 - SSIM_loss: 0.0196 - val_accuracy: 0.9262 - val_SSIM_loss: 0.0543
# Epoch 126/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.8890 - gen_gan_loss: 1.0123 - gen_l1_loss: 0.0088 - disc_loss: 1.2193 - accuracy: 0.9523 - SSIM_loss: 0.0196 - val_accuracy: 0.9352 - val_SSIM_loss: 0.0676
# Epoch 127/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.9998 - gen_gan_loss: 1.0444 - gen_l1_loss: 0.0096 - disc_loss: 1.2073 - accuracy: 0.9499 - SSIM_loss: 0.0207 - val_accuracy: 0.9302 - val_SSIM_loss: 0.0520
# Epoch 128/200
# 360/360 [==============================] - 208s 579ms/step - gen_total_loss: 1.9157 - gen_gan_loss: 1.0165 - gen_l1_loss: 0.0090 - disc_loss: 1.2224 - accuracy: 0.9452 - SSIM_loss: 0.0200 - val_accuracy: 0.9523 - val_SSIM_loss: 0.0552
# Epoch 129/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 1.9709 - gen_gan_loss: 1.0730 - gen_l1_loss: 0.0090 - disc_loss: 1.1935 - accuracy: 0.9445 - SSIM_loss: 0.0200 - val_accuracy: 0.8863 - val_SSIM_loss: 0.0550
# Epoch 130/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 2.0592 - gen_gan_loss: 1.1183 - gen_l1_loss: 0.0094 - disc_loss: 1.1461 - accuracy: 0.9446 - SSIM_loss: 0.0206 - val_accuracy: 0.9270 - val_SSIM_loss: 0.0540
# Epoch 131/200
# 360/360 [==============================] - 205s 568ms/step - gen_total_loss: 2.0533 - gen_gan_loss: 1.1135 - gen_l1_loss: 0.0094 - disc_loss: 1.1658 - accuracy: 0.9466 - SSIM_loss: 0.0206 - val_accuracy: 0.9569 - val_SSIM_loss: 0.0656
# Epoch 132/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 2.0448 - gen_gan_loss: 1.1175 - gen_l1_loss: 0.0093 - disc_loss: 1.1571 - accuracy: 0.9470 - SSIM_loss: 0.0203 - val_accuracy: 0.8641 - val_SSIM_loss: 0.0555
# Epoch 133/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 2.1204 - gen_gan_loss: 1.1578 - gen_l1_loss: 0.0096 - disc_loss: 1.1531 - accuracy: 0.9485 - SSIM_loss: 0.0209 - val_accuracy: 0.8942 - val_SSIM_loss: 0.0493
# Epoch 134/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 2.1118 - gen_gan_loss: 1.1606 - gen_l1_loss: 0.0095 - disc_loss: 1.1698 - accuracy: 0.9485 - SSIM_loss: 0.0211 - val_accuracy: 0.8707 - val_SSIM_loss: 0.0539
# Epoch 135/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 2.1145 - gen_gan_loss: 1.1611 - gen_l1_loss: 0.0095 - disc_loss: 1.1306 - accuracy: 0.9469 - SSIM_loss: 0.0209 - val_accuracy: 0.9138 - val_SSIM_loss: 0.0618
# Epoch 136/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 2.2024 - gen_gan_loss: 1.2082 - gen_l1_loss: 0.0099 - disc_loss: 1.1297 - accuracy: 0.9504 - SSIM_loss: 0.0213 - val_accuracy: 0.9542 - val_SSIM_loss: 0.0578
# Epoch 137/200
# 360/360 [==============================] - 207s 574ms/step - gen_total_loss: 2.2427 - gen_gan_loss: 1.2314 - gen_l1_loss: 0.0101 - disc_loss: 1.1189 - accuracy: 0.9516 - SSIM_loss: 0.0218 - val_accuracy: 0.9428 - val_SSIM_loss: 0.0590
# Epoch 138/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 2.3517 - gen_gan_loss: 1.2807 - gen_l1_loss: 0.0107 - disc_loss: 1.0737 - accuracy: 0.9455 - SSIM_loss: 0.0227 - val_accuracy: 0.9444 - val_SSIM_loss: 0.0589
# Epoch 139/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 2.2906 - gen_gan_loss: 1.2708 - gen_l1_loss: 0.0102 - disc_loss: 1.0717 - accuracy: 0.9493 - SSIM_loss: 0.0220 - val_accuracy: 0.6331 - val_SSIM_loss: 0.0503
# Epoch 140/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 2.3383 - gen_gan_loss: 1.2925 - gen_l1_loss: 0.0105 - disc_loss: 1.0797 - accuracy: 0.9456 - SSIM_loss: 0.0222 - val_accuracy: 0.9458 - val_SSIM_loss: 0.0610
# Epoch 141/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 2.7081 - gen_gan_loss: 1.4279 - gen_l1_loss: 0.0128 - disc_loss: 0.9876 - accuracy: 0.9419 - SSIM_loss: 0.0256 - val_accuracy: 0.9308 - val_SSIM_loss: 0.0669
# Epoch 142/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 2.4847 - gen_gan_loss: 1.3545 - gen_l1_loss: 0.0113 - disc_loss: 1.0807 - accuracy: 0.9457 - SSIM_loss: 0.0240 - val_accuracy: 0.9491 - val_SSIM_loss: 0.0552
# Epoch 143/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 2.4260 - gen_gan_loss: 1.3310 - gen_l1_loss: 0.0109 - disc_loss: 1.0570 - accuracy: 0.9466 - SSIM_loss: 0.0232 - val_accuracy: 0.9424 - val_SSIM_loss: 0.0602
# Epoch 144/200
# 360/360 [==============================] - 203s 563ms/step - gen_total_loss: 2.5094 - gen_gan_loss: 1.3957 - gen_l1_loss: 0.0111 - disc_loss: 1.0829 - accuracy: 0.9431 - SSIM_loss: 0.0237 - val_accuracy: 0.8794 - val_SSIM_loss: 0.0490
# Epoch 145/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 2.3901 - gen_gan_loss: 1.3338 - gen_l1_loss: 0.0106 - disc_loss: 1.0421 - accuracy: 0.9425 - SSIM_loss: 0.0225 - val_accuracy: 0.7149 - val_SSIM_loss: 0.0605
# Epoch 146/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 2.5572 - gen_gan_loss: 1.4144 - gen_l1_loss: 0.0114 - disc_loss: 1.0093 - accuracy: 0.9494 - SSIM_loss: 0.0236 - val_accuracy: 0.9346 - val_SSIM_loss: 0.0533
# Epoch 147/200
# 360/360 [==============================] - 210s 582ms/step - gen_total_loss: 2.5896 - gen_gan_loss: 1.4410 - gen_l1_loss: 0.0115 - disc_loss: 1.0156 - accuracy: 0.9432 - SSIM_loss: 0.0243 - val_accuracy: 0.9303 - val_SSIM_loss: 0.0583
# Epoch 148/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 2.5779 - gen_gan_loss: 1.4404 - gen_l1_loss: 0.0114 - disc_loss: 1.0278 - accuracy: 0.9552 - SSIM_loss: 0.0239 - val_accuracy: 0.9253 - val_SSIM_loss: 0.0574
# Epoch 149/200
# 360/360 [==============================] - 204s 566ms/step - gen_total_loss: 2.5886 - gen_gan_loss: 1.4563 - gen_l1_loss: 0.0113 - disc_loss: 0.9913 - accuracy: 0.9521 - SSIM_loss: 0.0238 - val_accuracy: 0.9250 - val_SSIM_loss: 0.0567
# Epoch 150/200
# 360/360 [==============================] - 206s 574ms/step - gen_total_loss: 2.5341 - gen_gan_loss: 1.4397 - gen_l1_loss: 0.0109 - disc_loss: 1.0349 - accuracy: 0.9462 - SSIM_loss: 0.0237 - val_accuracy: 0.8923 - val_SSIM_loss: 0.0499
# Epoch 151/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 2.6906 - gen_gan_loss: 1.5312 - gen_l1_loss: 0.0116 - disc_loss: 1.0100 - accuracy: 0.9397 - SSIM_loss: 0.0246 - val_accuracy: 0.8981 - val_SSIM_loss: 0.0487
# Epoch 152/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 2.8385 - gen_gan_loss: 1.6052 - gen_l1_loss: 0.0123 - disc_loss: 0.9096 - accuracy: 0.9454 - SSIM_loss: 0.0255 - val_accuracy: 0.9364 - val_SSIM_loss: 0.0616
# Epoch 153/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 2.8600 - gen_gan_loss: 1.6451 - gen_l1_loss: 0.0121 - disc_loss: 0.9334 - accuracy: 0.9519 - SSIM_loss: 0.0254 - val_accuracy: 0.9445 - val_SSIM_loss: 0.0589
# Epoch 154/200
# 360/360 [==============================] - 203s 563ms/step - gen_total_loss: 3.2275 - gen_gan_loss: 1.8157 - gen_l1_loss: 0.0141 - disc_loss: 0.8452 - accuracy: 0.9473 - SSIM_loss: 0.0281 - val_accuracy: 0.9578 - val_SSIM_loss: 0.0626
# Epoch 155/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 2.9721 - gen_gan_loss: 1.7579 - gen_l1_loss: 0.0121 - disc_loss: 0.9059 - accuracy: 0.9506 - SSIM_loss: 0.0255 - val_accuracy: 0.9376 - val_SSIM_loss: 0.0636
# Epoch 156/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 3.2289 - gen_gan_loss: 1.8401 - gen_l1_loss: 0.0139 - disc_loss: 0.8213 - accuracy: 0.9505 - SSIM_loss: 0.0274 - val_accuracy: 0.9458 - val_SSIM_loss: 0.0567
# Epoch 157/200
# 360/360 [==============================] - 209s 579ms/step - gen_total_loss: 3.0876 - gen_gan_loss: 1.8269 - gen_l1_loss: 0.0126 - disc_loss: 0.8781 - accuracy: 0.9481 - SSIM_loss: 0.0257 - val_accuracy: 0.9067 - val_SSIM_loss: 0.0487
# Epoch 158/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 3.1425 - gen_gan_loss: 1.7994 - gen_l1_loss: 0.0134 - disc_loss: 0.8959 - accuracy: 0.9407 - SSIM_loss: 0.0271 - val_accuracy: 0.9363 - val_SSIM_loss: 0.0502
# Epoch 159/200
# 360/360 [==============================] - 203s 564ms/step - gen_total_loss: 3.0919 - gen_gan_loss: 1.8098 - gen_l1_loss: 0.0128 - disc_loss: 0.9213 - accuracy: 0.9446 - SSIM_loss: 0.0259 - val_accuracy: 0.9360 - val_SSIM_loss: 0.0617
# Epoch 160/200
# 360/360 [==============================] - 207s 574ms/step - gen_total_loss: 3.3320 - gen_gan_loss: 1.9127 - gen_l1_loss: 0.0142 - disc_loss: 0.7804 - accuracy: 0.9494 - SSIM_loss: 0.0278 - val_accuracy: 0.9222 - val_SSIM_loss: 0.0529
# Epoch 161/200
# 360/360 [==============================] - 154s 428ms/step - gen_total_loss: 3.7413 - gen_gan_loss: 2.1538 - gen_l1_loss: 0.0159 - disc_loss: 0.7393 - accuracy: 0.9415 - SSIM_loss: 0.0299 - val_accuracy: 0.7610 - val_SSIM_loss: 0.0442
# Epoch 162/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 3.6386 - gen_gan_loss: 2.1854 - gen_l1_loss: 0.0145 - disc_loss: 0.7616 - accuracy: 0.9396 - SSIM_loss: 0.0288 - val_accuracy: 0.9068 - val_SSIM_loss: 0.0480
# Epoch 163/200
# 360/360 [==============================] - 139s 385ms/step - gen_total_loss: 3.7670 - gen_gan_loss: 2.2112 - gen_l1_loss: 0.0156 - disc_loss: 0.7249 - accuracy: 0.9441 - SSIM_loss: 0.0296 - val_accuracy: 0.8580 - val_SSIM_loss: 0.0645
# Epoch 164/200
# 360/360 [==============================] - 138s 384ms/step - gen_total_loss: 4.1499 - gen_gan_loss: 2.3371 - gen_l1_loss: 0.0181 - disc_loss: 0.6270 - accuracy: 0.9289 - SSIM_loss: 0.0334 - val_accuracy: 0.9297 - val_SSIM_loss: 0.0581
# Epoch 165/200
# 360/360 [==============================] - 139s 385ms/step - gen_total_loss: 4.3983 - gen_gan_loss: 2.4984 - gen_l1_loss: 0.0190 - disc_loss: 0.7247 - accuracy: 0.9387 - SSIM_loss: 0.0342 - val_accuracy: 0.9325 - val_SSIM_loss: 0.0498
# Epoch 166/200
# 360/360 [==============================] - 138s 384ms/step - gen_total_loss: 4.0596 - gen_gan_loss: 2.3129 - gen_l1_loss: 0.0175 - disc_loss: 0.6971 - accuracy: 0.9395 - SSIM_loss: 0.0323 - val_accuracy: 0.8021 - val_SSIM_loss: 0.0492
# Epoch 167/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 4.1279 - gen_gan_loss: 2.4500 - gen_l1_loss: 0.0168 - disc_loss: 0.6214 - accuracy: 0.9471 - SSIM_loss: 0.0313 - val_accuracy: 0.9087 - val_SSIM_loss: 0.0545
# Epoch 168/200
# 360/360 [==============================] - 139s 385ms/step - gen_total_loss: 3.9239 - gen_gan_loss: 2.2981 - gen_l1_loss: 0.0163 - disc_loss: 0.7357 - accuracy: 0.9369 - SSIM_loss: 0.0306 - val_accuracy: 0.9031 - val_SSIM_loss: 0.0562
# Epoch 169/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 3.8748 - gen_gan_loss: 2.3698 - gen_l1_loss: 0.0150 - disc_loss: 0.7056 - accuracy: 0.9395 - SSIM_loss: 0.0292 - val_accuracy: 0.9440 - val_SSIM_loss: 0.0628
# Epoch 170/200
# 360/360 [==============================] - 139s 385ms/step - gen_total_loss: 3.8863 - gen_gan_loss: 2.3362 - gen_l1_loss: 0.0155 - disc_loss: 0.7322 - accuracy: 0.9371 - SSIM_loss: 0.0295 - val_accuracy: 0.9402 - val_SSIM_loss: 0.0566
# Epoch 171/200
# 360/360 [==============================] - 138s 384ms/step - gen_total_loss: 3.9275 - gen_gan_loss: 2.3240 - gen_l1_loss: 0.0160 - disc_loss: 0.6709 - accuracy: 0.9302 - SSIM_loss: 0.0301 - val_accuracy: 0.7868 - val_SSIM_loss: 0.0445
# Epoch 172/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 4.0337 - gen_gan_loss: 2.4338 - gen_l1_loss: 0.0160 - disc_loss: 0.7121 - accuracy: 0.9306 - SSIM_loss: 0.0301 - val_accuracy: 0.9220 - val_SSIM_loss: 0.0561
# Epoch 173/200
# 360/360 [==============================] - 139s 387ms/step - gen_total_loss: 4.1755 - gen_gan_loss: 2.4794 - gen_l1_loss: 0.0170 - disc_loss: 0.6699 - accuracy: 0.9360 - SSIM_loss: 0.0315 - val_accuracy: 0.8578 - val_SSIM_loss: 0.0541
# Epoch 174/200
# 360/360 [==============================] - 138s 384ms/step - gen_total_loss: 4.5334 - gen_gan_loss: 2.7012 - gen_l1_loss: 0.0183 - disc_loss: 0.5306 - accuracy: 0.9349 - SSIM_loss: 0.0337 - val_accuracy: 0.9345 - val_SSIM_loss: 0.0572
# Epoch 175/200
# 360/360 [==============================] - 139s 387ms/step - gen_total_loss: 6.5048 - gen_gan_loss: 3.6335 - gen_l1_loss: 0.0287 - disc_loss: 0.2611 - accuracy: 0.9294 - SSIM_loss: 0.0460 - val_accuracy: 0.9032 - val_SSIM_loss: 0.0798
# Epoch 176/200
# 360/360 [==============================] - 139s 385ms/step - gen_total_loss: 6.3942 - gen_gan_loss: 3.6547 - gen_l1_loss: 0.0274 - disc_loss: 0.3662 - accuracy: 0.9319 - SSIM_loss: 0.0453 - val_accuracy: 0.9052 - val_SSIM_loss: 0.0595
# Epoch 177/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 5.2037 - gen_gan_loss: 3.0758 - gen_l1_loss: 0.0213 - disc_loss: 0.5783 - accuracy: 0.9302 - SSIM_loss: 0.0375 - val_accuracy: 0.9439 - val_SSIM_loss: 0.0603
# Epoch 178/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 5.0178 - gen_gan_loss: 2.9819 - gen_l1_loss: 0.0204 - disc_loss: 0.5253 - accuracy: 0.9360 - SSIM_loss: 0.0363 - val_accuracy: 0.9030 - val_SSIM_loss: 0.0522
# Epoch 179/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 5.2449 - gen_gan_loss: 3.1324 - gen_l1_loss: 0.0211 - disc_loss: 0.4127 - accuracy: 0.9301 - SSIM_loss: 0.0367 - val_accuracy: 0.9340 - val_SSIM_loss: 0.0628
# Epoch 180/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 5.3009 - gen_gan_loss: 3.1693 - gen_l1_loss: 0.0213 - disc_loss: 0.5633 - accuracy: 0.9301 - SSIM_loss: 0.0376 - val_accuracy: 0.9133 - val_SSIM_loss: 0.0524
# Epoch 181/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 5.5710 - gen_gan_loss: 3.3123 - gen_l1_loss: 0.0226 - disc_loss: 0.3469 - accuracy: 0.9214 - SSIM_loss: 0.0389 - val_accuracy: 0.9047 - val_SSIM_loss: 0.0510
# Epoch 182/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 5.5192 - gen_gan_loss: 3.2826 - gen_l1_loss: 0.0224 - disc_loss: 0.5009 - accuracy: 0.9360 - SSIM_loss: 0.0388 - val_accuracy: 0.8993 - val_SSIM_loss: 0.0573
# Epoch 183/200
# 360/360 [==============================] - 138s 385ms/step - gen_total_loss: 6.1518 - gen_gan_loss: 3.4338 - gen_l1_loss: 0.0272 - disc_loss: 0.3919 - accuracy: 0.9320 - SSIM_loss: 0.0445 - val_accuracy: 0.9225 - val_SSIM_loss: 0.0660
# Epoch 184/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 6.2792 - gen_gan_loss: 3.5542 - gen_l1_loss: 0.0272 - disc_loss: 0.4426 - accuracy: 0.9334 - SSIM_loss: 0.0442 - val_accuracy: 0.9251 - val_SSIM_loss: 0.0584
# Epoch 185/200
# 360/360 [==============================] - 138s 384ms/step - gen_total_loss: 5.5827 - gen_gan_loss: 3.2469 - gen_l1_loss: 0.0234 - disc_loss: 0.4949 - accuracy: 0.9375 - SSIM_loss: 0.0400 - val_accuracy: 0.9084 - val_SSIM_loss: 0.0663
# Epoch 186/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 6.3834 - gen_gan_loss: 3.7367 - gen_l1_loss: 0.0265 - disc_loss: 0.2801 - accuracy: 0.9343 - SSIM_loss: 0.0445 - val_accuracy: 0.9061 - val_SSIM_loss: 0.0528
# Epoch 187/200
# 360/360 [==============================] - 138s 383ms/step - gen_total_loss: 7.0179 - gen_gan_loss: 3.9196 - gen_l1_loss: 0.0310 - disc_loss: 0.3011 - accuracy: 0.9250 - SSIM_loss: 0.0496 - val_accuracy: 0.9150 - val_SSIM_loss: 0.0743
# Epoch 188/200
# 360/360 [==============================] - 141s 392ms/step - gen_total_loss: 6.7812 - gen_gan_loss: 4.0315 - gen_l1_loss: 0.0275 - disc_loss: 0.2806 - accuracy: 0.9272 - SSIM_loss: 0.0448 - val_accuracy: 0.8866 - val_SSIM_loss: 0.0432
# Epoch 189/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 6.6373 - gen_gan_loss: 3.9477 - gen_l1_loss: 0.0269 - disc_loss: 0.3127 - accuracy: 0.9341 - SSIM_loss: 0.0451 - val_accuracy: 0.9303 - val_SSIM_loss: 0.0606
# Epoch 190/200
# 360/360 [==============================] - 138s 384ms/step - gen_total_loss: 6.4704 - gen_gan_loss: 3.9413 - gen_l1_loss: 0.0253 - disc_loss: 0.3126 - accuracy: 0.9366 - SSIM_loss: 0.0430 - val_accuracy: 0.9043 - val_SSIM_loss: 0.0674
# Epoch 191/200
# 360/360 [==============================] - 139s 387ms/step - gen_total_loss: 5.8680 - gen_gan_loss: 3.5127 - gen_l1_loss: 0.0236 - disc_loss: 0.5525 - accuracy: 0.9361 - SSIM_loss: 0.0405 - val_accuracy: 0.9410 - val_SSIM_loss: 0.0611
# Epoch 192/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 6.3274 - gen_gan_loss: 3.8160 - gen_l1_loss: 0.0251 - disc_loss: 0.3323 - accuracy: 0.9336 - SSIM_loss: 0.0420 - val_accuracy: 0.8881 - val_SSIM_loss: 0.0600
# Epoch 193/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 6.3021 - gen_gan_loss: 3.7725 - gen_l1_loss: 0.0253 - disc_loss: 0.3303 - accuracy: 0.9378 - SSIM_loss: 0.0425 - val_accuracy: 0.9450 - val_SSIM_loss: 0.0528
# Epoch 194/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 5.7420 - gen_gan_loss: 3.4374 - gen_l1_loss: 0.0230 - disc_loss: 0.4808 - accuracy: 0.9349 - SSIM_loss: 0.0389 - val_accuracy: 0.8551 - val_SSIM_loss: 0.0549
# Epoch 195/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 6.3985 - gen_gan_loss: 3.8687 - gen_l1_loss: 0.0253 - disc_loss: 0.2700 - accuracy: 0.9354 - SSIM_loss: 0.0421 - val_accuracy: 0.9086 - val_SSIM_loss: 0.0610
# Epoch 196/200
# 360/360 [==============================] - 138s 384ms/step - gen_total_loss: 8.0607 - gen_gan_loss: 4.5530 - gen_l1_loss: 0.0351 - disc_loss: 0.2561 - accuracy: 0.9414 - SSIM_loss: 0.0545 - val_accuracy: 0.9188 - val_SSIM_loss: 0.0661
# Epoch 197/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 6.2284 - gen_gan_loss: 3.7209 - gen_l1_loss: 0.0251 - disc_loss: 0.4544 - accuracy: 0.9412 - SSIM_loss: 0.0420 - val_accuracy: 0.9475 - val_SSIM_loss: 0.0606
# Epoch 198/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 6.9726 - gen_gan_loss: 4.2759 - gen_l1_loss: 0.0270 - disc_loss: 0.2130 - accuracy: 0.9355 - SSIM_loss: 0.0451 - val_accuracy: 0.9037 - val_SSIM_loss: 0.0596
# Epoch 199/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 6.8220 - gen_gan_loss: 4.0655 - gen_l1_loss: 0.0276 - disc_loss: 0.2976 - accuracy: 0.9293 - SSIM_loss: 0.0457 - val_accuracy: 0.6664 - val_SSIM_loss: 0.0569
# Epoch 200/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 6.4102 - gen_gan_loss: 3.8213 - gen_l1_loss: 0.0259 - disc_loss: 0.3520 - accuracy: 0.9248 - SSIM_loss: 0.0431 - val_accuracy: 0.9286 - val_SSIM_loss: 0.0523
