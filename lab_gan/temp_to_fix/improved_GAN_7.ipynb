# %%
# %load_ext autoreload
# %autoreload 2

# %%
from configGAN import *
cfg = flying_objects_config()
import os

import tensorflow as tf
from tensorflow import keras
from utilsGAN import *
from sklearn.metrics import confusion_matrix
# import seaborn as sns
from datetime import datetime
import imageio
from skimage import img_as_ubyte

import pprint
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv3D, Conv2D, Conv1D, Convolution2D, Deconvolution2D, Cropping2D, UpSampling2D
from keras.layers import Input, Conv2DTranspose, ConvLSTM2D, TimeDistributed, GlobalMaxPooling2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers import Concatenate, concatenate, Reshape
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.models import Model
from keras.callbacks import TensorBoard
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.layers import Input, merge
from keras.regularizers import l2
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D, Reshape, core, Dropout, LeakyReLU
import keras.backend as kb
from tensorflow.python.keras.engine import compile_utils
import io

# %%
def limit_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)
limit_gpu()

if cfg.GPU >=0:
    print("creating network model using gpu " + str(cfg.GPU))
    os.environ['CUDA_VISIBLE_DEVICES'] = str(cfg.GPU)
elif cfg.GPU >=-1:
    print("creating network model using cpu ")  
    os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
    os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# creating network model using gpu 0

# %%
show_statistics(cfg.training_data_dir, fineGrained=False, title=" Training Data Statistics ")
show_statistics(cfg.validation_data_dir, fineGrained=False, title=" Validation Data Statistics ")
show_statistics(cfg.testing_data_dir, fineGrained=False, title=" Testing Data Statistics ")
# Out:
# ######################################################################
# ##################### Training Data Statistics #####################
# ######################################################################
# total image number 	 10817
# total class number 	 3
# class square 	 3488 images
# class circular 	 3626 images
# class triangle 	 3703 images
# ######################################################################
#
# ######################################################################
# ##################### Validation Data Statistics #####################
# ######################################################################
# total image number 	 2241
# total class number 	 3
# class triangle 	 745 images
# class square 	 783 images
# class circular 	 713 images
# ######################################################################
#
# ######################################################################
# ##################### Testing Data Statistics #####################
# ######################################################################
# total image number 	 2220
# total class number 	 3
# class triangle 	 733 images
# class square 	 765 images
# class circular 	 722 images
# ######################################################################

# %%
batch_size = 64
image_shape = (cfg.IMAGE_HEIGHT, cfg.IMAGE_WIDTH, cfg.IMAGE_CHANNEL)

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# # Prepare plots and logger

# %%
from improvedUtils import *

# %% [markdown]
# # Model Architecture

# %%
class architecture:
    __name__='Pix2Pix_model_v5'
    __changes__="Changed to a pix2pix model in order to test a greater network for generator and discriminator. Generator: U-Net, Discriminator: PatchGAN. Changed Discriminator optimizer to SGD. Lowered learning rate for SGD"
    
    __normalization__='[-1,1]'
    
    generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
    discriminator_optimizer = tf.keras.optimizers.SGD(learning_rate=2e-4)
    
    @staticmethod
    def discriminator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def main():
            
            initializer = tf.random_normal_initializer(0., 0.02)

            inp = tf.keras.layers.Input(shape=image_shape, name='input_image')
            tar = tf.keras.layers.Input(shape=image_shape, name='target_image')

            x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

            down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
            down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
            down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

            zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
            conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                        kernel_initializer=initializer,
                                        use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

            batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

            leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

            zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

            last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                        kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

            return tf.keras.Model(inputs=[inp, tar], outputs=last)
        
        
        return main()
    
    @staticmethod
    def generator():
        def downsample(filters, size, apply_batchnorm=True):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                                     kernel_initializer=initializer, use_bias=False))

            if apply_batchnorm:
                result.add(tf.keras.layers.BatchNormalization())

            result.add(tf.keras.layers.LeakyReLU())

            return result
        
        def upsample(filters, size, apply_dropout=False):
            initializer = tf.random_normal_initializer(0., 0.02)

            result = tf.keras.Sequential()
            result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                            padding='same',
                                            kernel_initializer=initializer,
                                            use_bias=False))

            result.add(tf.keras.layers.BatchNormalization())

            if apply_dropout:
                result.add(tf.keras.layers.Dropout(0.5))

            result.add(tf.keras.layers.ReLU())

            return result

        def main():
            inputs = tf.keras.layers.Input(shape=image_shape)

            down_stack = [
                downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
                downsample(128, 4), # (bs, 64, 64, 128)
                downsample(256, 4), # (bs, 32, 32, 256)
                downsample(512, 4), # (bs, 16, 16, 512)
                downsample(512, 4), # (bs, 8, 8, 512)
                downsample(512, 4), # (bs, 4, 4, 512)
                downsample(512, 4), # (bs, 2, 2, 512)
                #downsample(512, 4), # (bs, 1, 1, 512)
            ]

            up_stack = [
                upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
                upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
                upsample(512, 4), # (bs, 16, 16, 1024)
                upsample(256, 4), # (bs, 32, 32, 512)
                upsample(128, 4), # (bs, 64, 64, 256)
                upsample(64, 4), # (bs, 128, 128, 128)
            ]

            initializer = tf.random_normal_initializer(0., 0.02)
            last = tf.keras.layers.Conv2DTranspose(3, 4,
                                                 strides=2,
                                                 padding='same',
                                                 kernel_initializer=initializer,
                                                 activation='tanh') # (bs, 256, 256, 3)

            x = inputs

            # Downsampling through the model
            skips = []
            for down in down_stack:
                x = down(x)
                skips.append(x)

            skips = reversed(skips[:-1])

            # Upsampling and establishing the skip connections
            for up, skip in zip(up_stack, skips):
                x = up(x)
                x = tf.keras.layers.Concatenate()([x, skip])

            x = last(x)

            return tf.keras.Model(inputs=inputs, outputs=x)
        return main()
    
    def loss():  # Decided by https://arxiv.org/abs/1611.07004
        loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
        LAMBDA = 100
        def generator_loss(disc_generated_output, gen_output, target): # https://arxiv.org/abs/1611.07004
            gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

            # mean absolute error
            l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

            total_gen_loss = gan_loss + (LAMBDA * l1_loss)

            return total_gen_loss, gan_loss, l1_loss

        def discriminator_loss(disc_real_output, disc_generated_output):
            real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

            generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

            total_disc_loss = real_loss + generated_loss

            return total_disc_loss

        return {'g_loss_fn':generator_loss, 'd_loss_fn':discriminator_loss}
    
    def __model__():
        return [architecture.generator, architecture.discriminator]

# %%
train_batch_generator, valid_batch_generator, test_batch_generator, nbr_train_data,nbr_valid_data, nbr_test_data = preprocess(image_shape, normalize_type=architecture.__normalization__)
# Out:
# train_x (30, 128, 128, 3) float32 -1.0 1.0
# train_y (30, 128, 128, 3) float32 -1.0 1.0
# {'BATCH_SIZE': 30,
#  'DATA_AUGMENTATION': True,
#  'DEBUG_MODE': True,
#  'DROPOUT_PROB': 0.5,
#  'GPU': 0,
#  'IMAGE_CHANNEL': 3,
#  'IMAGE_HEIGHT': 128,
#  'IMAGE_WIDTH': 128,
#  'LEARNING_RATE': 0.01,
#  'LR_DECAY_FACTOR': 0.1,
#  'NUM_EPOCHS': 200,
#  'PRINT_EVERY': 50,
#  'SAVE_EVERY': 1,
#  'SEQUENCE_LENGTH': 10,
#  'testing_data_dir': '../data/FlyingObjectDataset_10K/testing',
#  'training_data_dir': '../data/FlyingObjectDataset_10K/training',
#  'validation_data_dir': '../data/FlyingObjectDataset_10K/validation'}

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
    def __init__(self, discriminator, generator):
        super(GAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        #self.epoch = 0
    
    def special_compile(self, 
                d_optimizer=None, 
                g_optimizer=None,
                d_loss=None,
                g_loss=None,               
                loss_fn=None,
                metrics=None,
                loss_weights=None,
                weighted_metrics=None,
                run_eagerly=None,
                steps_per_execution=None,
              **kwargs):
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.d_loss = d_loss
        self.g_loss = g_loss
        
        super().compile(metrics=metrics)
    
    def compile(self, **kwargs):
        raise NotImplementedError("Please use special_compile()")

    @tf.function
    def train_step(self, data): 
        #self.epoch += 1
        input_image, target = data # TODO: Must check if this iterates or take same image each run
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            
            # Generate images
            gen_output = self.generator(input_image, training=True)
            
            # Train discriminator
            disc_real_output = self.discriminator([input_image, target], training=True)
            disc_generated_output = self.discriminator([input_image, gen_output], training=True)
            
            # Training
            gen_total_loss, gen_gan_loss, gen_l1_loss = self.g_loss(disc_generated_output, gen_output, target)
            disc_loss = self.d_loss(disc_real_output, disc_generated_output)
            
            # Set weights
            generator_gradients = gen_tape.gradient(gen_total_loss,
                                              self.generator.trainable_variables)
            discriminator_gradients = disc_tape.gradient(disc_loss,
                                                   self.discriminator.trainable_variables)
            # Update weights
            self.g_optimizer.apply_gradients(zip(generator_gradients,
                                              self.generator.trainable_variables))
            self.d_optimizer.apply_gradients(zip(discriminator_gradients,
                                                  self.discriminator.trainable_variables))
            
        self.compiled_metrics.update_state(target, gen_output)
        
        met = {
                'gen_total_loss':gen_total_loss,
                'gen_gan_loss':gen_gan_loss,
                'gen_l1_loss':gen_l1_loss,
                'disc_loss':disc_loss, 
                
        }
        met.update({m.name: m.result() for m in self.metrics})
        return met
    

    def test_step(self, data):
        real_images, last_images = data
        valid, fake_last_frame = self(real_images, training=False)

        self.compiled_metrics.update_state(real_images, fake_last_frame)
            
        return {m.name: m.result() for m in self.metrics}
    
    def call(self, first_frame, training=False):
        fake_last_frame = self.generator(first_frame, training)
        validate_frame = self.discriminator([fake_last_frame, first_frame], training)
        
        return [validate_frame, fake_last_frame]

# %%
steps_per_epoch = (nbr_train_data // cfg.BATCH_SIZE) 
validation_steps=(nbr_valid_data//cfg.BATCH_SIZE)
log_dir = logger(architecture().__name__)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, update_freq='epoch')
file_writer = tf.summary.create_file_writer(log_dir + "/plots/")

generator, discriminator =  architecture.__model__()
loss = architecture.loss()
model_to_json(discriminator(), log_dir + "/discriminator.json")
model_to_json(generator(), log_dir + "/generator.json")

gan = GAN(discriminator=discriminator(), generator=generator())

gan.special_compile(
    d_optimizer=architecture.discriminator_optimizer,
    g_optimizer=architecture.generator_optimizer,
    d_loss=loss['d_loss_fn'],
    g_loss=loss['g_loss_fn'],
    metrics=['accuracy', SSIM_loss]
)
gan.fit(
    x=train_batch_generator, 
    epochs=cfg.NUM_EPOCHS, 
    verbose=1, 
    batch_size=cfg.BATCH_SIZE,
    steps_per_epoch=steps_per_epoch, #
    validation_data=valid_batch_generator,
    validation_steps=validation_steps, 
    callbacks=[GANMonitor(num_img=3, validation_data=valid_batch_generator,log_dir=log_dir), tensorboard_callback],
    
) 


with open(log_dir+"/gan_finished", 'a') as f:
    f.write(architecture.__changes__)
# Out:
# Epoch 1/200
#   1/360 [..............................] - ETA: 0s - gen_total_loss: 99.7878 - gen_gan_loss: 0.9358 - gen_l1_loss: 0.9885 - disc_loss: 1.6883 - accuracy: 0.4190 - SSIM_loss: 0.9982WARNING:tensorflow:From /home/stud/f/fremar16/miniconda3/envs/lab/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 360/360 [==============================] - 211s 587ms/step - gen_total_loss: 9.7012 - gen_gan_loss: 0.7559 - gen_l1_loss: 0.0895 - disc_loss: 1.4854 - accuracy: 0.3896 - SSIM_loss: 0.1311 - val_accuracy: 0.6608 - val_SSIM_loss: 0.0593
# Epoch 2/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 5.0559 - gen_gan_loss: 0.7443 - gen_l1_loss: 0.0431 - disc_loss: 1.4240 - accuracy: 0.4713 - SSIM_loss: 0.0662 - val_accuracy: 0.4938 - val_SSIM_loss: 0.0454
# Epoch 3/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 4.7814 - gen_gan_loss: 0.7541 - gen_l1_loss: 0.0403 - disc_loss: 1.3871 - accuracy: 0.4852 - SSIM_loss: 0.0637 - val_accuracy: 0.6092 - val_SSIM_loss: 0.0377
# Epoch 4/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 4.7191 - gen_gan_loss: 0.7754 - gen_l1_loss: 0.0394 - disc_loss: 1.3446 - accuracy: 0.4666 - SSIM_loss: 0.0634 - val_accuracy: 0.6043 - val_SSIM_loss: 0.0422
# Epoch 5/200
# 360/360 [==============================] - 211s 585ms/step - gen_total_loss: 4.6413 - gen_gan_loss: 0.7942 - gen_l1_loss: 0.0385 - disc_loss: 1.3109 - accuracy: 0.4914 - SSIM_loss: 0.0635 - val_accuracy: 0.4656 - val_SSIM_loss: 0.0445
# Epoch 6/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 4.4062 - gen_gan_loss: 0.7764 - gen_l1_loss: 0.0363 - disc_loss: 1.3338 - accuracy: 0.5346 - SSIM_loss: 0.0615 - val_accuracy: 0.6780 - val_SSIM_loss: 0.0672
# Epoch 7/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 3.9884 - gen_gan_loss: 0.7516 - gen_l1_loss: 0.0324 - disc_loss: 1.3681 - accuracy: 0.5371 - SSIM_loss: 0.0561 - val_accuracy: 0.2491 - val_SSIM_loss: 0.0713
# Epoch 8/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 3.5530 - gen_gan_loss: 0.7363 - gen_l1_loss: 0.0282 - disc_loss: 1.3863 - accuracy: 0.5294 - SSIM_loss: 0.0504 - val_accuracy: 0.3044 - val_SSIM_loss: 0.0644
# Epoch 9/200
# 360/360 [==============================] - 206s 574ms/step - gen_total_loss: 3.3733 - gen_gan_loss: 0.7278 - gen_l1_loss: 0.0265 - disc_loss: 1.3962 - accuracy: 0.5130 - SSIM_loss: 0.0480 - val_accuracy: 0.5731 - val_SSIM_loss: 0.0636
# Epoch 10/200
# 360/360 [==============================] - 210s 584ms/step - gen_total_loss: 3.2040 - gen_gan_loss: 0.7231 - gen_l1_loss: 0.0248 - disc_loss: 1.3999 - accuracy: 0.5209 - SSIM_loss: 0.0457 - val_accuracy: 0.6824 - val_SSIM_loss: 0.0743
# Epoch 11/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 3.0158 - gen_gan_loss: 0.7191 - gen_l1_loss: 0.0230 - disc_loss: 1.4017 - accuracy: 0.5283 - SSIM_loss: 0.0429 - val_accuracy: 0.2638 - val_SSIM_loss: 0.0468
# Epoch 12/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 2.9438 - gen_gan_loss: 0.7174 - gen_l1_loss: 0.0223 - disc_loss: 1.4025 - accuracy: 0.5249 - SSIM_loss: 0.0417 - val_accuracy: 0.4591 - val_SSIM_loss: 0.0742
# Epoch 13/200
# 360/360 [==============================] - 211s 585ms/step - gen_total_loss: 2.8593 - gen_gan_loss: 0.7166 - gen_l1_loss: 0.0214 - disc_loss: 1.4017 - accuracy: 0.5032 - SSIM_loss: 0.0405 - val_accuracy: 0.4400 - val_SSIM_loss: 0.0597
# Epoch 14/200
# 360/360 [==============================] - 205s 569ms/step - gen_total_loss: 2.7865 - gen_gan_loss: 0.7139 - gen_l1_loss: 0.0207 - disc_loss: 1.4032 - accuracy: 0.5018 - SSIM_loss: 0.0393 - val_accuracy: 0.4678 - val_SSIM_loss: 0.0649
# Epoch 15/200
# 360/360 [==============================] - 210s 584ms/step - gen_total_loss: 2.6979 - gen_gan_loss: 0.7135 - gen_l1_loss: 0.0198 - disc_loss: 1.4011 - accuracy: 0.4912 - SSIM_loss: 0.0379 - val_accuracy: 0.3177 - val_SSIM_loss: 0.0806
# Epoch 16/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 2.6792 - gen_gan_loss: 0.7125 - gen_l1_loss: 0.0197 - disc_loss: 1.4022 - accuracy: 0.4934 - SSIM_loss: 0.0371 - val_accuracy: 0.4234 - val_SSIM_loss: 0.0613
# Epoch 17/200
# 360/360 [==============================] - 209s 579ms/step - gen_total_loss: 2.6049 - gen_gan_loss: 0.7121 - gen_l1_loss: 0.0189 - disc_loss: 1.4027 - accuracy: 0.4547 - SSIM_loss: 0.0362 - val_accuracy: 0.4254 - val_SSIM_loss: 0.0716
# Epoch 18/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 2.5205 - gen_gan_loss: 0.7102 - gen_l1_loss: 0.0181 - disc_loss: 1.4018 - accuracy: 0.4482 - SSIM_loss: 0.0349 - val_accuracy: 0.4125 - val_SSIM_loss: 0.0615
# Epoch 19/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 2.4945 - gen_gan_loss: 0.7098 - gen_l1_loss: 0.0178 - disc_loss: 1.4016 - accuracy: 0.4376 - SSIM_loss: 0.0342 - val_accuracy: 0.2615 - val_SSIM_loss: 0.0668
# Epoch 20/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 2.4577 - gen_gan_loss: 0.7090 - gen_l1_loss: 0.0175 - disc_loss: 1.3991 - accuracy: 0.4325 - SSIM_loss: 0.0334 - val_accuracy: 0.5847 - val_SSIM_loss: 0.0674
# Epoch 21/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 2.3866 - gen_gan_loss: 0.7092 - gen_l1_loss: 0.0168 - disc_loss: 1.4003 - accuracy: 0.4433 - SSIM_loss: 0.0322 - val_accuracy: 0.4433 - val_SSIM_loss: 0.0753
# Epoch 22/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 2.3406 - gen_gan_loss: 0.7077 - gen_l1_loss: 0.0163 - disc_loss: 1.4021 - accuracy: 0.4471 - SSIM_loss: 0.0315 - val_accuracy: 0.8501 - val_SSIM_loss: 0.0661
# Epoch 23/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 2.2878 - gen_gan_loss: 0.7075 - gen_l1_loss: 0.0158 - disc_loss: 1.4002 - accuracy: 0.4453 - SSIM_loss: 0.0306 - val_accuracy: 0.4297 - val_SSIM_loss: 0.0464
# Epoch 24/200
# 360/360 [==============================] - 203s 565ms/step - gen_total_loss: 2.2383 - gen_gan_loss: 0.7068 - gen_l1_loss: 0.0153 - disc_loss: 1.3990 - accuracy: 0.4361 - SSIM_loss: 0.0296 - val_accuracy: 0.5931 - val_SSIM_loss: 0.0843
# Epoch 25/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 2.2381 - gen_gan_loss: 0.7073 - gen_l1_loss: 0.0153 - disc_loss: 1.4006 - accuracy: 0.4544 - SSIM_loss: 0.0294 - val_accuracy: 0.3242 - val_SSIM_loss: 0.0591
# Epoch 26/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 2.1747 - gen_gan_loss: 0.7070 - gen_l1_loss: 0.0147 - disc_loss: 1.3987 - accuracy: 0.4595 - SSIM_loss: 0.0284 - val_accuracy: 0.5941 - val_SSIM_loss: 0.0593
# Epoch 27/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 2.1506 - gen_gan_loss: 0.7057 - gen_l1_loss: 0.0144 - disc_loss: 1.4000 - accuracy: 0.4609 - SSIM_loss: 0.0280 - val_accuracy: 0.4252 - val_SSIM_loss: 0.0565
# Epoch 28/200
# 360/360 [==============================] - 208s 579ms/step - gen_total_loss: 2.1549 - gen_gan_loss: 0.7067 - gen_l1_loss: 0.0145 - disc_loss: 1.3984 - accuracy: 0.4741 - SSIM_loss: 0.0279 - val_accuracy: 0.2342 - val_SSIM_loss: 0.0433
# Epoch 29/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 2.0872 - gen_gan_loss: 0.7051 - gen_l1_loss: 0.0138 - disc_loss: 1.3976 - accuracy: 0.4842 - SSIM_loss: 0.0268 - val_accuracy: 0.5041 - val_SSIM_loss: 0.0581
# Epoch 30/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 2.0965 - gen_gan_loss: 0.7061 - gen_l1_loss: 0.0139 - disc_loss: 1.3975 - accuracy: 0.4970 - SSIM_loss: 0.0270 - val_accuracy: 0.2529 - val_SSIM_loss: 0.0579
# Epoch 31/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 2.0607 - gen_gan_loss: 0.7052 - gen_l1_loss: 0.0136 - disc_loss: 1.3979 - accuracy: 0.5147 - SSIM_loss: 0.0262 - val_accuracy: 0.2930 - val_SSIM_loss: 0.0571
# Epoch 32/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 2.0427 - gen_gan_loss: 0.7051 - gen_l1_loss: 0.0134 - disc_loss: 1.3971 - accuracy: 0.5304 - SSIM_loss: 0.0259 - val_accuracy: 0.1514 - val_SSIM_loss: 0.0620
# Epoch 33/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 2.0118 - gen_gan_loss: 0.7046 - gen_l1_loss: 0.0131 - disc_loss: 1.3983 - accuracy: 0.5252 - SSIM_loss: 0.0255 - val_accuracy: 0.7007 - val_SSIM_loss: 0.0635
# Epoch 34/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 1.9841 - gen_gan_loss: 0.7043 - gen_l1_loss: 0.0128 - disc_loss: 1.3975 - accuracy: 0.5623 - SSIM_loss: 0.0249 - val_accuracy: 0.5741 - val_SSIM_loss: 0.0619
# Epoch 35/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.9218 - gen_gan_loss: 0.7030 - gen_l1_loss: 0.0122 - disc_loss: 1.3976 - accuracy: 0.5608 - SSIM_loss: 0.0240 - val_accuracy: 0.7434 - val_SSIM_loss: 0.0569
# Epoch 36/200
# 360/360 [==============================] - 205s 569ms/step - gen_total_loss: 1.8781 - gen_gan_loss: 0.7044 - gen_l1_loss: 0.0117 - disc_loss: 1.3974 - accuracy: 0.5978 - SSIM_loss: 0.0235 - val_accuracy: 0.3347 - val_SSIM_loss: 0.0493
# Epoch 37/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 1.8798 - gen_gan_loss: 0.7036 - gen_l1_loss: 0.0118 - disc_loss: 1.3977 - accuracy: 0.5972 - SSIM_loss: 0.0235 - val_accuracy: 0.4785 - val_SSIM_loss: 0.0552
# Epoch 38/200
# 360/360 [==============================] - 205s 568ms/step - gen_total_loss: 1.8503 - gen_gan_loss: 0.7026 - gen_l1_loss: 0.0115 - disc_loss: 1.3971 - accuracy: 0.6255 - SSIM_loss: 0.0229 - val_accuracy: 0.5215 - val_SSIM_loss: 0.0548
# Epoch 39/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.9350 - gen_gan_loss: 0.7033 - gen_l1_loss: 0.0123 - disc_loss: 1.3968 - accuracy: 0.6293 - SSIM_loss: 0.0239 - val_accuracy: 0.5653 - val_SSIM_loss: 0.0593
# Epoch 40/200
# 360/360 [==============================] - 210s 582ms/step - gen_total_loss: 1.8880 - gen_gan_loss: 0.7032 - gen_l1_loss: 0.0118 - disc_loss: 1.3961 - accuracy: 0.6771 - SSIM_loss: 0.0233 - val_accuracy: 0.5956 - val_SSIM_loss: 0.0712
# Epoch 41/200
# 360/360 [==============================] - 204s 566ms/step - gen_total_loss: 1.8098 - gen_gan_loss: 0.7024 - gen_l1_loss: 0.0111 - disc_loss: 1.3964 - accuracy: 0.6728 - SSIM_loss: 0.0222 - val_accuracy: 0.6134 - val_SSIM_loss: 0.0527
# Epoch 42/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.8634 - gen_gan_loss: 0.7036 - gen_l1_loss: 0.0116 - disc_loss: 1.3961 - accuracy: 0.6836 - SSIM_loss: 0.0228 - val_accuracy: 0.8383 - val_SSIM_loss: 0.0604
# Epoch 43/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.8103 - gen_gan_loss: 0.7018 - gen_l1_loss: 0.0111 - disc_loss: 1.3967 - accuracy: 0.6949 - SSIM_loss: 0.0221 - val_accuracy: 0.5770 - val_SSIM_loss: 0.0536
# Epoch 44/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.7491 - gen_gan_loss: 0.7016 - gen_l1_loss: 0.0105 - disc_loss: 1.3975 - accuracy: 0.7113 - SSIM_loss: 0.0213 - val_accuracy: 0.4626 - val_SSIM_loss: 0.0529
# Epoch 45/200
# 360/360 [==============================] - 208s 577ms/step - gen_total_loss: 1.7999 - gen_gan_loss: 0.7021 - gen_l1_loss: 0.0110 - disc_loss: 1.3975 - accuracy: 0.7087 - SSIM_loss: 0.0219 - val_accuracy: 0.6565 - val_SSIM_loss: 0.0555
# Epoch 46/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.8156 - gen_gan_loss: 0.7010 - gen_l1_loss: 0.0111 - disc_loss: 1.3957 - accuracy: 0.7324 - SSIM_loss: 0.0221 - val_accuracy: 0.6631 - val_SSIM_loss: 0.0627
# Epoch 47/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.7420 - gen_gan_loss: 0.7017 - gen_l1_loss: 0.0104 - disc_loss: 1.3958 - accuracy: 0.7357 - SSIM_loss: 0.0210 - val_accuracy: 0.6108 - val_SSIM_loss: 0.0530
# Epoch 48/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 1.7210 - gen_gan_loss: 0.7013 - gen_l1_loss: 0.0102 - disc_loss: 1.3954 - accuracy: 0.7443 - SSIM_loss: 0.0208 - val_accuracy: 0.3739 - val_SSIM_loss: 0.0509
# Epoch 49/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.7123 - gen_gan_loss: 0.7019 - gen_l1_loss: 0.0101 - disc_loss: 1.3957 - accuracy: 0.7510 - SSIM_loss: 0.0207 - val_accuracy: 0.5074 - val_SSIM_loss: 0.0488
# Epoch 50/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.7132 - gen_gan_loss: 0.7016 - gen_l1_loss: 0.0101 - disc_loss: 1.3947 - accuracy: 0.7662 - SSIM_loss: 0.0205 - val_accuracy: 0.7301 - val_SSIM_loss: 0.0609
# Epoch 51/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.6922 - gen_gan_loss: 0.7011 - gen_l1_loss: 0.0099 - disc_loss: 1.3960 - accuracy: 0.7695 - SSIM_loss: 0.0203 - val_accuracy: 0.7555 - val_SSIM_loss: 0.0663
# Epoch 52/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.6706 - gen_gan_loss: 0.7010 - gen_l1_loss: 0.0097 - disc_loss: 1.3964 - accuracy: 0.7810 - SSIM_loss: 0.0199 - val_accuracy: 0.8085 - val_SSIM_loss: 0.0568
# Epoch 53/200
# 360/360 [==============================] - 205s 570ms/step - gen_total_loss: 1.6503 - gen_gan_loss: 0.7003 - gen_l1_loss: 0.0095 - disc_loss: 1.3957 - accuracy: 0.7897 - SSIM_loss: 0.0196 - val_accuracy: 0.6919 - val_SSIM_loss: 0.0583
# Epoch 54/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.6360 - gen_gan_loss: 0.7007 - gen_l1_loss: 0.0094 - disc_loss: 1.3956 - accuracy: 0.7970 - SSIM_loss: 0.0194 - val_accuracy: 0.7536 - val_SSIM_loss: 0.0594
# Epoch 55/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.6491 - gen_gan_loss: 0.6998 - gen_l1_loss: 0.0095 - disc_loss: 1.3950 - accuracy: 0.7997 - SSIM_loss: 0.0195 - val_accuracy: 0.8614 - val_SSIM_loss: 0.0757
# Epoch 56/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.6372 - gen_gan_loss: 0.7010 - gen_l1_loss: 0.0094 - disc_loss: 1.3958 - accuracy: 0.8099 - SSIM_loss: 0.0194 - val_accuracy: 0.8356 - val_SSIM_loss: 0.0465
# Epoch 57/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.6012 - gen_gan_loss: 0.6998 - gen_l1_loss: 0.0090 - disc_loss: 1.3953 - accuracy: 0.8200 - SSIM_loss: 0.0189 - val_accuracy: 0.9320 - val_SSIM_loss: 0.0669
# Epoch 58/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.5817 - gen_gan_loss: 0.7002 - gen_l1_loss: 0.0088 - disc_loss: 1.3953 - accuracy: 0.8231 - SSIM_loss: 0.0187 - val_accuracy: 0.6455 - val_SSIM_loss: 0.0541
# Epoch 59/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.5903 - gen_gan_loss: 0.6999 - gen_l1_loss: 0.0089 - disc_loss: 1.3948 - accuracy: 0.8338 - SSIM_loss: 0.0186 - val_accuracy: 0.8628 - val_SSIM_loss: 0.0642
# Epoch 60/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.6337 - gen_gan_loss: 0.7003 - gen_l1_loss: 0.0093 - disc_loss: 1.3952 - accuracy: 0.8372 - SSIM_loss: 0.0190 - val_accuracy: 0.5832 - val_SSIM_loss: 0.0556
# Epoch 61/200
# 360/360 [==============================] - 210s 582ms/step - gen_total_loss: 1.5700 - gen_gan_loss: 0.6994 - gen_l1_loss: 0.0087 - disc_loss: 1.3957 - accuracy: 0.8336 - SSIM_loss: 0.0184 - val_accuracy: 0.8828 - val_SSIM_loss: 0.0549
# Epoch 62/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.5213 - gen_gan_loss: 0.6998 - gen_l1_loss: 0.0082 - disc_loss: 1.3951 - accuracy: 0.8449 - SSIM_loss: 0.0176 - val_accuracy: 0.9285 - val_SSIM_loss: 0.0553
# Epoch 63/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.5665 - gen_gan_loss: 0.6993 - gen_l1_loss: 0.0087 - disc_loss: 1.3951 - accuracy: 0.8476 - SSIM_loss: 0.0182 - val_accuracy: 0.7017 - val_SSIM_loss: 0.0734
# Epoch 64/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.5910 - gen_gan_loss: 0.6990 - gen_l1_loss: 0.0089 - disc_loss: 1.3940 - accuracy: 0.8538 - SSIM_loss: 0.0185 - val_accuracy: 0.5730 - val_SSIM_loss: 0.0536
# Epoch 65/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.5563 - gen_gan_loss: 0.7002 - gen_l1_loss: 0.0086 - disc_loss: 1.3945 - accuracy: 0.8619 - SSIM_loss: 0.0180 - val_accuracy: 0.9122 - val_SSIM_loss: 0.0592
# Epoch 66/200
# 360/360 [==============================] - 210s 584ms/step - gen_total_loss: 1.5391 - gen_gan_loss: 0.6988 - gen_l1_loss: 0.0084 - disc_loss: 1.3951 - accuracy: 0.8705 - SSIM_loss: 0.0178 - val_accuracy: 0.8340 - val_SSIM_loss: 0.0570
# Epoch 67/200
# 360/360 [==============================] - 205s 571ms/step - gen_total_loss: 1.5263 - gen_gan_loss: 0.6989 - gen_l1_loss: 0.0083 - disc_loss: 1.3943 - accuracy: 0.8700 - SSIM_loss: 0.0175 - val_accuracy: 0.6800 - val_SSIM_loss: 0.0505
# Epoch 68/200
# 360/360 [==============================] - 210s 584ms/step - gen_total_loss: 1.5136 - gen_gan_loss: 0.6989 - gen_l1_loss: 0.0081 - disc_loss: 1.3949 - accuracy: 0.8706 - SSIM_loss: 0.0174 - val_accuracy: 0.6913 - val_SSIM_loss: 0.0554
# Epoch 69/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.5058 - gen_gan_loss: 0.6988 - gen_l1_loss: 0.0081 - disc_loss: 1.3949 - accuracy: 0.8830 - SSIM_loss: 0.0173 - val_accuracy: 0.7410 - val_SSIM_loss: 0.0551
# Epoch 70/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.4705 - gen_gan_loss: 0.6982 - gen_l1_loss: 0.0077 - disc_loss: 1.3944 - accuracy: 0.8931 - SSIM_loss: 0.0168 - val_accuracy: 0.8609 - val_SSIM_loss: 0.0572
# Epoch 71/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 1.4531 - gen_gan_loss: 0.6992 - gen_l1_loss: 0.0075 - disc_loss: 1.3939 - accuracy: 0.8895 - SSIM_loss: 0.0164 - val_accuracy: 0.8816 - val_SSIM_loss: 0.0591
# Epoch 72/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.4751 - gen_gan_loss: 0.6987 - gen_l1_loss: 0.0078 - disc_loss: 1.3940 - accuracy: 0.8913 - SSIM_loss: 0.0167 - val_accuracy: 0.8549 - val_SSIM_loss: 0.0597
# Epoch 73/200
# 360/360 [==============================] - 210s 582ms/step - gen_total_loss: 1.4459 - gen_gan_loss: 0.6987 - gen_l1_loss: 0.0075 - disc_loss: 1.3945 - accuracy: 0.8933 - SSIM_loss: 0.0163 - val_accuracy: 0.7703 - val_SSIM_loss: 0.0551
# Epoch 74/200
# 360/360 [==============================] - 207s 574ms/step - gen_total_loss: 1.4336 - gen_gan_loss: 0.6989 - gen_l1_loss: 0.0073 - disc_loss: 1.3940 - accuracy: 0.8960 - SSIM_loss: 0.0161 - val_accuracy: 0.8909 - val_SSIM_loss: 0.0554
# Epoch 75/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.4491 - gen_gan_loss: 0.6985 - gen_l1_loss: 0.0075 - disc_loss: 1.3937 - accuracy: 0.9046 - SSIM_loss: 0.0163 - val_accuracy: 0.8847 - val_SSIM_loss: 0.0564
# Epoch 76/200
# 360/360 [==============================] - 210s 584ms/step - gen_total_loss: 1.4412 - gen_gan_loss: 0.6983 - gen_l1_loss: 0.0074 - disc_loss: 1.3943 - accuracy: 0.9033 - SSIM_loss: 0.0162 - val_accuracy: 0.8767 - val_SSIM_loss: 0.0586
# Epoch 77/200
# 360/360 [==============================] - 203s 565ms/step - gen_total_loss: 1.4905 - gen_gan_loss: 0.6982 - gen_l1_loss: 0.0079 - disc_loss: 1.3932 - accuracy: 0.9070 - SSIM_loss: 0.0168 - val_accuracy: 0.9245 - val_SSIM_loss: 0.0539
# Epoch 78/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.5051 - gen_gan_loss: 0.6993 - gen_l1_loss: 0.0081 - disc_loss: 1.3930 - accuracy: 0.9101 - SSIM_loss: 0.0170 - val_accuracy: 0.8363 - val_SSIM_loss: 0.0557
# Epoch 79/200
# 360/360 [==============================] - 205s 570ms/step - gen_total_loss: 1.4297 - gen_gan_loss: 0.6981 - gen_l1_loss: 0.0073 - disc_loss: 1.3936 - accuracy: 0.9111 - SSIM_loss: 0.0160 - val_accuracy: 0.8591 - val_SSIM_loss: 0.0560
# Epoch 80/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.3879 - gen_gan_loss: 0.6977 - gen_l1_loss: 0.0069 - disc_loss: 1.3940 - accuracy: 0.9156 - SSIM_loss: 0.0153 - val_accuracy: 0.7832 - val_SSIM_loss: 0.0543
# Epoch 81/200
# 360/360 [==============================] - 209s 579ms/step - gen_total_loss: 1.3730 - gen_gan_loss: 0.6985 - gen_l1_loss: 0.0067 - disc_loss: 1.3939 - accuracy: 0.9204 - SSIM_loss: 0.0151 - val_accuracy: 0.9011 - val_SSIM_loss: 0.0570
# Epoch 82/200
# 360/360 [==============================] - 203s 565ms/step - gen_total_loss: 1.4207 - gen_gan_loss: 0.6980 - gen_l1_loss: 0.0072 - disc_loss: 1.3934 - accuracy: 0.9259 - SSIM_loss: 0.0158 - val_accuracy: 0.9056 - val_SSIM_loss: 0.0588
# Epoch 83/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.3765 - gen_gan_loss: 0.6979 - gen_l1_loss: 0.0068 - disc_loss: 1.3939 - accuracy: 0.9216 - SSIM_loss: 0.0151 - val_accuracy: 0.9341 - val_SSIM_loss: 0.0581
# Epoch 84/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.4079 - gen_gan_loss: 0.6974 - gen_l1_loss: 0.0071 - disc_loss: 1.3934 - accuracy: 0.9228 - SSIM_loss: 0.0156 - val_accuracy: 0.8712 - val_SSIM_loss: 0.0581
# Epoch 85/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.3910 - gen_gan_loss: 0.6984 - gen_l1_loss: 0.0069 - disc_loss: 1.3934 - accuracy: 0.9273 - SSIM_loss: 0.0154 - val_accuracy: 0.8915 - val_SSIM_loss: 0.0563
# Epoch 86/200
# 360/360 [==============================] - 210s 582ms/step - gen_total_loss: 1.3847 - gen_gan_loss: 0.6978 - gen_l1_loss: 0.0069 - disc_loss: 1.3934 - accuracy: 0.9321 - SSIM_loss: 0.0152 - val_accuracy: 0.9428 - val_SSIM_loss: 0.0588
# Epoch 87/200
# 360/360 [==============================] - 205s 570ms/step - gen_total_loss: 1.3848 - gen_gan_loss: 0.6979 - gen_l1_loss: 0.0069 - disc_loss: 1.3932 - accuracy: 0.9346 - SSIM_loss: 0.0151 - val_accuracy: 0.7903 - val_SSIM_loss: 0.0544
# Epoch 88/200
# 360/360 [==============================] - 208s 578ms/step - gen_total_loss: 1.3730 - gen_gan_loss: 0.6982 - gen_l1_loss: 0.0067 - disc_loss: 1.3932 - accuracy: 0.9406 - SSIM_loss: 0.0149 - val_accuracy: 0.8951 - val_SSIM_loss: 0.0550
# Epoch 89/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.3891 - gen_gan_loss: 0.6976 - gen_l1_loss: 0.0069 - disc_loss: 1.3927 - accuracy: 0.9406 - SSIM_loss: 0.0152 - val_accuracy: 0.8915 - val_SSIM_loss: 0.0542
# Epoch 90/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 1.3548 - gen_gan_loss: 0.6975 - gen_l1_loss: 0.0066 - disc_loss: 1.3932 - accuracy: 0.9429 - SSIM_loss: 0.0148 - val_accuracy: 0.9371 - val_SSIM_loss: 0.0598
# Epoch 91/200
# 360/360 [==============================] - 207s 576ms/step - gen_total_loss: 1.3542 - gen_gan_loss: 0.6978 - gen_l1_loss: 0.0066 - disc_loss: 1.3933 - accuracy: 0.9434 - SSIM_loss: 0.0146 - val_accuracy: 0.7013 - val_SSIM_loss: 0.0477
# Epoch 92/200
# 360/360 [==============================] - 209s 582ms/step - gen_total_loss: 1.3387 - gen_gan_loss: 0.6972 - gen_l1_loss: 0.0064 - disc_loss: 1.3932 - accuracy: 0.9450 - SSIM_loss: 0.0144 - val_accuracy: 0.9378 - val_SSIM_loss: 0.0595
# Epoch 93/200
# 360/360 [==============================] - 210s 584ms/step - gen_total_loss: 1.3422 - gen_gan_loss: 0.6971 - gen_l1_loss: 0.0065 - disc_loss: 1.3932 - accuracy: 0.9478 - SSIM_loss: 0.0144 - val_accuracy: 0.9361 - val_SSIM_loss: 0.0625
# Epoch 94/200
# 360/360 [==============================] - 204s 566ms/step - gen_total_loss: 1.3497 - gen_gan_loss: 0.6974 - gen_l1_loss: 0.0065 - disc_loss: 1.3932 - accuracy: 0.9484 - SSIM_loss: 0.0145 - val_accuracy: 0.7365 - val_SSIM_loss: 0.0588
# Epoch 95/200
# 360/360 [==============================] - 210s 584ms/step - gen_total_loss: 1.3582 - gen_gan_loss: 0.6976 - gen_l1_loss: 0.0066 - disc_loss: 1.3928 - accuracy: 0.9503 - SSIM_loss: 0.0146 - val_accuracy: 0.9254 - val_SSIM_loss: 0.0533
# Epoch 96/200
# 360/360 [==============================] - 205s 571ms/step - gen_total_loss: 1.3247 - gen_gan_loss: 0.6970 - gen_l1_loss: 0.0063 - disc_loss: 1.3931 - accuracy: 0.9542 - SSIM_loss: 0.0141 - val_accuracy: 0.9233 - val_SSIM_loss: 0.0537
# Epoch 97/200
# 360/360 [==============================] - 211s 585ms/step - gen_total_loss: 1.3090 - gen_gan_loss: 0.6972 - gen_l1_loss: 0.0061 - disc_loss: 1.3930 - accuracy: 0.9523 - SSIM_loss: 0.0138 - val_accuracy: 0.9364 - val_SSIM_loss: 0.0577
# Epoch 98/200
# 360/360 [==============================] - 210s 582ms/step - gen_total_loss: 1.3205 - gen_gan_loss: 0.6967 - gen_l1_loss: 0.0062 - disc_loss: 1.3931 - accuracy: 0.9536 - SSIM_loss: 0.0141 - val_accuracy: 0.8610 - val_SSIM_loss: 0.0542
# Epoch 99/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.3088 - gen_gan_loss: 0.6973 - gen_l1_loss: 0.0061 - disc_loss: 1.3928 - accuracy: 0.9550 - SSIM_loss: 0.0138 - val_accuracy: 0.9412 - val_SSIM_loss: 0.0583
# Epoch 100/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.3092 - gen_gan_loss: 0.6970 - gen_l1_loss: 0.0061 - disc_loss: 1.3928 - accuracy: 0.9570 - SSIM_loss: 0.0139 - val_accuracy: 0.9532 - val_SSIM_loss: 0.0594
# Epoch 101/200
# 360/360 [==============================] - 206s 572ms/step - gen_total_loss: 1.3311 - gen_gan_loss: 0.6972 - gen_l1_loss: 0.0063 - disc_loss: 1.3925 - accuracy: 0.9591 - SSIM_loss: 0.0141 - val_accuracy: 0.9055 - val_SSIM_loss: 0.0547
# Epoch 102/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 1.3267 - gen_gan_loss: 0.6971 - gen_l1_loss: 0.0063 - disc_loss: 1.3926 - accuracy: 0.9603 - SSIM_loss: 0.0141 - val_accuracy: 0.9409 - val_SSIM_loss: 0.0553
# Epoch 103/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.3242 - gen_gan_loss: 0.6970 - gen_l1_loss: 0.0063 - disc_loss: 1.3923 - accuracy: 0.9575 - SSIM_loss: 0.0140 - val_accuracy: 0.9531 - val_SSIM_loss: 0.0564
# Epoch 104/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.3022 - gen_gan_loss: 0.6968 - gen_l1_loss: 0.0061 - disc_loss: 1.3925 - accuracy: 0.9615 - SSIM_loss: 0.0137 - val_accuracy: 0.8585 - val_SSIM_loss: 0.0581
# Epoch 105/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.2951 - gen_gan_loss: 0.6972 - gen_l1_loss: 0.0060 - disc_loss: 1.3924 - accuracy: 0.9613 - SSIM_loss: 0.0136 - val_accuracy: 0.9384 - val_SSIM_loss: 0.0551
# Epoch 106/200
# 360/360 [==============================] - 204s 567ms/step - gen_total_loss: 1.2711 - gen_gan_loss: 0.6969 - gen_l1_loss: 0.0057 - disc_loss: 1.3924 - accuracy: 0.9617 - SSIM_loss: 0.0131 - val_accuracy: 0.8844 - val_SSIM_loss: 0.0483
# Epoch 107/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.2915 - gen_gan_loss: 0.6968 - gen_l1_loss: 0.0059 - disc_loss: 1.3926 - accuracy: 0.9618 - SSIM_loss: 0.0135 - val_accuracy: 0.9502 - val_SSIM_loss: 0.0627
# Epoch 108/200
# 360/360 [==============================] - 206s 571ms/step - gen_total_loss: 1.2756 - gen_gan_loss: 0.6969 - gen_l1_loss: 0.0058 - disc_loss: 1.3924 - accuracy: 0.9649 - SSIM_loss: 0.0132 - val_accuracy: 0.8368 - val_SSIM_loss: 0.0571
# Epoch 109/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.2512 - gen_gan_loss: 0.6968 - gen_l1_loss: 0.0055 - disc_loss: 1.3925 - accuracy: 0.9659 - SSIM_loss: 0.0128 - val_accuracy: 0.9520 - val_SSIM_loss: 0.0564
# Epoch 110/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.2803 - gen_gan_loss: 0.6965 - gen_l1_loss: 0.0058 - disc_loss: 1.3923 - accuracy: 0.9640 - SSIM_loss: 0.0133 - val_accuracy: 0.9245 - val_SSIM_loss: 0.0533
# Epoch 111/200
# 360/360 [==============================] - 204s 568ms/step - gen_total_loss: 1.2413 - gen_gan_loss: 0.6967 - gen_l1_loss: 0.0054 - disc_loss: 1.3923 - accuracy: 0.9659 - SSIM_loss: 0.0126 - val_accuracy: 0.9328 - val_SSIM_loss: 0.0595
# Epoch 112/200
# 360/360 [==============================] - 209s 581ms/step - gen_total_loss: 1.2444 - gen_gan_loss: 0.6965 - gen_l1_loss: 0.0055 - disc_loss: 1.3926 - accuracy: 0.9677 - SSIM_loss: 0.0127 - val_accuracy: 0.9472 - val_SSIM_loss: 0.0562
# Epoch 113/200
# 360/360 [==============================] - 205s 570ms/step - gen_total_loss: 1.2734 - gen_gan_loss: 0.6969 - gen_l1_loss: 0.0058 - disc_loss: 1.3919 - accuracy: 0.9672 - SSIM_loss: 0.0131 - val_accuracy: 0.9635 - val_SSIM_loss: 0.0614
# Epoch 114/200
# 360/360 [==============================] - 210s 582ms/step - gen_total_loss: 1.2373 - gen_gan_loss: 0.6965 - gen_l1_loss: 0.0054 - disc_loss: 1.3923 - accuracy: 0.9689 - SSIM_loss: 0.0125 - val_accuracy: 0.8899 - val_SSIM_loss: 0.0511
# Epoch 115/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.2675 - gen_gan_loss: 0.6967 - gen_l1_loss: 0.0057 - disc_loss: 1.3918 - accuracy: 0.9669 - SSIM_loss: 0.0130 - val_accuracy: 0.9605 - val_SSIM_loss: 0.0555
# Epoch 116/200
# 360/360 [==============================] - 207s 575ms/step - gen_total_loss: 1.2406 - gen_gan_loss: 0.6966 - gen_l1_loss: 0.0054 - disc_loss: 1.3921 - accuracy: 0.9688 - SSIM_loss: 0.0126 - val_accuracy: 0.9154 - val_SSIM_loss: 0.0525
# Epoch 117/200
# 360/360 [==============================] - 210s 583ms/step - gen_total_loss: 1.2661 - gen_gan_loss: 0.6965 - gen_l1_loss: 0.0057 - disc_loss: 1.3918 - accuracy: 0.9693 - SSIM_loss: 0.0130 - val_accuracy: 0.9522 - val_SSIM_loss: 0.0561
# Epoch 118/200
# 360/360 [==============================] - 207s 574ms/step - gen_total_loss: 1.2402 - gen_gan_loss: 0.6967 - gen_l1_loss: 0.0054 - disc_loss: 1.3922 - accuracy: 0.9700 - SSIM_loss: 0.0126 - val_accuracy: 0.9561 - val_SSIM_loss: 0.0559
# Epoch 119/200
# 360/360 [==============================] - 209s 580ms/step - gen_total_loss: 1.2200 - gen_gan_loss: 0.6963 - gen_l1_loss: 0.0052 - disc_loss: 1.3921 - accuracy: 0.9695 - SSIM_loss: 0.0122 - val_accuracy: 0.9559 - val_SSIM_loss: 0.0583
# Epoch 120/200
# 360/360 [==============================] - 206s 573ms/step - gen_total_loss: 1.2446 - gen_gan_loss: 0.6966 - gen_l1_loss: 0.0055 - disc_loss: 1.3917 - accuracy: 0.9692 - SSIM_loss: 0.0127 - val_accuracy: 0.9599 - val_SSIM_loss: 0.0601
# Epoch 121/200
# 360/360 [==============================] - 188s 522ms/step - gen_total_loss: 1.2408 - gen_gan_loss: 0.6962 - gen_l1_loss: 0.0054 - disc_loss: 1.3916 - accuracy: 0.9691 - SSIM_loss: 0.0125 - val_accuracy: 0.9586 - val_SSIM_loss: 0.0574
# Epoch 122/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.2082 - gen_gan_loss: 0.6967 - gen_l1_loss: 0.0051 - disc_loss: 1.3920 - accuracy: 0.9707 - SSIM_loss: 0.0120 - val_accuracy: 0.9418 - val_SSIM_loss: 0.0553
# Epoch 123/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.2093 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0051 - disc_loss: 1.3919 - accuracy: 0.9711 - SSIM_loss: 0.0120 - val_accuracy: 0.9476 - val_SSIM_loss: 0.0560
# Epoch 124/200
# 360/360 [==============================] - 141s 391ms/step - gen_total_loss: 1.2388 - gen_gan_loss: 0.6970 - gen_l1_loss: 0.0054 - disc_loss: 1.3916 - accuracy: 0.9707 - SSIM_loss: 0.0125 - val_accuracy: 0.9660 - val_SSIM_loss: 0.0622
# Epoch 125/200
# 360/360 [==============================] - 142s 394ms/step - gen_total_loss: 1.2433 - gen_gan_loss: 0.6961 - gen_l1_loss: 0.0055 - disc_loss: 1.3916 - accuracy: 0.9708 - SSIM_loss: 0.0126 - val_accuracy: 0.9420 - val_SSIM_loss: 0.0566
# Epoch 126/200
# 360/360 [==============================] - 141s 392ms/step - gen_total_loss: 1.2244 - gen_gan_loss: 0.6963 - gen_l1_loss: 0.0053 - disc_loss: 1.3918 - accuracy: 0.9717 - SSIM_loss: 0.0122 - val_accuracy: 0.9601 - val_SSIM_loss: 0.0578
# Epoch 127/200
# 360/360 [==============================] - 141s 392ms/step - gen_total_loss: 1.2235 - gen_gan_loss: 0.6968 - gen_l1_loss: 0.0053 - disc_loss: 1.3914 - accuracy: 0.9729 - SSIM_loss: 0.0121 - val_accuracy: 0.9538 - val_SSIM_loss: 0.0537
# Epoch 128/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 1.2033 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0051 - disc_loss: 1.3916 - accuracy: 0.9726 - SSIM_loss: 0.0119 - val_accuracy: 0.9518 - val_SSIM_loss: 0.0506
# Epoch 129/200
# 360/360 [==============================] - 141s 391ms/step - gen_total_loss: 1.2149 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0052 - disc_loss: 1.3914 - accuracy: 0.9732 - SSIM_loss: 0.0120 - val_accuracy: 0.9503 - val_SSIM_loss: 0.0507
# Epoch 130/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.2111 - gen_gan_loss: 0.6964 - gen_l1_loss: 0.0051 - disc_loss: 1.3917 - accuracy: 0.9737 - SSIM_loss: 0.0120 - val_accuracy: 0.9593 - val_SSIM_loss: 0.0556
# Epoch 131/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 1.2327 - gen_gan_loss: 0.6963 - gen_l1_loss: 0.0054 - disc_loss: 1.3914 - accuracy: 0.9748 - SSIM_loss: 0.0123 - val_accuracy: 0.9540 - val_SSIM_loss: 0.0539
# Epoch 132/200
# 360/360 [==============================] - 139s 387ms/step - gen_total_loss: 1.1955 - gen_gan_loss: 0.6963 - gen_l1_loss: 0.0050 - disc_loss: 1.3914 - accuracy: 0.9735 - SSIM_loss: 0.0118 - val_accuracy: 0.9613 - val_SSIM_loss: 0.0610
# Epoch 133/200
# 360/360 [==============================] - 141s 393ms/step - gen_total_loss: 1.2174 - gen_gan_loss: 0.6962 - gen_l1_loss: 0.0052 - disc_loss: 1.3915 - accuracy: 0.9742 - SSIM_loss: 0.0121 - val_accuracy: 0.9623 - val_SSIM_loss: 0.0573
# Epoch 134/200
# 360/360 [==============================] - 141s 391ms/step - gen_total_loss: 1.1851 - gen_gan_loss: 0.6961 - gen_l1_loss: 0.0049 - disc_loss: 1.3916 - accuracy: 0.9747 - SSIM_loss: 0.0116 - val_accuracy: 0.9624 - val_SSIM_loss: 0.0541
# Epoch 135/200
# 360/360 [==============================] - 142s 395ms/step - gen_total_loss: 1.1971 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0050 - disc_loss: 1.3915 - accuracy: 0.9750 - SSIM_loss: 0.0118 - val_accuracy: 0.9482 - val_SSIM_loss: 0.0545
# Epoch 136/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 1.1950 - gen_gan_loss: 0.6966 - gen_l1_loss: 0.0050 - disc_loss: 1.3913 - accuracy: 0.9762 - SSIM_loss: 0.0116 - val_accuracy: 0.9598 - val_SSIM_loss: 0.0583
# Epoch 137/200
# 360/360 [==============================] - 141s 391ms/step - gen_total_loss: 1.1905 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0049 - disc_loss: 1.3913 - accuracy: 0.9747 - SSIM_loss: 0.0117 - val_accuracy: 0.9557 - val_SSIM_loss: 0.0542
# Epoch 138/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 1.1692 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0047 - disc_loss: 1.3914 - accuracy: 0.9757 - SSIM_loss: 0.0113 - val_accuracy: 0.9501 - val_SSIM_loss: 0.0577
# Epoch 139/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 1.1886 - gen_gan_loss: 0.6962 - gen_l1_loss: 0.0049 - disc_loss: 1.3913 - accuracy: 0.9753 - SSIM_loss: 0.0115 - val_accuracy: 0.9646 - val_SSIM_loss: 0.0541
# Epoch 140/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.1864 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0049 - disc_loss: 1.3913 - accuracy: 0.9762 - SSIM_loss: 0.0116 - val_accuracy: 0.9608 - val_SSIM_loss: 0.0611
# Epoch 141/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 1.1936 - gen_gan_loss: 0.6961 - gen_l1_loss: 0.0050 - disc_loss: 1.3914 - accuracy: 0.9759 - SSIM_loss: 0.0116 - val_accuracy: 0.9461 - val_SSIM_loss: 0.0567
# Epoch 142/200
# 360/360 [==============================] - 139s 387ms/step - gen_total_loss: 1.1690 - gen_gan_loss: 0.6959 - gen_l1_loss: 0.0047 - disc_loss: 1.3913 - accuracy: 0.9772 - SSIM_loss: 0.0112 - val_accuracy: 0.9587 - val_SSIM_loss: 0.0549
# Epoch 143/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.1758 - gen_gan_loss: 0.6959 - gen_l1_loss: 0.0048 - disc_loss: 1.3913 - accuracy: 0.9757 - SSIM_loss: 0.0113 - val_accuracy: 0.9514 - val_SSIM_loss: 0.0549
# Epoch 144/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.1720 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0048 - disc_loss: 1.3911 - accuracy: 0.9766 - SSIM_loss: 0.0112 - val_accuracy: 0.9594 - val_SSIM_loss: 0.0587
# Epoch 145/200
# 360/360 [==============================] - 141s 392ms/step - gen_total_loss: 1.1464 - gen_gan_loss: 0.6962 - gen_l1_loss: 0.0045 - disc_loss: 1.3911 - accuracy: 0.9771 - SSIM_loss: 0.0107 - val_accuracy: 0.9609 - val_SSIM_loss: 0.0556
# Epoch 146/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.1887 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0049 - disc_loss: 1.3910 - accuracy: 0.9770 - SSIM_loss: 0.0115 - val_accuracy: 0.9627 - val_SSIM_loss: 0.0569
# Epoch 147/200
# 360/360 [==============================] - 142s 395ms/step - gen_total_loss: 1.1375 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0044 - disc_loss: 1.3912 - accuracy: 0.9780 - SSIM_loss: 0.0106 - val_accuracy: 0.9653 - val_SSIM_loss: 0.0584
# Epoch 148/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 1.1887 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0049 - disc_loss: 1.3910 - accuracy: 0.9769 - SSIM_loss: 0.0115 - val_accuracy: 0.9499 - val_SSIM_loss: 0.0568
# Epoch 149/200
# 360/360 [==============================] - 139s 386ms/step - gen_total_loss: 1.1624 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0047 - disc_loss: 1.3910 - accuracy: 0.9785 - SSIM_loss: 0.0110 - val_accuracy: 0.9565 - val_SSIM_loss: 0.0582
# Epoch 150/200
# 360/360 [==============================] - 141s 391ms/step - gen_total_loss: 1.1667 - gen_gan_loss: 0.6961 - gen_l1_loss: 0.0047 - disc_loss: 1.3911 - accuracy: 0.9777 - SSIM_loss: 0.0111 - val_accuracy: 0.9636 - val_SSIM_loss: 0.0509
# Epoch 151/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 1.1622 - gen_gan_loss: 0.6955 - gen_l1_loss: 0.0047 - disc_loss: 1.3909 - accuracy: 0.9788 - SSIM_loss: 0.0111 - val_accuracy: 0.9650 - val_SSIM_loss: 0.0650
# Epoch 152/200
# 360/360 [==============================] - 140s 388ms/step - gen_total_loss: 1.1463 - gen_gan_loss: 0.6959 - gen_l1_loss: 0.0045 - disc_loss: 1.3911 - accuracy: 0.9791 - SSIM_loss: 0.0108 - val_accuracy: 0.9590 - val_SSIM_loss: 0.0571
# Epoch 153/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 1.1576 - gen_gan_loss: 0.6959 - gen_l1_loss: 0.0046 - disc_loss: 1.3908 - accuracy: 0.9795 - SSIM_loss: 0.0109 - val_accuracy: 0.9525 - val_SSIM_loss: 0.0553
# Epoch 154/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.1803 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0048 - disc_loss: 1.3908 - accuracy: 0.9787 - SSIM_loss: 0.0112 - val_accuracy: 0.9381 - val_SSIM_loss: 0.0515
# Epoch 155/200
# 360/360 [==============================] - 141s 392ms/step - gen_total_loss: 1.1436 - gen_gan_loss: 0.6956 - gen_l1_loss: 0.0045 - disc_loss: 1.3911 - accuracy: 0.9789 - SSIM_loss: 0.0107 - val_accuracy: 0.9639 - val_SSIM_loss: 0.0548
# Epoch 156/200
# 360/360 [==============================] - 140s 390ms/step - gen_total_loss: 1.1435 - gen_gan_loss: 0.6960 - gen_l1_loss: 0.0045 - disc_loss: 1.3908 - accuracy: 0.9797 - SSIM_loss: 0.0107 - val_accuracy: 0.9344 - val_SSIM_loss: 0.0549
# Epoch 157/200
# 360/360 [==============================] - 141s 393ms/step - gen_total_loss: 1.1403 - gen_gan_loss: 0.6956 - gen_l1_loss: 0.0044 - disc_loss: 1.3909 - accuracy: 0.9788 - SSIM_loss: 0.0106 - val_accuracy: 0.9677 - val_SSIM_loss: 0.0607
# Epoch 158/200
# 360/360 [==============================] - 140s 389ms/step - gen_total_loss: 1.1700 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0047 - disc_loss: 1.3909 - accuracy: 0.9787 - SSIM_loss: 0.0111 - val_accuracy: 0.9461 - val_SSIM_loss: 0.0485
# Epoch 159/200
# 360/360 [==============================] - 141s 392ms/step - gen_total_loss: 1.1455 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0045 - disc_loss: 1.3909 - accuracy: 0.9798 - SSIM_loss: 0.0106 - val_accuracy: 0.9602 - val_SSIM_loss: 0.0596
# Epoch 160/200
# 360/360 [==============================] - 141s 391ms/step - gen_total_loss: 1.1337 - gen_gan_loss: 0.6957 - gen_l1_loss: 0.0044 - disc_loss: 1.3909 - accuracy: 0.9802 - SSIM_loss: 0.0105 - val_accuracy: 0.9286 - val_SSIM_loss: 0.0531
# Epoch 161/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.1346 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0044 - disc_loss: 1.3908 - accuracy: 0.9796 - SSIM_loss: 0.0105 - val_accuracy: 0.9727 - val_SSIM_loss: 0.0612
# Epoch 162/200
# 360/360 [==============================] - 89s 246ms/step - gen_total_loss: 1.1452 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0045 - disc_loss: 1.3906 - accuracy: 0.9805 - SSIM_loss: 0.0106 - val_accuracy: 0.9630 - val_SSIM_loss: 0.0585
# Epoch 163/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1374 - gen_gan_loss: 0.6955 - gen_l1_loss: 0.0044 - disc_loss: 1.3906 - accuracy: 0.9800 - SSIM_loss: 0.0105 - val_accuracy: 0.9687 - val_SSIM_loss: 0.0554
# Epoch 164/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1369 - gen_gan_loss: 0.6958 - gen_l1_loss: 0.0044 - disc_loss: 1.3907 - accuracy: 0.9809 - SSIM_loss: 0.0105 - val_accuracy: 0.9618 - val_SSIM_loss: 0.0603
# Epoch 165/200
# 360/360 [==============================] - 89s 249ms/step - gen_total_loss: 1.1360 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0044 - disc_loss: 1.3906 - accuracy: 0.9806 - SSIM_loss: 0.0105 - val_accuracy: 0.9637 - val_SSIM_loss: 0.0596
# Epoch 166/200
# 360/360 [==============================] - 89s 246ms/step - gen_total_loss: 1.1190 - gen_gan_loss: 0.6959 - gen_l1_loss: 0.0042 - disc_loss: 1.3907 - accuracy: 0.9811 - SSIM_loss: 0.0101 - val_accuracy: 0.9649 - val_SSIM_loss: 0.0601
# Epoch 167/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.1191 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0042 - disc_loss: 1.3906 - accuracy: 0.9808 - SSIM_loss: 0.0102 - val_accuracy: 0.9664 - val_SSIM_loss: 0.0554
# Epoch 168/200
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 1.1295 - gen_gan_loss: 0.6957 - gen_l1_loss: 0.0043 - disc_loss: 1.3906 - accuracy: 0.9804 - SSIM_loss: 0.0103 - val_accuracy: 0.9679 - val_SSIM_loss: 0.0592
# Epoch 169/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1293 - gen_gan_loss: 0.6957 - gen_l1_loss: 0.0043 - disc_loss: 1.3904 - accuracy: 0.9801 - SSIM_loss: 0.0103 - val_accuracy: 0.9619 - val_SSIM_loss: 0.0564
# Epoch 170/200
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 1.1254 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0043 - disc_loss: 1.3906 - accuracy: 0.9804 - SSIM_loss: 0.0103 - val_accuracy: 0.9613 - val_SSIM_loss: 0.0570
# Epoch 171/200
# 360/360 [==============================] - 91s 253ms/step - gen_total_loss: 1.1197 - gen_gan_loss: 0.6957 - gen_l1_loss: 0.0042 - disc_loss: 1.3906 - accuracy: 0.9802 - SSIM_loss: 0.0102 - val_accuracy: 0.9653 - val_SSIM_loss: 0.0564
# Epoch 172/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1267 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0043 - disc_loss: 1.3905 - accuracy: 0.9807 - SSIM_loss: 0.0102 - val_accuracy: 0.9628 - val_SSIM_loss: 0.0571
# Epoch 173/200
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 1.1368 - gen_gan_loss: 0.6957 - gen_l1_loss: 0.0044 - disc_loss: 1.3905 - accuracy: 0.9814 - SSIM_loss: 0.0105 - val_accuracy: 0.9563 - val_SSIM_loss: 0.0540
# Epoch 174/200
# 360/360 [==============================] - 91s 252ms/step - gen_total_loss: 1.1103 - gen_gan_loss: 0.6955 - gen_l1_loss: 0.0041 - disc_loss: 1.3905 - accuracy: 0.9814 - SSIM_loss: 0.0100 - val_accuracy: 0.9678 - val_SSIM_loss: 0.0582
# Epoch 175/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.1062 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0041 - disc_loss: 1.3905 - accuracy: 0.9813 - SSIM_loss: 0.0098 - val_accuracy: 0.9632 - val_SSIM_loss: 0.0554
# Epoch 176/200
# 360/360 [==============================] - 91s 253ms/step - gen_total_loss: 1.1306 - gen_gan_loss: 0.6956 - gen_l1_loss: 0.0043 - disc_loss: 1.3904 - accuracy: 0.9805 - SSIM_loss: 0.0104 - val_accuracy: 0.9675 - val_SSIM_loss: 0.0571
# Epoch 177/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1072 - gen_gan_loss: 0.6955 - gen_l1_loss: 0.0041 - disc_loss: 1.3904 - accuracy: 0.9811 - SSIM_loss: 0.0099 - val_accuracy: 0.9661 - val_SSIM_loss: 0.0565
# Epoch 178/200
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 1.1229 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0043 - disc_loss: 1.3903 - accuracy: 0.9808 - SSIM_loss: 0.0102 - val_accuracy: 0.9707 - val_SSIM_loss: 0.0560
# Epoch 179/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1060 - gen_gan_loss: 0.6955 - gen_l1_loss: 0.0041 - disc_loss: 1.3904 - accuracy: 0.9811 - SSIM_loss: 0.0099 - val_accuracy: 0.9644 - val_SSIM_loss: 0.0558
# Epoch 180/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.1074 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0041 - disc_loss: 1.3904 - accuracy: 0.9809 - SSIM_loss: 0.0098 - val_accuracy: 0.9683 - val_SSIM_loss: 0.0601
# Epoch 181/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1300 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0043 - disc_loss: 1.3902 - accuracy: 0.9820 - SSIM_loss: 0.0102 - val_accuracy: 0.9644 - val_SSIM_loss: 0.0564
# Epoch 182/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1104 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0041 - disc_loss: 1.3904 - accuracy: 0.9819 - SSIM_loss: 0.0099 - val_accuracy: 0.9635 - val_SSIM_loss: 0.0597
# Epoch 183/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.0962 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0040 - disc_loss: 1.3903 - accuracy: 0.9815 - SSIM_loss: 0.0098 - val_accuracy: 0.9648 - val_SSIM_loss: 0.0586
# Epoch 184/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.0956 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0040 - disc_loss: 1.3903 - accuracy: 0.9815 - SSIM_loss: 0.0097 - val_accuracy: 0.9559 - val_SSIM_loss: 0.0549
# Epoch 185/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1018 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0041 - disc_loss: 1.3903 - accuracy: 0.9817 - SSIM_loss: 0.0097 - val_accuracy: 0.9351 - val_SSIM_loss: 0.0554
# Epoch 186/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1233 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0043 - disc_loss: 1.3902 - accuracy: 0.9816 - SSIM_loss: 0.0102 - val_accuracy: 0.9604 - val_SSIM_loss: 0.0578
# Epoch 187/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.0945 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0040 - disc_loss: 1.3903 - accuracy: 0.9822 - SSIM_loss: 0.0096 - val_accuracy: 0.9613 - val_SSIM_loss: 0.0579
# Epoch 188/200
# 360/360 [==============================] - 91s 254ms/step - gen_total_loss: 1.0920 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0040 - disc_loss: 1.3902 - accuracy: 0.9820 - SSIM_loss: 0.0096 - val_accuracy: 0.9602 - val_SSIM_loss: 0.0578
# Epoch 189/200
# 360/360 [==============================] - 91s 252ms/step - gen_total_loss: 1.0882 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0039 - disc_loss: 1.3903 - accuracy: 0.9822 - SSIM_loss: 0.0095 - val_accuracy: 0.9553 - val_SSIM_loss: 0.0526
# Epoch 190/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.0939 - gen_gan_loss: 0.6954 - gen_l1_loss: 0.0040 - disc_loss: 1.3902 - accuracy: 0.9818 - SSIM_loss: 0.0097 - val_accuracy: 0.9410 - val_SSIM_loss: 0.0530
# Epoch 191/200
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 1.0844 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0039 - disc_loss: 1.3902 - accuracy: 0.9821 - SSIM_loss: 0.0094 - val_accuracy: 0.9670 - val_SSIM_loss: 0.0570
# Epoch 192/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1120 - gen_gan_loss: 0.6951 - gen_l1_loss: 0.0042 - disc_loss: 1.3901 - accuracy: 0.9819 - SSIM_loss: 0.0099 - val_accuracy: 0.9662 - val_SSIM_loss: 0.0611
# Epoch 193/200
# 360/360 [==============================] - 90s 249ms/step - gen_total_loss: 1.0930 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0040 - disc_loss: 1.3902 - accuracy: 0.9823 - SSIM_loss: 0.0096 - val_accuracy: 0.9635 - val_SSIM_loss: 0.0577
# Epoch 194/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.0656 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0037 - disc_loss: 1.3902 - accuracy: 0.9826 - SSIM_loss: 0.0091 - val_accuracy: 0.9587 - val_SSIM_loss: 0.0546
# Epoch 195/200
# 360/360 [==============================] - 89s 247ms/step - gen_total_loss: 1.0808 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0039 - disc_loss: 1.3902 - accuracy: 0.9827 - SSIM_loss: 0.0093 - val_accuracy: 0.9687 - val_SSIM_loss: 0.0554
# Epoch 196/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1004 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0041 - disc_loss: 1.3900 - accuracy: 0.9825 - SSIM_loss: 0.0097 - val_accuracy: 0.9671 - val_SSIM_loss: 0.0561
# Epoch 197/200
# 360/360 [==============================] - 90s 251ms/step - gen_total_loss: 1.0882 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0039 - disc_loss: 1.3901 - accuracy: 0.9822 - SSIM_loss: 0.0095 - val_accuracy: 0.9586 - val_SSIM_loss: 0.0549
# Epoch 198/200
# 360/360 [==============================] - 89s 247ms/step - gen_total_loss: 1.0656 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0037 - disc_loss: 1.3901 - accuracy: 0.9827 - SSIM_loss: 0.0091 - val_accuracy: 0.9652 - val_SSIM_loss: 0.0576
# Epoch 199/200
# 360/360 [==============================] - 90s 250ms/step - gen_total_loss: 1.1004 - gen_gan_loss: 0.6953 - gen_l1_loss: 0.0041 - disc_loss: 1.3900 - accuracy: 0.9826 - SSIM_loss: 0.0097 - val_accuracy: 0.9602 - val_SSIM_loss: 0.0542
# Epoch 200/200
# 360/360 [==============================] - 91s 252ms/step - gen_total_loss: 1.0766 - gen_gan_loss: 0.6952 - gen_l1_loss: 0.0038 - disc_loss: 1.3900 - accuracy: 0.9826 - SSIM_loss: 0.0092 - val_accuracy: 0.9662 - val_SSIM_loss: 0.0587
